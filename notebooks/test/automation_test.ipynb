# %% [markdown]
# # Automation Test

# %%
# %pip install requests==2.31.0 --quiet

# %% [markdown]
# ## You must Modify these Variable Definition according to your Backend Server

# %%
API_URL = 'https://yhh2rpwue8.execute-api.us-west-2.amazonaws.com/prod/'
MODEL_NAME = 'claude-v3-sonnet'
COMPANY = "mihoyo"

# %%
import requests

class ChatbotWrapper:

    def invoke_chatbot_api(self, prompt, model_name=MODEL_NAME, api_url=API_URL):

        payload = {
            "msgid": "id-1699868804605-a4e9b6110d998_res",
            "chat_name": "benchmark01",
            "user_id" : "benchmark_user_01",
            "prompt": prompt,
            "system_role": "",
            "use_qa": True,
            "multi_rounds": False,
            "hide_ref": False,
            "system_role_prompt": "",
            "obj_prefix": "ai-content/",
            "use_stream": True,
            "max_tokens": 3000,
            "temperature": 0.01,
            "use_trace": False,
            "model_name": model_name,
            "template_id": "default",
            "username": "admin",
            "company" : COMPANY,
            "feature_config" : "search_disabled"
        }

        headers = {
            "Content-Type": "application/json"
        }

        response = requests.post(api_url, json=payload, headers=headers)

        json_data = response.json()
        return json_data

# %% [markdown]
# ## Define Questions

# %%
AccountTest_1 = [
"""
1. What's the most appropriate way to proceed in the following situation?:
(single choice)

The Player filled out an Application Form but forgot to add his list of owned 5☆ Characters to the Form and wants to update it before the result is known.

A) Ask the Player to provide the updated information and send it to a GM handling account issues to update the Application Form.

B) Inform the Player that the list of 5☆ Characters isn't useful information to recover the HoYoverse Account and that he should only provide replies to the existing questions.  

C) Advise the Player to fill out a new Application Form with the updated information.

D) Reject the Player's Request and inform him that the Application Form information can't be modified/changed.
""", """
2. What's the most appropriate way to proceed in the following situation?: 
(single choice)

The player claims he encountered a "Submission failed" error when trying to fill out an Application Form.

A) Record the Player's information in the "Acc Issue after New Process" sheet.

B) Ask for more detailed information or a screenshot of the "Submission failed" error.

C) Provide the FAQ reply for the "Your application submissions are too frequent" error.
""", """
3. What's the most appropriate way to proceed in the following situation?:
(single choice)

The player encounters the "Your application submissions are too frequent" error when trying to fill out a form. They had recently filled out multiple forms but received negative results due to inconsistent information.

A) Record the player's information in the "Acc Issue after New Process" sheet.

B) Record the player's information in the "HoYoverse Error Notification" sheet.

C) Inform the Player that there are too frequent submissions in recent 30 days.  

D) Send a new Application Form Link.
""",
"""
4. What's the most appropriate way to proceed in the following situation?:

A Player contacts us, saying he has been hacked, recovered his HoYoverse Account, and now wants to change the Username that the Player himself set previously. He is afraid that the Hacker knows the Username and hacks him again.

A) Politely reject his request as we do not provide such a service.
B) Ask the player for his "Case No".
C) Record the information provided by the player in the "Acc Issue after New Process" sheet.
""",
"""
5. Which statement(s) is/are incorrect for the following situation?:

The Player's HoYoverse Account is only linked to PSN, but the PSN Account can't be accessed anymore. He now wants our help to link an Email Address so he can play on PC/Mobile.  

A) The Player can link an Email Address by logging in to https://account.hoyoverse.com/ and linking an Email Address there.

B) If the Player doesn't have access to his PSN Account, he won't be able to link an Email Address.

C) If the Player can't access his PSN Account and would like to link an Email Address, we should provide him an Application Form to link an Email Address.

D) If the Player is unable to access his PSN Account, he should contact Sony CS for help.
""",
"""
6. Which Tools/Logs are used for regular Account-related issues?(one or multiple correct choices)

A) CSC / Appeal Record
B) Game SDK Management Platform
C) miHoYo Overseas Account Backend
D) GM Tools or Toolbox (Treasure Chest)
""", """
7. Which of these statement(s) is/are correct for the following situation?:
(one or multiple correct choices)

The Player wants to delete his HoYoverse Account. There is a Genshin Impact and Honkai: Star Rail progress on it.

A) Deleting the HoYoverse Account through one of the Games Client's User Center will only delete the Game Progression from that specific Game and not the other game progressions.

B) After initiating the Deletion of the HoYoverse Account, it will be deleted immediately.

C) A Verification Process is required to confirm the Deletion of the HoYoverse Account.  

D) Players will need to wait an additional 30 days before they can start the Deletion of the HoYoverse Account, if they recently changed the Password.
""", """
8. Which of the following statement(s) is/are correct for when Players encounter the error "Email already exists?"
(one or multiple correct choices)

A) The Player's Email Address is already linked to another HoYoverse Account and can't be linked to the desired HoYoverse Account at the same time.

B) The Player can first unlink the Email Address from the HoYoverse Account that it's currently linked to in order to later link it to the desired HoYoverse Account.

C) The Player can delete the HoYoverse Account that the Email Address is currently linked to in order to make it immediately available for linking again.

D) We could advise the Player to link another Email Address to the desired HoYoverse Account instead.
""", """
9. What information do you may need to check with a Honkai Impact 3rd CS when you receive a Recovery Request for a Honkai Impact 3rd UID in the HoYoverse Mailbox?
(one or multiple correct choices)

A) None, the Player should contact the Honkai Impact 3rd CS Team directly.  

B) Whether the UID provided by player is valid and is correctly linked to an AID.

C) None, we should directly send the Application Form to the Player.
""", """
10. Is the following statement true or false?
(If false, please provide an explanation)

The Account ID that can be found on a Player's HoYoLAB profile is the HoYoverse AID.
""", """
11. Is the following statement true or false? 
(If false, please provide an explanation)

The login method "Email Address + Password" is the only login method that can be used on all platforms to log in to a HoYoverse Account (PC, Mobile, PlayStation).
""", """
12. Is the following statement true or false?
(If false, please provide an explanation)

To unlink or change a linked Mobile Number, a Verification Code can only be sent to the linked Email Address.
""", """
13. Is the following statement true or false?
(If false, please provide an explanation)

A Player tries to link his email address "genshin.account1@docomo.ne.jp" but doesn't receive a Verification Code in his Inbox. In this situation we should record the issue inVerification Code Receiving Issue and ask the Player to fill out an Application Form
""", """
14. Is the following statement true or false?
(If false, please provide an explanation)

If Players ask for the result of their Application Form and provide the UID (NOT Case No.), I can provide the result of the Application Form by searching the UID in CSC and then send the result to the Player.
""", """
15. Is the following statement true or false?
(If false, please provide an explanation)

The Player provided a Case No. and asks for the Status of it. The Status is as follows:

This indicates that the Player has successfully recovered the Account and we can guide the Player to reset the Password.
""", """
16. Is the following statement true or false?
(If false, please provide an explanation)

A Player would like to link his Google Account to his HoYoverse Account. He can log in to the game on his iOS Mobile Device and link it via the User Center.
""", """
17. Is the following statement true or false?
(If false, please provide an explanation)

The Player lost their HoYoverse Account and doesn't know the UID. Despite having provided all options to help finding the UID, none of the information that the Player provided leads to the UID of the Account they're looking for. We're unable to further assist, apologise to the Player and inform him about the bad news.
""", """
18. Is the following statement true or false?
(If false, please provide an explanation)

The player indicated in his message that he lost the account access after selling it/buying it from another player. I can refuse to help as we do not tolerate account trading as per our Terms of Services.
""", """
19. Is the following statement true or false?
(If false, please provide an explanation)

The player encounters a "Your recent submission is currently being processed" error when trying to fill out a form. I can share with the player that this error is because of a previously filled out the form that received a "Pass" result.
""", """
20. Is the following statement true or false?
(If false, please provide an explanation)

A Player on Android is encountering the error "System error" when trying to get a Verification Code to log in to a new Device, we should guide him to delete the Windows Registry to solve this issue temporarily.
""", """
21. Is the following statement true or false?
(If false, please provide an explanation)

If Players encounter the error "Too many requests. Please try again later." when trying to log in to the Game, rather than inputting information in the Sheet, we should collect all relevant information and dm Joang Belo for further verification.
"""
]

# %%
AccountTest_2 = [
"""
1. What's the most appropriate way to proceed in the following situation?: 
(single choice)

The HoYoverse Account of a Player only has a Username linked and he doesn't remember his Password.

A) The Player can reset his password through the link: https://account.hoyoverse.com

B) The Player should fill out an application form and select the service "I want to retrieve my account".

C) The Player should fill out an application form and select the service "I need to update the account security information".
"""
,"""
2. What's the most appropriate way to proceed in the following situation?:
(single choice) 

The Player claims that he is unable to fill out an Application Form due to receiving the notification "Your recent submission is currently being processed".

A) I can check CSC for an existing Case No. for the UID of the Player. If there is a Case No. then I should record the relevant information, including the Case No. in the "Acc Issue after New Process" Sheet.

B) I should ask the Player if he filled out an Application Form previously already and if he could provide the Case No. of it. If he provides a Case No. of a passed form then I should record all relevant information, including the Case No. in the "Acc Issue after New Process" Sheet.

C) I should inform the Player that this issue is due to an Application Form that was previously filled out for this UID, and ask him to provide the Case No. of that Application Form. If he provides a Case No. then I should record all relevant information, including the Case No. in the "Acc Issue after New Process" Sheet.
"""
,"""
3. What's the most appropriate way to proceed in the following situation?:
(single choice)

A Player is contacting us in Genshin Impact CSC, saying their Honkai: Star Rail Account has been hacked and needs our help for the recovery.

A) Allocate the Ticket to a HSR CS.

B) Ask a HSR CS for assistance. 

C) Guide them to contact support_os@hoyoverse.com.
"""
,"""
4. What's the most appropriate way to proceed in the following situation?:

A Player is contacting us, providing a UID that is only linked to a Username. When asking whether he recognises the censored Username, he says No. He asks you to provide the uncensored Username to help him recover the HoYoverse Account.

A) I add his UID to the Sheet "Search info  (UID/full Email etc) " and provide the uncensored Username once the Handler provides it to me.

B) I inform him that we can't provide the Username and offer an Application Form instead.  

C) I dm a GM and ask if it's possible to provide the uncensored Username in this situation.
"""
,"""
5. Which of the following statement(s) about the UID is/are incorrect?

A) The HoYoverse Username can be used to find a UID.

B) All Purchase Receipts can be used to find a UID.

C) After re-installing the game on the PC, the UID will no longer be registered in the Windows Registry until the UID logs in again on the same PC.

D) The currently linked Email Address or Mobile Number can be used to find a UID.
"""

,"""
6. Which of these statement(s) is/are correct for the following situation?:
(one or multiple correct choices)

The Player contacted us with the request to change the currently linked Email Address. No further explanation or details were provided by him.

A) We should ask for additional information to have a clearer understanding of the situation.

B) We may suggest the Player change the Email Address through the in-game User Center or through the official Website account.hoyoverse.com.

C) We should directly send an Application Form to the Player for the Email Address to be changed.

D) We should guide the Player to try again later.
"""
,"""
7. Which of the following statement(s) about the HoYoverse Username is/are incorrect?
(one or multiple correct choices)

A) We don't provide a service to change the HoYoverse Username, unless the Username was set by a Hacker (with "pass" case No. provided by player).

B) The Username can be used to log in to the HoYoverse Account along with the set Password.

C) The Player can change the HoYoverse account Username in-game in Paimon Menu > Profile.

D) Once Players set their own Usernames, they cannot be removed or changed anymore.
"""
,"""
8. Which of the following statement(s) about the PSN Account is/are incorrect?
(one or multiple correct choices)

A) If the Player can't log in to their HoYoverse Account, which is only linked to a PSN Account (no Email Address) and they can't access it, we can help them unlink the PlayStation account through an Application Form.

B) If the Player can log in to their HoYoverse Account through PlayStation, they can unlink it themselves in the User Center in-game.

C) If the Player can log in to their HoYoverse Account through PlayStation, they will need to fill out a PSN Account Unlink form to unlink the PlayStation account.

D) If the Player can login to their HoYoverse Account on the Website (e.g. via Email Address+Password), they will be able to unlink PSN themselves.
"""
,"""
9. Which of the following statement(s) is/are correct for Google?
(one or multiple correct choices)

A) Players that only have Google linked can login on PC.
B) Players that only have Google linked can login on the Website.
C) Players that only have Google linked can login on both Android and iOS.
D) Players that only have Google linked can login on PlayStation.
"""
,"""
10. Is the following statement true or false?
(If false, please provide an explanation)

The Player can fill out an Application Form as long as he knows his AID.
"""
,"""
11. Is the following statement true or false?
(If false, please provide an explanation)

The Player can log in to the game using his In-Game Nickname + Password.
"""
,"""
12. Is the following statement true or false?
(If false, please provide an explanation)

A Player can unlink the 3rd Party Account Google in-game via the User Center on Android
(excluding games downloaded from Galaxy Store).
"""
,"""
13. Is the following statement true or false?
(If false, please provide an explanation)

I can provide the Application Form in the first reply in this situation:

The Player provided his UID, Email Address and stated that he doesn't have access to his
Email Address anymore. When checking, the Email Address is correct and is the only thing
linked to the HoYoverse Account. There is no Case No. found in CSC.
"""
,"""
14. Is the following statement true or false?
(If false, please provide an explanation)

I don't need to ask for the Account Information (e.g. UID, Issue Description, etc.) anymore, if all the information was already provided by the Player.
"""
,"""
15. Is the following statement true or false? 
(If false, please provide an explanation)

Players can cancel the Application Form by providing us the Case No. To cancel it we need to dm the responsible GM.
"""
,"""
16. Is the following statement true or false?
(If false, please provide an explanation)

When Players encounter the error "Your application submissions are too frequent" while trying to fill out an Application Form, I can inform them to try again in 2 weeks.
"""
,"""
17. Is the following statement true or false?
(If false, please provide an explanation)

The Player recently filled out an Application Form and received a negative result due to the "new email" being taken. He now can't submit an Application Form anymore due to receiving the error "Your application submissions are too frequent". We should record the Player's information in the "Acc Issue After New Process" sheet, wait for GM's reply and provide the results to the Player.
"""
,"""
18. Is the following statement true or false?
(If false, please provide an explanation)

When Players on PC encounter and keep complaining about the error "System error" when trying to receive the Verification Code I need to record all relevant information and create a Trouble Ticket 2.0 if the normal solution doesn't work.
"""
,"""
19. Is the following statement true or false?
(If false, please provide an explanation)

If Players encounter the error "Request failed. The current network environment is at risk." when trying to create a HoYoverse Account, we should collect all relevant information and dm Joang Belo for further verification.
"""
,"""
20. Is the following statement true or false?
(If false, please provide an explanation)

I should provide the Application Form for Players that encounter the error "Login failed" when they try to login via Google. With the Application Form they can add an Email Address and use that one instead.
"""
,"""
21. Is the following statement true or false?
(If false, please provide an explanation)

We can inform Players that we can only help with the unlinking of the Hackers' Username, if they were hacked and have a Case No. with a "Pass" result.
"""
]

# %%
OverallTest_1 = ["""
1. Please select the correct answer. (Single choice)

What is the correct way to handle a case where the player doesn't receive the verification code SMS in their phone number, which is the only link they have to verify access with?

A. I help them link an email to their account by sending them the form link and resolve the ticket.  

B. I inform them they can link an email themselves in our official website.

C. I suggest player to try a few more times and if the problem persists, I collect necessary information and submit the ticket to second-line and send the form link if the player urgently needs help.

D. I suggest player to try a few more times and if the problem persists, I send the form link if the player urgent needs help.
"""
,"""
2. Please select the correct answer. (Single choice)  

A player contacts us saying their Mondstadt progress will not reach 100% even though they are certain they have explored as much as they can, even followed on-line guides and our interactive map. They did not provide images. What is the correct procedure?

A. I guide them to check online guides and our interactive guide to find the missing content needed to 100% the progress.

B. I collect information such as screenshots of their achievements, collected chests, Seelies and unfinished map progress to make sure the player is actually facing an issue and submit a TT of the issue.  

C. I inform the player that this is a known issue and ask them to please stay tuned for further notices about it.

D. I collect information such as screenshots of their achievements, collected chests, Seelies and unfinished map progress to make sure the player is actually facing an issue and fill out the [Exploration Progress] sheet.
"""
,"""
3. Please select the correct answer. (Single choice)

A player sent us an email on Aihelp citing that their game is crashing constantly with only a screenshot of the game freezing during warning screen on PC. How can we proceed?

A. I must simply inform them that if it's crashing, then their PC is incompatible with the game.

B. I must collect necessary information about their device (CPU, RAM, GPU) in order to correctly identify the problem and reply accordingly.

C. I must collect necessary information about their device (Platform, CPU, RAM, GPU) in order to correctly identify the problem.

D. I ask the player to please re-install the game, and if the problem persists, to please try changing network.
"""
,"""
4. Please select the correct answer. (Single choice)

If a player contacts us with an event issue via HoYoverse Pass inbox in Aihelp, which is the correct action to handle the case?

A. Advise the player to contact the appropriate mailbox
B. Figure out the issue the player encountered and help him/her accordingly
C. Collect necessary info and record in the event issue KM sheet
D. Manually create a ticket on CSC, choose event issue tag and submit it to GM
"""
,"""
5. Please select the correct answer. (Single choice) 

Which email should the player contact if he/she wants to obtain merchandising authorization?

A. support_os@hoyoverse.com
B. genshin_cm@hoyoverse.com
C. business_global@hoyoverse.com 
D. pr_global@hoyoverse.com
"""
,"""
6. Please select the corrects answers. (Multiple choices)

Which of the following statements about Fate exchange process are correct?

A. CS cannot submit a second-line ticket on CSC for fate exchange request.  

B. Fate exchange service would be inapplicable if the number of the wrong exchange gets passed 100 fates

C. Fate exchange service would be inapplicable if the player already used the exchanged fates

D. We could assure the player that we are able to provide the fate exchange service once the player contacted us, if the player was frustrated and sad.
"""
,"""
7. Please select the corrects answers. (Multiple choices)

Which are the possible reasons for players not receiving the Genshin Impact Twitch Drops rewards?

A. A wrong Genshin Impact UID was linked to the player's Twitch account
B. The player didn't claim the rewards in time
C. The player only watched live streams under the Honkai: Starrail category
D. The player only watched live streams of an unofficial streamer under the Genshin Impact category
"""
,"""
8. Please select the corrects answers. (Multiple choices) 

What are the currently available 3rd party Cloud Gaming services?

A. Geforce Experience
B. Geforce Now
C. VK Play
D. PlayKey
"""

,"""
9. Please select the corrects answers. (Multiple choices)

Which of the following actions are correct when a player contacted us claiming his HoYoverse account has been hacked and couldn't log in to the account anymore?

A. Ask whether the player has submitted an account appeal application before
B. Ask for basic info such as UID and linked info then try to determine the issue the player is facing
C. Confirm with the player whether he/she recognizes the currently linked info
D. Make sure that the player knows the account UID before sending the account appeal guidance
"""
,"""
10. Please select the corrects answers. (Multiple choices)

Which of the following are the products available for players to top-up (pay with real money) in the game?

A. Genesis Crystals
B. Blessing of the Welkin Moon
C. Character outfits
D. Gnostic Chorus
"""

,"""
11. Please determine if the statement below is true or false. If false, please provide an explanation.

A player contacts us saying they tried trading their account but the person scammed them, and now they're asking for help to recover it. Since account trading is not allowed, I must reject the player's request, citing that trading accounts is against ToS.
"""
,"""
12. Please determine if the statement below is true or false. If false, please provide an explanation.

Players can only unlink their PSN account themselves via our official website once, and cannot unlink it for the second time. If the player contacts CS for assistance, we could only politely reject the request.
"""
,"""
13. Please determine if the statement below is true or false. If false, please provide an explanation.

Players can freely change their birthday in-game, and if they're unable to do so, they can contact us and we'll assist them with that.
"""
,"""
14. Please determine if the statement below is true or false. If false, please provide an explanation.

We must make TTs for unknown issues that players are facing with Web Events.
"""
,"""
15. Please determine if the statement below is true or false. If false, please provide an explanation.

CS must contact GM directly without any reply if the player mentioned a certain law from his/her region when asking for a refund.
"""
]

# %%
OverallTest_2 = ["""
1. Please select the correct answer. (Single choice)

Which Genshin Impact UID on Server "Europe" is connected to the HoYoverse Username "Ahuhaa"?
A. 720068130
B. 206775432
C. 701143081
D. 625591542
"""
,"""
2. Please select the correct answer. (Single choice) 

Please choose a correct Tier 5 issue type for this ticket:

After purchasing crystals on PlayStation, player logged out from PlayStation and logged in to the game on his phone, but he didn't receive his crystals there. So he sent us a ticket and asked for a reason.
A) Crystals not Shared Between PC/Mobile and PS
B) PlayStation Top-up Failure
C) IOS Top-up Failure 
D) PS Top-up Restriction
"""
,"""
3. Please select the correct answer. (Single choice)

What should CS do after receiving such a ticket: Player reports a third-party top-up shop he saw online and asks whether it's authorized by Genshin Impact.
A) Thanks for his feedback and close the ticket.
B) Look it up in the sheet which lists all authorized third-party top-up website and see whether CS needs to submit a second-line ticket to GM.
C) Tell player directly that he can make purchases there.
D) Advise player to contact customer service of that website for help.
"""
,"""
4. Please select the correct answer. (Single choice)

What's the most appropriate way to proceed in the following situation?
A Player is contacting you regarding the error "Too many requests. Please try again later." when trying to change their Email Address. You are already at the point where you've provided the Application Form, received the Case No. back from the Player and have submitted all information in

the Sheet for the GM/Handler to check.
A) Reply to the Player that their concern has been forwarded and "follow" the Ticket. 
B) Don't reply to the Player yet. Instead, wait for the GM/Handler to check and then provide the result to the Player, which may lead to your Ticket being as "waiting for agent"/"processing" for a few days.
C) Reply to the Player that their concern has been forwarded and "close" the Ticket.
D) Thank for feedback and suggest the player to try again later, then "close" the Ticket.
"""
,"""
5. Please select the correct answer. (Single choice)

Which issue type suits the following ticket the best?

Issue Description: I cannot do the "A new star approaches" quest because when I made it to the jade chamber I fell down
Upload Image (Can upload up to 20 images, each must not exceed 10MB):
Contact Email:

A. In-game issues - Game Launcher/Server/Device - Abnormal display
B. In-game issues - Open World - Scene
C. In-game issues - World Quest - World Quest
D. In-game issues - Archon (Main) Quest - Archon (Main) Quest
"""

,"""
6. Please select the corrects answers. (Multiple choices)

What's the purpose of asking Players their UID when they encounter an Account issue?
A) So that we can check the linked data in the account logs.
B) So that we can see how much they play and if it's worth helping.
C) So that we can confirm that the Player knows his UID.
D) So that we can understand their account issue better.
"""
,"""
7. Please select the corrects answers. (Multiple choices)

Which of these statement(s) is/are correct for the following situation?
A Player complains that the 3rd Party Account of the Hacker is still linked to their HoYoverse Account after they've just recovered their Account through the Application Form.
A) The Player must have chosen the Issue Type "Retrieve account", otherwise we can't add their issue to the Sheet.
B) The Case No. has to be provided by the Player. You can ask the Player to provide it.
C) The Player must fill out a new Application Form, even if they have already filled out an Application
Form before.

D) The 3rd Party Accounts can only be unlinked by the Player themselves, we can't interfere.
"""
,"""
8. Please select the corrects answers. (Multiple choices)

Which of the following statements regarding Malicious Refund are correct?

A. All refunds of completed purchases made via payment channels or banks by players are deemed as Malicious Refunds.

B. After receiving the in-game mail entitled "Notice of Refund Behaviour and Balance Settlement", player's UID will be banned if he doesn't recover the primogems balance to above 0 by the date specified in the mail.

C. Players who had their account banned due to malicious refund could apply for temporary unban to recover the primogems for unlimited times. 

D. Hacker Malicious Refund is not applicable if the player recovered the account by himself after getting hacked.
"""
,"""
9. Please select the corrects answers. (Multiple choices)

Which are the correct steps when a player reported a device graphic issue with which you are not familiar?

A. Thank the player for their report and resolve the ticket

B. Check Known Issues & Solutions -> Device, Installation & Login Issues, if the issue is recorded in it, then assist the player accordingly

C. Transfer the ticket to leader or GM in order to update the team with the urgent problem  

D. Collect basic information and submit TT if the issue is not known before
"""
,"""
10. Please select the corrects answers. (Multiple choices)

Which of the following issues should be reported to GM or leaders directly once received?

A. Localization issue where the player complaint some translation insulted their religion

B. A bug preventing the player to finish the time-limited event

C. Players can't send in-game feedback and send us emails to report it

D. Player got seizures while playing Genshin Impact and was about to make a lawsuit against HoYoverse
"""
,"""
11. Please determine if the statement below is true or false. If false, please provide an explanation.

A player submitted a localization issue as followed, CS should record it in the Genshin Impact
localization issue reports.

Typo for a char in the quest "On the Stage, Behind the Stage" It seems to
me the "Xingqui" was misspelled here and is written as "Xingyan" a few ti
mes here but only in this quest dialo. Only just found out about this in v
3.5 to be clear. Or maybe there actually is a char called Xingyan somewh
ere I suppose.
""","""
12. Please determine if the statement below is true or false. If false, please provide an explanation.

CS should contact GM/leader directly as the bug greatly affects the player's gaming
experience.

Issue Description: Hello. After one random player enter
my world, now I cannot interact with Katheryne and
many other NPCs.

Please help me
Upload Image (Can upload up to 20 images, each must
not exceed 10 MB):

Contact Email: [...redacted...]
"""
,"""
13. Please determine if the statement below is true or false. If false, please provide an explanation.

A player contacted us for abnormal display issue in the game. Based on the player's device
info shown on CSC, the player was using a device with Power AR structure, which was not
supported by the game. CS should inform the player about it directly and suggest using a
compatible device for the game.
"""
,"""
14. Please determine if the statement below is true or false. If false, please provide an explanation.

A player contacted us claiming his Genshin Impact account was banned for unknown reasons.
CS should send him the account application form guidance in order to help him apply for
account unban.
"""
,"""
15. Please determine if the statement below is true or false. If false, please provide an explanation.

When a player sent in a ticket complaining about the gacha system with repeated words,
regardless of how CS tried to appease him, CS should also repeat the same soothing words
and cannot close the ticket until the player calms down and stops sending in messages.
"""
]

# %%
PaymentTest_1 = ["""
1. [Single Choice] "With no Blessing of the Welkin Moon active, if a Player purchases two Blessing of the Welkin Moon on the same day, which rewards will be provided?"
A) 300 Genesis Crystals, 180 Primogems and 60 days of Blessing.
B) 600 Genesis Crystals, 90 Primogems and 30 days of Blessing. 
C) 330 Genesis Crystals, 90 Primogems and 30 days of Blessing.
D) 600 Genesis Crystals, 90 Primogems and 59 days of Blessing.
"""
,"""
2. [Single Choice] "What is the first step when a player contacts us complaining about that his money has been charged, but he didn't receive anything in the game? Player hasn't provided any screenshots or transaction id or anything."
A) Check 'Top-Up & Delivery' Logs
B) Verify if there's enough information
C) Message GM
D) Tell player to re-log into the game
""","""
3. [Single Choice] "When should you submit a case to GM about the situation ""player didn't receive items""?"
A) When player didn't provide enough information.
B) When player mentioned the UID, date of purchase and items purchased and purchase is not delivered.
C) When items were not delivered and player provided UID, date of purchase, items, order screenshot and order number.
D) None of these options
"""
,"""
4. [Single Choice] "If a Player completes a duplicate purchase of the Gnostic Chorus, which reward(s) will be provided?"
A) 1410 Genesis Crystals
B) 10 BP levels, 5 Fragile Resin and Exclusive Furnishing item.
C) 680 Primogems  
D) None
"""
,"""
5. [Single Choice] "If korean players who are minors receive a notification in ingame store telling them they have reached the top up limit this month, player is asking what does that notification mean. What should CS advise players to do?"
A) CS should advise players to top up in our official website
B) CS should offer help to change players' age so that they can make purchases
C) CS should advise players to follow the notification they receive in the game and make purchases next month
D) CS should report this case to GM
"""
,"""
6. [Single Choice] "If japanese players who are minors receive a notification in ingame store telling them they have reached the top up limit this month, player is asking what does that notification mean. What should CS advise players to do?"
A) CS should advise players to top up in our official website
B) CS should offer help to change players' age so that they can make purchases  
C) CS should advise players to follow the notification they receive in the game and make purchases next month
D) CS should report this case to GM
"""
,"""
7. [Single Choice] "How many times can we help players to unban their accounts so that they have time to recover primogems in the game after their accounts have been banned because of malicious refund?"
A) Once
B) Twice
C) Three Times
D) Four Times
"""
,"""
8. [Single Choice] "What should CS do after getting a ""Korean Refund Request"" ticket? Player is speaking Korean."
A) Forward it to KR CS.
B) Ask player to contact CN support email.
C) Inform GM.
D) Contact group chat with ticket details.
"""
,"""
9. [Single Choice] "What should CS (who is not a CHT CS) do after getting a ""Taiwan Refund Request"" ticket?"
A) Record email / ticket in the transfer sheet.
B) Ask player to contact CN support email.
C) Inform GM.
D) Contact group chat with ticket details.
"""
,"""
10. [Single Choice] "When purchasing the 60 Genesis Crystals for a second time, how many crystals will the player receive?"
A) 60 Genesis Crystals
B) 120 Genesis Crystals
C) 90 Genesis Crystals
D) 100 Genesis Crystals
"""
,"""
11. [True or False] "When purchasing the 1980 Genesis Crystals for a second time, the player will receive a total of 3960 Genesis Crystals."
If it's false, please give a reason about why it's false.
"""
,"""
12. [True or False] "Player's account has been retrieved successfully by us after getting hacked before, and it's confirmed by us that the hacker refunded some purchases, that's why player receives an ingame mail titled 'Notice of Refund Behavior and Balance 'Settlement', he asks us for advice. We should advise him to fix the Game Currency balance to above 0 within the date limit mentioned in the Notice, we can't do anything in this situation."
If it's false, please give a reason about why it's false.
"""
,"""
13. [True or False] "When purchasing the 6480 Genesis Crystals for the first time, the player will receive a total of 8080 Genesis Crystals."
If it's false, please give a reason about why it's false.
"""
,"""
14. [True or False] "A double bonus is guaranteed for a player. If he purchases a 6480 Genesis Crystals pack on PC client, he can still get his double bonus for a 6480 Genesis Crystals pack when purchasing it on our official top-up website."
If it's false, please give a reason about why it's false.
"""
,"""
15. [True or False] "Country/region set by the player in the app store (i.e. iOS App Store, Google Play Store) is the main factor affecting the currency displayed in the mobile game."
If it's false, please give a reason about why it's false.
"""
,"""
16. [True or False] "Game server is the main factor for price or currency inconsistency on PC/official Top-Up website."
If it's false, please give a reason about why it's false.
"""
,"""
17. [True or False] "Changes in network conditions such as the use of VPN will change the currency displayed in PC ingame shop / official top-up website."
If it's false, please give a reason about why it's false.
"""
,"""
18. [True or False] "We can provide player with a refund right away after he asks for a refund."
If it's false, please give a reason about why it's false.
"""
,"""
19. [True or False] "There are no situations where we can agree with a refund request in Genshin Impact."
If it's false, please give a reason about why it's false.
"""
,"""
20. [True or False] If it's false, please give a reason about why it's false" A card owner reports that there was an unauthorized transaction for Genshin Impact, he claims that he knows the UID information and requests for a refund. We should first advise the card owner to contact card issuing bank to apply for a refund. Player sends an email to our mailbox "genshin_de@hoyoverse.com".
"""
,"""
21. [Multiple Choice] "Player contacts us complaining that he cannot purchase due to "Transaction rejected, please select another payment method". Please indicate which sentences are ACCURATE about this type of issue."

A) The transaction was rejected by payment channel.
B) The transaction was rejected by us (the company).
C) CS should advise Player to check if the card's information is correct.
D) If money was charged, we will help getting a refund.
E) CS report this case to GM when Traveler insists on using this card or all other payment methods failed or are unavailable to use.
""","""
22. [Multiple Choice] "Which of the following descriptions are correct?"

A) Player can upgrade his Gnostic Hymn to Gnostic Chorus on his PlayStation4, after he purchases a Gnostic Hymn on his PC.
B) Player who purchases a Bless of the Welkin Moon can receive 300 Crystals every day.
C) Player who created his account originally with his PlayStation4 can unlink his PlayStation in order to make purchases on his PC.
D) If player accidentally purchases Gnostic Hymn twice, the 2nd payment will be rewarded with 750 Genesis Crystals.
E) If a player asks for a refund of his purchase and mentions the EU Right of Withdrawal, CS should not reply right away, instead, CS should contact GM 刘琴(qin.liu)or @沈思贝(sibei.shen)directly.
"""
,"""
23. [Multiple Choice] "Which of the following descriptions are incorrect?"

A) Player who refunds his purchase in the game successfully and receives a letter "Notice of Refund Behavior and Primogem Deduction" should recover the balance of Game Currencies to above 0, otherwise his account will be banned on Thursday one week after.
B) All players who play on PlayStation can purchase products in the game using the local currencies of their own countries.
C) Country/region set by the player in the app store (i.e. iOS App Store, Google Play Store) is the main factor affecting the currency displayed in the mobile game.
D) Genshin Impact doesn't have any official authorized third-party top-up shops.
E) If the Player purchases Gnostic Hymn or Gnostic Chorus on PC/mobile, the BP rewards will not be available to claim via "PlayStation Network".
"""
,"""
24. [Multiple Choice] "Which may cause an error notification "Transaction rejected, please contact bank." when player makes purchases with his bank card?"

A) The bank does not support online purchase.
B) Insufficient balance. 
C) Bank considers the purchase a risky transaction.
D) None of explanations above is correct.
""","""
25. [Multiple Choice] "In which countries players who are minors will reach a top up limit in the game monthly?"

A) Japan
B) Germany.
C) South Korea
D) Italy
"""
]

# %%
PaymentTest_2 = ["""
1. [Single Choice] "In which situation should CS submit a second-line ticket to GM?"
A) Player gives advice about our payment methods.
B) Player has this problem: Shop unavailable on his iPhone.
C) Player is confused why he hasn't received 300 Genesis Crystals after purchasing a Bless of Welkin Moon. But CS confirms he has received his 300 Crystals based on our system logs.
D) Player asks whether he can top up for his friends in the game.
""","""
2. [Single Choice] "What does code "ys_glb_primogem6thstall_tier60" refer to?"
A) 6480 Genesis Crystals
B) 3280 Genesis Crystals
C) 1980 Genesis Crystals
D) 980 Genesis Crystals
""","""
3. [Single Choice] "Which one of the following transaction ids is a transaction id from apple?"
A) A2309231922450016
B) 1249993118
C) 452642749683
D) MLDZ1HZYFL
""","""
4. [Single Choice] "For players who reach a certain amount of deductions, they will receive a Warning Letter in advance titled 'Notice of Refund Behavior and Balance Settlement', what will happen after players receive such an email?"
A) If these players do not recover the balance of Game Currencies to above 0, the UID will be banned on Thursday one week after.
B) Players have plenty of time to recover their primogems in the game.
C) Players' accounts will be banned when they receive such an email.
D) It's a spam email.
""","""
5. [Single Choice] "Player who originally created his account on PlayStation4 can purchase Genostic Hymn on his:"
A) PlayStation4
B) iPhone
C) PC
D) our official top up website
"""
,"""
6. [Single Choice] "If a player refunded successfully his newly purchased 6480 Genesis Crystals, which also includes a double bonus. How many Primogems will our development team deduct after they notices this player has refunded his purchase successfully?"
A) 12960 Primogems
B) 6480 Primogems
C) not a single Primogem
D) 300 Primogems
"""
,"""
7. [Single Choice] "A player tried multiple times to make purchases with his credit card on his PC, but his card keeps being rejected. Player has no other payment methods and insists on using his credit card to make purchases. What should CS do?"
A) Contact GM for help.
B) Tell the player to keep trying his credit card until it succeeds.
C) Take player's words as suggestion and close the ticket.
D) Keep telling the player to use other payment methods.
"""
,"""
8. [Single Choice] "What is a possible reason that makes a player who lives in Germany see "GBP" currency in the ingame shop on his mobile? Player sends a screenshot proving the currency is GBP."
A) He set his region in his app store as Great Britain.
B) Player turned on his VPN and got himself to Great Britain.
C) Player bought his phone in Great Britain.
D) Player lied.
""","""
9. [Single Choice] "A card owner requests for a refund for an unauthorized transaction with his card. Player is sending an email to our mailbox "privacy@hoyoverse.com". What should CS do?"
A) Advise this card owner to contact his bank for help.
B) Advise player to contact police for help.
C) CS should contact GM for advice.
D) CS reports this issue in a group chat and gets advice from other CSs.
"""
,"""
10. [Single Choice] "When purchasing 6480 Genesis Crystals for a second time, how many crystals will the player receive?"
A) 6480 Genesis Crystals
B) 8080 Genesis Crystals
C) 12960 Genesis Crystals
D) 300 Genesis Crystals
"""
,"""
11. [True or False] "This is a receipt player will receive after making a purchase with his iPhone."
If it's false, please give a reason about why it's false.
""","""
12. [True or False] "CS doesn't need to ask player about an order number, or a transaction id or an invoice id, before submitting a second-line ticket to GM about the issue "didn't receive items after purchasing""
If it's false, please give a reason about why it's false.
"""
,"""
13. [True or False] "Players who originally registered their account on a Samsung device and have logged in to the same account on PlayStation are not able to make purchases on their PlayStation. Because they need to top up on their Samsung device which was used to create their account."
If it's false, please give a reason about why it's false.
""","""
14. [True or False] "A police officer is investigating a credit card fraudulent transaction and is requesting for more information of a Genshin Impact account: UID, Email, and IP address. CS has to redirect the police officer to write an email to privacy@hoyoverse.com, and provide an official investigation document so that we can help."
If it's false, please give a reason about why it's false.
"""
,"""
15. [True or False] "Player originally created his account on PlayStation4, now since he has sold his PlayStation and only plays Genshin on his PC, if he wants to purchase a Gnostic Hymn, CS should advise him to top up on our official website."
If it's false, please give a reason about why it's false.
"""
,"""
16. [True or False] "With no Bless of Welkin Moon active for their account, players can only purchase one Bless of Welkin Moon monthly."
If it's false, please give a reason about why it's false.
"""
,"""
17. [True or False] "Player comes from Germany and claims that he used to pay 99,99 Euro for 6480 Genesis Crystals, but now he has paid 103,99 Euro for them on his iPhone. There's no official announcement about price adjustment for products in the game for german players. By selecting tag for this ticket, CS should choose tag "Price Adjustment"."
If it's false, please give a reason about why it's false.
"""
,"""
18. [True or False] "Player plays Genshin on PC and he is in Italy. If he turns on his VPN and gets himself to USA, he may see the currency displayed in the ingame shop changing from Euro to US-Dollar."
If it's false, please give a reason about why it's false.
"""
,"""
19. [True or False] "There's a top-up limit in the game for japanese and korean players who are also minors monthly."
If it's false, please give a reason about why it's false.
"""
,"""
20. [True or False] "Funtap is a third-party top-up shop authorized by Genshin Impact."
If it's false, please give a reason about why it's false.
"""
,"""
21. [Multiple Choice] "Which of the following third-party top-up shops are authorized by Genshin Impact?"
A) Unipin.
B) Codashop. 
C) Kachishop.
D) Razershop.
E) Funtap.
"""
,"""
22. [Multiple Choice] "In which situation can CS submit a second-line ticket so that GM can help?"
A) Player reports a 3rd Top-up website.
B) Player complains about payment methods that we offer currently.
C) Player asks for receipts / invoice.
D) Player asks about price adjustment.
""","""
23. [Multiple Choice] "In which of the following countries is Genshin Impact unavailable, and because of that players who log in to their PlayStation account will receive an error notification saying "There is no content. It might not be for sale yet, or might no longer be for sale"?"
A) Saudi Arabia
B) Belgium
C) USA
D) Germany
"""
,"""
24. [Multiple Choice] "How many different types of Refund Requests exist?"
A) KR 7-Day Guaranteed Refund / Minor Refund
B) TW (HK/Macao) 7-Day New Users & Minors Refund
C) USA Refund for Minors
D) Other Refund requests
"""
,"""
25. [Multiple Choice] "What can players not purchase on our official website?"
A) Gnostic Hymn
B) Gnostic Chorus
C) 6480 Genesis Crystals pack
D) Blessing of Welkin Moon
"""]

# %% [markdown]
# ## Standard Answer

# %%
AccountTest1_Answers = ['D','B','C','A','A,C','A,C,D','C,D','A,D','B','TRUE','TRUE','FALSE','FALSE','FALSE','FALSE','FALSE','TRUE','FALSE','FALSE','FALSE','FALSE']

AccountTest2_Answers = ['C','B','C','B','B','A,B','C','A,B,C','B','FALSE','FALSE','TRUE','TRUE','TRUE','FALSE','FALSE','TRUE','FALSE','TRUE','FALSE','FALSE']

OverallTest1_Answers = ['C','D','B','A','B','A,C','A,B,C','B,C,D','A,B,C,D','A,B,D','FALSE','FALSE','FALSE','FALSE','TRUE']

OverallTest2_Answers = ['A','A','B','A','D','A,C,D','A,B','B,D','B,D','A,B,C,D','FALSE','FALSE','FALSE','FALSE','FALSE']

PaymentTest1_Answers = ['D','B','C','A','C','C','C','A','A','A','FALSE','FALSE','FALSE','FALSE','TRUE','FALSE','TRUE','FALSE','FALSE','FALSE','B,C,E','A,D,E','A,B,D','A,B,C','A,C']

PaymentTest2_Answers = ['A','A','D','A','A','A','A','A','A','B','FALSE','FALSE','FALSE','TRUE','FALSE','FALSE','FALSE','TRUE','TRUE','TRUE','A,B,C,D,E','A,B,C','A,B','A,B,C,D','A,B']

# %% [markdown]
# ## ChatBot Test

# %%
chatbot=ChatbotWrapper()

def judge_test(test_question_list, answer_list, test_name):
    print(f"--------{test_name}--------")
    for idx, question in enumerate(test_question_list):
        result = chatbot.invoke_chatbot_api(question)
        option = result['body'][0]['choices'][0]['text'].split('\n')[0].replace('*','')
        correct = ( option.upper() == answer_list[idx].upper())
        print(f"[{idx+1}] {correct} chatbot:{option.upper()} - standard:{answer_list[idx].upper()}")

judge_test(AccountTest_1, AccountTest1_Answers, 'AccountTest_1')
judge_test(AccountTest_2, AccountTest2_Answers, 'AccountTest_2')
judge_test(OverallTest_1, OverallTest1_Answers, 'OverallTest_1')
judge_test(OverallTest_2, OverallTest2_Answers, 'OverallTest_2')
judge_test(PaymentTest_1, PaymentTest1_Answers, 'PaymentTest_1')
judge_test(PaymentTest_2, PaymentTest2_Answers, 'PaymentTest_2')
