# %%
from langchain.document_loaders import UnstructuredPDFLoader
from bs4 import BeautifulSoup
from langchain.document_loaders import PDFMinerPDFasHTMLLoader
from langchain.docstore.document import Document
import re
import json
import html2markdown

# %%
def link_header(semantic_snippets):
    heading_fonts_arr = [ item.metadata['heading_font'] for item in semantic_snippets ]
    heading_arr = [ item.metadata['heading'] for item in semantic_snippets ]

    def fontsize_mapping(heading_fonts_arr):
        heading_fonts_set = list(set(heading_fonts_arr))
        heading_fonts_set.sort(reverse=True)
        idxs = range(len(heading_fonts_set))
        font_idx_mapping = dict(zip(heading_fonts_set,idxs))
        return font_idx_mapping
        
    fontsize_dict = fontsize_mapping(heading_fonts_arr)

    snippet_arr = []
    for idx, snippet in enumerate(semantic_snippets):
        font_size = heading_fonts_arr[idx]
        heading_stack = []
        heading_info = {"font_size":heading_fonts_arr[idx], "heading":heading_arr[idx], "fontsize_idx" : fontsize_dict[font_size]}
        heading_stack.append(heading_info)
        for id in range(0,idx)[::-1]:
            if font_size < heading_fonts_arr[id]:
                font_size = heading_fonts_arr[id]
                heading_info = {"font_size":font_size, "heading":heading_arr[id], "fontsize_idx" : fontsize_dict[font_size]}
                heading_stack.append(heading_info)
            
        snippet_info = {
            "heading" : heading_stack,
            "content" : snippet.page_content
        }
        snippet_arr.append(snippet_info)
        
    json_arr = json.dumps(snippet_arr, ensure_ascii=False)
    return json_arr

# %%
def parse_pdf_to_json(file_content):
    soup = BeautifulSoup(file_content,'html.parser')
    content = soup.find_all('div')

    cur_fs = None
    cur_text = ''
    snippets = []   # first collect all snippets that have the same font size
    for c in content:
        td = c.find('tr')
        if td:
            print(td)

        sp = c.find('span')
        if not sp:
            continue
        st = sp.get('style')
        if not st:
            continue
        fs = re.findall('font-size:(\d+)px',st)
        if not fs:
            continue
        fs = int(fs[0])
        if not cur_fs:
            cur_fs = fs
        if fs == cur_fs:
            cur_text += c.text
        else:
            snippets.append((cur_text,cur_fs))
            cur_fs = fs
            cur_text = c.text
    snippets.append((cur_text,cur_fs))

    cur_idx = -1
    semantic_snippets = []
    # Assumption: headings have higher font size than their respective content
    for s in snippets:
        # if current snippet's font size > previous section's heading => it is a new heading
        if not semantic_snippets or s[1] > semantic_snippets[cur_idx].metadata['heading_font']:
            metadata={'heading':s[0], 'content_font': 0, 'heading_font': s[1]}
            #metadata.update(data.metadata)
            semantic_snippets.append(Document(page_content='',metadata=metadata))
            cur_idx += 1
            continue
        
        # if current snippet's font size <= previous section's content => content belongs to the same section (one can also create
        # a tree like structure for sub sections if needed but that may require some more thinking and may be data specific)
        if not semantic_snippets[cur_idx].metadata['content_font'] or s[1] <= semantic_snippets[cur_idx].metadata['content_font']:
            semantic_snippets[cur_idx].page_content += s[0]
            semantic_snippets[cur_idx].metadata['content_font'] = max(s[1], semantic_snippets[cur_idx].metadata['content_font'])
            continue
        
        # if current snippet's font size > previous section's content but less tha previous section's heading than also make a new 
        # section (e.g. title of a pdf will have the highest font size but we don't want it to subsume all sections)
        metadata={'heading':s[0], 'content_font': 0, 'heading_font': s[1]}
        #metadata.update(data.metadata)
        semantic_snippets.append(Document(page_content='',metadata=metadata))
        cur_idx += 1

    json_content = link_header(semantic_snippets)
    return json_content

# %%
# pdf_path='~/Downloads/LLM/wiki/Network and Edge (GCR_SSO.Network.WebHome) - XWiki.pdf'
pdf_path='~/Downloads/LLM/wiki/FOOBquickguide.pdf'
loader = PDFMinerPDFasHTMLLoader(pdf_path)
file_content = loader.load()[0].page_content
json_content = parse_pdf_to_json(file_content)

# %%
content = json.loads(json_content)

# %%
content[4]
# Out:
# {'heading': [{'font_size': 13, 'heading': '！！注意事项！！：\n', 'fontsize_idx': 2},
#   {'font_size': 25,
#    'heading': '1. FOOB Ticket快速指南 (For EC2)\n1.1 步骤\n',
#    'fontsize_idx': 0}],
#  'content': "如果申请超过 $500K 或者 3 racks,则需要Sales L8 Director 或者 local business L8 Director的ap‐\nproval（在Ticket中附上approval邮件截图即可）。\n即使FOOB申请被capacity team approved了，仍然有⼀定的⻛险会延迟交付 “While Capacity\nPlanning does its best to use forecasts and levers to deliver on requests, we cannot make any\n'guarantees' on delivering capacity on a future date.”\n请保持关注提交的Ticket，并及时响应处理⼈员提出的question。\n再三检查MatrieD的信息是否填写正确，如instance type，AZ， NBD，Instance Eligibility等\nCapacity预留conﬁrm之后，请提醒客户在Need By Date之前在后台接受，否则资源会被回收。并在\nTicket中回复客户是否接受，Close the Loop。\n"}

# %% [markdown]
# ## Using Seleium to crawl website directly

# %%
# !pip install -U selenium
# Out:
# Requirement already satisfied: selenium in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (4.11.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from selenium) (1.26.8)
# Requirement already satisfied: trio~=0.17 in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.10.3)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: attrs>=20.1.0 in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sortedcontainers in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.0.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/chuanxie/opt/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from __future__ import annotations
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from typing import Any, Dict, List, Optional
from pydantic import BaseModel,Extra
from datetime import datetime
from selenium.common import exceptions

# %%
#Using googal Chrome
# options = Options()
# options.add_argument("--headless=new")
# driver = webdriver.Chrome(options=options)

#Midway 权限问题，可以Using firefox 
options = webdriver.FirefoxOptions()
driver = webdriver.Firefox(options=options)

# %%
import re
import os, json

    


class CrawlerWorkder(BaseModel):
    url_map:Dict[str,int]   ## {'url':depth}
    driver:Any
    max_depth:int = 1 
    content:List[Any] = []
    save_path:str = 'temp_webcontent/'
    prefix:str = None
    body_id:str
    url_validate_callback: Optional[Any] = None
    class Config:
        """Configuration for this pydantic object."""
        extra = Extra.forbid

    @property
    def _url_maps(self) -> Dict[str,int]:
        return self.url_map
        """return ulr_maps"""


    def _savefile(self):
        os.makedirs(os.path.dirname(f'{self.save_path}{self.prefix}/'), exist_ok=True)
        str_date = datetime.now().strftime("%Y-%m-%d-%H:%M:%S") 
        with open(f'{self.save_path}{self.prefix}/file-{str_date}.wiki','w') as f:
            f.write(json.dumps(self.content,ensure_ascii=False))


    def _call(self,url:str,current_depth:int) ->List [List[str],Dict[str,int]]:
        """crawl website infor"""
        # text = ['Purpose','Region Build Automation Framework','1 - Complete Prerequisites Guide']
        # url_map = {'https://w.amazon.com/bin/view/AWSRegionBuildEngineering/RIP/FAQ':current_depth+1}
        text = []
        url_map = {}
        print(f'processing:{url}   depth:{current_depth}')
        driver.get(url)
        driver.implicitly_wait(1)
        main_container = driver.find_elements(By.ID, self.body_id)
        if not len(main_container):
            return text,url_map
        for e in main_container:
            text.append(e.text)
        links = driver.find_elements(By.TAG_NAME,'a')
        for link in links:
            ## 跳过空的链接
            try: 
                if not link.text:
                    continue
            except exceptions.StaleElementReferenceException as e:
                print(e)
                continue
            href = link.get_attribute('href')
            if not href:
                continue
            ##检查url
            if self.url_validate_callback:
                if not self.url_validate_callback(href):
                    continue
            url_map[href]=current_depth+1
            # print(f"Text: {link.text}, URL: {href}")
        return text,url_map

    def destroy(self):
        print('quite driver')
        self.driver.quit()

    def start(self) ->List[Any]:
        self.prefix = datetime.now().strftime("%Y-%m-%d-%H-%M-%S") 
        while 1:
            if len(self.url_map) == 0:
                break
            url, depth = self.url_map.popitem()
            print(len(self.url_map),self.url_map)
            ##如果不超过最大depth则抓取
            if depth <= self.max_depth: 
                text,new_url_map = self._call(url,depth)
                self.content.append({url:text})
                #检查url是否重复
                if url in new_url_map:
                    del new_url_map[url]
                #合并新的
                self.url_map = {**self.url_map,**new_url_map}
            self._savefile()
        return self.content

# %%
def validate_url(url):
    # pattern = re.compile(r'^https?://(?:www\.)?[a-zA-Z0-9-]+\.[a-zA-Z]{2,}(?:/[^\s]*)?$')
    pattern = re.compile(r'^https://w(iki)?.amazon.com/bin(?:/[^\s#]*)?$')
    matched  = re.match(pattern, url) 
    if not matched:
        return False 
    ## exclude ticket
    elif url.startswith('https://t.corp.amazon.com'):
        return False
    elif url.find('WebHome') > -1:
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/Main',url,re.I):
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/KnowledgeTech',url,re.I):
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/WikiManager',url,re.I): 
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/AmazonWiki/Wiki/Help',url,re.I): 
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/XWiki',url,re.I): 
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/Users/',url,re.I): 
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/Bindles/',url,re.I): 
        return False
    return True

# %%
print(validate_url('https://wiki.amazon.com/bin/view/RegionBuildAutomation/FAQ'))
print(validate_url('https://w.amazon.com/bin/view/RegionBuildAutomation/FAQ'))
print(validate_url('https://wiki.amazon.com/bin/viewrev/RegionBuildAutomation/FAQ/WebHome?viewer=code&rev=33.1'))
print(validate_url('https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance'))
# Out:
# True
# True
# False
# True

# %%
# url = 'https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance'
# url = 'https://wiki.amazon.com/bin/view/RegionBuildAutomation/FAQ'
url = 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook'
cwoker = CrawlerWorkder(url_map={url:0},driver=driver,max_depth=1,url_validate_callback=validate_url,body_id='contentcontainer')

# %%
content = cwoker.start()
# Out:
# 0 {}
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook   depth:0
# 15 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1}
# processing:https://w.amazon.com/bin/view/KnowledgeTech   depth:1
# 27 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2, 'https://w.amazon.com/bin/view/Broadcast': 2, 'https://w.amazon.com/bin/view/Broadcast/CustomerSupport': 2, 'https://w.amazon.com/bin/view/InternalSearch': 2, 'https://w.amazon.com/bin/view/InternalSearch/CustomerSupport': 2, 'https://w.amazon.com/bin/view/EE/Learn/DocBarRaisers/DocBarRaiserReviewer/': 2, 'https://w.amazon.com/bin/view/DocBarRaisers/WritingHelp/': 2, 'https://w.amazon.com/bin/view/WritingHub': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/KT_Insights': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/Amazon_Tech_Survey/': 2}
# 26 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2, 'https://w.amazon.com/bin/view/Broadcast': 2, 'https://w.amazon.com/bin/view/Broadcast/CustomerSupport': 2, 'https://w.amazon.com/bin/view/InternalSearch': 2, 'https://w.amazon.com/bin/view/InternalSearch/CustomerSupport': 2, 'https://w.amazon.com/bin/view/EE/Learn/DocBarRaisers/DocBarRaiserReviewer/': 2, 'https://w.amazon.com/bin/view/DocBarRaisers/WritingHelp/': 2, 'https://w.amazon.com/bin/view/WritingHub': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/KT_Insights': 2}
# 25 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2, 'https://w.amazon.com/bin/view/Broadcast': 2, 'https://w.amazon.com/bin/view/Broadcast/CustomerSupport': 2, 'https://w.amazon.com/bin/view/InternalSearch': 2, 'https://w.amazon.com/bin/view/InternalSearch/CustomerSupport': 2, 'https://w.amazon.com/bin/view/EE/Learn/DocBarRaisers/DocBarRaiserReviewer/': 2, 'https://w.amazon.com/bin/view/DocBarRaisers/WritingHelp/': 2, 'https://w.amazon.com/bin/view/WritingHub': 2}
# 24 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2, 'https://w.amazon.com/bin/view/Broadcast': 2, 'https://w.amazon.com/bin/view/Broadcast/CustomerSupport': 2, 'https://w.amazon.com/bin/view/InternalSearch': 2, 'https://w.amazon.com/bin/view/InternalSearch/CustomerSupport': 2, 'https://w.amazon.com/bin/view/EE/Learn/DocBarRaisers/DocBarRaiserReviewer/': 2, 'https://w.amazon.com/bin/view/DocBarRaisers/WritingHelp/': 2}
# 23 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2, 'https://w.amazon.com/bin/view/Broadcast': 2, 'https://w.amazon.com/bin/view/Broadcast/CustomerSupport': 2, 'https://w.amazon.com/bin/view/InternalSearch': 2, 'https://w.amazon.com/bin/view/InternalSearch/CustomerSupport': 2, 'https://w.amazon.com/bin/view/EE/Learn/DocBarRaisers/DocBarRaiserReviewer/': 2}
# 22 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2, 'https://w.amazon.com/bin/view/Broadcast': 2, 'https://w.amazon.com/bin/view/Broadcast/CustomerSupport': 2, 'https://w.amazon.com/bin/view/InternalSearch': 2, 'https://w.amazon.com/bin/view/InternalSearch/CustomerSupport': 2}
# 21 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2, 'https://w.amazon.com/bin/view/Broadcast': 2, 'https://w.amazon.com/bin/view/Broadcast/CustomerSupport': 2, 'https://w.amazon.com/bin/view/InternalSearch': 2}
# 20 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2, 'https://w.amazon.com/bin/view/Broadcast': 2, 'https://w.amazon.com/bin/view/Broadcast/CustomerSupport': 2}
# 19 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2, 'https://w.amazon.com/bin/view/Broadcast': 2}
# 18 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2, 'https://w.amazon.com/bin/view/AmazonWiki': 2}
# 17 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2, 'https://w.amazon.com/bin/view/KnowledgeTech/': 2}
# 16 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/create/KnowledgeTech': 2}
# 15 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1}
# 14 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1}
# processing:https://w.amazon.com/bin/view/EC2-MVP/Engagement   depth:1
# 66 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/create/EC2-MVP/Engagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/': 2, 'https://w.amazon.com/bin/view/EC2-MVP': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Tenets': 2, 'https://w.amazon.com/bin/view/EC2-MVP/FAQs': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team': 2, 'https://w.amazon.com/bin/view/MVP_Parks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/West': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Templates': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Training': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/EC2MVPEnhancedMCMProcess': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/CMBR': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Oncall': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2Oncalls': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/ManagerOncall/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/SIMTemplates/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks/MVP_Customer_Cases/': 2, 'https://w.amazon.com/bin/view/BlackMirror/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/MW2': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview/Stalemate': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2_MVP_Parks_Customer_Case_Goals': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development/MW2/OnboardingProcess/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Getting_Started/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Roadmap/': 2, 'https://w.amazon.com/bin/view/Serverless_ADC': 2, 'https://w.amazon.com/bin/view/EC2-MVP/MVP_Parks/': 2, 'https://w.amazon.com/bin/view/TechOps/Module/AWS_Pager_Engagement_List': 2, 'https://w.amazon.com/bin/view/BubbleTea': 2, 'https://w.amazon.com/bin/view/MVP-CST': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/AmazonLinux/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Autoscaling': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Parks/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EBS': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2Capacity': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2FoundationalTechnologies': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2PricingReservedInstances': 2 ...
# 65 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/create/EC2-MVP/Engagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/': 2, 'https://w.amazon.com/bin/view/EC2-MVP': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Tenets': 2, 'https://w.amazon.com/bin/view/EC2-MVP/FAQs': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team': 2, 'https://w.amazon.com/bin/view/MVP_Parks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/West': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Templates': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Training': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/EC2MVPEnhancedMCMProcess': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/CMBR': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Oncall': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2Oncalls': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/ManagerOncall/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/SIMTemplates/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks/MVP_Customer_Cases/': 2, 'https://w.amazon.com/bin/view/BlackMirror/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/MW2': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview/Stalemate': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2_MVP_Parks_Customer_Case_Goals': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development/MW2/OnboardingProcess/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Getting_Started/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Roadmap/': 2, 'https://w.amazon.com/bin/view/Serverless_ADC': 2, 'https://w.amazon.com/bin/view/EC2-MVP/MVP_Parks/': 2, 'https://w.amazon.com/bin/view/TechOps/Module/AWS_Pager_Engagement_List': 2, 'https://w.amazon.com/bin/view/BubbleTea': 2, 'https://w.amazon.com/bin/view/MVP-CST': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/AmazonLinux/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Autoscaling': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Parks/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EBS': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2Capacity': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2FoundationalTechnologies': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2PricingReservedInstances': 2 ...
# 64 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/create/EC2-MVP/Engagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/': 2, 'https://w.amazon.com/bin/view/EC2-MVP': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Tenets': 2, 'https://w.amazon.com/bin/view/EC2-MVP/FAQs': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team': 2, 'https://w.amazon.com/bin/view/MVP_Parks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/West': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Templates': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Training': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/EC2MVPEnhancedMCMProcess': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/CMBR': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Oncall': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2Oncalls': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/ManagerOncall/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/SIMTemplates/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks/MVP_Customer_Cases/': 2, 'https://w.amazon.com/bin/view/BlackMirror/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/MW2': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview/Stalemate': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2_MVP_Parks_Customer_Case_Goals': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development/MW2/OnboardingProcess/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Getting_Started/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Roadmap/': 2, 'https://w.amazon.com/bin/view/Serverless_ADC': 2, 'https://w.amazon.com/bin/view/EC2-MVP/MVP_Parks/': 2, 'https://w.amazon.com/bin/view/TechOps/Module/AWS_Pager_Engagement_List': 2, 'https://w.amazon.com/bin/view/BubbleTea': 2, 'https://w.amazon.com/bin/view/MVP-CST': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/AmazonLinux/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Autoscaling': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Parks/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EBS': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2Capacity': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2FoundationalTechnologies': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2PricingReservedInstances': 2 ...
# 63 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/create/EC2-MVP/Engagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/': 2, 'https://w.amazon.com/bin/view/EC2-MVP': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Tenets': 2, 'https://w.amazon.com/bin/view/EC2-MVP/FAQs': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team': 2, 'https://w.amazon.com/bin/view/MVP_Parks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/West': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Templates': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Training': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/EC2MVPEnhancedMCMProcess': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/CMBR': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Oncall': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2Oncalls': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/ManagerOncall/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/SIMTemplates/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks/MVP_Customer_Cases/': 2, 'https://w.amazon.com/bin/view/BlackMirror/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/MW2': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview/Stalemate': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2_MVP_Parks_Customer_Case_Goals': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development/MW2/OnboardingProcess/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Getting_Started/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Roadmap/': 2, 'https://w.amazon.com/bin/view/Serverless_ADC': 2, 'https://w.amazon.com/bin/view/EC2-MVP/MVP_Parks/': 2, 'https://w.amazon.com/bin/view/TechOps/Module/AWS_Pager_Engagement_List': 2, 'https://w.amazon.com/bin/view/BubbleTea': 2, 'https://w.amazon.com/bin/view/MVP-CST': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/AmazonLinux/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Autoscaling': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Parks/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EBS': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2Capacity': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2FoundationalTechnologies': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2PricingReservedInstances': 2 ...
# 62 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/create/EC2-MVP/Engagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/': 2, 'https://w.amazon.com/bin/view/EC2-MVP': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Tenets': 2, 'https://w.amazon.com/bin/view/EC2-MVP/FAQs': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team': 2, 'https://w.amazon.com/bin/view/MVP_Parks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/West': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Templates': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Training': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/EC2MVPEnhancedMCMProcess': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/CMBR': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Oncall': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2Oncalls': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/ManagerOncall/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/SIMTemplates/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks/MVP_Customer_Cases/': 2, 'https://w.amazon.com/bin/view/BlackMirror/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/MW2': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview/Stalemate': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2_MVP_Parks_Customer_Case_Goals': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development/MW2/OnboardingProcess/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Getting_Started/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Roadmap/': 2, 'https://w.amazon.com/bin/view/Serverless_ADC': 2, 'https://w.amazon.com/bin/view/EC2-MVP/MVP_Parks/': 2, 'https://w.amazon.com/bin/view/TechOps/Module/AWS_Pager_Engagement_List': 2, 'https://w.amazon.com/bin/view/BubbleTea': 2, 'https://w.amazon.com/bin/view/MVP-CST': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/AmazonLinux/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Autoscaling': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Parks/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EBS': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2Capacity': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2FoundationalTechnologies': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2PricingReservedInstances': 2 ...
# 61 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning/': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/': 1, 'https://w.amazon.com/bin/create/EC2-MVP/Engagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/': 2, 'https://w.amazon.com/bin/view/EC2-MVP': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Tenets': 2, 'https://w.amazon.com/bin/view/EC2-MVP/FAQs': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team': 2, 'https://w.amazon.com/bin/view/MVP_Parks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/West': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Team/Templates': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Training': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/EC2MVPEnhancedMCMProcess': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/CMBR': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Oncall': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2Oncalls': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/ManagerOncall/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/SIMTemplates/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/Runbooks/MVP_Customer_Cases/': 2, 'https://w.amazon.com/bin/view/BlackMirror/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/MW2': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview/Stalemate': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Dashboards/OpsReview': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Operations/EC2_MVP_Parks_Customer_Case_Goals': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Development/MW2/OnboardingProcess/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Getting_Started/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/ChangeManagement/FullCD/Roadmap/': 2, 'https://w.amazon.com/bin/view/Serverless_ADC': 2, 'https://w.amazon.com/bin/view/EC2-MVP/MVP_Parks/': 2, 'https://w.amazon.com/bin/view/TechOps/Module/AWS_Pager_Engagement_List': 2, 'https://w.amazon.com/bin/view/BubbleTea': 2, 'https://w.amazon.com/bin/view/MVP-CST': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/AmazonLinux/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Autoscaling': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/Parks/': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EBS': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2Capacity': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2FoundationalTechnologies': 2, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement/EC2PricingReservedInstances': 2 ...
# ...
# 8 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2}
# 7 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 1}
# 6 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1}
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/   depth:1
# 12 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/create/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2, 'https://w.amazon.com/bin/view/EC2/XPQ/Operations/ConfigurablePlacement/ConfigurableODCRs': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/AcceptanceState/': 2}
# 11 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/create/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2, 'https://w.amazon.com/bin/view/EC2/XPQ/Operations/ConfigurablePlacement/ConfigurableODCRs': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/': 2}
# 10 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/create/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2, 'https://w.amazon.com/bin/view/EC2/XPQ/Operations/ConfigurablePlacement/ConfigurableODCRs': 2}
# 9 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/create/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2}
# 8 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/create/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2}
# 7 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1, 'https://w.amazon.com/bin/create/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR': 2}
# 6 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 1}
# 5 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1}
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/   depth:1
# 7 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/create/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources': 2, 'https://w.amazon.com/bin/view/AmazonWiki/Permissions/UserGuide/': 2}
# 6 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1, 'https://w.amazon.com/bin/create/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources': 2}
# 5 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/': 1}
# 4 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2}
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native/   depth:1
# 12 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/FOOB_Threshold/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2, 'https://w.amazon.com/bin/view/EC2/ReservedInstances/': 2, 'https://w.amazon.com/bin/view/EC2/ReservedInstances/API': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr/': 2}
# 11 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/FOOB_Threshold/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2, 'https://w.amazon.com/bin/view/EC2/ReservedInstances/': 2, 'https://w.amazon.com/bin/view/EC2/ReservedInstances/API': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR/': 2}
# 10 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/FOOB_Threshold/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2, 'https://w.amazon.com/bin/view/EC2/ReservedInstances/': 2, 'https://w.amazon.com/bin/view/EC2/ReservedInstances/API': 2}
# 9 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/FOOB_Threshold/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2, 'https://w.amazon.com/bin/view/EC2/ReservedInstances/': 2}
# 8 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/FOOB_Threshold/': 2, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/': 2}
# 7 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/FOOB_Threshold/': 2}
# 6 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/': 2}
# 5 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/': 2}
# 4 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning/': 2}
# 3 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2, 'https://w.amazon.com/bin/view/EC2_capacity_faqs/': 2}
# 2 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/': 2}
# 1 {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/': 2}
# 0 {}

# %%
elements = driver.find_elements(By.ID,'contentcontainer')

# %%
list(content[0].values())[0]
# Out:
# ['External Capacity Runbook\nView Source\nTools\n<\nCustomer Planning Group\nExternal Capacity Planning Runbook\nCPG Home FAQs\nExternal Capacity Planning Runbook AWS Internal Capacity Planning Runbook CDO Native Capacity Planning Runbook Internal Team Resources\nObjective\nThe purpose of this Runbook is to provide a step by step operating guideline for TAM or the account teams to request additional EC2 capacity across any AZ globally for AWS customers. \nOverview\nAWS uses historical usage data, organic demand signals, and manual complements to our forecast in order to anticipate customer requirements and ensure that we provision enough capacity. We are constantly working to expand the capacity within our data centers, the physical capacity of our availability zones and regions, and our global geographical coverage (new regions).\n\nEC2 Capacity Planning assists in preparing the future capacity needs of external customers, adds them into AWS demand signals through the FOOB process, and then manages the delivery of capacity to the customer account through AWS Assisted CR. TAMs and SAs should proactively work with their customers to understand future capacity needs and engage EC2 Capacity Planning following the below process.\n\nDefinitions\nFOOB: FOOB stands for "Future Out Of Band" signal. FOOBs are used to communicate to EC2 that there is an emergent or spiky customer demand event that is not predicted by the past behavior of the customer. The ultimate goal of submitting FOOBs is to reduce the likelihood that customers will find insufficient capacity to support these exceptional events. The EC2 Organic Forecast leverages historical, seasonal and recent trends to recommend run-rate growth of EC2 capacity across customer segments. We recommend submitting a FOOB (Via the MaitreD tool - see below) at least 7-8 weeks in advance of the customer requirement. The most frequent use cases requiring FOOBs include:\nLaunching a new workload in an existing or a new AZ\nDemand events outside of the historical demand pattern and seasonality of the business - This includes spikes as well as decreases or \'scale-downs\'\nPlanned changes in the type of EC2 instance type used (e.g migrating from C5 to C6G)\nMid to large scale migrations (from On Prem to AWS or between regions or Server Types)\nMaitreD: MaitreD is the user interface for CRS (capacity reservation system) where capacity requirements are submitted to generate a FOOB and subsequently collect, reserve, and transfer specified capacity to a customer account through AWS Assisted CR.\n\nMaitreD can be accessed via this link. Note, many teams already have MaitreD access, so please take a look at your team here or try MaitreD first before requesting the access. In case you don\'t have the access, request it by following the steps on \'Getting Access\' section here. See MaitreD user guide here. If you are looking for the MaitreD access to others\' submission, please ask the requester to add you onto the \'User Access\' list of his/her submission.\n\nAWS Assisted Capacity Reservation: Capacity requested in MaitreD is delivered directly to customers\' accounts via AWS-Assisted CR. Customers will be notified through their console and Personal Health Dashboard of upcoming capacity requests made though MaitreD and MUST \'accept\' these reservations in either their Console or SKD/CLI before the Need By Date to receive the Capacity Reservation. Once a request is approved by Capacity Planning, the Incremental Requested Quantity will be visible as a tag value for each CR under the ‘aws:ec2capacityreservation:incrementalRequestedQuantity’ system key. For first time delivery with AWS-Assisted CR, please follow the User Guide for setup instructions and customer requirements.\nAuto-Acceptance for all future, requested ODCRs can be toggled on by region through either the Console or CLI.\nOnce the AWS-Assisted CR delivers to the customer account on the specified Need By Date/Time, it becomes an active On ...

# %%
with open('temp_webcontent/2023-08-24-09-57-50/file-2023-08-24-09:58:42.wiki','r') as f:
    print(json.loads(f.read()))
# Out:
# [{'https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance': ["AWS_GCR_GTMSServiceLaunchFOOB 提交快速指南\nFOOB 提交快速指南\nPrimary Contact chuanxie (user) How do I change this value?\nLast modified 16 hours ago by chuanxie.\nView Source Edit Edit Source\nTools\n1. FOOB Ticket快速指南 (For EC2)\n1.1 步骤\na) 什么场景需要提FOOB？\n新增的需求，如客户迁移新的workload，workload突增（6/18，11/11等），客户计划的机型升级（例如C4->C5， x86→Gravition) , Region切换等\n有些特殊机型如GPU/Inf1实例，U型实例，可提前去看下Baywatch现在的剩余资源情况。\n另外全球高端GPU资源很紧张，P4/P5 机型的申请，除了要提FOOB，还需要额外流程。见1.3 P4/P5附加流程 \nb) 提前多久时间？\n需要提前8周提交。建议先去baywatch查看一下可用的capacity是否有剩余，如果free slots较多，则fullfill时间会较短些，如果slots很少，则可能需要涉及采购新硬件, 需要预留足够的buffer时间。\nc) FOOB ticket 提交模板\n需求类型 quicklink 相应SLA 提交时请填写自己base地对应的location，例如您base在PEK17，就填PEK17\n普通EC2需求（包括GPU） https://t.corp.amazon.com/create/templates/a55f20c1-8bda-447d-86b4-5172493fa7a0 72小时（Sea工作日时间）\nHigh Memory实例 (U-6tb/U-9tb/U-12tb等) https://t.corp.amazon.com/create/templates/8a4fd90d-791d-48c2-88ad-bdfcd75d3f49  \nHigh Memory bare metal实例（u-6tb1.metal, u-9tb1.metal, u-12tb1.metal, u-18tb1.metal, u-24tb1.metal https://t.corp.amazon.com/create/templates/a941800e-939f-4029-b662-376b83bfcb35  \n紧急需求的提交模板（Only for unblock customers in SEV2 situations, not for future planning needs. ） https://t.corp.amazon.com/create/templates/6c98e02f-8886-4b3a-a13d-f151cbeec412 7*24，oncall list\ne) 按对应模板要求填写所需的信息，并且在Ticket里附上 MaitreD (Ticket模板里也有链接) 申请链接。\nMaitrieD 填写Tips ，注意必须严格按系统要求的格式来填写，否则会提交失败，如Region，AZ，NBD等，千万注意机型别申请错了：https://www.figma.com/proto/KIW7T0o3WyHBV0psCS7RDq/MaitreD-Instruction?node-id=7%3A49&scaling=min-zoom&page-id=0%3A1\n ！！提醒：Instance Eligibility 选项填写\n“open”，会动态的把NBD之前的已经在run的按需实例数量例如z，跟MatrieD里填写的数量x，累加到一起，然后按（z+x）台算ODCR。\n“taget”，只交付MatrieD里填写的数量x，则只把x台算成ODCR。但是客户启动资源时，需要填入预留ID才能跟ODCR的资源匹配上。\nf) Ticket和MaitrieD里抄送对应的GTMS和PM(chuanxie@)。\nDomain name login 备注\nEC2 Wang Ping/Yao Kai/Cao Xu wapng,yaoks,billcaox,chuanxie Wang Ping( Gravition及其他 )，Yao Kai（amd/i/d系列），Cao Xu （x/u/intel 系列）,\nGPU/Inf1 Huang Bingyang bingyanh,chuanxie 申请GPU实例\n        ！！注意事项！！：\n如果申请超过 $500K 或者 3 racks,则需要Sales L8 Director 或者 local business L8 Director的approval（在Ticket中附上approval邮件截图即可）。\n即使FOOB申请被capacity team approved了，仍然有一定的风险会延迟交付 “While Capacity Planning does its best to use forecasts and levers to deliver on requests, we cannot make any 'guarantees' on delivering capacity on a future date.”\n请保持关注提交的Ticket，并及时响应处理人员提出的question。\n再三检查MatrieD的信息是否填写正确，如instance type，AZ， NBD，Instance Eligibility等\nCapacity预留confirm之后，请提醒客户在Need By Date之前在后台接受，否则资源会被回收。并在Ticket中回复客户是否接受，Close the Loop。\n1.2 常见问题\n1）ODCR预留实例怎么计费？\n只要交付到客户账户里，无论是否预留实例是否运行，都按等同的按需费率计费。如果客户没有使用预留，将在客户的EC2 账单中显示为未使用的预留。如果客户运行的实例属性与预留匹配，则客户只需要为该实例付费，不需要为预留付费。\n2）ODCR交付的实例怎么享受RI/Savings Plan计费折扣？\nSavings Plans 和区域RI实例的账单折扣适用于ODCR。AWS 自动将这些折扣应用于具有匹配属性的容量预留, 客户只要购买与ODCR 实例相同的Regional RI 或者Savings Plan，就能享受到对应的计费折扣。查看更多\n3）需求需要更改怎么办？\n在客户Accpet之前，请及时在Ticket里面提出更改需求。\n4）怎么看现有的Capacity？\n使用https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer\nTips：通常情况下使用默认值搜索即可\n5）怎么看FOOB 审批状态？\n打开申请的matried链接，看status字段，如果仍然是Pending Approval，则说明FOOB后台还没有批复，如果是Approve，应该是running等其他状态。\n6）怎么看资源分配是否有risk？\nFOOB的机制并不能百分百保证资源到位，如果池子剩余资源较少的情况下，可能会延迟交付或者部分交付，可以在Matried中查看allocation status这个字段。这个字段不是默认展示，第一次开启时需要点击做上的设置按钮，打开这个字段。\nAllocationStatus（每15分钟更新一次） Description\nNOT_ALLOCATING (previous unknown) status. Used for if reservation has just been made\nON_TRACK When the reservation is allocating just right/当前预留正好合适\nAHEAD_OF_SCHEDULE When there is a surplus in what the current allocation holds/当前分配有盈余时\nBEHIND_OF_SCHEDULE When there is a deficit in allocation/当分配不够\n1.3 P4/P5 Instance 附加流程\n1. https://approvals.amazon.com/Template/Details/110748 根据这个模板填写您负责的用户的相关信息，并且清楚的描述用户的相关需求\n2. 在上述链接中贴上的你的FOOB Ticket Link 和 MaitreD Ticket Link\n3. 提交请求，然后等待各级负责人人员审批\n1.4 其他常用链接：\n完整培训视频：https://broadcast.amazon.com/videos/564991\nBaywatch查看当前capacity:https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer\nUrgent 需求查看oncall: https://oncall.corp.amazon. ...

# %%
cwoker.content
# Out:
# [{'https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance': ["AWS_GCR_GTMSServiceLaunchFOOB 提交快速指南\nFOOB 提交快速指南\nPrimary Contact chuanxie (user) How do I change this value?\nLast modified 20 days ago by chuanxie.\nView Source Edit Edit Source\nTools\n1. FOOB Ticket快速指南 (For EC2)\n1.1 步骤\na) 什么场景需要提FOOB？\n新增的需求，如客户迁移新的workload，workload突增（6/18，11/11等），客户计划的机型升级（例如C4->C5， x86→Gravition) , Region切换等\n有些特殊机型如GPU/Inf1实例，U型实例，可提前去看下Baywatch现在的剩余资源情况。\n另外全球高端GPU资源很紧张，P4/P5 机型的申请，除了要提FOOB，还需要额外流程。见1.3 P4/P5附加流程 \nb) 提前多久时间？\n需要提前8周提交。建议先去baywatch查看一下可用的capacity是否有剩余，如果free slots较多，则fullfill时间会较短些，如果slots很少，则可能需要涉及采购新硬件, 需要预留足够的buffer时间。\nc) FOOB ticket 提交模板\n需求类型 quicklink 相应SLA 提交时请填写自己base地对应的location，例如您base在PEK17，就填PEK17\n普通EC2需求（包括GPU） https://t.corp.amazon.com/create/templates/a55f20c1-8bda-447d-86b4-5172493fa7a0 72小时（Sea工作日时间）\nHigh Memory实例 (U-6tb/U-9tb/U-12tb等) https://t.corp.amazon.com/create/templates/8a4fd90d-791d-48c2-88ad-bdfcd75d3f49  \nHigh Memory bare metal实例（u-6tb1.metal, u-9tb1.metal, u-12tb1.metal, u-18tb1.metal, u-24tb1.metal https://t.corp.amazon.com/create/templates/a941800e-939f-4029-b662-376b83bfcb35  \n紧急需求的提交模板（Only for unblock customers in SEV2 situations, not for future planning needs. ） https://t.corp.amazon.com/create/templates/6c98e02f-8886-4b3a-a13d-f151cbeec412 7*24，oncall list\ne) 按对应模板要求填写所需的信息，并且在Ticket里附上 MaitreD (Ticket模板里也有链接) 申请链接。\nMaitrieD 填写Tips ，注意必须严格按系统要求的格式来填写，否则会提交失败，如Region，AZ，NBD等，千万注意机型别申请错了：https://www.figma.com/proto/KIW7T0o3WyHBV0psCS7RDq/MaitreD-Instruction?node-id=7%3A49&scaling=min-zoom&page-id=0%3A1\n ！！提醒：Instance Eligibility 选项填写\n“open”，会动态的把NBD之前的已经在run的按需实例数量例如z，跟MatrieD里填写的数量x，累加到一起，然后按（z+x）台算ODCR。\n“taget”，只交付MatrieD里填写的数量x，则只把x台算成ODCR。但是客户启动资源时，需要填入预留ID才能跟ODCR的资源匹配上。\nf) Ticket和MaitrieD里抄送对应的GTMS和PM(chuanxie@)。\nDomain name login 备注\nEC2 Wang Ping/Yao Kai/Cao Xu wapng,yaoks,billcaox,chuanxie Wang Ping( Gravition及其他 )，Yao Kai（amd/i/d系列），Cao Xu （x/u/intel 系列）,\nGPU/Inf1 Brenda Li liyuanb,chuanxie 申请GPU实例\n        ！！注意事项！！：\n如果申请超过 $500K 或者 3 racks,则需要Sales L8 Director 或者 local business L8 Director的approval（在Ticket中附上approval邮件截图即可）。\n即使FOOB申请被capacity team approved了，仍然有一定的风险会延迟交付 “While Capacity Planning does its best to use forecasts and levers to deliver on requests, we cannot make any 'guarantees' on delivering capacity on a future date.”\n请保持关注提交的Ticket，并及时响应处理人员提出的question。\n再三检查MatrieD的信息是否填写正确，如instance type，AZ， NBD，Instance Eligibility等\nCapacity预留confirm之后，请提醒客户在Need By Date之前在后台接受，否则资源会被回收。并在Ticket中回复客户是否接受，Close the Loop。\n1.2 常见问题\n1）ODCR预留实例怎么计费？\n只要交付到客户账户里，无论是否预留实例是否运行，都按等同的按需费率计费。如果客户没有使用预留，将在客户的EC2 账单中显示为未使用的预留。如果客户运行的实例属性与预留匹配，则客户只需要为该实例付费，不需要为预留付费。\n2）ODCR交付的实例怎么享受RI/Savings Plan计费折扣？\nSavings Plans 和区域RI实例的账单折扣适用于ODCR。AWS 自动将这些折扣应用于具有匹配属性的容量预留, 客户只要购买与ODCR 实例相同的Regional RI 或者Savings Plan，就能享受到对应的计费折扣。查看更多\n3）需求需要更改怎么办？\n在客户Accpet之前，请及时在Ticket里面提出更改需求。\n4）怎么看现有的Capacity？\n使用https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer\nTips：通常情况下使用默认值搜索即可\n5）怎么看FOOB 审批状态？\n打开申请的matried链接，看status字段，如果仍然是Pending Approval，则说明FOOB后台还没有批复，如果是Approve，应该是running等其他状态。\n6）怎么看资源分配是否有risk？\nFOOB的机制并不能百分百保证资源到位，如果池子剩余资源较少的情况下，可能会延迟交付或者部分交付，可以在Matried中查看allocation status这个字段。这个字段不是默认展示，第一次开启时需要点击做上的设置按钮，打开这个字段。\nAllocationStatus（每15分钟更新一次） Description\nNOT_ALLOCATING (previous unknown) status. Used for if reservation has just been made\nON_TRACK When the reservation is allocating just right/当前预留正好合适\nAHEAD_OF_SCHEDULE When there is a surplus in what the current allocation holds/当前分配有盈余时\nBEHIND_OF_SCHEDULE When there is a deficit in allocation/当分配不够\n1.3 P4/P5 Instance 附加流程\n1. https://approvals.amazon.com/Template/Details/110748 根据这个模板填写您负责的用户的相关信息，并且清楚的描述用户的相关需求\n2. 在上述链接中贴上的你的FOOB Ticket Link 和 MaitreD Ticket Link\n3. 提交请求，然后等待各级负责人人员审批\n1.4 其他常用链接：\n完整培训视频：https://broadcast.amazon.com/videos/564991\nBaywatch查看当前capacity:https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer\nUrgent 需求查看oncall: https://oncall.corp.amazon.com/#/v ...
#  {'https://w.amazon.com/bin/view/KnowledgeTech': ["Knowledge Tech\nTools\nKnowledge Tech (KT)\nProducts\nRoadmaps\nInternal\nOur Mission\nKnowledge Tech provides peer-to-peer knowledge sharing tools, including Wiki, Broadcast, Sage and Internal Search.\nOur mission is to make it easy, fast, and frugal for the engineering community to discover, manage, and share knowledge across Amazon. \nTenets (for now... we're working on some better ones...)\nAmazon's Librarians: We are stewards of Amazon's most valuable information assets - with this comes a responsibility to raising the bar on quality and relevancy of these assets.\nLess is More: Our customers prefer fewer tools and workflows. Therefore, we choose to reduce, reuse, and enhance instead of inherit, replicate, or create.\nLead with Empathy: We foster a psychologically safe environment where ourselves and our coworkers are the most important element.\nWe build for all: Our experiences are born accessible (by launching without critical accessibility issues) and we consider the global reach of the products we release.\nLeading with testing: We use data, two-way door mechanisms, and A/B testing to guide decisions.\nKnowledge Tech Leaders\nProduct Management\nHank\ncycyotah@\nEKG Product Manager\nDerek\nleblondd@\nAnalytics & Doc BR Tool\nCassie\nrybolt@\nProduct Manager\nMardi\nmardi@\nProduct Manager\nAlex\nleonov@\nTPM\nUser Experience\nJason\njruddy@\nBuilder Experience Manager\nJae\njaeyelee@\nUser Experience\nEngineering Team\nChris\ncmaca@\nKnowledge Tech Manager\nSteph\nstephsig@\nInternal Search Manager\nMark\nmarkvanh@\nBroadcast and Publication Manager\nTracy\ntracylau@\nDoc BR Manager\nGuru\ngpaladi@\nWiki Manager\nChris\nqfiechri@\nSage Manager\nKnowledge Tech Products\nWiki\nAmazon Wiki is a content sharing system that enables our customers to create, manage, and share essential knowledge.\nTool Link https://w.amazon.com/bin/view/Main\nTeam Wiki AmazonWiki\nHelp Wiki Help or Ask a question on Sage\nInterest List wiki-users@\nBroadcast\nBroadcast is an Amazon internal video-on-demand service, we provide knowledge to learners with relevant Amazon video content. \nTool Link https://broadcast.amazon.com\nTeam Wiki Broadcast Wiki\nHelp Broadcast Customer Support or Ask a question on Sage\nInterest List broadcast-interest@\nSage\nSage is Amazon's technical Q&A Forum. Users contribute answers to questions and earn points for the quality and usefulness of the content, as determined by the community.\nTool Link https://sage.amazon.com\nTeam Wiki Sage Wiki\nHelp Sage Customer Support or Sage Meta\nInterest List sage-announcements@\nInternal Search (IS)\nInternal Search provides a single interface for users to search across internal Amazon websites. Today, IS ingests and indexes documents from Wiki, Sage, Broadcast, and select data sources outside of Knowledge Tech.\nTool Link https://is.amazon.com\nTeam Wiki IS Wiki\nHelp Internal Search Customer Support or Ask a question on Sage\nInterest List internal-search-interest@\nDoc Bar Raiser Reviewer (DBRR)\nDoc Bar Raiser Reviewer is an internal Amazon tool to help Amazonians write better docs.\nTool Link https://console.harmony.a2z.com/doc-bar-raiser-reviewer/\nTeam Wiki https://w.amazon.com/bin/view/EE/Learn/DocBarRaisers/DocBarRaiserReviewer/\nSupport https://issues.amazon.com/issues/create?template=be650e6b-6d7b-44b1-9039-71f6c7f1c77c\nRequest Feature\nhttps://issues.amazon.com/issues/create?template=f96322a4-ae54-47f2-9339-d0b00b4067ae\n1 on 1 Review  https://w.amazon.com/bin/view/DocBarRaisers/WritingHelp/\nWriting Hub https://w.amazon.com/bin/view/WritingHub\nEmail List https://email-list.corp.amazon.com/email-list/expand-list/docbr-reviewer\nTools Formerly owned by Knowledge Tech\nKT Insights (KTI): KTI Wiki\nTech Survey: TS Wiki\nTrawler (RIP): Trawler Wiki, replaced by FieldSense\nTags: EKG KnowledgeTech\nComments (1)\nAttachments (10)\nHistory\nInformation\nrybolt Jul 01, 2021 10:44 PM UTC\nPlease do not use Wiki comment ...
#  {'https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#Information': ["AWS_GCR_GTMSServiceLaunchFOOB 提交快速指南\nFOOB 提交快速指南\nPrimary Contact chuanxie (user) How do I change this value?\nLast modified 20 days ago by chuanxie.\nView Source Edit Edit Source\nTools\n1. FOOB Ticket快速指南 (For EC2)\n1.1 步骤\na) 什么场景需要提FOOB？\n新增的需求，如客户迁移新的workload，workload突增（6/18，11/11等），客户计划的机型升级（例如C4->C5， x86→Gravition) , Region切换等\n有些特殊机型如GPU/Inf1实例，U型实例，可提前去看下Baywatch现在的剩余资源情况。\n另外全球高端GPU资源很紧张，P4/P5 机型的申请，除了要提FOOB，还需要额外流程。见1.3 P4/P5附加流程 \nb) 提前多久时间？\n需要提前8周提交。建议先去baywatch查看一下可用的capacity是否有剩余，如果free slots较多，则fullfill时间会较短些，如果slots很少，则可能需要涉及采购新硬件, 需要预留足够的buffer时间。\nc) FOOB ticket 提交模板\n需求类型 quicklink 相应SLA 提交时请填写自己base地对应的location，例如您base在PEK17，就填PEK17\n普通EC2需求（包括GPU） https://t.corp.amazon.com/create/templates/a55f20c1-8bda-447d-86b4-5172493fa7a0 72小时（Sea工作日时间）\nHigh Memory实例 (U-6tb/U-9tb/U-12tb等) https://t.corp.amazon.com/create/templates/8a4fd90d-791d-48c2-88ad-bdfcd75d3f49  \nHigh Memory bare metal实例（u-6tb1.metal, u-9tb1.metal, u-12tb1.metal, u-18tb1.metal, u-24tb1.metal https://t.corp.amazon.com/create/templates/a941800e-939f-4029-b662-376b83bfcb35  \n紧急需求的提交模板（Only for unblock customers in SEV2 situations, not for future planning needs. ） https://t.corp.amazon.com/create/templates/6c98e02f-8886-4b3a-a13d-f151cbeec412 7*24，oncall list\ne) 按对应模板要求填写所需的信息，并且在Ticket里附上 MaitreD (Ticket模板里也有链接) 申请链接。\nMaitrieD 填写Tips ，注意必须严格按系统要求的格式来填写，否则会提交失败，如Region，AZ，NBD等，千万注意机型别申请错了：https://www.figma.com/proto/KIW7T0o3WyHBV0psCS7RDq/MaitreD-Instruction?node-id=7%3A49&scaling=min-zoom&page-id=0%3A1\n ！！提醒：Instance Eligibility 选项填写\n“open”，会动态的把NBD之前的已经在run的按需实例数量例如z，跟MatrieD里填写的数量x，累加到一起，然后按（z+x）台算ODCR。\n“taget”，只交付MatrieD里填写的数量x，则只把x台算成ODCR。但是客户启动资源时，需要填入预留ID才能跟ODCR的资源匹配上。\nf) Ticket和MaitrieD里抄送对应的GTMS和PM(chuanxie@)。\nDomain name login 备注\nEC2 Wang Ping/Yao Kai/Cao Xu wapng,yaoks,billcaox,chuanxie Wang Ping( Gravition及其他 )，Yao Kai（amd/i/d系列），Cao Xu （x/u/intel 系列）,\nGPU/Inf1 Brenda Li liyuanb,chuanxie 申请GPU实例\n        ！！注意事项！！：\n如果申请超过 $500K 或者 3 racks,则需要Sales L8 Director 或者 local business L8 Director的approval（在Ticket中附上approval邮件截图即可）。\n即使FOOB申请被capacity team approved了，仍然有一定的风险会延迟交付 “While Capacity Planning does its best to use forecasts and levers to deliver on requests, we cannot make any 'guarantees' on delivering capacity on a future date.”\n请保持关注提交的Ticket，并及时响应处理人员提出的question。\n再三检查MatrieD的信息是否填写正确，如instance type，AZ， NBD，Instance Eligibility等\nCapacity预留confirm之后，请提醒客户在Need By Date之前在后台接受，否则资源会被回收。并在Ticket中回复客户是否接受，Close the Loop。\n1.2 常见问题\n1）ODCR预留实例怎么计费？\n只要交付到客户账户里，无论是否预留实例是否运行，都按等同的按需费率计费。如果客户没有使用预留，将在客户的EC2 账单中显示为未使用的预留。如果客户运行的实例属性与预留匹配，则客户只需要为该实例付费，不需要为预留付费。\n2）ODCR交付的实例怎么享受RI/Savings Plan计费折扣？\nSavings Plans 和区域RI实例的账单折扣适用于ODCR。AWS 自动将这些折扣应用于具有匹配属性的容量预留, 客户只要购买与ODCR 实例相同的Regional RI 或者Savings Plan，就能享受到对应的计费折扣。查看更多\n3）需求需要更改怎么办？\n在客户Accpet之前，请及时在Ticket里面提出更改需求。\n4）怎么看现有的Capacity？\n使用https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer\nTips：通常情况下使用默认值搜索即可\n5）怎么看FOOB 审批状态？\n打开申请的matried链接，看status字段，如果仍然是Pending Approval，则说明FOOB后台还没有批复，如果是Approve，应该是running等其他状态。\n6）怎么看资源分配是否有risk？\nFOOB的机制并不能百分百保证资源到位，如果池子剩余资源较少的情况下，可能会延迟交付或者部分交付，可以在Matried中查看allocation status这个字段。这个字段不是默认展示，第一次开启时需要点击做上的设置按钮，打开这个字段。\nAllocationStatus（每15分钟更新一次） Description\nNOT_ALLOCATING (previous unknown) status. Used for if reservation has just been made\nON_TRACK When the reservation is allocating just right/当前预留正好合适\nAHEAD_OF_SCHEDULE When there is a surplus in what the current allocation holds/当前分配有盈余时\nBEHIND_OF_SCHEDULE When there is a deficit in allocation/当分配不够\n1.3 P4/P5 Instance 附加流程\n1. https://approvals.amazon.com/Template/Details/110748 根据这个模板填写您负责的用户的相关信息，并且清楚的描述用户的相关需求\n2. 在上述链接中贴上的你的FOOB Ticket Link 和 MaitreD Ticket Link\n3. 提交请求，然后等待各级负责人人员审批\n1.4 其他常用链接：\n完整培训视频：https://broadcast.amazon.com/videos/564991\nBaywatch查看当前capacity:https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer\nUrgent 需求查看oncall: https://oncall.corp.am ...

# %%
driver.quit()

# %%
url = 'https://w.amazon.com/bin/view/RegionBuildAutomation/Guidelines'

# %%
driver.get(url)

# %%
driver.implicitly_wait(1)

# %%
links = driver.find_elements(By.TAG_NAME,'a')
for link in links:
    href = link.get_attribute('href')
    text = link.text
    print(f"Text: {text}, URL: {href}")
# Out:
# Text: , URL: https://w.amazon.com/bin/view/Main
# Text: Create a Page, URL: https://w.amazon.com/bin/create/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance
# Text: User Profile, URL: https://w.amazon.com/bin/view/Users/chuanxie
# Text: Wiki Help, URL: https://w.amazon.com/bin/view/AmazonWiki/Wiki/Help
# Text: EN, URL: None
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: , URL: None
# Text: Contributions, URL: https://w.amazon.com/bin/view/XWiki/UserContributions
# Text: , URL: https://w.amazon.com/bin/view/XWiki/chuanxie
# Text: , URL: https://w.amazon.com/bin/view/XWiki/chuanxie
# Text: , URL: https://w.amazon.com/bin/view/WikiManager/
# Text: , URL: https://w.amazon.com/bin/view/Main/AllDocs
# Text: , URL: https://w.amazon.com/bin/view/Main/UserDirectory
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#
# Text: Take the Tour, URL: https://w.amazon.com/bin/view/Main?startTour=true
# Text: this ticket, URL: https://t.corp.amazon.com/V995297740
# Text: , URL: https://w.amazon.com/bin/view/XWiki/SIMForm/
# Text: , URL: https://w.amazon.com/bin/view/Main/
# Text: FOOB 提交快速指南, URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/
# Text: , URL: https://w.amazon.com/bin/view/AmazonWiki/Wiki/Help/WikiInclusiveTech/PreSaveScanner
# Text: chuanxie (user), URL: https://phonetool.amazon.com/users/chuanxie
# Text: How do I change this value?, URL: https://w.amazon.com/bin/view/AmazonWiki/Permissions/UserGuide/#HHowdoIchangethePrimaryContactvalueofaWikipage3F
# Text: chuanxie, URL: https://w.amazon.com/bin/view/XWiki/chuanxie
# Text: View Source, URL: https://w.amazon.com/bin/viewrev/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?viewer=code&rev=33.1
# Text: Edit, URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome
# Text: Edit Source, URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?editor=wiki
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?xpage=watch&do=adddocument&%20xredirect=%2Fbin%2Fview%2FAWS_GCR_GTMS%2FServiceLaunch%2FFOOBguidance%2F
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?xpage=watch&do=removedocument&%20xredirect=%2Fbin%2Fview%2FAWS_GCR_GTMS%2FServiceLaunch%2FFOOBguidance%2F
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?viewer=history
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?viewer=comments
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?viewer=attachments
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?viewer=children
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?viewer=information
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?xpage=move
# Text: , URL: https://w.amazon.com/bin/delete/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?viewer=share
# Text: , URL: https://w.amazon.com/bin/replication/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?enabled=true
# Text: , URL: https://w.amazon.com/bin/replication/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?enabled=false
# Text: , URL: https://w.amazon.com/bin/owner/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#Comments
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?xpage=pdfoptions&qs=
# Text: , URL: https://w.amazon.com/bin/export/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?format=html
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=1
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=1&editor=wiki
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=2
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=2&editor=wiki
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#
# Text: baywatch, URL: https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer
# Text: https://t.corp.amazon.com/create/templates/a55f20c1-8bda-447d-86b4-5172493fa7a0, URL: https://t.corp.amazon.com/create/templates/a55f20c1-8bda-447d-86b4-5172493fa7a0
# Text: https://t.corp.amazon.com/create/templates/8a4fd90d-791d-48c2-88ad-bdfcd75d3f49, URL: https://t.corp.amazon.com/create/templates/8a4fd90d-791d-48c2-88ad-bdfcd75d3f49
# Text: https://t.corp.amazon.com/create/templates/a941800e-939f-4029-b662-376b83bfcb35, URL: https://t.corp.amazon.com/create/templates/a941800e-939f-4029-b662-376b83bfcb35
# Text: https://t.corp.amazon.com/create/templates/6c98e02f-8886-4b3a-a13d-f151cbeec412, URL: https://t.corp.amazon.com/create/templates/6c98e02f-8886-4b3a-a13d-f151cbeec412
# Text: oncall list, URL: https://oncall.corp.amazon.com/#/view/ec2-capacity-delegates/schedule?aliases=
# Text: MaitreD, URL: https://ec2-maitre-d-prod-iad.iad.proxy.amazon.com/batchCreate?noTrigger=true
# Text: https://www.figma.com/proto/KIW7T0o3WyHBV0psCS7RDq/MaitreD-Instruction?node-id=7%3A49&scaling=min-zoom&page-id=0%3A1, URL: https://www.figma.com/proto/KIW7T0o3WyHBV0psCS7RDq/MaitreD-Instruction?node-id=7%3A49&scaling=min-zoom&page-id=0%3A1
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=3
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=3&editor=wiki
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#
# Text: 查看更多, URL: https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/capacity-reservations-pricing-billing.html
# Text: https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer, URL: https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=4
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=4&editor=wiki
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#
# Text: https://approvals.amazon.com/Template/Details/110748, URL: https://approvals.amazon.com/Template/Details/110748
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=5
# Text: , URL: https://w.amazon.com/bin/edit/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/WebHome?section=5&editor=wiki
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#
# Text: https://broadcast.amazon.com/videos/564991, URL: https://broadcast.amazon.com/videos/564991
# Text: https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer, URL: https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer
# Text: https://oncall.corp.amazon.com/#/view/ec2-capacity-delegates/schedule?aliases=, URL: https://oncall.corp.amazon.com/#/view/ec2-capacity-delegates/schedule?aliases=
# Text: https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/, URL: https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/
# Text: https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/#HHighMemoryVirtualizedCapacity28[…]xlargethroughu-12tb1.112xlarge29, URL: https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/#HHighMemoryVirtualizedCapacity28u-3tb1.56xlargethroughu-12tb1.112xlarge29
# Text: https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/#HHighMemoryCapacity28u-6tb1.metalthroughu-24tb1.metal2, URL: https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/#HHighMemoryCapacity28u-6tb1.metalthroughu-24tb1.metal29
# Text: [+], URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?showTagAddForm=true#xdocTags
# Text: Comments (1), URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#Comments
# Text: Attachments (14), URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#Attachments
# Text: History, URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#History
# Text: Information, URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance#Information
# Text: jackyqin, URL: https://w.amazon.com/bin/view/XWiki/jackyqin
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?xpage=xpart&vm=commentsinline.vm&replyto=0#xwikicomment_0
# Text: , URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?viewer=comments#xwikicomment_0
# Text: chuanxie, URL: https://w.amazon.com/bin/view/XWiki/chuanxie
# Text: Cancel, URL: https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/
# Text: Knowledge Tech, URL: https://w.amazon.com/bin/view/KnowledgeTech
# Text: Get Help, URL: https://w.amazon.com/bin/view/AmazonWiki/Wiki/Help/

# %%
main_container = driver.find_elements(By.ID, "contentcontainer")

# %%
main_container
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="19874776c077df483fd05ebf10c0df25", element="E6E9D2C0D094BC996B213F1A3912632A_element_87")>]

# %%
for e in main_container:
    print(e.text)
# Out:
# AWS_GCR_GTMSServiceLaunchFOOB 提交快速指南
# FOOB 提交快速指南
# Primary Contact chuanxie (user) How do I change this value?
# Last modified 20 days ago by chuanxie.
# View Source Edit Edit Source
# Tools
# 1. FOOB Ticket快速指南 (For EC2)
# 1.1 步骤
# a) 什么场景需要提FOOB？
# 新增的需求，如客户迁移新的workload，workload突增（6/18，11/11等），客户计划的机型升级（例如C4->C5， x86→Gravition) , Region切换等
# 有些特殊机型如GPU/Inf1实例，U型实例，可提前去看下Baywatch现在的剩余资源情况。
# 另外全球高端GPU资源很紧张，P4/P5 机型的申请，除了要提FOOB，还需要额外流程。见1.3 P4/P5附加流程
# b) 提前多久时间？
# 需要提前8周提交。建议先去baywatch查看一下可用的capacity是否有剩余，如果free slots较多，则fullfill时间会较短些，如果slots很少，则可能需要涉及采购新硬件, 需要预留足够的buffer时间。
# c) FOOB ticket 提交模板
# 需求类型 quicklink 相应SLA 提交时请填写自己base地对应的location，例如您base在PEK17，就填PEK17
# 普通EC2需求（包括GPU） https://t.corp.amazon.com/create/templates/a55f20c1-8bda-447d-86b4-5172493fa7a0 72小时（Sea工作日时间）
# High Memory实例 (U-6tb/U-9tb/U-12tb等) https://t.corp.amazon.com/create/templates/8a4fd90d-791d-48c2-88ad-bdfcd75d3f49
# High Memory bare metal实例（u-6tb1.metal, u-9tb1.metal, u-12tb1.metal, u-18tb1.metal, u-24tb1.metal https://t.corp.amazon.com/create/templates/a941800e-939f-4029-b662-376b83bfcb35
# 紧急需求的提交模板（Only for unblock customers in SEV2 situations, not for future planning needs. ） https://t.corp.amazon.com/create/templates/6c98e02f-8886-4b3a-a13d-f151cbeec412 7*24，oncall list
# e) 按对应模板要求填写所需的信息，并且在Ticket里附上 MaitreD (Ticket模板里也有链接) 申请链接。
# MaitrieD 填写Tips ，注意必须严格按系统要求的格式来填写，否则会提交失败，如Region，AZ，NBD等，千万注意机型别申请错了：https://www.figma.com/proto/KIW7T0o3WyHBV0psCS7RDq/MaitreD-Instruction?node-id=7%3A49&scaling=min-zoom&page-id=0%3A1
#  ！！提醒：Instance Eligibility 选项填写
# “open”，会动态的把NBD之前的已经在run的按需实例数量例如z，跟MatrieD里填写的数量x，累加到一起，然后按（z+x）台算ODCR。
# “taget”，只交付MatrieD里填写的数量x，则只把x台算成ODCR。但是客户启动资源时，需要填入预留ID才能跟ODCR的资源匹配上。
# f) Ticket和MaitrieD里抄送对应的GTMS和PM(chuanxie@)。
# Domain name login 备注
# EC2 Wang Ping/Yao Kai/Cao Xu wapng,yaoks,billcaox,chuanxie Wang Ping( Gravition及其他 )，Yao Kai（amd/i/d系列），Cao Xu （x/u/intel 系列）,
# GPU/Inf1 Brenda Li liyuanb,chuanxie 申请GPU实例
#         ！！注意事项！！：
# 如果申请超过 $500K 或者 3 racks,则需要Sales L8 Director 或者 local business L8 Director的approval（在Ticket中附上approval邮件截图即可）。
# 即使FOOB申请被capacity team approved了，仍然有一定的风险会延迟交付 “While Capacity Planning does its best to use forecasts and levers to deliver on requests, we cannot make any 'guarantees' on delivering capacity on a future date.”
# 请保持关注提交的Ticket，并及时响应处理人员提出的question。
# 再三检查MatrieD的信息是否填写正确，如instance type，AZ， NBD，Instance Eligibility等
# Capacity预留confirm之后，请提醒客户在Need By Date之前在后台接受，否则资源会被回收。并在Ticket中回复客户是否接受，Close the Loop。
# 1.2 常见问题
# 1）ODCR预留实例怎么计费？
# 只要交付到客户账户里，无论是否预留实例是否运行，都按等同的按需费率计费。如果客户没有使用预留，将在客户的EC2 账单中显示为未使用的预留。如果客户运行的实例属性与预留匹配，则客户只需要为该实例付费，不需要为预留付费。
# 2）ODCR交付的实例怎么享受RI/Savings Plan计费折扣？
# Savings Plans 和区域RI实例的账单折扣适用于ODCR。AWS 自动将这些折扣应用于具有匹配属性的容量预留, 客户只要购买与ODCR 实例相同的Regional RI 或者Savings Plan，就能享受到对应的计费折扣。查看更多
# 3）需求需要更改怎么办？
# 在客户Accpet之前，请及时在Ticket里面提出更改需求。
# 4）怎么看现有的Capacity？
# 使用https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer
# Tips：通常情况下使用默认值搜索即可
# 5）怎么看FOOB 审批状态？
# 打开申请的matried链接，看status字段，如果仍然是Pending Approval，则说明FOOB后台还没有批复，如果是Approve，应该是running等其他状态。
# 6）怎么看资源分配是否有risk？
# FOOB的机制并不能百分百保证资源到位，如果池子剩余资源较少的情况下，可能会延迟交付或者部分交付，可以在Matried中查看allocation status这个字段。这个字段不是默认展示，第一次开启时需要点击做上的设置按钮，打开这个字段。
# AllocationStatus（每15分钟更新一次） Description
# NOT_ALLOCATING (previous unknown) status. Used for if reservation has just been made
# ON_TRACK When the reservation is allocating just right/当前预留正好合适
# AHEAD_OF_SCHEDULE When there is a surplus in what the current allocation holds/当前分配有盈余时
# BEHIND_OF_SCHEDULE When there is a deficit in allocation/当分配不够
# 1.3 P4/P5 Instance 附加流程
# 1. https://approvals.amazon.com/Template/Details/110748 根据这个模板填写您负责的用户的相关信息，并且清楚的描述用户的相关需求
# 2. 在上述链接中贴上的你的FOOB Ticket Link 和 MaitreD Ticket Link
# 3. 提交请求，然后等待各级负责人人员审批
# 1.4 其他常用链接：
# 完整培训视频：https://broadcast.amazon.com/videos/564991
# Baywatch查看当前capacity:https://ec2-baywatch-prod-iad.iad.proxy.amazon.com/pages/poolViewer
# Urgent 需求查看oncall: https://oncall.corp.amazon.com/#/view/ec2-capacity-delegates/schedule?aliases=
# Runbook Wiki：https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/
# HM virts runbook https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/#HHighMemoryVirtualizedCapacity28[…]xlargethroughu-12tb1.112xlarge29
# HM bare metal runbook: https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/#HHighMemoryCapacity28u-6tb1.metalthroughu-24tb1.metal2
# Tags: [+]
# Comments (1)
# Attachments (14)
# History
# Information
# jackyqin Jan 13, 2023 02:33 AM UTC
# good materials
# Add comment
# chuanxie says:
# Comment
# Cancel

# %%
driver.quit()
