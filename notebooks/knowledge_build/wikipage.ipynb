# %% [markdown]
# ## Using Seleium to crawl website directly

# %%
# !pip install -U selenium

# %%
from __future__ import annotations
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from typing import Any, Dict, List, Optional
from pydantic import BaseModel,Extra
from datetime import datetime
from selenium.common import exceptions  
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import re

# %%
# Using googal Chrome
options = Options()

options.add_argument("--headless=new") #running in headless mode
driver = webdriver.Chrome(options=options)

#Using firefox 
# options = webdriver.FirefoxOptions()
# driver = webdriver.Firefox(options=options)

# %%
import re
import os, json
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

    


class CrawlerWorkder(BaseModel):
    url_map:Dict[str,int]   ## {'url':depth}
    url_processed:Dict[str,int] = {}
    driver:Any
    max_depth:int = 1 
    content:List[Any] = []
    save_path:str = 'temp_webcontent/'
    prefix:str = None
    body_id:str
    extract_wiki_href:bool = False
    offset:int = 10
    url_validate_callback: Optional[Any] = None
    class Config:
        """Configuration for this pydantic object."""
        extra = Extra.forbid


    def _savefile(self):
        self.save_path = self.save_path.rstrip('/')
        os.makedirs(os.path.dirname(f'{self.save_path}/{self.prefix}/'), exist_ok=True)
        str_date = datetime.now().strftime("%Y-%m-%d-%H:%M:%S") 
        with open(f'{self.save_path}/{self.prefix}/file-{str_date}.wiki.json','w') as f:
            f.write(json.dumps(self.content,ensure_ascii=False))


    ## open wiki page in source code mode, to parse hrefs
    def _find_hrefs(self,url:str) -> List[Any]:
        suffix = '/WebHome?viewer=code'
        driver.get(url+suffix)
        current_hrefs = []
        try:
            main_container = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.ID, self.body_id)))
        except exceptions.TimeoutException as e:
            print (f"{url} error: timeout, please check the div ID, or network connection")
            return current_hrefs
        if not main_container:
            return current_hrefs
        text = main_container.text
        it = re.finditer(r'\[\[([^\]]+)>>((url:)?https?:\/\/[^\]]+)\]\]',text,re.M)
        p = re.compile(r'(\s)+')
        for match in it: 
            a,b = match.span()
            offset_index = 0 if a - self.offset < 0 else a - self.offset
            # print(text[offset_index:a])
            key = re.sub(r'(.*)]]','',text[offset_index:a])

            # excluded case such as: [[ >>https://ec2-maitre-d-prod-iad.iad.proxy.amazon.com/]]
            if not p.match(match.group(1)):
                current_hrefs.append([key,match.group(1),match.group(2)])
        return current_hrefs
        

    def _call(self,url:str,current_depth:int) ->List [List[Any],Dict[str,int]]:
        """crawl website infor"""
        # text = ['Purpose','Region Build Automation Framework','1 - Complete Prerequisites Guide']
        # url_map = {'https://w.amazon.com/bin/view/AWSRegionBuildEngineering/RIP/FAQ':current_depth+1}
        text = []
        current_url_map = {}
        print(f'processing:{url}   depth:{current_depth}')
        self.url_processed[url] = current_depth
        driver.get(url)
        # driver.implicitly_wait(1)
        try:
            main_container = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.ID, self.body_id)))
        except exceptions.TimeoutException as e:
            print (f"{url} error: timeout, please check the div ID, or network connection")
            return text,current_url_map
        # main_container = driver.find_element(By.ID, self.body_id)
        if not main_container:
            return text,current_url_map
        origintext = main_container.text
        ##获取下一级的链接
        links = main_container.find_elements(By.TAG_NAME,'a')
        for link in links:
            ## 跳过空的链接
            # try: 
            #     if not link.text:
            #         continue
            # except exceptions.StaleElementReferenceException as e:
            #     print(e)
            #     continue
            try: 
                href = link.get_attribute('href')
            except exceptions.StaleElementReferenceException as e:
                print(e)
                continue
            if not href:
                continue
            ##检查url
            if self.url_validate_callback:
                if not self.url_validate_callback(href):
                    continue
            
            ##检查是否已经存在
            if href not in self.url_map:
                current_url_map[href]=current_depth+1
         
        ## 提取wiki中的链接，转成md格式
        if self.extract_wiki_href:
            current_hrefs = self._find_hrefs(url)
            for a,b,c in current_hrefs:
                c = c.replace('url:','')
                if origintext.find(f'{a}{b}'):
                    origintext = origintext.replace(f'{a}{b}',f'{a}[{b}]({c})',1)
                    # print (f'{a}{b} ==> {a}[{b}]({c})')
        text.append(origintext) 
        
        return text,current_url_map

    def destroy(self):
        print('quite driver')
        self.driver.quit()

    def start(self) ->List[Any]:
        self.prefix = datetime.now().strftime("%Y-%m-%d-%H-%M-%S") 
        while 1:
            if len(self.url_map) == 0:
                break
            url, depth = self.url_map.popitem()
            url = url.rstrip('/')
            if url in self.url_processed:
                continue
            # print(self.url_map)
            ##如果不超过最大depth则抓取
            if depth <= self.max_depth: 
                text,new_url_map = self._call(url,depth)
                if len(text):
                    self.content.append({url:text})
                #检查url是否重复
                if url in new_url_map:
                    del new_url_map[url]
                #合并新的
                self.url_map = {**self.url_map,**new_url_map}
            self._savefile()
        print(f'processed urls:{self.url_processed}')
        return self.content

# %%
def validate_wiki_url(url):
    # pattern = re.compile(r'^https?://(?:www\.)?[a-zA-Z0-9-]+\.[a-zA-Z]{2,}(?:/[^\s]*)?$')
    pattern = re.compile(r'^https://w(iki)?.amazon.com/bin/view(?:/[^\s#]*)?$')
    matched  = re.match(pattern, url) 
    if not matched:
        return False 
    ## exclude ticket
    elif url.startswith('https://t.corp.amazon.com'):
        return False
    elif url.find('WebHome') > -1:
        return False
    elif url.find('/?viewer') > -1:
        return False
    elif url.find('/?xpage') > -1:
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/Main',url,re.I):
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/null',url,re.I):
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/KnowledgeTech',url,re.I):
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/WikiManager',url,re.I): 
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/AmazonWiki/Wiki/Help',url,re.I): 
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/XWiki',url,re.I): 
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/Users/',url,re.I): 
        return False
    elif re.match(r'https://w(iki)?.amazon.com/bin/view/Bindles/',url,re.I): 
        return False
    return True

# %%
# print(validate_url('https://w.amazon.com/bin/create/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance'))
# print(validate_url('https://w.amazon.com/bin/view/RegionBuildAutomation/FAQ'))
# print(validate_url('https://wiki.amazon.com/bin/viewrev/RegionBuildAutomation/FAQ/WebHome?viewer=code&rev=33.1'))
# print(validate_wiki_url('https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?viewer=history'))
# print(validate_wiki_url('https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance/?xpage=pdfoptions&qs='))

# %%
# input_url = {'https://w.amazon.com/bin/view/AWS_GCR_GTMS/ServiceLaunch/FOOBguidance':0}
# input_url = {'https://wiki.amazon.com/bin/view/RegionBuildAutomation/FAQ':0}
input_url = {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook':0}
cwoker = CrawlerWorkder(url_map=input_url,
                        driver=driver,
                        max_depth=1,
                        url_validate_callback=validate_wiki_url,
                        body_id='mainContentArea',
                        extract_wiki_href=True
                        )

# %%
content = cwoker.start()
# Out:
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook   depth:0
# processing:https://w.amazon.com/bin/view/EC2-MVP/Engagement   depth:1
# processing:https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance   depth:1
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning   depth:1
# processing:https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning   depth:1
# processing:https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD   depth:1
# processing:https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals   depth:1
# processing:https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr   depth:1
# processing:https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide   depth:1
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR   depth:1
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources   depth:1
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native   depth:1
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning   depth:1
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/MaitreD_Quick_Reference   depth:1
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Baywatch_User_Guide   depth:1
# processing:https://w.amazon.com/bin/view/EC2_capacity_faqs   depth:1
# processing:https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group   depth:1
# processed urls:{'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook': 0, 'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1, 'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning': 1, 'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD': 1, 'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr': 1, 'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/MaitreD_Quick_Reference': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Baywatch_User_Guide': 1, 'https://w.amazon.com/bin/view/EC2_capacity_faqs': 1, 'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group': 1}

# %%
cwoker.url_processed
# Out:
# {'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook': 0,
#  'https://w.amazon.com/bin/view/EC2-MVP/Engagement': 1,
#  'https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance': 1,
#  'https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning': 1,
#  'https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning': 1,
#  'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD': 1,
#  'https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals': 1,
#  'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr': 1,
#  'https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide': 1,
#  'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR': 1,
#  'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources': 1,
#  'https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native': 1,
#  'https://w.amazon.com/bin/view/EC2_Capacity_Planning/AWS_Internal_Planning': 1,
#  'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/MaitreD_Quick_Reference': 1,
#  'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Baywatch_User_Guide': 1,
#  'https://w.amazon.com/bin/view/EC2_capacity_faqs': 1,
#  'https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group': 1}

# %%
driver.quit()

# %% [markdown]
# ### 估算文档切分token

# %%
from langchain.text_splitter import CharacterTextSplitter,RecursiveCharacterTextSplitter
import tiktoken
def num_tokens_from_string(string: str) -> int:
    """Returns the number of tokens in a text string."""
    # encoding = tiktoken.get_encoding(encoding_name)
    encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
doc = '/Users/chuanxie/Downloads/datalake/web/myapp/private-llm-qa-bot/docs/Foobquickguide.wiki' ##FOOB Runbook 
doc = '/Users/chuanxie/Downloads/datalake/web/myapp/private-llm-qa-bot/docs/ec2capacityrunbook.wiki'
# doc = 'file-2023-08-23-17:17:02.wiki' ## RBA FAQ
with open(doc,'r') as f:
    content = f.read()
content_json = json.loads(content)

# %%
text_splitter = RecursiveCharacterTextSplitter(        
        chunk_size = 500,
        chunk_overlap  = 100,
        length_function = len,
)
texts = []
for page in content_json:
    for url,p in page.items():
        if len(p):
            print(f'page:{url}, size: {len(p[0])}')
            chunks = text_splitter.split_text(p[0])
            texts+=chunks
# Out:
# page:https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook, size: 16720
# page:https://w.amazon.com/bin/view/EC2-MVP/Engagement, size: 6975
# page:https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance, size: 37408
# page:https://w.amazon.com/bin/view/EC2_Capacity_Planning_-_External_Capacity_Runbook/MVP_Planning, size: 15744
# page:https://w.amazon.com/bin/view/EC2/EBS/Product_Management/DemandPlanning, size: 17973
# page:https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD, size: 1286
# page:https://w.amazon.com/bin/view/AWS/Teams/Core_Services/EC2_Capacity_Escalation_Approvals, size: 8847
# page:https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/LaunchAnnouncements/targetedOdcr, size: 4376
# page:https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources/AWS-Assisted_CR, size: 20115
# page:https://w.amazon.com/bin/view/EC2_Capacity_Planning/Customer_Planning_Group/Customer_Planning_Resources, size: 748
# page:https://w.amazon.com/bin/view/EC2_Capacity_Planning/CDO_Native, size: 10958

# %%
len(texts)
# Out:
# 400

# %%
line = ''.join(['-']*150)
for text in texts:
    print(f'--tokens:{num_tokens_from_string(text)}-{line}')
    print(f'{text}\n\n')
# Out:
# --tokens:85-------------------------------------------------------------------------------------------------------------------------------------------------------
# External Capacity Runbook
# View Source
# Tools
# <
# Customer Planning Group
# External Capacity Planning Runbook
# CPG Home FAQs
# External Capacity Planning Runbook AWS Internal Capacity Planning Runbook CDO Native Capacity Planning Runbook Internal Team Resources
# Objective
# The purpose of this Runbook is to provide a step by step operating guideline for TAM or the account teams to request additional EC2 capacity across any AZ globally for AWS customers.
#
#
# --tokens:90-------------------------------------------------------------------------------------------------------------------------------------------------------
# CCX Customer Planning does not respond to Sev2 tickets outside of Seattle working hours. If you have a capacity challenge that requires immediate assistance off hours, please escalate to the Capacity Delegates (AWS>EC2>Customer Capacity Issue>EC2 Capacity Delegates) for 24/7 emergency support. If your issue can wait for a resolution during the Seattle workday, your Customer Planner will be available to help you resolve the problem.
# Overview
#
#
# --tokens:65-------------------------------------------------------------------------------------------------------------------------------------------------------
# Overview
# AWS uses historical usage data, organic demand signals, and manual complements to our forecast in order to anticipate customer requirements and ensure that we provision enough capacity. We are constantly working to expand the capacity within our data centers, the physical capacity of our availability zones and regions, and our global geographical coverage (new regions).
#
#
# --tokens:73-------------------------------------------------------------------------------------------------------------------------------------------------------
# EC2 Capacity Planning assists in preparing the future capacity needs of external customers, adds them into AWS demand signals through the FOOB process, and then manages the delivery of capacity to the customer account through AWS Assisted CR. TAMs and SAs should proactively work with their customers to understand future capacity needs and engage EC2 Capacity Planning following the below process.
#
#
# --tokens:1-------------------------------------------------------------------------------------------------------------------------------------------------------
# Definitions
#
#
# --tokens:102-------------------------------------------------------------------------------------------------------------------------------------------------------
# FOOB: FOOB stands for "Future Out Of Band" signal. FOOBs are used to communicate to EC2 that there is an emergent or spiky customer demand event that is not predicted by the past behavior of the customer. The ultimate goal of submitting FOOBs is to reduce the likelihood that customers will find insufficient capacity to support these exceptional events. The EC2 Organic Forecast leverages historical, seasonal and recent trends to recommend run-rate growth of EC2 capacity across customer segments.
#
#
# --tokens:62-------------------------------------------------------------------------------------------------------------------------------------------------------
# seasonal and recent trends to recommend run-rate growth of EC2 capacity across customer segments. We recommend submitting a FOOB (Via the MaitreD tool - see below) at least 7-8 weeks in advance of the customer requirement. The most frequent use cases requiring FOOBs include:
#
#
# --tokens:82-------------------------------------------------------------------------------------------------------------------------------------------------------
# Launching a new workload in an existing or a new AZ
# Demand events outside of the historical demand pattern and seasonality of the business - This includes spikes as well as decreases or 'scale-downs'
# Planned changes in the type of EC2 instance type used (e.g migrating from C5 to C6G)
# Mid to large scale migrations (from On Prem to AWS or between regions or Server Types)
#
#
# --tokens:69-------------------------------------------------------------------------------------------------------------------------------------------------------
# Mid to large scale migrations (from On Prem to AWS or between regions or Server Types)
# MaitreD: MaitreD is the user interface for CRS (capacity reservation system) where capacity requirements are submitted to generate a FOOB and subsequently collect, reserve, and transfer specified capacity to a customer account through AWS Assisted CR.
#
#
# --tokens:139-------------------------------------------------------------------------------------------------------------------------------------------------------
# MaitreD can be accessed via this [link](https://ec2-maitre-d-prod-iad.iad.proxy.amazon.com/). Note, many teams already have MaitreD access, so please take a look at your team [here ](https://permissions.amazon.com/a/team/Maitre%20D%20-%20Users)or try MaitreD first before requesting the access. In case you don't have the access, request it by following the steps on 'Getting Access' section [here](https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/). See MaitreD user guide
#
#
# --tokens:92-------------------------------------------------------------------------------------------------------------------------------------------------------
# [here](https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/). See MaitreD user guide [here](https://w.amazon.com/bin/view/EC2/DemandShaping/MaitreD/UserGuide/). If you are looking for the MaitreD access to others' submission, please ask the requester to add you onto the 'User Access' list of his/her submission.
#
#
# --tokens:94-------------------------------------------------------------------------------------------------------------------------------------------------------
# AWS Assisted Capacity Reservation: Capacity requested in MaitreD is delivered directly to customers' accounts via AWS-Assisted CR. Customers will be notified through their console and Personal Health Dashboard of upcoming capacity requests made though MaitreD and MUST 'accept' these reservations in either their Console or SKD/CLI before the Need By Date to receive the Capacity Reservation. Once a request is approved by Capacity Planning, the Incremental Requested Quantity will be visible as a
#
#
# --tokens:64-------------------------------------------------------------------------------------------------------------------------------------------------------
# a request is approved by Capacity Planning, the Incremental Requested Quantity will be visible as a tag value for each CR under the ‘aws:ec2capacityreservation:incrementalRequestedQuantity’ system key. For first time delivery with AWS-Assisted CR, please follow the User Guide for setup instructions and customer requirements.
#
#
# --tokens:27-------------------------------------------------------------------------------------------------------------------------------------------------------
# Auto-Acceptance for all future, requested ODCRs can be toggled on by region through either the Console or CLI.
#
#
# --tokens:100-------------------------------------------------------------------------------------------------------------------------------------------------------
# Once the AWS-Assisted CR delivers to the customer account on the specified Need By Date/Time, it becomes an active On-Demand Capacity Reservation (ODCR). The size of the ODCR to be delivered will be the sum of the capacity requested in MaitreD. The customer will be billed 24/7 for both used and unused capacity under the ODCR from when it’s delivered on the need by date/time until they cancel the reservation and terminate instances. More details on
#
#
# --tokens:38-------------------------------------------------------------------------------------------------------------------------------------------------------
# on the need by date/time until they cancel the reservation and terminate instances. More details on https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/ec2-capacity-reservations.html
#
#
# --tokens:60-------------------------------------------------------------------------------------------------------------------------------------------------------
# Please note that the capacity requested in the ticket and submitted in MaitreD should be the incremental quantity needed, not the total capacity footprint the customer wants.
# As of 10/4/2021, MaitreD' can now deliver Open or Targeted ODCRS (documentation).
#
#
# --tokens:95-------------------------------------------------------------------------------------------------------------------------------------------------------
# Dedicated Hosts (DH). NOTE!!! Assisted ODCR is not available with this product. On the specified need-by-date and time, the instances will automatically be placed into the customer's account and billing will commence. There will NOT be an acceptance notification sent to the customer's PHD. You will need to acknowledge the understanding of this nuance in the ticket before these are approved as evidence the customer understands the billing implications associated with this product and delivery via
#
#
# --tokens:55-------------------------------------------------------------------------------------------------------------------------------------------------------
# the customer understands the billing implications associated with this product and delivery via MaitreD'. Confirmation that the customer acknowledges the size of the Dedicated Host that will be delivered, billing method, and reservation management responsibilities must be attached to the ticket before the capacity reservation process can begin.
#
#
# --tokens:90-------------------------------------------------------------------------------------------------------------------------------------------------------
# Runbook
# For general compute instances: open a ticket (Commercial Regions or ADC (MVP/GovCloud) Regions) with EC2 CCX and fill in the requested information. Include your customer name in the ticket title of the TT. There should be one ticket submitted per project, but multiple need by dates, family types, account IDs, and AZs can be included in a single request if for the same program/event. Please note:
#
#
# --tokens:97-------------------------------------------------------------------------------------------------------------------------------------------------------
# For High Memory instances (U-Series virtual machine and bare metals), please refer to the sections below: High Memory Virtualized Capacity, High Memory Bare Metal.
# For Machine Learning requests (P4D, P4DE, P5, TRN1/N):
# Step 1: Please request leadership approvals using this template: https://approvals.amazon.com/Template/Details/110748. Details on this step can be found in this wiki: EC2 Capacity Escalation Approvals
#
#
# --tokens:115-------------------------------------------------------------------------------------------------------------------------------------------------------
# Step 2: Once approvals are obtained, please create a ticket using this new template: ML FOOB Ticket .
# Build your capacity request in [MaitreD’](https://ec2-maitre-d-prod-iad.iad.proxy.amazon.com/batchCreate?noTrigger=true) and paste the link to the completed request in the ticket from Step 1 (MaitreD’ User Guide). Include your customer name in the “Notes” block above the main body of the reservation. Add your alias to the “Assignee(s)” block.
#
#
# --tokens:94-------------------------------------------------------------------------------------------------------------------------------------------------------
# If you are having issues with MaitreD’, please cut a ticket (MaitreD' Issues) or reach out to the PAO On-call. For more information, see the Maitre D' Overview page.
# An EC2 CCX customer planner will analyze the supportability and provide the recommendations against your request to help build a supportable plan that has a high fulfillment probability. This supportability update and confirmation are tracked via your capacity request TT.
#
#
# --tokens:65-------------------------------------------------------------------------------------------------------------------------------------------------------
# Once you as proxy of your customer agreed with the supportable plan, your planner may request Sales/Business/Financial approvals per Amazon S&TP by requesting you to obtain Sales L8 approval on the TT. CCX planner will follow up the EC2 Business and EC2 Financial approval after the Sales L8 approval obtained.
#
#
# --tokens:48-------------------------------------------------------------------------------------------------------------------------------------------------------
# Once CCX planner finishes all the approval, the MaitreD’ request will be approved and the capacity plan signal will be added to the EC2 Production Forecast to drive server orders to support your customer's capacity requirements.
# Additional Notes:
#
#
# --tokens:124-------------------------------------------------------------------------------------------------------------------------------------------------------
# Maitre'D can be accessed via this link. Note, many teams already have MaireD access, so please take a look at your team here or try MaitreD first before requesting the acess. In case you don't have the access, request it by following the steps on 'Getting Access' section here. See MaitreD user guide here https://w.amazon.com/index.php/EC2/DemandShaping/MaitreD/UserGuide  If you are looking for the MaitreD access to others' submission. Please ask the requester to add you onto the 'User Access'
#
#
# --tokens:50-------------------------------------------------------------------------------------------------------------------------------------------------------
# the MaitreD access to others' submission. Please ask the requester to add you onto the 'User Access' list of his/her submission. Additional MaitreD update is required if you need to change the approved plan (capacity request)
#
#
# --tokens:92-------------------------------------------------------------------------------------------------------------------------------------------------------
# Please raise one TT for one customer, see the TT here.
# If your customer has significant EBS requirements along with their EC2 scaling request please follow the EBS specific process here.
# AWS Infrastructure teams have a 7-8 weeks lead time to land more capacity in the data centers because of the various steps involved (new rack ordering, rack manufacturing, shipping, testing etc.) Please allow EC2 capacity planning enough lead time to process and fulfill your request.
#
#
# --tokens:101-------------------------------------------------------------------------------------------------------------------------------------------------------
# If you are supporting a Global Financial Services Customer under Frank Fallon please make sure to also complete the steps here (https://w.amazon.com/bin/view/FinServSATeam/GFSCCMT/?#HOpening2Fupdatinganewcapacityrequest)
# To increase the limit on the desired instance, please cut the TT to (AWS > CS - Billing and Accounts > Limit Increase)
# Capacity requests for ADC regions (GovCloud, MVP) are planned separately than Commercial regions. Guidance can be found here.
#
#
# --tokens:55-------------------------------------------------------------------------------------------------------------------------------------------------------
# If it's a RI renewal request - Please clarify both the current capacity of the customer and the incremental ask as this request will be processed differently from a standard incremental FOOB request.
# For instance platform technical questions or roadmap plans, reach the instance PM directly: PM Ownership
#
#
# --tokens:90-------------------------------------------------------------------------------------------------------------------------------------------------------
# To get the right operation system code (Usage Operation) for MaitreD submissions, check the mapping between product_description and billing_product (https://w.amazon.com/index.php/EC2/DropletMeteringService/BillingProducts.
# To get the TAM Training for EC2 capacity and other support around EC2 capacity within TAM Org, cut TT to CCMT ( AWS > EC2 Customer Capacity Management > CCMT >aws-ccmt)
#
#
# --tokens:122-------------------------------------------------------------------------------------------------------------------------------------------------------
# To get more info and processes about EC2 Finance, check here: https://w.amazon.com/bin/view/AWS_Finance/AWS_Services_Finance/EC2_Finance/EC2_Capacity_Finance/
# Given one yellow badge contractor team in CN, EC2 capacity broadcast in mandarin addresses the local requests: https://broadcast.amazon.com/videos/143892g
# To search resources for getting work done in the the ADC MVP spaces for EC2, EBS, ELB, and ECS, check here: https://w.amazon.com/bin/view/EC2-MVP/Engagement
#
#
# --tokens:95-------------------------------------------------------------------------------------------------------------------------------------------------------
# High Memory Virtualized Capacity (u-3tb1.56xlarge through u-24tb1.112xlarge)
# For high memory virtualized instance requests, u-3tb1.56xlarge through u-24tb1.112xlarge, please follow the below guidelines to help streamline the planning processes.
# To initiate a capacity request, please have L8+ Sales approval ready prior to opening the ticket if your request is  >= 2 instances.
#
#
# --tokens:101-------------------------------------------------------------------------------------------------------------------------------------------------------
# Please open a ticket and complete the needed information using the following template:https://t.corp.amazon.com/create/templates/8a4fd90d-791d-48c2-88ad-bdfcd75d3f49 or use CTI: AWS / EC2 Capacity Planning / EC2 High Memory FOOB Requests and select the template for Virtualized requests. Please note this is the CTI for High Memory planning and it is different from the CTI for other instance types.
#
#
# --tokens:87-------------------------------------------------------------------------------------------------------------------------------------------------------
# Submit the request in MaitreD here: https://ec2-maitre-d-prod-iad.iad.proxy.amazon.com/batchCreate?noTrigger=true. Please include the link to the MaitreD batch on the ticket.
# Please note due to the complexity involved in High Memory capacity planning, we do not handle sev2/2.5 for High Memory. It cannot be handled by on-call either.
#
#
# --tokens:100-------------------------------------------------------------------------------------------------------------------------------------------------------
# NOTE: Baywatch is not a reliable source of truth for High Memory capacity availability assessments.  Coordinate with Rack Planners to have a capacity assessment conducted and learn timelines and/or to discuss options.  Lead time to land new capacity is 10 weeks.  Where possible, existing capacity will be used to satisfy demand sooner than that.
# Dedicated hosts delivery for High memory Virtualized Capacity (u-3tb1.56xlarge through u-24tb1.112xlarge)
#
#
# --tokens:95-------------------------------------------------------------------------------------------------------------------------------------------------------
# For dedicated hosts high memory virtualized instance requests, u-3tb1.56xlarge through u-24tb1.112xlarge, please follow the below guidelines to help streamline the planning processes. Best practice would be to confirm with a Solution Architect/SAP Proserve team if dedicated hosts delivery are needed for Virtualized capacity for the customer's specific use case.
# To initiate a capacity request, please have L8+ Sales approval ready prior to opening the ticket.
#
#
# --tokens:121-------------------------------------------------------------------------------------------------------------------------------------------------------
# To initiate a capacity request, please have L8+ Sales approval ready prior to opening the ticket.
# Please open a ticket and complete the needed information using the following template:https://t.corp.amazon.com/create/templates/8a4fd90d-791d-48c2-88ad-bdfcd75d3f49 or use CTI: AWS / EC2 Capacity Planning / EC2 High Memory FOOB Requests and select the template for Virtualized requests. Please note this is the CTI for High Memory planning and it is different from the CTI for other instance types.
#
#
# --tokens:107-------------------------------------------------------------------------------------------------------------------------------------------------------
# It is compulsory for the requester to submit a MaitreD, in the "Notes" field please enter the customer name and the phrase "DH" or "Dedicated Host". Set the Reservation Type as "Dedicated Host", and Transfer Strategy as "Auto_Full". Please attach the MaitreD link in the ticket.
# Please note due to the complexity involved in High Memory capacity planning, we do not handle sev2/2.5 for High Memory. It cannot be handled by on-call either.
#
#
# --tokens:67-------------------------------------------------------------------------------------------------------------------------------------------------------
# NOTE: Baywatch is not a reliable source of truth for High Memory capacity availability assessments.  Coordinate with Rack Planners to have a capacity assessment conducted and learn timelines and/or to discuss options.  Lead time to land new capacity is 10 weeks.  Where possible, existing capacity will be used to satisfy demand sooner than that.
#
#
# --tokens:118-------------------------------------------------------------------------------------------------------------------------------------------------------
# External facing document on how to launch onto dedicated hosts after delivery.(https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/how-dedicated-hosts-work.html#dedicated-hosts-allocating)
# High Memory Bare Metal Capacity (u-6tb1.metal through u-24tb1.metal)
# For high memory instance requests, u-6tb1.metal through u-24tb1.metal, please follow the below guidelines to help streamline the planning processes.
# To initiate a capacity request, please have L8+ approval ready prior to opening the ticket.
#
#
# --tokens:81-------------------------------------------------------------------------------------------------------------------------------------------------------
# To initiate a capacity request, please have L8+ approval ready prior to opening the ticket.
# Please open a ticket and complete the needed information using the following Quicklink: https://tiny.amazon.com/a0zdbd96/tcorpamazcreatempa941 or use CTI: AWS / EC2 Capacity Planning / EC2 High Memory FOOB Request and select the template for Metal requests.
#
#
# --tokens:102-------------------------------------------------------------------------------------------------------------------------------------------------------
# It is compulsory for the requester to submit a MaitreD, in the "Notes" field please enter the customer name and the phrase "DH" or "Dedicated Host". Set the Reservation Type as "Internal Guarantee", and Transfer Strategy as "Manual". Please attach the MaitreD link in the ticket. Dedicated hosts will not be delivered via MaitreD it will be a tracking mechanism only. We will cut a ticket for the actual host allocation and provide a link to track.
#
#
# --tokens:110-------------------------------------------------------------------------------------------------------------------------------------------------------
# Complete customer authorization form and attach it to the FOOB ticket. Download the form here - https://amazon.awsapps.com/workdocs/index.html#/document/5aefc661d8d43ce9174e0bfdcb8e4e751491b4a451a83fce4c849e4ed9cea2a9
# Please note due to the complexity involved in High Memory capacity planning, we do not handle sev2/2.5 for High Memory. It cannot be handled by on-call either.
#
#
# --tokens:67-------------------------------------------------------------------------------------------------------------------------------------------------------
# NOTE: Baywatch is not a reliable source of truth for High Memory capacity availability assessments.  Coordinate with Rack Planners to have a capacity assessment conducted and learn timelines and/or to discuss options.  Lead time to land new capacity is 12 weeks.  Where possible, existing capacity will be used to satisfy demand sooner than that.
#
#
# --tokens:121-------------------------------------------------------------------------------------------------------------------------------------------------------
# NOTE: Once a High Memory .metal host is allocated to a customer, the reservation can only be cancelled via this process (not customer self-service): https://w.amazon.com/index.php/EC2/DedicatedHosts/Reservations/#Dedicated_Host_Reservation_Cancellations
# Mac1 / Mac2 Capacity (mac1.metal and mac2.metal)
# Please cut the FOOB ticket as you normally would. While creating a Maitre D select 'Dedicated Host' as the reservation type, as EC2 can only deliver Mac instances as Dedicated Hosts.
#
#
# --tokens:138-------------------------------------------------------------------------------------------------------------------------------------------------------
# EC2-MVPEngagement
# View Source
# Tools
# ADC2S
# ADC2S Services
# About
# Change Management
# Operations
# Dashboards
# Development MVP Warden Website (MW2)
# ADC2S is Now an Org of Many Teams
# It's an emergency (Sev 2) and I need help from ADC2S
# It's not an emergency (Sev 3-5) and I need help from ADC2S
# Limit Increases
# NRE Engagement
# Switches not building properly
# Blackfoot Issues
# FullCD / ADC Allowlisting Requests
# ADC2S West Teams Reporting to dbrown@ and deesingh@
# ADC Engagement FAQ's
#
#
# --tokens:123-------------------------------------------------------------------------------------------------------------------------------------------------------
# ADC2S West Teams Reporting to dbrown@ and deesingh@
# ADC Engagement FAQ's
# Who do I engage for support?
# All Other Issues
# This page points you to the necessary resources for getting work done in the MVP spaces and GovCloud for EC2, EBS, ELB, and ECS.  All of these services are supported by the EC2 MVP team. If you require support for GovCloud (PDT/OSU), please reach out to the commercial service team first and they will escalate to EC2 GovCloud as needed.
# ADC2S is Now an Org of Many Teams
#
#
# --tokens:114-------------------------------------------------------------------------------------------------------------------------------------------------------
# ADC2S is Now an Org of Many Teams
# ADC2S West
# ADC Serverless
# MVP Parks
# Please install our PhoneTool alignment Grease Monkey (GM) script to identify ADC alignments. It provides details of the supporting ADC manager when viewing a PhoneTool profile.
# To locate owners of services, refer to the AWS Pager Engagement List, which lists CTIs, team names and owners of teams. CTIs can be used to identify resolver groups and their owners.
# It's an emergency (Sev 2) and I need help from ADC2S
#
#
# --tokens:143-------------------------------------------------------------------------------------------------------------------------------------------------------
# It's an emergency (Sev 2) and I need help from ADC2S
# Page Us!  If you don't have time to understand which team supports your org (instructions above) just pick any CTI or oncall and page us, we'll be happy to help and redirect.
# If you need help with L7, EBS, ELB, ECS, ECR, VPC Endpoints, Outposts Snapshots or EC2 Capacity
# Paging oncalls directly:
# DCA/APA (AWS-ISO partition):
# ec2-mvp-west-primary:
# page-ec2-mvp-west-primary@
# LCK (AWS-ISOB partition):
# ec2-mvp-west-lck-primary:
#
#
# --tokens:182-------------------------------------------------------------------------------------------------------------------------------------------------------
# ec2-mvp-west-primary:
# page-ec2-mvp-west-primary@
# LCK (AWS-ISOB partition):
# ec2-mvp-west-lck-primary:
# page-ec2-mvp-west-lck-primary@
# GovCloud (PDT/OSU):
# ec2-mvp-west-govcloud:
# page-ec2-mvp-west-govcloud@
# Manager Escalation:
# ec2-mvp-west-manager-oncall:
# page-ec2-mvp-west-manager-oncall@
# CTIs:
# AWS/EC2 MVP/Bastions (Manager: ryanaedw@)
# AWS/EC2 MVP/Heroes (Manager: rohinsha@)
# AWS/EC2 MVP/Mavericks (Manager: gbogart@)
# AWS/EC2 MVP/Padawans (Manager: paulyah@)
# AWS/EC2 MVP/Rangers (Manager: rohinsha@)
#
#
# --tokens:117-------------------------------------------------------------------------------------------------------------------------------------------------------
# AWS/EC2 MVP/Padawans (Manager: paulyah@)
# AWS/EC2 MVP/Rangers (Manager: rohinsha@)
# AWS/EC2 MVP/Bierstadt (Manager: arrinot@)
# If you need help with EC2 Control Plane, EC2 Networking, VPC, VPN, Outposts or TGW
# Paging Oncalls directly:
# DCA/APA:
# mvp-parks-primary:
# page-mvp-parks-primary@
# LCK:
# mvp-parks-lck-primary:
# page-mvp-parks-lck-primary@
#
#
# --tokens:159-------------------------------------------------------------------------------------------------------------------------------------------------------
# mvp-parks-govcloud-primary:
# page-mvp-parks-govcloud-primary@
# CTI: AWS/MVP Parks GovCloud/GovCloud Support
# Resolver Group: MVP Parks GovCloud
# Manager Escalation:
# mvp-parks-manager-oncall:
# page-mvp-parks-manager-oncall@
# CTIs:
# AWS/EC2 MVP/Acadia (Manager: gbarnhil@)
# AWS/EC2 MVP/Biscayne (Manager: wtwang@)
# AWS/EC2 MVP/Denali (Manager: mikeviz@)
# AWS/EC2 MVP/Katmai (Manager: kailasks@)
# AWS/EC2 MVP/Redwood (Manager: kamidon@)
# AWS/EC2 MVP/Yosemite (Manager: rmbowie@)
#
#
# --tokens:111-------------------------------------------------------------------------------------------------------------------------------------------------------
# AWS/EC2 MVP/Redwood (Manager: kamidon@)
# AWS/EC2 MVP/Yosemite (Manager: rmbowie@)
# AWS/EC2 MVP/Olympic (Manager: leasq@)
# It's not an emergency (Sev 3-5) and I need help from ADC2S
# Limit Increases
# Please create a Bubbletea request in the ADC region (not commercial BubbleTea) that the increase is needed in or create a SIM for ADC Consolidated Support Team (CST).
# NRE Engagement
#
#
# --tokens:106-------------------------------------------------------------------------------------------------------------------------------------------------------
# NRE Engagement
# Please cut a ticket answering the following questions to ec2-mvp-ops SIM folder in the classified region you are concerned about:
# Switches not building properly
# Which Fabric is the issue located in, Prod or Substrate?
# Are switches building?
# Are credentials being pushed to the Switches?
# If not, are your errors showing SSL or timeout?
# Is Joshua showing an issues with communicating with EC2-Torpedo?
# If the question isn't above, please provide more detail in the SIM about the issue.
#
#
# --tokens:127-------------------------------------------------------------------------------------------------------------------------------------------------------
# If the question isn't above, please provide more detail in the SIM about the issue.
# Blackfoot Issues
# Is this customer impacting? If so, page our on call:
# DCA/APA:
# mvp-parks-primary:
# page-mvp-parks-primary@
# LCK:
# mvp-parks-lck-primary:
# page-mvp-parks-lck-primary@
# Are the links to the Blackfoot still showing it as on?
# Are you getting paged for a device that’s out of service?
# If the question isn't above, please provide more detail in the SIM about the issue.
# FullCD / ADC Allowlisting Requests
#
#
# --tokens:123-------------------------------------------------------------------------------------------------------------------------------------------------------
# FullCD / ADC Allowlisting Requests
# The current process for ADC FullCD Allowlisting (EC2 ADC Change Management) must be followed and teams need to create SIMs (HERE) to add to this prioritization.
# ADC2S West Teams Reporting to dbrown@ and deesingh@
# Team ADC2S Manager Service Team Leader Engagement Process Links
# Amazon Linux
# Ryan Edwards
# [ info | email ]
# Makho Ngazimbi
# [ info | email ]
# Engagement
# App Mesh
# Otis Arrington
# [ info | email ]
# Carlos Batista
# [ info | email ]
# Engagement
#
#
# --tokens:152-------------------------------------------------------------------------------------------------------------------------------------------------------
# Engagement
# App Mesh
# Otis Arrington
# [ info | email ]
# Carlos Batista
# [ info | email ]
# Engagement
# AWS Autoscaling/Anyscale
# Rohini Shah
# [ info | email ]
# Ramya Sunil
# [ info | email ]
# Engagement
# Cloud Map
# Otis Arrington
# [ info | email ]
# Carlos Batista
# [ info | email ]
# Engagement
# EBS
# Jerry Bogart
# [ info | email ]
# Rajesh Sheth
# [ info | email ]
# Engagement
# EBS SnapShots
# Jerry Bogart
# [ info | email ]
# Ashish Palekar
# [ info | email ]
# Engagement
# EC2 Capacity Lifecycle
# Rohini Shah
# [ info | email ]
#
#
# --tokens:152-------------------------------------------------------------------------------------------------------------------------------------------------------
# Ashish Palekar
# [ info | email ]
# Engagement
# EC2 Capacity Lifecycle
# Rohini Shah
# [ info | email ]
# Jeremy Truelove
# [ info | email ]
# Engagement
# EC2 Fleet Health and Lifecycle
# Paul Yahnig
# [ info | email ]
# Nauman Khan
# [ info | email ]
# Engagement
# EC2 Nitro
# Paul Yahnig
# [ info | email ]
# Supreeth Sheshadri
# [ info | email ]
# Engagement
# EC2 Pricing and Reserved Instances
# Paul Yahnig
# [ info | email ]
# Hans Hesse
# [ info | email ]
# Engagement
# EC2 PrivateLink + Titan
# Rohini Shah
# [ info | email ]
# Brad Zobrist
#
#
# --tokens:145-------------------------------------------------------------------------------------------------------------------------------------------------------
# [ info | email ]
# Engagement
# EC2 PrivateLink + Titan
# Rohini Shah
# [ info | email ]
# Brad Zobrist
# [ info | email ]
# Engagement
# EC2 Commercial
# Ryan Edwards
# [ info | email ]
# Fred Wurden
# [ info | email ]
# Engagement
# Elastic Container Service (ECS)
# Otis Arrington
# [ info | email ]
# Richard Sanders
# [ info | email ]
# Engagement
# Elastic Container Repository (ECR)
# Otis Arrington
# [ info | email ]
# Nick Coult
# [ info | email ]
# Engagement
# Elastic Kubernetes Service (EKS)
# Otis Arrington
# [ info | email ]
# Eswar Bala
#
#
# --tokens:155-------------------------------------------------------------------------------------------------------------------------------------------------------
# Engagement
# Elastic Kubernetes Service (EKS)
# Otis Arrington
# [ info | email ]
# Eswar Bala
# [ info | email ]
# Engagement
# ELB
# Rohini Shah
# [ info | email ]
# Venugopal Manukonda
# [ info | email ]
# Engagement
# Fargate
# Otis Arrington
# [ info | email ]
# Mats Lanner
# [ info | email ]
# Engagement
# Hailstone
# Paul Yahnig
# [ info | email ]
# Elias Theocharis
# [ info | email ]
# Engagement
# Spectre / KaOS Bucharest
# Ryan Edwards
# [ info | email ]
# Adrian Stanciu
# [ info | email ]
# Engagement
# KaOS Dresden
# Ryan Edwards
#
#
# --tokens:124-------------------------------------------------------------------------------------------------------------------------------------------------------
# Ryan Edwards
# [ info | email ]
# Adrian Stanciu
# [ info | email ]
# Engagement
# KaOS Dresden
# Ryan Edwards
# [ info | email ]
# Andreas Stieger
# [ info | email ]
# Engagement
# L7 Load Balancing + Tardigrade
# Rohini Shah
# [ info | email ]
# Yousef Ourabi
# [ info | email ]
# Engagement
# VMIE AWS-114
# Ryan Edwards
# [ info | email ]
# Bhupendra Patni
# [ info | email ]
# Engagement
# ADC Engagement FAQ's
# Who do I engage for support?
#
#
# --tokens:105-------------------------------------------------------------------------------------------------------------------------------------------------------
# Bhupendra Patni
# [ info | email ]
# Engagement
# ADC Engagement FAQ's
# Who do I engage for support?
# Please reference the ADC2S Teams Reporting to dbrown@ section and follow the engagement process link for your organization.
# Where can I provide feedback?
# Please provide feedback to ec2-mvp-managers@
# All Other Issues
# Create a SIM in the EC2 MVP Ops folder HERE with the following information:
# A detailed description
# List the region(s) you need help with
# Your need by date
#
#
# --tokens:54-------------------------------------------------------------------------------------------------------------------------------------------------------
# A detailed description
# List the region(s) you need help with
# Your need by date
# References to any other tickets or MCMs needed to complete the work
# Examples of work that would need a ticket:
# Substrate account creation or troubleshooting
# Rack maintenance request
#
#
# --tokens:113-------------------------------------------------------------------------------------------------------------------------------------------------------
# AWS Finance & Global Business ServicesAWS Services FinanceEC2 FinanceEC2 Capacity Finance
# EC2 Capacity Finance
# Primary Owner ec2-capacity-finance (LDAP)
# Last modified 1 month ago by rkashat.
# View Source Edit Edit Source
# Tools
# Contents
# 1
# 2 EC2 Capacity Finance - Team
# 3 EC2 Capacity Finance - Support for Business and Finance Partners
# 3.1 EC2 Capacity - Guides to Improve Efficiency
# 3.2 Cancelling EC2 Reserved Instances (RI)
# 3.3 FOOBs and FOOB Approvals
#
#
# --tokens:146-------------------------------------------------------------------------------------------------------------------------------------------------------
# 3.2 Cancelling EC2 Reserved Instances (RI)
# 3.3 FOOBs and FOOB Approvals
# 3.4 Capacity Internal Guarantees (IG) Approvals
# 3.5 Utilization
# 3.6 EC2 Costs
# 3.7 Capital Efficiency and Optimization
# 4 EC2 Capacity Finance - Team Processes and Training Reference
# 4.1 New Hire Resources and Team Norms
# 4.2 Capacity Planning OP1/OP2, Hailstone and AWS Prod
# 4.2.1 Hailstone Capacity Planning
# 4.2.2 AWS Prod Capacity Planning
# 4.3 Rack Order Approvals
# 4.4 Test Racks, Development Costs, Retrofits and Risk Buys
#
#
# --tokens:124-------------------------------------------------------------------------------------------------------------------------------------------------------
# 4.3 Rack Order Approvals
# 4.4 Test Racks, Development Costs, Retrofits and Risk Buys
# 4.5 Rack Retirements
# 4.6 OpEx
# 4.7 Stale FOOB Controls
# 4.8 EC2 Capacity Background for Finance
# 4.9 EC2 Capacity Finance Queries
# 1
# 2 EC2 Capacity Finance - Team
# EC2 Capacity Finance Team - Roles and Responsibilities
# Team Name  [C] Name  [D] Responsibility
# Fleet and Capital Planning Zhen Hua Cheryl Zhang
# Coverage of CDO planning for OP1/OP2
#
#
# --tokens:95-------------------------------------------------------------------------------------------------------------------------------------------------------
# Fleet and Capital Planning Zhen Hua Cheryl Zhang
# Coverage of CDO planning for OP1/OP2
# EC2 CapEx planning (including forecast, actuals, variance analysis, bridging commentaries)
# R&O planning and engagement with SFPA
# Review and approval of monthly CDO % split
# Automated CapEx Bridging project
# Yulia Espinosa
# Utilization WBR Oversight
# Metrics definitions and reporting
# Utilization goal tracking and initiatives
#
#
# --tokens:92-------------------------------------------------------------------------------------------------------------------------------------------------------
# Metrics definitions and reporting
# Utilization goal tracking and initiatives
# Overall utilization reporting and build common platform for other cuts of utilization reporting
# Ensure Consistency of reporting systems, single source of truth
# OP planning process lead
# a. Project management of OP cycles
# b. Interaction with ARF for development of planning tools
# Operationalize Engagement model with ARF PM for Finance Dan Pershe
# Luis Bustamante
# Utilization Reporting, goal setting and tracking
#
#
# --tokens:111-------------------------------------------------------------------------------------------------------------------------------------------------------
# Luis Bustamante
# Utilization Reporting, goal setting and tracking
# Controllership: approvals of'
# changes to ARF Configurations including buffers TSU and TSR
# TSU/Online buffer goal setting and tracking
# Leading BI efforts related to Utilization
# Utilization Insights deck
# Manuel Canella
# EC2 CapEx planning (including forecast, actuals, variance analysis, bridging commentaries)
# R&O planning and engagement with SFPA
# Oversight of FOAA Costa Rica Team
# Valeria Aguilar
# Rack order approvals
#
#
# --tokens:85-------------------------------------------------------------------------------------------------------------------------------------------------------
# Oversight of FOAA Costa Rica Team
# Valeria Aguilar
# Rack order approvals
# Usage and CapEx reporting
# Analysis of Regulated Approval rules
# Utilization WBR reporting and support
# New Regions reporting and analysis support
# Sergio Miranda
# Controllership: Future-Out-Of-Band (FOOB) approvals
# Usage Quality Assurance
# New Product Analysis and Insights
# Barrett Rothwell
# New Products
#
#
# --tokens:83-------------------------------------------------------------------------------------------------------------------------------------------------------
# Usage Quality Assurance
# New Product Analysis and Insights
# Barrett Rothwell
# New Products
# Forecasting and Tracking (incl. New Product utilization, improvements in New Products planning process, and continuous planning implementation)
# New Product utilization
# Overall Controllership
# Server rack ordering
# Last Time buy, Risk buy, New product launch footprint
# Finance owner of Regulated Approval project and its expansion
# Test Rack orders weekly review and approvals
#
#
# --tokens:82-------------------------------------------------------------------------------------------------------------------------------------------------------
# Test Rack orders weekly review and approvals
# Finance Owner of Forecast Buffer covering related goal setting, tracking and analysis.
# Quarterly Cone Forecast analysis
# Mohammed Almeala
# Monthly Rack Landing Analysis and Commentary
# Monthly CapEx reporting and analysis, MBR support
# New/MVP Regions planning and actuals including refinement of current processes to track/improve a) Utilization b)  runaway growth leading to DC constraints
#
#
# --tokens:93-------------------------------------------------------------------------------------------------------------------------------------------------------
# Usage analysis (how usage changes over time and driving Capacity/CapEx changes)
# EC2 Infrastructure Unit Costs and Allocation Processes, EC2 Incentive Rates TBH Steven Myers
# Design and implement EC2 rate-based cost allocation (successor to Std. Cost Initiative)
# Residual cost methodology and  bridging model
# Rate incentive calculation methodology
# Quarterly rate adjustment process for demand shaping
# Design and implement new TM1 process (and cube) to support this.
#
#
# --tokens:104-------------------------------------------------------------------------------------------------------------------------------------------------------
# Design and implement new TM1 process (and cube) to support this.
# Design and Implement future iterations of EC2 Incentive Rates
# Update Premiums/Discounts
# Standard Cost
# Manage Recurring EC2 Incentive Rate processes
# EC2 Control Plane Costs
# Business partner support to EC2 Fleet owners
# Uncover opportunities to reduce usage and drive CapEx savings
# EC2 Cost
# EC2 OpEx approvals
# Unit cost reporting and variance analysis
# Ad Hoc Projects
# CDO Abandonment rates
#
#
# --tokens:123-------------------------------------------------------------------------------------------------------------------------------------------------------
# EC2 OpEx approvals
# Unit cost reporting and variance analysis
# Ad Hoc Projects
# CDO Abandonment rates
# OD/RI costing update: evaluation of new/long term costing methdology for various purchase options including OD/RI (Zonal, Regional, Convertible, etc).
# TBH
# EC2 Control Plane Costs (EC2 use of EC2 and other services)
# OP forecast by fleet for usage of EC2, EBS, S3, DynamoDB, CW Logs, Hailstone, and Prod
# Monthly MBR - variance reporting/controllership, tracking progress to efficiency goals.
#
#
# --tokens:104-------------------------------------------------------------------------------------------------------------------------------------------------------
# Monthly MBR - variance reporting/controllership, tracking progress to efficiency goals.
# Playbook on approving control plane capacity provisioning/limit increases.
# FH/FHI reporting and migration tracking.
# EC2 fleet mapping updates in FMC
# TM1 Projects (dynamic list)
# FF usage in IRU calculation
# Change from IRU to NIH as cost allocation basis
# Add new usage types to allocation logic
# Partner on hetero x-family implementation in TM1
# Agustin Lastra
# EC2 Incentive Rates / AIR for EC2
#
#
# --tokens:118-------------------------------------------------------------------------------------------------------------------------------------------------------
# Partner on hetero x-family implementation in TM1
# Agustin Lastra
# EC2 Incentive Rates / AIR for EC2
# Monthly P&L adjustment process
# OP rate cards (EC2 IRU rates + Incentive Rates)
# Publish Ranking Forecast
# Residuals analysis
# Ad Hoc Service Deep Dives
# EC2 Costs (OpEx and P&L analysis)
# EC2 Average Unit Cost model and rate variances
# Fleet infrastructure Cost bridge
# Bridging Average cost to Marginal cost
# Support dependent services business case analysis with EC2 cost rates.
#
#
# --tokens:98-------------------------------------------------------------------------------------------------------------------------------------------------------
# Support dependent services business case analysis with EC2 cost rates.
# Modeling support for ad-hoc projects
# FMC limit approvals
#     TBH
#  EC2 Costs (OpEx and P&L analysis)
# EC2 Average Unit Cost model and rate variances
# Fleet infrastructure Cost bridge
# Support dependent services business case analysis with EC2 cost rates.
# Manual P&L credits for Demand Shaping and Flexible Fleets
# Modeling support for ad-hoc projects
# FMC limit approvals
#
#
# --tokens:97-------------------------------------------------------------------------------------------------------------------------------------------------------
# Modeling support for ad-hoc projects
# FMC limit approvals
#   Capital and Fleet Efficiency Optimization and Operations Support TBH TBH
# EC2 Fleet Efficiency and Operations Support
# Unsellables backlog reduction program support
# Retirement program, planning and operations support
# Remediation/Migration support
# Capacity planning offline buffers (DSR) for OP
# Test capacity loan tracking
# DNR/early retirement approvals
# Constrained AZs and site exits
# Other capital efficiency initiative supporting projects
#
#
# --tokens:110-------------------------------------------------------------------------------------------------------------------------------------------------------
# Constrained AZs and site exits
# Other capital efficiency initiative supporting projects
# Hailstone & AWS Legacy Prod/Corp
# Ronny Kashat
# EC2 Fleet Efficiency and Operations Support
# Unsellables backlog reduction program support
# Capacity planning offline buffers (DSR) for OP
# Remediation/Migration support
# Test capacity loan tracking
# DNR/early retirement approvals
# Constrained AZs and site exits
# Other capital efficiency initiative supporting projects
# Ify Nwosisi
# Hailstone and AWS Prod, EC2 Retirements
#
#
# --tokens:131-------------------------------------------------------------------------------------------------------------------------------------------------------
# Ify Nwosisi
# Hailstone and AWS Prod, EC2 Retirements
# Hailstone Support (Gen Pop account)
# Monthly cost allocation
# TM1 Cost Allocation projects
# OP1/OP2 usage forecast
# Monthly Commentary
# FOOB approvals
# RI Monitoring
# AWS Prod Support
# Monthly Commentary
# OP Planning for rack landings/retirements
# EC2 Retirements
# OP1/OP2/3YF planning
# OP1/OP2/Monthly reporting
# Rack retirement operational support
# Alex Angola
# Capital Efficiency & Optimization (EC2-CEO)
# Demand Shaping Programs
# Graviton2 adoption
#
#
# --tokens:106-------------------------------------------------------------------------------------------------------------------------------------------------------
# Alex Angola
# Capital Efficiency & Optimization (EC2-CEO)
# Demand Shaping Programs
# Graviton2 adoption
# Hailstone Demand Shaping
# CMRT migration for retirements
# ...
#
#
# --tokens:89-------------------------------------------------------------------------------------------------------------------------------------------------------
# CCX Customer Planning does not respond to Sev2 tickets outside of Seattle working hours. If you have a capacity challenge that requires immediate assistance off hours, please escalate to the Capacity Delegates (AWS>EC2>Customer Capacity Issue>EC2 Capacity Delegates) for 24/7 emergency support. If your issue can wait for a resolution during the Seattle workday, your Customer Planner will be available to help you resolve the problem.
#
#
# --tokens:65-------------------------------------------------------------------------------------------------------------------------------------------------------
# This wiki will walk you through the steps to ensure that your demand is supportable, server racks are ordered, and that the capacity is collected and transferred to the right accounts on your desired delivery date. To help you understand if this process applies to you, please answer the following question:
# Have you heard about Flexible Fleets?
#
#
# --tokens:101-------------------------------------------------------------------------------------------------------------------------------------------------------
# Want to reduce your IMR? Before reading on, do you know about Flexible Fleets? Flexible Fleets is an EC2 feature to enable internal teams to make generation- and family-agnostic requests for capacity in order to scale up more reliably and lower their total costs. Teams can select the bundle that best suits their instance requirements and then launch via EC2 Auto Scaling groups or the EC2 Fleet API. By allowing EC2 to determine where to best launch customer's capacity, AWS will drive higher total
#
#
# --tokens:29-------------------------------------------------------------------------------------------------------------------------------------------------------
# By allowing EC2 to determine where to best launch customer's capacity, AWS will drive higher total EC2 utilization and pass those savings onto customers.
#
#
# --tokens:7-------------------------------------------------------------------------------------------------------------------------------------------------------
# SDO Flexible Fleets ordering process
#
#
# --tokens:107-------------------------------------------------------------------------------------------------------------------------------------------------------
# SDO teams ordering public EC2 capacity for peak but scaling via Flex Fleets (FF) will need to follow this process: Create a SDO Public capacity planning ticket outlining the AZ/region, instance size/FF bundle, required need by date/s, and quantity required for your scaling. These details will be provided in the overview of the created ticket rather than in the MaitreD batch as outlined in the non-Flex Fleets SOP below on this Wiki. Once submitted, EC2 will review your request and determine what
#
#
# --tokens:53-------------------------------------------------------------------------------------------------------------------------------------------------------
# Fleets SOP below on this Wiki. Once submitted, EC2 will review your request and determine what portion of your requested scaling needs to be manually signaled in the EC2 forecast. Scaling on the requested capacity will still be handled via Flex Fleets placement mechanisms.
#
#
# --tokens:107-------------------------------------------------------------------------------------------------------------------------------------------------------
# Are you in the right place?
# 1. Is your desired incremental capacity below the thresholds defined by this amazingly awesome new data driven FOOB threshold eye chart?
# Yes: This wiki is not for you. You are not required to contact EC2 CCX to plan your capacity requirements. You may scale directly from the EC2 pools when you require capacity. If you  feel inclined to reach out, please ask your question in this ticket and we will get back to you.
#  No: This wiki is for you. Please continue reading.
#
#
# --tokens:74-------------------------------------------------------------------------------------------------------------------------------------------------------
# No: This wiki is for you. Please continue reading.
# EC2 asks service teams to signal their capacity needs ahead of time for new feature launches and new service launches if those needs are significant relative to existing EC2 usage for the specific instance family and AZ. Scaling for a peak event would qualify as use case that requires EC2 planning engagement.
# Capacity Planning and Ordering Process
#
#
# --tokens:104-------------------------------------------------------------------------------------------------------------------------------------------------------
# Capacity Planning and Ordering Process
# 1. Open a ticket with EC2 CCX and fill in the requested information. Include your service name in the ticket title. Ensure markbash@ is added as a ticket watcher.
# Note: For Machine Learning requests (P4D, P4DE, P5, TRN1/N), please use this ticket template: https://issues.amazon.com/issues/create?template=4ac35479-eb77-4f67-94eb-ef87b7f73779
#
#
# --tokens:115-------------------------------------------------------------------------------------------------------------------------------------------------------
# 2. Build your capacity request in [MaitreD’](https://ec2-maitre-d-prod-iad.iad.proxy.amazon.com/batchCreate?noTrigger=true) and paste the link to the completed request in the ticket from Step 1 (MaitreD’ User Guide). Include your service name in the “Notes” block above the main body of the reservation. Add your alias to the “Assignee(s)” block.
# If you are having issues with MaitreD’, reach out to the PAO On-call for support.
#
#
# --tokens:108-------------------------------------------------------------------------------------------------------------------------------------------------------
# If you are having issues with MaitreD’, reach out to the PAO On-call for support.
# 3. Once a MaitreD’ request is built, the Automated Approval System will check to see if your request is eligible for auto-approval. The auto-approval decision will posted on the ticket submitted in your MaitreD’ form. Based on the approval system’s conclusion, there are two potential workflows: A. the Auto-approval Workflow and B. the Traditional Workflow.
# A. The Auto-approval Workflow
#
#
# --tokens:57-------------------------------------------------------------------------------------------------------------------------------------------------------
# A. The Auto-approval Workflow
# A1. If your request has been auto-approved (messaging on the ticket: “AUTO APPROVAL: Capacity Reservation Service (CRS) has automatically approved your request.”), then your planner will review the request to double check supportability.
#
#
# --tokens:89-------------------------------------------------------------------------------------------------------------------------------------------------------
# A2. If your CCX planner concurs with the approval decision, then please have your Finance partners approve the IMR spend associated with the capacity request on the ticket (direct comment or attached email are both acceptable). The Finance approval level (L7 or L8) should be determined based on your team's internal approval process according to the IMR spend associated with the request. Without appropriate Finance approval, the capacity request cannot be processed.
#
#
# --tokens:78-------------------------------------------------------------------------------------------------------------------------------------------------------
# A3. Once your Finance partner has approved the IMR associated with the request, then your MaitreD’ request will be approved. Your demand signal will be added to the EC2 Production Forecast and server orders will be cut to support your requirements. If you have questions about or require changes to your reservation, reach out to your planner on the ticket.
# B. The Traditional Workflow
#
#
# --tokens:89-------------------------------------------------------------------------------------------------------------------------------------------------------
# B. The Traditional Workflow
# B1. If your request was auto-approved and found unsupportable (your customer planner will note this on the ticket) or the system rejected the request (messaging on the ticket: “AUTO-APPROVAL BYPASSED: Capacity Reservation Service (CRS) is referring your request for further review.”), then EC2 CCX will direct you to approve the IMR spend for your request.
#
#
# --tokens:82-------------------------------------------------------------------------------------------------------------------------------------------------------
# B2. Please calculate the IMR impact and have your Finance partners approve the IMR spend associated with the capacity request on the ticket (direct comment or attached email are both acceptable). The Finance approval level (L7 or L8) should be determined based on your team's internal approval process according to the IMR spend associated with the request. Without appropriate Finance approval, the capacity request cannot be processed.
#
#
# --tokens:94-------------------------------------------------------------------------------------------------------------------------------------------------------
# B3. Next, an EC2 CCX customer planner will analyze your request for supportability and provide recommendations to help build a plan that has a high fulfillment probability.
# B4. Once EC2 and your service agree to a capacity plan, the MaitreD’ request will be updated to reflect any changes.
# B5. EC2 CCX planner will pursue final approval from the CCX Senior Manager, who will provide the ultimate sign off on the ticket.
#
#
# --tokens:99-------------------------------------------------------------------------------------------------------------------------------------------------------
# B6. After CCX approval, your MaitreD’ request will be approved and the capacity plan signal will be added to the EC2 Production Forecast to drive server orders to support your capacity requirements.
# Capacity Delivery
# 1. Within four weeks of the need-by-dates specified on your request, MaitreD’ will begin collecting capacity and placing it in the EC2 Escrow Account. The amount collected can be seen in the “Quantity Allocated” column of your request.
#
#
# --tokens:58-------------------------------------------------------------------------------------------------------------------------------------------------------
# 2. On your desired need-by-date, the capacity will transfer from the EC2 Escrow Account to the accounts specified in the reservation. In MaitreD’, you will see this capacity in the “Quantity Transferred” column. Once transferred, you are free to begin scaling.
#
#
# --tokens:54-------------------------------------------------------------------------------------------------------------------------------------------------------
# 3. Capacity will transfer in one of two forms, which you will set with your CCX planner based on if you want to purchase reserved instances (RIs) or if you plan on using the capacity on-demand (i.e. without a long-term reservation commitment):
#
#
# --tokens:100-------------------------------------------------------------------------------------------------------------------------------------------------------
# Internal Guarantee (IG): Capacity will deliver as an IG to support Zonal RI purchases (see Note 1 regarding Zonal RI returns to EC2). You will have four business days to purchase your RIs once the IGs deliver. RI purchases can be done via the EC2 Console, an API call, or through Concierge. After four business days, if no action is taken, the IG will expire and the capacity will return to the EC2 pool. (Reserved Instances Public Documentation)
#
#
# --tokens:52-------------------------------------------------------------------------------------------------------------------------------------------------------
# IMPORTANT NOTE, PLEASE READ!! Zonal RIs come with a term obligation. If you would like to return your capacity earlier than the lease expiration, you may request an early take back but EC2 is not obligated to accept the return. Learn more here.
#
#
# --tokens:100-------------------------------------------------------------------------------------------------------------------------------------------------------
# On-Demand Capacity Reservation (ODCR): If you would like to run your capacity on-demand, please state explicitly in the ticket that you wish for your capacity to deliver as an ODCR. Once an ODCR delivers, billing begins immediately but the capacity is reserved for your exclusive use. Once you have completed your work and you no longer require the capacity, simply terminate your instance and release the capacity reservation (through the EC2 Console). This will return the instance to EC2 and stop
#
#
# --tokens:30-------------------------------------------------------------------------------------------------------------------------------------------------------
# the capacity reservation (through the EC2 Console). This will return the instance to EC2 and stop billing on your account.(ODCR Public Documentation)
#
#
# --tokens:115-------------------------------------------------------------------------------------------------------------------------------------------------------
# Change to ODCR Delivery by MaitreD as of 1/19/2021 (for all commercial, non-China regions): On-Demand Capacity Reservations (ODCR) delivered by EC2 through MaitreD, are now supported by AWS-Assisted CR. Customers will now be notified through their console and Personal Health Dashboard of upcoming ODCR requests made though MaitreD and MUST approve in either their Console or SKD/CLI before the Need By Date to receive the Capacity Reservation. Once a request is approved by Capacity Planning, the
#
#
# --tokens:100-------------------------------------------------------------------------------------------------------------------------------------------------------
# By Date to receive the Capacity Reservation. Once a request is approved by Capacity Planning, the Incremental Requested Quantity will be visible as a tag value for each CR under the ‘aws:ec2capacityreservation:incrementalRequestedQuantity’ system key. For first time delivery with AWS-Assisted CR, please follow the User Guide for setup instructions and customer requirements. Auto-Acceptance for all future, requested ODCRs can be toggled on by region through either the Console or CLI.
#
#
# --tokens:110-------------------------------------------------------------------------------------------------------------------------------------------------------
# The ODCR Memorandum of Understanding: As a reminder, the capacity quantities listed in the MaitreD will transfer INCREMENTALLY on top of any capacity the customer may be running. As of 10/4/21, ODCRs can now deliver Open (covering all running usage in addition to the delivered instances) or Targeted (covering only the instances delivered through MaitreD'). They will be billed for the total amount for both unused and used instances until they cancel or reduce the ODCR quantity from their console.
#
#
# --tokens:39-------------------------------------------------------------------------------------------------------------------------------------------------------
# for both unused and used instances until they cancel or reduce the ODCR quantity from their console. Can you please confirm that the customer understands this ODCR behavior and is good to proceed?
#
#
# --tokens:33-------------------------------------------------------------------------------------------------------------------------------------------------------
# If you have any questions throughout this process or if your needs change, reach out to your CCX Customer Planner and they will get you pointed in the right direction.
