# %%
# !pip install --upgrade pip
# !pip install openai
# !pip install tiktoken

# %%
# !pip install -U boto3 botocore

# %%
# !pip install transformers==4.30.2
# !pip install accelerate -U
# !pip install sentencepiece -U

# %% [markdown]
# # 加载embedding 模型的tokenizer，用于计算token

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')

# %% [markdown]
# # Option1: 用本地Sagemaker模型进行增强

# %%
import json
import boto3

smr_client = boto3.client("sagemaker-runtime")

parameters = {
  "max_length": 4096,
  "top_p":1,
    "temperature":0.1
}

# %%
import io
class StreamScanner:
    """
    A helper class for parsing the InvokeEndpointWithResponseStream event stream. 
    
    The output of the model will be in the following format:
    ```
    b'{"outputs": [" a"]}\n'
    b'{"outputs": [" challenging"]}\n'
    b'{"outputs": [" problem"]}\n'
    ...
    ```
    
    While usually each PayloadPart event from the event stream will contain a byte array 
    with a full json, this is not guaranteed and some of the json objects may be split across
    PayloadPart events. For example:
    ```
    {'PayloadPart': {'Bytes': b'{"outputs": '}}
    {'PayloadPart': {'Bytes': b'[" problem"]}\n'}}
    ```
    
    This class accounts for this by concatenating bytes written via the 'write' function
    and then exposing a method which will return lines (ending with a '\n' character) within
    the buffer via the 'readlines' function. It maintains the position of the last read 
    position to ensure that previous bytes are not exposed again. 
    """
    
    def __init__(self):
        self.buff = io.BytesIO()
        self.read_pos = 0
        
    def write(self, content):
        self.buff.seek(0, io.SEEK_END)
        self.buff.write(content)
        
    def readlines(self):
        self.buff.seek(self.read_pos)
        for line in self.buff.readlines():
            if line[-1] != b'\n':
                self.read_pos += len(line)
                yield line[:-1]
                
    def reset(self):
        self.read_pos = 0

# %% [markdown]
# ### 需要填入对于的sagemaker endpoint

# %%
endpoint_name='qwen-stream-int4-2023-08-31-02-25-35-582-endpoint'

def call_llm(prompt,endpoint_name=endpoint_name,parameters=parameters):
    response_model = smr_client.invoke_endpoint_with_response_stream(
            EndpointName=endpoint_name,
            Body=json.dumps(
            {
                "inputs": prompt,
                "parameters": parameters,
                "history" : [],
                "stream":True
            }
            ),
            ContentType="application/json",
        )

    event_stream = response_model['Body']
    scanner = StreamScanner()
    text = ''
    for event in event_stream:
        scanner.write(event['PayloadPart']['Bytes'])
        for line in scanner.readlines():
            try:
                resp = json.loads(line)
                print(resp.get("outputs")['outputs'], end='')
                text +=resp.get("outputs")['outputs']
            except Exception as e:
                # print(line)
                continue
    return text

# %% [markdown]
# # Option 2: 用Chatgpt3.5，添加api_key

# %%
import os,json
import openai
openai.api_key = ''


def call_llm(prompt):
    completion = openai.ChatCompletion.create(
    model="gpt-3.5-turbo-16k-0613",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
        ]
    )
    return completion.choices[0].message['content']

# %% [markdown]
# # 创建结果格式化解析（本地部署模型，输出结果的格式不太稳定，需要格式化，如果使用ChatGPT不需要这个解析）

# %%
import re
##example cases
#line1 = '问题1:我在游戏中怎么查看当前升级所需要的经验？ 回答1: 15级解锁神奇宝玩家可以点击左上角查看当前升级所需要的经验。'
#line2 = '问题1:我在游戏中怎么查看当前升级所需要的经验？'
#line3 = '回答1: 充值可以让玩家获得更多的游戏内物品和特权，如游戏道具、游戏时间等。它们可以帮助玩家更快地提高游戏水平和游戏体验。'
#line4 = '问题1: 12我在游戏中遇到了其他玩家的不当言论，应该怎样举报？ 回答1: 如果在游戏中遇到其他玩家不当言论的情况，可以在聊天框点击对方的头像选择举报或者联系客服提供聊天截图进行举报（建议同时点击对方头像选择屏蔽）。 问题2: 举报需要提供哪些信息？ 回答2: 举报时需要提供相关的聊天截图以及被举报者的账号信息，以确保举报的有效性。希望以上回答能够帮助您更好地了解如何举报。'
pattern_1 = re.compile(r'(问题\d*:[^回答:]*)(回答\d*:[^问题:]*)',re.I)
pattern_2 = re.compile(r'问题\d*:[^回答:]*',re.I)
pattern_3 = re.compile(r'回答\d*:[^问题:].*',re.I)

def parse_response(response):
    new_data = []
    qna = []
    for line in response.split('\n'):
        
        groups = pattern_1.findall(line)
        for question,answer in groups: ##如果问题和答案在一行
            question = re.sub(r'^问题\d*:','',question)
            answer = re.sub(r'^回答\d*:','',answer)
            new_data.append((question,answer))
            
        if not len(groups): ##如果问题和答案是分行
            groups_q = pattern_2.match(line)
            groups_a = pattern_3.match(line)
            if groups_q:
                question = re.sub(r'^问题\d*:','',groups_q[0])
                qna.append(question)
            elif groups_a:
                answer = re.sub(r'^回答\d*:','',groups_a[0])
                qna.append(answer)
            if len(qna) == 2:
                new_data.append((qna[0],qna[1]))
                qna = []
                
    return new_data

# %% [markdown]
# # 读取原始FAQ文件

# %%
origin_faqfilename = "topwar_faq/topwarfaq230908.faq"

# %%
import os
def parse_faq(file_content,QA_SEP='====='):
    arr = file_content.split(QA_SEP)
    list_arr = []
    for item in arr:
        # print(item)
        try:
            question, answer = item.strip().split("\n", 1)
            question = question.replace("Question: ", "")
            answer = answer.replace("Answer: ", "")
            list_arr.append((answer.strip(),question.strip()))
        except:
            pass
    return list_arr


all_data = []
with open(origin_faqfilename) as f:
        data = f.read()
        all_data += parse_faq(data)
        
print(f"data size:{len(all_data)}")
# Out:
# data size:2178

# %% [markdown]
# ####  如果用chat gpt，可以直接使用以下模板
# ```python
# prompt = f"""
# 如下三个反引号中是《口袋奇兵》游戏的相关知识信息, 请基于这部分知识信息生成{nums}的问题以及对应答案
# ```
# {context}
# ```
# 要求尽可能详细全面, 并且遵循如下规则:
# 1. 生成的内容不要超出反引号中信息的范围
# 2. 问题部分需要以"Question:"开始
# 3. 答案部分需要以"Answer:"开始
# """
# ```

# %%
import math,time

newfaq_filename = 'docs/topwar_enrich_faq_0911.faq'

def generate_query(new_data,alldata,tokenizer):
    faqtext = ''
    for i, (answer, query) in enumerate (alldata):
        context = f"问:{query}\n答:{answer}"
        tokens = len(tokenizer(context)['input_ids'])
        nums =  math.ceil(tokens/40)
        
        ##如果用chat gpt，可以直接使用以下模板
        # prompt = f"""
        # 如下三个反引号中是《口袋奇兵》游戏的相关知识信息, 请基于这部分知识信息生成{nums}的问题以及对应答案
        # ```
        # {context}
        # ```
        # 要求尽可能详细全面, 并且遵循如下规则:
        # 1. 生成的内容不要超出反引号中信息的范围
        # 2. 问题部分需要以"Question:"开始
        # 3. 答案部分需要以"Answer:"开始
        # """
        prompt= f"请根据以下内容生成{nums}个独立的新问题和对应问题的回答\n ```\n{context}\n```，问题和回答使用一对一的形式展示,问题的语气模拟你是一个游戏玩家，例如:\n问题1: \n回答1:\n\n问题2:\n回答2:\n\n"
        print (f"\n-------[{i}]-----Origin FAQ--------\n")
        print (context)
        print (f"\n-------[{i}]-----New FAQ--------\n")
        response = call_llm_sagemaker(prompt)
        parsed_qa = parse_response(response)
        
        for q,a in parsed_qa:
            faqtext+=f"Question: {q}\nAnswer: {a}\n=====\n"
        with open(newfaq_filename,"w") as f:
            f.write(faqtext)

# %% [markdown]
# #### 开始合成faq

# %%
generate_query(newdata,all_data,tokenizer)
# Out:
# -------[0]-----Origin FAQ--------
#
# 问:小游戏在哪
# 答:目前只有10-20级玩家可以看到小游戏中心，您可以点击右上角的（大喇叭）常规活动，翻到最后面就可以看到了哦！
#
# -------[0]-----New FAQ--------
#
# 问题1：小游戏在哪里可以找到？ 回答1：目前只有10-20级玩家可以看到小游戏中心。您可以点击右上角的（大喇叭）常规活动，翻到最后面就可以看到了哦！ 问题2：小游戏中心有哪些游戏可以玩呢？ 回答2：小游戏中心提供了多种不同种类的游戏供玩家畅玩，包括简单的休闲游戏、策略游戏等等。每个游戏的玩法和规则都不相同，您可以根据自己的兴趣爱好来选择适合自己的游戏。
# -------[1]-----Origin FAQ--------
#
# 问:装饰物
# 答:装饰物是一种游戏道具，可以通过摆放在基地，获得属性增益
# 1.15级解锁神奇宝箱建筑，每隔一定时间会获得装饰宝箱。
# 2.装饰物宝箱开出来的装饰物，放在主城里，可以修饰主城并带来各种BUFF，最多生效有数量限制。
# 3.放置后的BUFF效果，装饰属性可以在建筑神奇宝箱里面的BUFF分页看到，所有的装饰属性可以在BUFF旁边的图鉴分页点击查看。
# 4.有关装饰品合成问题：在整体数量生效有限制的情况下，三合一升级更高一级的时候没有直接按照玩家理解的原有属性*3叠加，是一级比一级更高。
# 5.由于目前游戏内显示的最多是一位小数，所以有一些级别增加了但是没有显示出来，导致玩家认为没有增加，例如从0.2提升到0.24，游戏内目前显示都是0.2。
# 6.高等级装饰可以分解为低等级装饰。
#
# -------[1]-----New FAQ--------
#
# 问题1: 我如何获得装饰物？
#
#
# 回答1: 装饰物可以通过摆放在基地，每周会根据活跃度获得一个免费的永久装饰物，也可以通过购买或者参与活动获取更多的装饰物。
#
# 问题2: 我最多能放置多少个装饰物？
#
#
# 回答2: 你最多可以放置20个装饰物，但是每个装饰物的属性都是有限的，并且只有一个建筑能够放置装饰物，所以在放置装饰物时需要谨慎选择。
#
# 问题3: 我如何查看我的装饰物的属性？
#
#
# 回答3: 在主城市中，你可以找到"建筑-神奇宝箱"的按钮，点击后会显示你所有已放置的装饰物的属性，还可以通过点击"图鉴"按钮查看所有的装饰物属性。
#
# 问题4: 我如何合成更高等级的装饰物？
#
#
# 回答4: 在合成高等级装饰物时，需要将三个同等级的装饰物进行合成，合成后会得到一个更高一级的装饰物，但是合成后不会将原有装饰物的属性直接叠加，而是按照合成后的新属性进行叠加。
#
# 问题5: 我的游戏等级显示为什么只有0.2而没有显示0.24？
#
#
# 回答5: 由于游戏内显示的最多有一位小数，所以当你从0.2提升到0.24时，游戏内会显示0.2，但是实际上你的游戏等级已经得到了提升。
#
# 问题6: 我如何分解高等级装饰物？
#
#
# 回答6: 你可以通过消耗一定数量的经验值来分解高等级装饰物，分解后会获得对应的经验值和低等级的装饰物。
# -------[2]-----Origin FAQ--------
#
# 问:专3
# 答:专属技能3级
#
# -------[2]-----New FAQ--------
#
# 问题1: 请问专3技能有哪些可以升级的选项？
# 回答1: 专3技能有多种升级选项，包括攻击力、生命值、防御力、移动速度等。你可以根据自己的需要和战斗策略来选择合适的升级选项。
# 问题2: 我需要多少经验才能将专3技能升级到下一个等级？
# 回答2: 每次升级专3技能需要一定数量的经验。具体情况可以参考游戏内的指导手册或者咨询游戏内的客服。一般情况下，你需要积累一定数量的经验点数才能将专3技能升级到下一个等级。
# -------[3]-----Origin FAQ--------
#
# 问:专5
# 答:专属技能5级
#
# -------[3]-----New FAQ--------
#
# 问题1: 我在游戏里达到了专5级，这意味着什么？
# 回答1: 专5级代表着你在游戏中的专属技能已经到达了最高水平，对应的技能也变得更加强大可靠。这意味着您在游戏中的表现将更加突出，能够应对更高级别的挑战。此外，专5级也可以为您的角色带来更高的经验和能力加成。
# -------[4]-----Origin FAQ--------
#
# 问:专7
# 答:专属技能7级
#
# -------[4]-----New FAQ--------
#
# 问题1: "专7是什么级别的技能？" 回答1: "专7是专属技能的第七等级，它可以提供更高的伤害和更优秀的生存能力。" 问题2: "专7可以给角色带来哪些好处？" 回答2: "专7可以让角色的攻击更高，同时还可以提高角色的抗性和生命值，使角色在战斗中更加耐打。此外，专7还可以增加角色的移动速度，让角色更方便地躲避敌人的攻击。"
# -------[5]-----Origin FAQ--------
#
# 问:经验
# 答:经验是指玩家通过游戏行为获得的累计数值，积累到一定程度后会提升玩家的等级
# 经验获取：
# 1.游戏内经验获取是通过金币消耗来实现的，消耗5金币=获取1经验。这不包括帮助联盟成员的金币消耗。
# 2.游戏内显示经验单位较大，会以四舍五入形式显示。因此，获取少量经验时，可能无法直接通过游戏内显示的结果查看到，但系统已经为玩家增加了经验，玩家不必担心。
# 3.玩家可以点击左上角查看当前升级所需要的经验。
# 4.联盟科技-勤俭节约：这个科技只减少消耗的金币，不减少获得的经验。
#
# -------[5]-----New FAQ--------
#
# 问题1: 游戏内经验是如何获取的？
# 回答1: 游戏内经验可以通过金币消耗来获取，消耗5金币=获取1经验。但是，游戏内显示的经验单位较大，会以四舍五入形式显示。因此，即使获取少量经验，系统也会为玩家增加经验，玩家不必担心。
#
# 问题2: 玩家如何查看升级所需要的经验？
# 回答2: 玩家可以点击左上角查看当前升级所需要的经验。
#
# 问题3: 联盟科技-勤俭节约有什么作用？
# 回答3: 联盟科技-勤俭节约只能减少消耗的金币，不减少获得的经验。
#
# 问题4: 如果玩家消耗了金币来获取经验，但经验值没增加怎么办？
# 回答4: 玩家可以点击左上角查看当前升级所需要的经验，确保消耗金币的数量正确。如果经验数不变，可能是其他原因导致的，建议检查下游戏设置或者联系客服。
# -------[6]-----Origin FAQ--------
#
# 问:队列
# 答:队列是指玩家在游戏内可用于战斗、采集等的行为的基本编制概念
# 队列的获取方式：
# 1.游戏内默认包含1个出征队列。
# 2.黑金百夫长（原至尊永久卡）和铂金指挥官卡（原精英月卡）各自包含1个出征队列。
# 3.简易指挥所达到25级时增加1个出征队列。
# 4.职业天赋的见习军官中的骁勇善战研究完成后增加1个出征队列。
# 5.首府的首领官职会增加1个出征队列。
# 6.在创建新角色时，系统会通过游戏内活动向玩家赠送一个限时增加出征队列的道具。使用多个限时队列道具只叠加时间，不会额外获得更多队列。有效期结束后，该队列会被取消。
#
# -------[6]-----New FAQ--------
#
# 问题1: 请问游戏中如何获得更多的出征队列？ 回答1: 在游戏中可以通过完成游戏内活动或通过领取系统赠送的道具来获得更多的出征队列。
#
# 问题2: 那在创建新角色时，系统赠送的限时出征队列道具是无限时间的吗？ 回答2: 不是的，该限时出征队列道具的有效期结束后会被取消。
# -------[7]-----Origin FAQ--------
#
# 问:新区
# 答:1、新区是指开放时间最近的服务器
# 2、新区开放时间：不定期开放，您可以留意下头像-设置-角色管理里的服务器列表进行关注，或通过客服渠道进行预约提醒。
#
# -------[7]-----New FAQ--------
#
# 新问题1：我在角色管理里没有找到新区的列表，能否告诉我怎么找到它呢？
# 回答1：可以通过以下几个步骤来找到新区的列表：1. 在游戏中打开设置界面；2. 在设置界面中找到角色管理；3. 在角色管理中点击“查看新区”按钮，即可查看到最近开放的服务器列表。
# 新问题2：如果我在新区中受到了不公正的待遇，应该向谁反映呢？
# -------[8]-----Origin FAQ--------
#
# 问:联盟
# 答:1.加入联盟的条件：基地5级后可以，加入联盟后可以与盟友在联盟频道进行交流、分享坐标、交换矿石等。
# 2.联盟积分：可以消耗金币或钻石捐献联盟科技和联盟占领的遗迹等途径获得，用于在联盟商店兑换道具，每日最多可以通过捐献获得3000联盟积分。
# 3.联盟礼物：购买包含联盟礼物的礼包后，全盟都会收到联盟礼物（在联盟-联盟礼物-稀有礼物中展示和领取）。
# 4.升级、逐出联盟：点击联盟-成员-点击管理-可以逐出联盟或者升降级。点击联盟-设置-可以离开联盟，如果是盟主，需要将盟主让位给其他盟友才能退盟。
# 5.联盟堡垒：1.建造联盟堡垒可以形成联盟领地，盟主和R4可以放置和拆除联盟堡垒，联盟成员可以通过捐献增加建造进度。
# 2.在倒计时归零前无成员进行下一次捐献或长时间无联盟成员活跃时则会自动收回联盟堡垒，收回的联盟堡垒建造进度值会保留。
# 6.联盟迁城：盟主和R4联盟成员可以点击联盟堡垒-邀请迁城可以邀请盟友将基地迁移到联盟领地内，被邀请的盟友需要消耗联盟迁城道具进行迁移。
# 7.如何成为盟主/取代盟主：玩家可以创建一个新的联盟，成为联盟盟主。同时也可以通过取代当前联盟内盟主成为新一任联盟盟主。盟主超过一段时间不登录游戏，可以通过游戏内的联盟-设置-取代盟主，相关罢免条件会在对应页面显示。
# 8.联盟科技：联盟科技可以通过捐献提升联盟科技等级获得个人增益和联盟增益，盟主和R4及以上联盟成员可以选择升级联盟科技。
# 9.联盟技能：1.可以通过捐献累积经验，捐献次数与联盟科技捐献次数通用，达到最大值后盟主以及联盟官员可以释放技能。
#  2.已经释放的联盟技能需要等待24小时的冷却时间，且期间无法继续捐献已释放的联盟技能捐献进度。
# 10.遗迹：联盟最多可以占领最外层遗迹3个，中间层遗迹2个，最内层遗迹2个，遗迹功能每次刷新后只能使用一次（0点后刷新），盟主和R4及以上联盟成员可以进行遗迹升级和放弃。
# 11.联盟成就：联盟成就任务完成会获得任务勋章，每个成就任务的额奖励只能领取一次，已完成并领取奖励的任务更换联盟也无法重复领取，勋章可以提高联盟等级。
# 12.联盟徽章：联盟等级提高或者研究全新荣光科技可以获得新的联盟徽章，盟主和R4及以上联盟成员可以进行联盟徽章更换，除初始联盟徽章外不同的联盟徽章有不同的使用属性。
# 13.联盟守卫：联盟等级达到5级，联盟前100名成员达到60级，联盟当前拥有6个遗迹，联盟累计采集粮食和石油达到2.5B（火神守卫功能上线后），满足条件解锁后不会再次关闭。
# 14.联盟排行：可以查看联盟各个成员的排行榜情况。
# 15.联盟机甲：1.盟主以及联盟官员可以选择不同类型和不同等级机甲进行捐献，机甲难度越高奖励越丰厚。
#  2.需要捐献机甲碎片提高机甲部署的进度，捐献最多的成员奖励最丰厚（相同捐献数量则以先达到的成员为顺位向下排名）。
# 3.挑战结束后机甲需要进厂检修，不同的机甲种类检修期不同，可以选择未在检修期的机甲进行捐献。
# 4.机甲部署后有攻击倒计时，攻击成功后按照联盟成员的伤害排名进行奖励发放，联盟成员至少参与一次并造成伤害才可以进入伤害排名，未在倒计时击败机甲则没有战斗奖励。
# 5.机甲部署后，盟主以及联盟官员可以向整个战区发起援助请求，援助挑战成功后，所有参与攻击的成员只能获得最后一档伤害奖励且召唤机甲的联盟不能解锁下一等级的联盟机甲。
#
# -------[8]-----New FAQ--------
#
# 1. 联盟是如何加入的？
#
# 回复1: 加入联盟的条件是基地5级后可以，加入联盟后可以与盟友在联盟频道进行交流、分享坐标、交换矿石等。
# 2. 联盟积分有什么用？
#
# 回复2: 联盟积分可以消耗金币或钻石捐献联盟科技和联盟占领的遗迹等途径获得，用于在联盟商店兑换道具，每日最多可以通过捐献获得3000联盟积分。
# -------[9]-----Origin FAQ--------
#
# 问:皮肤
# 答:1.购买超级月卡后，可以在月卡持续期间使用月卡皮肤。其他皮肤外观需要活动获得。
# 2.可以点击头像查看各种皮肤的获取途径。
# 3.普通基地占用地块1*1，其他皮肤占用地块2*2。如果购买月卡后不自动装扮外观，需要迁移至空旷区域手动装扮。
# 4.皮肤属性分为2种：拥有属性和使用属性。拥有属性是指只要玩家拥有了这个皮肤，不需要装备就可以获得属性。使用属性是指玩家在使用这个皮肤的时候才会生效。
#
# -------[9]-----New FAQ--------
#
# 问题1: 可以在哪里查看各种皮肤的获取途径？ 回答1: 可以点击头像查看各种皮肤的获取途径。
#
# 问题2: 皮肤需要怎么装扮？ 回答2: 普通基地占用地块1*1，其他皮肤占用地块2*2。如果购买月卡后不自动装扮外观，需要迁移至空旷区域手动装扮。
#
# 问题3: 皮肤属性有哪两种？ 回答3: 皮肤属性分为2种：拥有属性和使用属性。拥有属性是指只要玩家拥有了这个皮肤，不需要装备就可以获得属性。使用属性是指玩家在使用这个皮肤的时候才会生效。
#
# 问题4: 购买月卡后如何获得月卡皮肤？ 回答4: 购买超级月卡后，可以在月卡持续期间使用月卡皮肤。其他皮肤外观需要活动获得。
# -------[10]-----Origin FAQ--------
#
# 问:好友
# 答:点击头像-设置-好友可以查看好友列表。世界聊天中可以点击头像添加好友~在世界地图中点击其他玩家的基地-头像也有添加好友的选项喔~可以在好友页面，点击“邀请好友”发送申请链接，好友点击即可成功添加。如果不在同一个服务器就无法添加好友哦~
#
# -------[10]-----New FAQ--------
#
# 问题1: 我怎么查找我的好友？
# 回答1: 点击头像-设置-好友可以查看好友列表。世界聊天中可以点击头像添加好友～在世界地图中点击其他玩家的基地-头像也有添加好友的选项喔～可以在好友页面，点击“邀请好友”发送申请链接，好友点击即可成功添加。如果不在同一个服务器就无法添加好友哦。
# -------[11]-----Origin FAQ--------
#
# 问:车库
# 答:车库相关建筑点击基地内下方的建筑列表可以放置。建筑放置后，可以将地面上的士兵统一收纳到车库内。收纳到车库中的士兵，仍然可以正常参加出征以及防御战斗。车库这3个建筑容纳上限是150（不含城堡皮肤、城堡特效增加的数量）。同时1.在车库内滑动士兵可以进行合成（也可以一键合成）2.按住士兵，点击红色删除按钮会进行删除操作
#
# -------[11]-----New FAQ--------
#
# 问题1: 能否给士兵进行升级操作？ 回答1: 不可以，目前只支持士兵的合成和删除操作。 问题2: 能否在车库外放置士兵？ 回答2: 不可以，士兵必须放在车库内才能被收纳。
# -------[12]-----Origin FAQ--------
#
# 问:钻石
# 答:1、钻石的定义：钻石是《口袋奇兵》世界中的珍惜货币
# 2、钻石获得方法：可以通过购买以及参与游戏内活动、观看视频等方式获得钻石。
# 3、钻石的用途：部分活动可以通过消费钻石进行参与，比如：累计钻石消费、丘比特、翻翻卡等
#
# -------[12]-----New FAQ--------
#
# 问题1: 我如何获得更多的钻石？
# 回答1: 除了购买之外，你还可以通过参与游戏内的活动、观看视频等方式来获得钻石。例如，完成每日任务、参加在线比赛、完成活动任务等，都会有机会获得钻石奖励。另外，你也可以尝试在对局中获得胜利、展示技巧，这样也可以提高你获得钻石的几率。
#
# 问题2: 钻石在游戏中的作用有哪些？
# 回答2: 钻石在《口袋奇兵》游戏中可以用于部分活动的参与，例如：累计钻石消费、丘比特、翻翻卡等。购买一些特殊的道具可以帮助你在游戏中更好地发挥，而消费钻石也可以让你在对局中获得更多的优势。此外，你还可以用钻石来购买新的角色或者道具，让你的游戏体验更加丰富。
# -------[13]-----Origin FAQ--------
#
# 问:金币
# 答:1、金币的定义：金币是《口袋奇兵》世界中的通用货币
# 2、金币的获得方法：在游戏内可以通过税收中心/金币收割机进行获取。需要放置金矿生产金币，同时有部分装饰是可以提高金币产量。税收中心只需要20个当前玩家等级民居即可达到之前造满民居的收益。新版本的金币自动收割机是需要10个当前等级的金矿。
# 3、金币的用途：建筑升级、装备制造与改造等大部分游戏功能均需要消耗一定数量的金币
#
# -------[13]-----New FAQ--------
#
# 问题1：如何获得金币？
#
# 回答1：在《口袋奇兵》游戏中，金币可以通过税收中心和金币收割机获得。税收中心只需设置20个当前等级民居即可获得高收益，而新版本的金币收割机则需要10个当前等级的金矿。此外，部分装饰还可以提高金币产量。
#
# 问题2：金币的主要用途是什么？
#
# 回答2：金币在《口袋奇兵》游戏中是非常重要的一种资源，可以用来升级建筑、装备制造和改造等大部分游戏功能。
# -------[14]-----Origin FAQ--------
#
# 问:集结
# 答:点击联盟-战争-左上方按钮【自动加入】可以设置：1.自动加入集结的兵力（单兵加入、全兵加入）2.加入类型（战锤、砰砰、难民）点击【自动加入】按钮右侧的滑动按钮，可以开启此功能。重要提示：自动加入功能一次开启后持续8个小时。8个小时后，会自动关掉。
#
# -------[14]-----New FAQ--------
#
# 问题1: 我可以如何设置自动加入集结的兵力？
# 回答1：
# 问题2: 有哪些类型可以加入集结？
# 回答2：
# 问题3: 我如何关闭自动加入功能？
# 回答3：
# -------[15]-----Origin FAQ--------
#
# 问:职业天赋
# 答:1.转职系统在游戏中的开放等级是45级。玩家可以选择战斗精英和机械大师两个职业，战斗精英能够大幅强化玩家的战斗能力，机械大师则是增强发展的能力。
# 2.升级职业技能过程中需要消耗道具，对应消耗规则为：战斗精英--狗牌，机械大师-齿轮。
# 3.当第一页的基础科技天赋点满后，将开启专精科技天赋，需要玩家等级达到60级。战斗精英专精——（大元帅、战术大师），大元帅是大幅度强化英雄的职业，最终天赋是可以上阵3个英雄。机械大师专精——（传奇工匠、大科学家）。传奇工匠可以在大地图上建造特殊的强化建筑。
# 4.机械大师可以在大地图上建造采集建筑，完成（采金设施）（炼油设施）（建造谷仓）可以在大地图上建造对应的采集设施。
# 5.资源设施可采集时间为1级：6h，2级：7h，3级：8h。建造完毕后的资源设施拥有一定耐久，被攻击会导致耐久降低，耐久降低至0后，资源设施会被摧毁。
# 6.战斗精英--战斗礼物，战斗礼物研究至3级后，击杀中立单位后，可以额外获得额外奖励。
#
# -------[15]-----New FAQ--------
#
# 问题1: 请问职业天赋中的战斗精英和机械大师分别是什么？
# 回答1: 战斗精英可以大幅强化玩家的战斗能力，而机械大师则是增强发展的能力。
# -------[16]-----Origin FAQ--------
#
# 问:成长基金
# 答:在礼包商城-成长基金中可以购买，达到页面要求等级可以手动领取钻石。共可以领取14000钻石。如您在购买之后无法进行领取，请您先尝试彻底关闭游戏后重新登录领取。
#
# -------[16]-----New FAQ--------
#
# 问题1: 我购买了成长基金，但是为什么无法领取钻石？ 回答1: 请您先尝试彻底关闭游戏后重新登录领取。如果仍然无法领取，请联系客服寻求帮助。 问题2: 成长基金可以购买多少钻石？ 回答2: 在礼包商城-成长基金中可以购买14000钻石。
# -------[17]-----Origin FAQ--------
#
# 问:成长基金2
# 答:成长基金和成长基金2是两个不同的礼包，在购买过成长基金并达到55级后可以购买。
#
# -------[17]-----New FAQ--------
#
# 问题1: 我是否需要达到55级才能购买成长基金2？
# 回答1: 是的，在购买过成长基金并达到55级后可以购买成长基金2。
# -------[18]-----Origin FAQ--------
#
# 问:vip
# 答:VIP等级需要点数（1点=付费1rmb）对应点数越多，vip等级（即军级）越高。如果您希望提升vip等级~可以点击头像右边的vip按钮在vip页面查看距离下一个vip等级缺少多少点~点击头像，选择【设置】可以开启关闭vip显示标记，vip显示关闭后，不显示vip标记，但是头像框和属性依然享受。
#
# -------[18]-----New FAQ--------
#
# 问题1: 我需要点数才能提升VIP等级吗？ 答: 是的，VIP等级需要点数（1点=付费1rmb），点数越多，VIP等级越高。
#
# 问题2: 如何查看我还差多少点可以提升VIP等级？ 答: 可以点击头像右边的VIP按钮，然后在VIP页面查看距离下一个VIP等级还差多少点。
# -------[19]-----Origin FAQ--------
#
# 问:买了成长基金为什么不能领取？
# 答:成长基金是需要达到一定的等级要求才能领取对应的钻石。
#
# 成长基金：
# 达到5级可领取2000钻石，达到10级可领取1000钻石，达到15级可领取1000钻石，达到20级可领取3000钻石，达到25级可领取1000钻石，达到30级可领取1000钻石，达到35级可领取1000钻石，达到40级可领取1000钻石，达到45级可领取1000钻石，达到50级可领取2000钻石。
#
# 成长基金2：
# 达到50级可领取2000钻石，达到55级可领取1000钻石，达到60级可领取1000钻石，达到65级可领取2000钻石，达到70级可领取2500钻石，达到75级可领取2500钻石，达到80级可领取3000钻石。
#
# -------[19]-----New FAQ--------
#
# 问题1: 我怎么才能达到5级？
# 回答1: 你需要完成一些游戏任务并逐步升级来达到5级。
# 问题2: 我可以在哪些等级领取成长基金呢？
# 回答2: 成长基金可以按等级要求依次领取，包括达到5级可领取2000钻石，达到10级可领取1000钻石，达到15级可领取1000钻石，达到20级可领取3000钻石，达到25级可领取1000钻石，达到30级可领取1000钻石，达到35级可领取1000钻石，达到40级可领取1000钻石，达到45级可领取1000钻石，达到50级可领取2000钻石，达到55级可领取1000钻石，达到60级可领取1000钻石，达到65级可领取2000钻石，达到70级可领取2500钻石，达到75级可领取2500钻石，达到80级可领取3000钻石。
# -------[20]-----Origin FAQ--------
#
# 问:实名认证
# 答:一.严格控制未成年人使用网络游戏时段、时长。每日22时至次日8时，未成年人玩家将无法登录游戏。未成年人将限制游戏时长，每日累计不得超过1.5小时。二.规范向未成年人提供付费服务。未满8周岁的玩家将禁止充值。同一网络游戏企业所提供的游戏付费服务，8周岁以上未满16周岁的玩家，单次充值金额不得超过50元人民币，每月充值金额累计不得超过200元人民币;16周岁以上未满18周岁的用户，单次充值金额不得超过100元人民币，每月充值金额累计不得超过400元人民币。三.未进行实名认证的玩家，将不可登录游戏。
#
# -------[20]-----New FAQ--------
#
# 问题1: 为什么未成年人玩家在晚上22点到次日 8点之间将无法登录游戏呢？ 回答1：为了保护未成年人的身体健康，这两个时段是需要特别注意的。
#
# 问题2: 对于未成年人玩家，单次充值金额和月充值金额有什么限制？ 回答2：未满8周岁的玩家将禁止充值。8周岁以上未满16周岁的玩家，单次充值金额不得超过50元人民币，每月充值金额累计不得超过200元人民币；16周岁以上未满18周岁的用户，单次充值金额不得超过100元人民币，每月充值金额累计不得超过400元人民币。
#
# 问题3: 我如何进行实名认证？ 回答3：您可以使用身份证信息去游戏平台进行实名认证，也可以通过第三方身份验证机构进行实名认证。
#
# 问题4: 如何检查我的实名认证状态？ 回答4：您可以在游戏平台的个人中心中查看您的实名认证状态，也可以联系客服进行查询。
#
# 问题5: 没有实名认证的玩家会有怎样的影响？ 回答5：没有进行实名认证的玩家，将不可登录游戏。
# -------[21]-----Origin FAQ--------
#
# 问:修理工厂
# 答:1、修理工厂如何扩充：每日物资会赠送一个修理厂扩容，累计修理厂扩容券，扩容修理厂。
# 2、80级职业天赋中的通用天赋，会有修理车间扩容
# 3、修理工厂每天可以免费修理多少个：根据您的英雄韦德战地维修技能，如五星可以修理53个.
# 4、韦德是如何获得的：新手阶段赠送、英雄招募。
#
# -------[21]-----New FAQ--------
#
# 问题1: 请问韦德战地维修技能需要达到什么等级才能解锁？
#
# 回答1: 韦德战地维修技能需要达到4级才能解锁。
#
# 问题2: 修理工厂每天可以免费修理多少个单位？
#
# 回答2: 根据您的英雄韦德战地维修技能，如五星可以修理53个单位。
# -------[22]-----Origin FAQ--------
#
# 问:功能设置
# 答:如何更换皮肤？点击头像，点击城堡外观，找到你想切换的皮肤，点击立即使用即可如何切换铭牌？点击头像，点击铭牌，找到你想切换的铭牌，点击立即使用即可如何切换队列外观？点击头像，点击队列外观，找到你想切换的队列外观，点击立即使用即可如何切换城堡装饰?点击头像，点击城堡装饰，找到你想切换的城堡装饰，点击立即使用即可如何切换头像框？点击聊天界面，点击左下角的设置，点击后点击头像框设置，选择你想要更改的头像框，点击立即使用即可如何切换区服？点击头像，点击设置点击角色管理，点击新建账号，就可以选择自己想要去的区服了如何删除角色？想要删除现在的角色，需要先到其他区创建一个角色，在其他区的角色上，可以删除该角色。如何输入礼品码？点击头像，点击设置，点击礼品码，输入口袋奇兵的礼品码，点击确定即可兑换。如何查看自己的版本是否最新版本？点击头像，点击设置，点击对话框右下角的修复版本，就可以更新到游戏的最新版本如何绑定游戏账号?点击头像，点击设置，，点击账号绑定，选择微信还是QQ。（国外的是FB）
#
# -------[22]-----New FAQ--------
#
# 问题1: 如何更换城堡外观？ 答案: 点击头像，点击城堡外观，找到你想切换的皮肤，点击立即使用即可。
# -------[23]-----Origin FAQ--------
#
# 问:头像框如何设置
# 答:点击聊天----左下角设置----点击头像设置---挑选您想要使用的头像框---点击立即使用即可
#
# -------[23]-----New FAQ--------
#
# 问题1: 哪里可以找到游戏中的成就列表？
# 回答1: 在游戏中，您可以点击主屏幕右上角的“成就”按钮来查看您的成就列表。您也可以通过按下“菜单”按钮，然后选择“设置”>“显示”>“成就”来查看成就列表。
# -------[24]-----Origin FAQ--------
#
# 问:怎么举报？
# 答:1、举报是指玩家在游戏中遇到不良言论后，向官方提交相关信息的正义之举
# 2、举报的方法：如果在游戏中遇到其他玩家不当言论的情况，可以在聊天框点击对方的头像选择举报或者联系客服提供聊天截图进行举报（建议同时点击对方头像选择屏蔽）
#
# -------[24]-----New FAQ--------
#
# 问题1:
# 我在游戏中遇到了一个玩家，他说了一些脏话，我应该怎么做才能举报他？
#
# 回答1: 如果在游戏中遇到其他玩家不当言论的情况，可以在聊天框点击对方的头像选择举报。也可以联系客服提供聊天截图进行举报。请一定要注意保护自己，不要和对方发生争执。
# -------[25]-----Origin FAQ--------
#
# 问:禁言
# 答:1、禁言是指玩家无法在世界、联盟、私聊等发送任何信息的状态
# 2、禁言解除方法：可以联系客服确认是不是禁言状态，若确认为禁言，请等待禁言结束并留意措辞
#
# -------[25]-----New FAQ--------
#
# 问题1: 我被禁言了，怎么解除禁言？ 回答1: 您可以联系客服确认您是否被禁言，若确认为禁言，请等待禁言结束。在解除禁言之前，请一定要注意措辞，以避免再次被禁言。
# -------[26]-----Origin FAQ--------
#
# 问:性别和头像修改方法
# 答:点击头像可以选择修改性别和头像。如果修改自定义头像，需要修改下微信头像再重新登陆游戏等待一段时间就可以了（也可以通过修改微信性别来修改游戏角色性别）ps：游戏内修改性别首次免费，第二次500钻石
#
# -------[26]-----New FAQ--------
#
# 问题1: 怎样修改游戏头像？
#
# 回答1: 点击头像，可以选择修改性别和头像。如果修改自定义头像，需要修改下微信头像再重新登陆游戏等待一段时间就可以了（也可以通过修改微信性别来修改游戏角色性别）。
# -------[27]-----Origin FAQ--------
#
# 问:怎么联系人工客服
# 答:您可以点击右上角联系客服图标，选择对应问题分类填写信息并提交给人工客服喔
#
# -------[27]-----New FAQ--------
#
# 问题1:
# 回答1: 如果您在游戏中遇到了问题，可以通过点击右上角的“联系客服”图标，选择对应问题分类填写信息并提交给人工客服。我们会有专业的客服团队竭诚为您服务。
# -------[28]-----Origin FAQ--------
#
# 问:英雄
# 答:英雄是口袋骑兵游戏中的核心作战单位，不同英雄具有不同特色的技能、专属
# 1、英雄系统在游戏中的开放等级是5级。
# 2、英雄招募分为低级招募和高级招募，每种招募方式都有自己的消耗和获取的英雄类型。
# 3、低级招募每日有5次免费机会，可招募到蓝色、紫色英雄以及碎片。
# 4、高级招募每24小时有一次免费机会，可招募到紫色、橙色英雄以及碎片。
# 5、当英雄碎片达到10个时，可在英雄界面进行合成。
# 6、玩家获得英雄后，可以查看英雄的属性、升级和升星信息。
# 7、精英招募可以针对不同兵种英雄进行招募。
# 8、限时招募不定期开启，实际招募英雄以及时间以当次活动为准。
# 9、英雄可以通过消耗经验书进行升级，升级后英雄可以获得属性，英雄等级上限=20+英雄星级*20。
# 10、英雄可以通过消耗一定英雄碎片进行升星操作，每一个大星分为5阶，每次升星操作为升一次阶级，升阶会给予英雄大量的基础属性，升星的时候还回给予统率属性。
#
# -------[28]-----New FAQ--------
#
# 问题1: 什么是英雄？
#
# 回答1: 英雄是口袋骑兵游戏中的核心作战单位，不同英雄具有不同特色的技能、专属装备以及被动技能。
#
# 问题2: 英雄招募分为哪两种？
#
# 回答2: 英雄招募分为低级招募和高级招募，每种招募方式都有自己的消耗和获取的英雄类型。低级招募每日有5次免费机会，可招募到蓝色、紫色英雄以及碎片；高级招募每24小时有一次免费机会，可招募到紫色、橙色英雄以及碎片。
# -------[29]-----Origin FAQ--------
#
# 问:充值
# 答:1、充值的定义：是玩家通过有针对性、有目的性的对游戏内喜爱的礼包、特权、收益进行付费的行为
# 2、充值推荐：购买新手礼包、黑金百夫长（永久卡），成长基金，再进一步购买月卡、周卡、远征关卡礼包等都是性价比超高的礼包！礼包可以为您带来巨大的收益！建议您多和盟友们交流，一起探索游戏内的最佳薅羊毛大法！
#
# -------[29]-----New FAQ--------
#
# 问题1: 你觉得购买新手礼包和黑金百夫长哪个更划算？ 回答1: 我觉得购买新手礼包和黑金百夫长都是非常不错的，但是具体哪个更划算，还要看个人的需求。
#
# 问题2: 你有什么推荐的月卡、周卡和远征关卡礼包吗？ 回答2: 我推荐购买月卡、周卡和远征关卡礼包，它们可以给您带来巨大的收益和体验。
#
# 问题3: 充值怎么可以带来收益？ 回答3: 充值可以帮您获得更多的游戏资源和福利，比如游戏内的道具、经验、金币等等，这些资源和福利可以帮助您在游戏中更好地发展和成长。
# -------[30]-----Origin FAQ--------
#
# 问:充值未到账怎么办？
# 答:建议您先关闭手机免密支付，然后再次点击购买该礼包，但是不要支付（支付界面出现时，取消支付），试试看能否收到该礼包。如果您还是无法收到，您可以点击头像-设置-联系客服，将您的订单发给人工客服帮您核实补发一下~
#
# -------[30]-----New FAQ--------
#
# 问题1：充值为什么还没有到账？
# 回答1：建议您先关闭手机免密支付，然后再次点击购买该礼包，但是不要支付（支付界面出现时，取消支付），试试看能否收到该礼包。如果您还是无法收到，您可以点击头像-设置-联系客服，将您的订单发给人工客服帮您核实补发一下~
# 问题2：为什么我无法收到充值？
# 回答2：请您检查一下是否满足充值条件，例如是否已满18岁、充值的平台是否正确等。如果 all ok，可以尝试重新操作，或者联系客服进行反馈。
# -------[31]-----Origin FAQ--------
#
# 问:重复扣款怎么办？
# 答:我们游戏是不会双倍扣款的，请您确认下，其中是否有之前购买的礼包，平台延迟扣款了呢。如果您还有疑问，您可以点击头像-设置-联系客服帮您核对下~
#
# -------[31]-----New FAQ--------
#
# 问题1：我在你们游戏中意外地重复扣款了一次，请问你们会有双倍扣款的规定吗？
# 回答1：非常抱歉给您带来了不便。我们游戏是不会出现双倍扣款的，请您确认下，这其中是否有之前购买的礼包，平台延迟扣款了呢。如果有疑问，您可以点击头像-设置-联系客服帮您核对下。
# -------[32]-----Origin FAQ--------
#
# 问:充值记录查询
# 答:1、充值记录查询：由于您的消费行为属于您的隐私，我们无权进行全面查看，同时考虑到存在泄露风险（比如盗号者冒用您身份套取信息，进而非法获取所有权），所以我们无法向您提供，建议您自主查询支付平台（支付宝、银行卡等）的消费记录
# 2、一共充值了多少钱：建议您在游戏内查询对应军级点数即可大致估算，超过军级16的金额因为考虑保证您的隐私，已设置为隐藏，我们也无法查询具体金额，只知道您是尊贵的V16玩家
#
# -------[32]-----New FAQ--------
#
# 问题1: 能否查看我的充值历史记录？ 回答1: 您的消费行为属于您的隐私，我们无权进行全面查看，同时考虑到存在泄露风险（比如盗号者冒用您身份套取信息，进而非法获取所有权），所以我们无法向您提供，建议您自主查询支付平台（支付宝、银行卡等）的消费记录。
# -------[33]-----Origin FAQ--------
#
# 问:退款
# 答:1、退款的定义：已充值并成功到账的礼包等虚拟道具，用户自主向支付平台申请了返还操作。若成功，则用户已支付的金额会原路退回，同时已成功到账的虚拟道具会同步删除，无法删除则会扣除钻石或角色暂时封停。如果您对购买的礼包不满意，建议您联系游戏内人工客服可以帮您更换成其他等价礼包。
# 2、退款流程：如果您对购买的礼包不满意，建议您联系游戏内人工客服可以帮您更换成其他等价礼包。如果您确认想要退款，需要联系对应的支付平台，可以在账单里点击对“订单有疑惑”申请退款，如果已经提交退款申请，请您耐心等待留意平台反馈。
# 3、订单查看方法举例：在微信中点击【我】-【服务】-【钱包】-右上角的【账单】，找到对应订单并点击进入订单详情，下方有【对订单有疑惑】选项。
#
# -------[33]-----New FAQ--------
#
#  praise
#
# -------[34]-----Origin FAQ--------
#
# 问:礼包购买
# 答:1、礼包是什么：游戏官方基于广大玩家的需求，根据不同活动特性，精心准备的虚拟道具，往往具有较高的性价比
# 2、礼包的时效：所有礼包基本都会根据活动同步推出，具体的有效期会以倒计时的形式明确标注
# 3、礼包补买：因为不同礼包有不同的售卖周期和规则，具体是否可以补买需要联系游戏内客服，他们会根据您的实际情况（已购数量、开服时间、同期活动等）给您最精确的帮助和建议。
#
# -------[34]-----New FAQ--------
#
# 问题1：游戏内有哪些类型的礼包？ 回答1：游戏内提供的礼包类型非常丰富，包括但不限于新用户礼包、等级奖励、节日活动礼包、充值返利等等。
# 问题2：如何获得游戏内的新用户礼包？ 回答2：新用户礼包通常在游戏开服后一段时间内提供，可以通过参加官网、社区或者在游戏中获得相关的活动来获得。建议玩家多多关注官方活动，以抢占先机。
# 问题3：游戏内如何购买和使用合适的礼包？ 回答3：游戏内会有一些关于如何购买和使用合适的礼包的说明文档，建议玩家查看，并在游戏内通过相关操作进行购买和使用。如果还有疑问，可以随时联系游戏内客服，他们会根据您的具体情况给出帮助和建议。
# 问题4：游戏内不同的礼包有什么不同的优惠和限制？ 回答4：游戏内不同的礼包优惠和限制不同，包括但不限于活动时间、开服时间、已购数量等。建议玩家多关注官方活动，以了解近期最新的活动和购买限制。如果不确定是否可以购买某些特定类型的礼包，请随时联系游戏内客服，他们会根据您的实际情况给您最精确的帮助和建议。
# -------[35]-----Origin FAQ--------
#
# 问:金砖
# 答:1、金砖是一种充值后的代币，可以使用本地货币在官网进行金砖购买，在游戏内可直接购买付费礼包并优先消耗金砖，金砖的价值与本地货币价值一致。
# 2、金砖的使用方式：在游戏内可直接购买付费礼包，均可以优先消耗金砖，避免繁琐的充值操作
# 3、金砖的购买方式：可以通过官方网站→官方充值（右上角），输入您游戏内的识别码UID确认后，进行购买
# 4、金砖在游戏内消费后增加军级经验(VIP经验)。
#
# -------[35]-----New FAQ--------
#
# 问题1: 金砖的价值与本地货币价值是否一致？ 回答1: 是的，金砖的价值与本地货币价值一致。
#
# 问题2: 在游戏内如何购买付费礼包？ 回答2: 可以通过官方网站→官方充值（右上角），输入您游戏内的识别码UID确认后，进行购买。
#
# 问题3: 金砖的使用有什么优势？ 回答3: 金砖的使用方式更加便捷，可以直接购买付费礼包，可以优先消耗金砖，避免繁琐的充值操作。
#
# 问题4: 金砖如何增加军级经验(VIP经验)? 回答4: 金砖在游戏内消费后增加军级经验(VIP经验)。
# -------[36]-----Origin FAQ--------
#
# 问:设置按钮
# 答:在游戏中点击左上角头像-左下角设置弹出的界面中有设置按钮，可以对音效、操作、显示等进行调整或开启/关闭。
#
# -------[36]-----New FAQ--------
#
#
#
# 问: 游戏中的敌人有哪些类型?
# 答: 游戏中一共有三种敌人类型，分别是普通敌人、 Boss 敌人和小动物敌人。普通敌人是最常见的敌人类型，它们的数量最多，而且攻击力度也不大。Boss 敌人通常比较强大，需要玩家更多的策略和技巧才能击败。小动物敌人则较为可爱，但它们会主动攻击玩家，需要玩家小心应对。
# -------[37]-----Origin FAQ--------
#
# 问:数值单位
# 答:游戏的数值显示单位为
# k→m→b→t→aa→bb→cc→dd→ee→ff→gg→hh依次递进，1000进一个单位，比如1000=1k，1000k=1m，1000m=1b，1000b=1t，1000t=1aa，1000aa=1bb，1000bb=1cc。
#
# -------[37]-----New FAQ--------
#
# 问题1: 游戏中能量值的显示单位是什么？回答1: 游戏中能量值的显示单位是“bb”，每点能量值相当于1/1000次全功率输出的结果。问题2: 游戏中金币数量的最小显示单位是什么？回答2: 游戏中金币数量的最小显示单位是“kk”，即1000个金币。
# -------[38]-----Origin FAQ--------
#
# 问:帝国宝藏
# 答:帝国宝藏背景介绍：疯狂博士和他的黑暗英雄们,率领着黑暗军团冲入口袋奇兵大陆,他们不但大肆掠夺,还在寻找遗留在世界里帝国宝藏。指挥官们,就地组织反击,夺取宝藏和资源。最好,搞清楚这么多的疯狂博士和那些黑暗英雄到底从何而来。鉴于他们戒备森严,难以接近,希望你能获得他们内部的徽章。
# 帝国宝藏玩法介绍：
# 1.击败帝国宝藏的守卫--博士警卫,可获得大量道具,不同兵种的博士警卫的奖励也有不同。
# 2.您必须依次击败各个等级的博士警卫,才能挑战最高级的帝国宝藏。
# 3.您需要拥有伪造徽章,才能对博士警卫发起攻击。
# 4.被击败的博士警卫会进入整修时间。整修完毕,指挥官们才可以再次发起攻击
#
# -------[38]-----New FAQ--------
#
# 问题1:帝国宝藏中的博士警卫都有哪些不同等级？
# 回答1:帝国宝藏中的博士警卫分为多个等级，每个等级都拥有不同的实力和奖励。低等级的博士警卫可能只拥有少量资源，而高等级的博士警卫则可能拥有丰厚的道具和经验。
# 问题2:如何获得伪造徽章，可以对博士警卫发起攻击？
# 回答2:伪造徽章可以通过击败帝国宝藏中的博士英雄获取，每个博士英雄都有自己的徽章，如果成功击败他们，就可以得到伪造徽章，然后对博士警卫发起攻击。
# 问题3:帝国宝藏中的道具都有哪些，可以带来什么样的效果？
# 回答3:帝国宝藏中的道具多种多样，例如恢复生命值的药物、增加攻击速度的饰品、增强防御力的装备等等，这些道具可以帮助玩家更好的战斗。
# 问题4:帝国宝藏中的黑暗英雄从哪里来？
# 回答4:帝国宝藏中的黑暗英雄可能是来自于某个邪恶势力或者某个神话传说中的生物，因为帝国宝藏中战利品的奖励非常丰厚，所以吸引了众多黑暗英雄前来抢夺。
# 问题5:帝国宝藏可以给玩家带来什么样的收益？
# 回答5:帝国宝藏是一个可以获得丰厚奖励的区域，其中可以击败博士警卫获得道具、击败黑暗英雄获取徽章，还可以获得高额的经验和财富。
# 问题6:帝国宝藏中最高等级的博士警卫有多强大？
# 回答6:帝国宝藏中最高等级的博士警卫拥有无比强大的实力，他们的攻击和防御力都非常高，而且可能拥有特殊的技能和攻击方式。如何击败他们需要玩家运用智慧和实力的完美组合。
# -------[39]-----Origin FAQ--------
#
# 问:帝国宝藏怎么开启？
# 答:需要指挥官等级达到23级在原区服会开启帝国宝藏，如您在曙光之地中需要等到活动活动结束返回原服才能再次攻击帝国宝藏，您如果已经购买了伪造徽章是会正常计入的，请您活动结束后查看。
#
# -------[39]-----New FAQ--------
#
# 问题1: 我需要什么条件才能开启帝国宝藏？ 回答1: 需要指挥官等级达到23级 在原区服会开启帝国宝藏，如您在曙光之地中需要等到活动活动结束返回原服才能再次攻击帝国宝藏，您如果已经购买了伪造徽章是会正常计入的，请您活动结束后查看。
# -------[40]-----Origin FAQ--------
#
# 问:我的军级图标不见了
# 答:点击头像，设置，找到”是否显示军级“并打开后，就可以在头像下方查看到军级图标了
#
# -------[40]-----New FAQ--------
#
#
#
# 问: 我在游戏里找不到任务列表
# 答: 您可以在游戏设置中找到任务列表设置，并将其调整为打开状态。或者您也可以在主菜单中选择”任务“，然后即可查看您的任务列表。
# -------[41]-----Origin FAQ--------
#
# 问:游戏声音怎么关闭
# 答:点击头像，设置，可选择音乐，音效，配音的关闭或者开启
#
# -------[41]-----New FAQ--------
#
# 问题1: 如何变更游戏中的角色名称？
# 回答1: 在游戏中点击头像，选择“个人信息”或“账户设置”，即可进行角色名称的修改。
#
# 问题2: 怎样在游戏中购买更加强大的武器装备？
# 回答2: 在游戏中可以通过完成任务、击败敌人等方式获得游戏内的货币或虚拟物品，然后使用这些货币或虚拟物品在商店中购买更加强大的武器装备。
# -------[42]-----Origin FAQ--------
#
# 问:神秘盟友购买了礼包是怎么设置的
# 答:点击头像，设置，找到”购买者显示“并关闭后，
# 在购买带有联盟礼物的礼包时稀有礼物那边就会显示：一位神秘盟友购买了礼包
#
# -------[42]-----New FAQ--------
#
# 问题1:如何关闭”购买者显示“？ 回答1: 点击头像，选择设置，找到”购买者显示“并关闭即可。 问题2: 神秘盟友购买了礼包后，显示的内容是什么？ 回答2: 若购买带有联盟礼物的礼包，则稀有礼物那一栏会显示：一位神秘盟友购买了此礼包。
# -------[43]-----Origin FAQ--------
#
# 问:转区，转服后多久之后才能再次转
# 答:转入成功后需要冷却30天后才能再次转
#
# -------[43]-----New FAQ--------
#
# 问题1: 转区后可以在同一账号下进行转服吗？回答1: 不可以，转区操作会清空账号下的角色和数据，需要重新创建角色。问题2: 如果我想转到另一个服务器，需要等多久才可以再次转区？回答2: 根据游戏的规定，转区成功后需要等待30天才可以再次转区。
# -------[44]-----Origin FAQ--------
#
# 问:目前战斗力包含哪些？
# 答:领地战斗力、科技战斗力、英雄战斗力、军火库战斗力、职业战斗力、重装机兵战斗力、军阵战斗力。
#
# -------[44]-----New FAQ--------
#
# 问题1: 领地战斗力包括哪些方面的内容？
# 回答1: 领地战斗力包括领土面积、驻军数量、建筑等级、城市设施等。
#
# 问题2: 重装机兵战斗力是什么？有什么提高方法？
# 回答2: 重装机兵战斗力指的是使用重装机兵士兵在战斗中的表现。可以通过升级重装机兵武器、技能、装备等来提高重装机兵的战斗力。
# -------[45]-----Origin FAQ--------
#
# 问:兵种克制是什么
# 答:兵种克制是一个功能，基地等级达到45级时可解锁该功能，
# 陆军克制空军，空军克制海军，海军克陆军，运用兵种克制取得胜利吧！
#
# -------[45]-----New FAQ--------
#
# 问题1: 什么是兵种克制？ 回答1: 兵种克制是一个功能，基地等级达到45级时可解锁该功能。 问题2: 如何运用兵种克制取得胜利？ 回答2: 通过合理搭配和运用不同兵种之间的克制关系，可以取得对对手的胜利。例如，可以先用空军打击对手的海军，再用陆军击败剩余的对手。
# -------[46]-----Origin FAQ--------
#
# 问:通用天赋是什么
# 答:通用天赋是一个功能，基地等级达到80级时可解锁该功能
#
# -------[46]-----New FAQ--------
#
# 问题1: 我基地等级已经达到了80级，但是为什么我还不能解锁通用天赋呢？
# 回答1: 需要是满足一定的条件才能解锁通用天赋，例如邮箱绑定、花一定的金币购买、完成指定的任务等等。你可以查看游戏内的说明或者咨询客服来获取更多详细信息。
# -------[47]-----Origin FAQ--------
#
# 问:增加战斗回合上限是什么
# 答:目前默认战斗回合上限为35,研究对应天赋后可以增加回合数量。
# 当战斗中AB双方势均力敌打满35回合后,如果A的回合上
# 限为36回合,B的回合为35,此时由于B无队伍可更换,
# B会因此战斗失败。
#
# -------[47]-----New FAQ--------
#
# 问题1: 我可以通过哪种方式来增加战斗回合上限？
# 回答1: 目前默认战斗回合上限为35，可以通过研究对应的天赋来增加回合数量。如果武术天赋被研究，战斗回合上限可以增加至40。如果武术天赋和政治天赋都被研究，战斗回合上限可以增加至45。
# -------[48]-----Origin FAQ--------
#
# 问:一回合是怎么算的
# 答:您打对方一下，对方又打您一下为一回合
#
# -------[48]-----New FAQ--------
#
# 问题1:在一局游戏中，当我攻击对手时，他是否也会同时攻击我？
#
# 回答1:是的，当你攻击对手时，他也会同时攻击你。这就是一回合的计算方式：你攻击对方，对方同时攻击你，这就算作一回合。
# -------[49]-----Origin FAQ--------
#
# 问:一轮次是怎么算的
# 答:双方全部单位行动后为一轮
#
# -------[49]-----New FAQ--------
#
# 问题1: 什么是轮次？
# 回答1: 轮次指的是双方全部单位行动后的一轮。
# -------[50]-----Origin FAQ--------
#
# 问:空投
# 答:空投是一种游戏内的常规活动
# 1.空投补给活动以2天为单位，隔天开启。以联盟为单位进行的活动，开启时间由投票（无首领）或首领选择，每两天兑换活动会刷新一次兑换次数。
# 2.活动第一天0点，兑换活动将刷新兑换次数，并清除指挥官在上一轮活动中剩余的空投资源箱道具。
# 3.运输机将在地图上随机投放3轮空投。指挥官可以派兵前往空投点争夺空投资源箱。在搬运过程中，其他玩家可以对运输车队进行拦截。成功将空投箱运至要塞后，盟内所有成员均可在聊天界面领取空投资源箱奖励，同时搬运的指挥官将通过邮件额外获得奖励。
# 4.争夺空投不消耗体力、同时不会取消已有的护盾保护状态。
# 特殊说明：
# 1.为了让更广大的指挥官能参与到活动中，我们将大幅增加每轮空投点的个数。并大幅提高橙色空投点包含的空投资源箱数量。同时兑换功能将适度调整道具数量。
# 2.空投轮数将由3轮降低为2轮。
#
# -------[50]-----New FAQ--------
#
# 1. 请问空投刷新时间是固定的吗？答: 不是固定的。空投补给活动会以2天为单位，隔天开启。以联盟为单位进行的活动，开启时间由投票（无首领）或首领选择，每两天兑换活动会刷新一次兑换次数。
# -------[51]-----Origin FAQ--------
#
# 问:最强指挥官
# 答:最强指挥官是一种游戏内的常规活动
# 最强指挥官开启时间：服务器开启后就会开放最强指挥官活动，可以在游戏内点击右侧活动中心按钮查看。
# 最强指挥官介绍：各位指挥官每天达到制定的目标即可获得高额奖励，此活动每周循环。
# 最强指挥官奖励发放时间：次日0点结算当日积分，丰厚的排行奖励将以邮件形式送达。
# 最强指挥官活动详情：
# 周一：消耗金币-消耗金币可获得积分（金币消耗量=积分获取量）
# 周二：疯狂造兵-生产兵种获得积分（训练士兵等级越高，积分越多）
# 周三：击杀战锤-击杀战锤获得积分（集结队长2分，队员1分。作为队员每日最多获得50分）
# 周四：肃清怪物-击杀野外怪物获得积分
# 周五：采集资源-采集资源数量（采集量、采集速度、基地等级有关）
# 周六：提升战力-提升自身战斗力（训练士兵、建造建筑）
# 周日：击杀敌兵-攻击/防守其他玩家时杀死对方士兵获得积分
#
# -------[51]-----New FAQ--------
#
# 问题1: 在最强指挥官活动中，如何获得积分？ 回答1: 消耗金币、疯狂造兵、击杀战锤、肃清怪物、采集资源和提升战力都可以获得积分。
#
# 问题2: 可以在最强指挥官活动中获得什么奖励？ 回答2: 除了可以每天都达到目标获得高额奖励外，周结算时还会以邮件形式送达丰厚的排行奖励，包括金币、钻石、道具和其他游戏内的福利。
# -------[52]-----Origin FAQ--------
#
# 问:人气之星
# 答:1.人气之星是一种不定期开启的常规活动。
# 2.人气之星活动玩法：活动中通过赠送玫瑰和话筒提升排行榜积分。
# 3.人气之星奖励：玩家通过收到和送出的玫瑰/麦克风分为收花榜和送花榜，总排行榜分为本战区的收花榜、送花榜和全战区排行的收花榜、送花榜。具体奖励可以进入活动中心-人气之星，左上角“！”查看。可以通过活动获得特定活动皮肤：人气之星皮肤（收花榜）和粉丝团长皮肤（送花榜）。上述活动皮肤使用属性均为：最高兵种合成等级+1，相当于合成士兵科技等级+1，不针对补给礼包内购买的士兵，如果海陆空同样最高级，可以同时享受。除全战区排行收花榜、送花榜第一为永久皮肤，其他排行奖励包含的皮肤奖励均有使用期限，使用期限以使用对应皮肤道具后开始计算时间。详细活动玩法，活动开放期间参考具体的活动开放时间和内容哦~
#
# -------[52]-----New FAQ--------
#
# 问题1: 活动中心-人气之星在哪里可以找到？ 回答1: 活动中心-人气之星在游戏主界面的右上角，可以通过点击“活动中心”图标进入。您也可以点击左下角的“福利”按钮，再选择“活动中心”进入。
#
# 问题2: 都有什么皮肤可以被评为人气之星？ 回答2: 可以被评为人气之星的皮肤有：人气之星皮肤（收花榜）和粉丝团长皮肤（送花榜）。这些皮肤有独特的外观效果，可以为您的游戏角色添加一些额外的个性化元素。此外，这些皮肤还可以带来一些额外的属性加成，如最高兵种合成等级+1等。
#
# 问题3: 活动期间，排行榜是如何计算的？ 回答3: 影响排行榜的计算因素有很多，包括您在活动中赠送和收到的玫瑰/麦克风数量、质量和时间。每次赠送和收到的玫瑰/麦克风都会为您的收花榜和送花榜增加积分，最终的排行榜排名将根据总积分情况进行计算。
#
# 问题4: 活动结束后，哪些皮肤可以永久保留？ 回答4: 在活动结束后，只有全战区排行榜收花榜、送花榜第一的玩家可以获得永久皮肤。其他排名奖励中的皮肤奖励都将有限时使用期限，使用期限以使用对应皮肤道具后开始计算时间。
#
# 问题5: 活动期间，如何查看自己的排名？ 回答5: 在活动期间，您可以通过活动中心-人气之星的左上角查看自己的排名，具体排名信息包括：收花榜和送花榜的排名、总排行榜收花榜、送花榜和全战区排行榜的收花榜、送花榜。
#
# 问题6: 可以与其他排行榜排名进行比较吗？ 回答6: 是的，您可以与其他排行榜排名进行比较，看看自己在全战区排行榜、收花榜、送花榜的表现如何。
#
# 问题7: 活动期间，皮肤奖励的具体属性是什么？ 回答7: 活动期间，皮肤奖励可以为您的角色带来一定的属性加成，如最高兵种合成等级+1等。除此之外，这些皮肤还可以为您的角色带来一些特殊的外观效果，让您的游戏角色更加与众不同。
# -------[53]-----Origin FAQ--------
#
# 问:人气之星送花限制
# 答:人气之星送花限制：
# VIP0：每天可送花5朵
# VIP1：每天可送花9朵
# VIP2：每天可送花45朵
# VIP3：每天可送花99朵
# VIP4：每天可送花520朵
# VIP5：每天可送花999朵
# VIP6：每天可送花1314朵
# VIP7及以上：每天可送花数量无限制
#
# -------[53]-----New FAQ--------
#
# 问题1: 普通玩家每天可以送花多少朵? 回答1: 普通玩家每天可以送花5朵。
#
# 问题2: VIP会员可以送花的数量限制是多少？ 回答2: VIP会员可以送花数量限制是按照VIP等级的不同而有所不同，具体如下：
# VIP0：每天可送花5朵 VIP1：每天可送花9朵 VIP2：每天可送花45朵 VIP3：每天可送花99朵 VIP4：每天可送花520朵 VIP5：每天可送花999朵 VIP6：每天可送花1314朵 VIP7及以上：每天可送花数量无限制
# -------[54]-----Origin FAQ--------
#
# 问:玫瑰/麦克风怎么使用？
# 答:在人气之星活动期间，在送花限制数量内您可以在活动页面点击右侧的【送给好友】按钮，会弹出好友列表，可以选择一个好友进行赠送喔，也可以点击排行榜里的玩家赠送，有不同数量的玫瑰/麦克风个数选择，如玫瑰/麦克风不足会弹出商店购买界面，购买成功后即可赠送对应数量的玫瑰/麦克风。
#
# -------[54]-----New FAQ--------
#
# 问题1: 在活动中赠送玫瑰/麦克风时，如果数量不足如何操作？
#
# 回答1: 如果数量不足，您可以在活动页面点击商店购买界面进行购买，购买成功后即可赠送对应数量的玫瑰/麦克风。
# -------[55]-----Origin FAQ--------
#
# 问:战争之源
# 答:1、战争之源是一种常规活动
# 2、战争之源的时间：世界BOSS是在每天的凌晨4点、中午12点和晚上的8点开启（跨服战准备阶段和战斗阶段不开启）
# 3、战争之源奖励发放时间：每日3次击杀boss活动只奖励一次，取最高排名进行奖励，所以会在每日第3个boss被击杀或者离开后发放奖励。
# 4、战争之源玩法：每轮活动中，您仅能针对boss发起最多不超过5次的攻击。按照伤害排名发放对应奖励
# 5、战争之源是注意事项：和BOSS战斗中如果队列中的士兵全输的时候，队列会立即返回，到家之后生成20%伤兵。
#
# -------[55]-----New FAQ--------
#
# 问题3:
# 回答3:
#
# 问题4:
# 回答4:
#
# 问题5:
# 回答5:
# -------[56]-----Origin FAQ--------
#
# 问:我的攻击属性明明增加了怎么打boss伤害没有提高？
# 答:对世界BOSS造成的总伤害，会因暴击、闪避、英雄技能触发情况有所浮动喔。如果您提升了攻击加成属性，建议您根据战斗回放对比下单次伤害是否增加了喔
#
# -------[56]-----New FAQ--------
#
# 问题1: 我在战斗中怎么提高我的暴击率呢？ 回答1: 暴击率的提高可以通过一些方法实现，如角色的技能、装备、宝石等。先来了解一下你的角色技能是否有暴击效果，如果有，那么就可以通过升级技能，提高暴击率。另外，装备方面，可以通过购买具有暴击效果的装备，如武器、项链等，来增加暴击率。此外，还可以通过宝石的镶嵌，选择增加暴击率的宝石，来提升暴击率。综上所述，在游戏中提高暴击率需要对角色的技能、装备和宝石都有所了解，并一一进行相应的提升。
# -------[57]-----Origin FAQ--------
#
# 问:我打了世界boss但是没有收到奖励
# 答:世界boss会在每天这三个时间（UTC+8时区）：4:00、12:00（周日是12:05）、20:00出现，每次世界boss出现时，每个玩家最多可以攻击5次（每天三场共可以攻击15次）。奖励将在当天21:00（UTC+8时区）根据单场最高名次，通过邮件发放奖励。
#
# -------[57]-----New FAQ--------
#
# 问题1: 我该如何攻击世界boss？
# 回答1: 您可以每天定时关注世界boss出现的时间，然后在它出现时及时参与攻击。在攻击时，您最多可以攻击5次，并且需要和其他玩家竞争获得最高名次才会获得奖励。
# 问题2: 奖励会在何时发放？
# 回答2: 奖励会在每天21:00（UTC+8时区）发放。因此，您需要在攻击世界boss后等待一段时间，才能获得您的奖励。
# 问题3: 我可以在不同时间段攻击世界boss吗？
# 回答3: 您可以在每个出现的时间段都参与攻击，但是您只有每次参与攻击的5次机会。因此，您需要在每次出现的时间段内都积极参与，以获得最高名次和最佳奖励。
# -------[58]-----Origin FAQ--------
#
# 问:为什么我拉空投的时候，我的全兵种攻击加成是负数
# 答:运输空投的队列会有负面效果的哦行军速度-全部-百分比：减90%全部单位生命加成：减60%全部单位攻击加成：减60%
#
# -------[58]-----New FAQ--------
#
# 赞扬回答
#
# 问题1: 为什么我拉空投的时候，我的全兵种攻击加成会变成负数？ 回答1: 运输空投的队列会有负面效果，会给您的行军速度、全部单位生命加成和全部单位攻击加成都带来降低，具体降低数值为：减去90%的行军速度，减去60%的全部单位生命加成，以及减去60%的全部单位攻击加成。
#
# 问题2: 如何解决这个问题？ 回答2: 很抱歉，这个问题是游戏中固有的设定，解决方法有限。您可以在游戏过程中尽量避免拉空投或者尽量减少空投的数量，以保持您的队伍攻击加成的最大化。此外，您还可以通过使用一些游戏辅助工具，如游戏脚本和网络加速工具等，来提高游戏的流畅度和稳定性，从而提高游戏体验。
# -------[59]-----Origin FAQ--------
#
# 问:联盟保卫战
# 答:联盟保卫战开启条件：玩家至少有一个联盟且联盟有一个联盟堡垒。只有盟主才能报名开启。报名时可以选择XX小时后开启。
# 联盟保卫战如何参加防守据点：玩家可以点击开启联盟保卫战的联盟据点，点击之后点击驻守，在点增员就可以参加保卫据点。
# 如何知道哪个据点在参加联盟保卫战：可以点击活动，点击前往据点，或者查看堡垒，就可以找到参与活动的联盟据点。
# 联盟保卫战期间为什么没办法加入联盟：该联盟从报名联盟保卫战开始就无法加入联盟，只有该联盟保卫战结束之后，才可以在进行申请。
# 联盟保卫战积分如何获得：可以杀死怪物，或者使用精科导弹削弱怪物跟修理联盟堡垒都可以获得积分。
# 精科导弹哪里获取：击杀大地图上的野怪有一定概率获取精准导弹。
# 精科导弹有什么用：1.可以修理联盟堡垒的血量。2.可以降低当前波次攻城怪物的实力。
# 联盟保卫战如何能打高分：建议不要急着打，联保保卫战是联盟所有人的事，所以先准备充足的精科导弹，人员齐备之后再开启。精科导弹可以降低怪物的实力，可以修理堡垒。
# 联盟保卫战换盟可以重新打，排行榜积分记录在新盟，已经领取的波次奖励和积分奖励无法重复领取。
#
# -------[59]-----New FAQ--------
#
# 问题1: 入盟保卫战需要哪些条件？如何参加防御据点？
# 回答1: 联盟保卫战开启条件：玩家至少有一个联盟且联盟有一个联盟堡垒。只有盟主才能报名开启。报名时可以选择XX小时后开启。参加防御据点：玩家可以点击开启联盟保卫战的联盟据点，点击之后点击驻守，在点增员就可以参加保卫据点。
# -------[60]-----Origin FAQ--------
#
# 问:个人保卫战只失败了一次就结束了？
# 答:个人保卫战一共有25波怪物攻城，失败三次或者打完25波就会结束噢
#
# -------[60]-----New FAQ--------
#
# 问题1: 我在个人保卫战中失败了两次，还能继续游戏吗？
# 回答1: 当然，你还可以继续游戏，但是你需要在接下来的23波怪物攻城中成功击败它们。建议你查看游戏中的攻略，加强你的技能，并尝试不同的策略来战胜敌人。
# 问题2: 在个人保卫战中，怪物的攻击力很强，我应该怎么办？
# 回答2: 在个人保卫战中，怪物的攻击力很强，你可以尝试使用一些防御装备和道具来加强你的防御能力。此外，你还可以升级你的角色，提高你的攻击力，以更好地应对怪物的攻击。
# -------[61]-----Origin FAQ--------
#
# 问:个人保卫战报名
# 答:因为要预留出怪物攻城的时间，该活动的报名时间会在活动结束时间前两小时截止哦，还请下次提早报名
#
# -------[61]-----New FAQ--------
#
# 问题1: 报名截止时间是什么时候？
# 回答1: 报名截止时间会在活动结束时间前两小时截止，还请下次提早报名。
# 问题2: 这个活动是怎样的？
# 回答2: 这个活动是一个个人保卫战，玩家需要和其他玩家一起击败怪物，保卫城市。
# -------[62]-----Origin FAQ--------
#
# 问:个人保卫战能重新打吗
# 答:个人保卫战每次活动只能打一次
#
# -------[62]-----New FAQ--------
#
# 问题1: 请问个人保卫战重不重新开始？
#
# 回答1: 不可以，个人保卫战每次活动只能打一次，无法重新开始。
# -------[63]-----Origin FAQ--------
#
# 问:跨服战
# 答:【匹配阶段】占领敌方控制的要塞（在真正获得要塞指挥权时，每名身处要塞的玩家可获得60分）。注意：1.前线堡垒、导弹发射井不需要占领时间，攻打下的瞬间即交换控制权。2.区域要塞有占领时间，是固定值。3.首府有占领时间，随着战斗时间的延长，占领时间将逐渐缩短。若直到战斗阶段结束，两服都没能成功占领对方首府，则占领区域数量多的服获得胜利。若两服占领区域数量一致，则两服同时判负。【领奖阶段】在领奖阶段，指挥官可以根据跨服战过程中的表现在活动界面领取奖励。系统也会自动发放“跨服战胜利奖励”及“杀敌排名奖励”。【特殊说明】1.部分活动暂时关闭：在战斗阶段，补给争夺和世界boss活动将暂时关闭。2.联盟相关功能暂时关闭：在战斗阶段，联盟相关的功能将暂时关闭。指挥官无法成立、加入、退出联盟，也无法进行科技捐献。3.新增跨服聊天：匹配在一起的两服指挥官可以在新增的跨服聊天频道中交流。4.伤兵迁服功能：若身处敌服的您想回到本服，可以点击前线堡垒进行迁回。其中通过己方占领的前线堡垒可以无伤迁回本服，通过地方占领的前线堡垒会以一定比例士兵为代价迁回本服。5.在《准备阶段》《战斗阶段》过程中，玩家无法攻击“相同服务器归属”的玩家。【时间调整】11月24日起，首府战：由《每周六13:00~15:00》调整为《每周日10:00~12:00》跨服战：由《周一至周六捐献，周日10:00~12:00战斗》调整为捐献阶段：周一00:00-周六18:59准备阶段：周六19:00-周六20:59战斗阶段：周六21:00-周六22:59领奖阶段：周六23:00-周日23:59后续活动时间如有调整，可关注游戏内公告以及活动页面。
#
# -------[63]-----New FAQ--------
#
# 1. 跨服战的匹配阶段需要占领哪些区域才能获得要塞指挥权？ 答案：占领敌方控制的前线堡垒、导弹发射井和区域要塞全部获胜，获得60分。注意：前线堡垒、导弹发射井不需要占领时间，攻打下的瞬间即交换控制权；区域要塞有占领时间，是固定值；首府有占领时间，随着战斗时间的延长，占领时间将逐渐缩短。若直到战斗阶段结束，两服都没能成功占领对方首府，则占领区域数量多的服获得胜利；若两服占领区域数量一致，则两服同时判负。
# 2. 跨服战的领奖阶段，指挥官可以获得哪些奖励？ 答案：在领奖阶段，指挥官可以根据跨服战过程中的表现在活动界面领取奖励。系统也会自动发放“跨服战胜利奖励”及“杀敌排名奖励”。
# 3. 跨服战期间，哪些活动将暂时关闭？ 答案：在战斗阶段，补给争夺和世界boss活动将暂时关闭。指挥官无法成立、加入、退出联盟，也无法进行科技捐献。
# 4. 跨服战期间，新增了哪些功能？ 答案：新增了跨服聊天，匹配在一起的两服指挥官可以在新增的跨服聊天频道中交流。
# 5. 在准备阶段和战斗阶段，玩家可以攻击“相同服务器归属”的玩家吗？ 答案：在《准备阶段》《战斗阶段》过程中，玩家无法攻击“相同服务器归属”的玩家。
# 6. 跨服战的时间安排是什么？ 答案：11月24日起，首府战：由《每周六13:00~15:00》调整为《每周日10:00~12:00》
# 7. 跨服战的捐献阶段是什么时候？ 答案：周一00:00-周六18:59
# 8. 跨服战的准备阶段是什么时候？ 答案：周六19:00-周六20:59
# 9. 跨服战的战斗阶段是什么时候？ 答案：周六21:00-周六22:59
# 10. 跨服战的领奖阶段是什么时候？ 答案：周六23:00-周日23:59
# 11. 未来汉新手玩家可以参加跨服战吗？ 答案：目前汉新手玩家暂时不允许参加跨服战，需要达到一定条件才能参加。
# 12. 有没有跨服转服的功能？ 答案：暂时没有跨服转服的功能，玩家需要回到本服。
# 13. 在跨服民间战争中，如何加快获取积分？ 答案：修建更多的首都建筑，越多的建筑代表着可以更快的赚取积分。
# -------[64]-----Origin FAQ--------
#
# 问:个人保卫战波数26
# 答:兵种：海军、 士兵数量：550
#
# -------[64]-----New FAQ--------
#
# 问题1: 我拥有550名士兵，如何搭配兵种组成一支强大的海军？
# 回答1: 在搭配兵种方面，可以考虑将补充型的支援型和防御型兵种相结合，例如水雷、驱逐舰、反潜舰以及巡洋舰等。同时，也可以考虑增加ный корабль（旗舰）以提高舰队的指挥和协调能力。此外，还可以使用各种可以提供额外攻击和防御能力的装备和道具，例如鱼雷发射器、防空导弹和反潜导弹等。
# -------[65]-----Origin FAQ--------
#
# 问:个人保卫战波数27
# 答:兵种：空军、 士兵数量：620
#
# -------[65]-----New FAQ--------
#
# 问题1: "在个人保卫战波数27的战斗中，我应该如何更加有效地利用我的空军？"
# 回答1: "在个人保卫战波数27的战斗中，有效地利用空军可以让你的防御更加坚固，可以考虑以下几点：
#
# 1. 安排恰当的空袭时间：在敌方军队靠近你的防御区域时进行空袭，可以有效地减缓其攻击速度。
#
# 2. 配合 soldiers 部队：空中支援 soldiers 部队，在关键时刻关键时刻给予关键性支援。
#
# 3. 尽量避免空袭失败：如果空袭失败，将会对你的防御造成极大威胁。"
#
# 问题2: "在个人保卫战波数27中，我应该如何配置士兵数量来展示我的力量？"
# 回答2: "在 personal保卫战波数27 中，配置合适的士兵数量对于展示你的力量非常重要。一般来说，可以根据以下几点来配置士兵数量：
#
# 1. 了解敌我双方的实力：了解敌人的兵种和数量，从而合理配置 soldiers数量。
#
# 2. 配置士兵的位置：根据你的防御区域和敌方进攻方案，配置 soldiers位置能够有效保护你的防御区域。
#
# 3. 调整兵种搭配：要根据敌人的兵种和自己的 soldiers数量进行搭配，例如，可以用老兵替换新技术兵种，从而加强防御力量。"
# -------[66]-----Origin FAQ--------
#
# 问:个人保卫战波数28
# 答:兵种：陆军、 士兵数量：700
#
# -------[66]-----New FAQ--------
#
# 问题1:如何在个人保卫战波数28中使用陆军？
# 回答1:在波数28中使用陆军的最佳做法是充分了解每个兵种的优势和劣势，以便在战略和战术上做出最佳选择。 你可以考虑将兵力集中在一些关键词可能被搜索到的地方，以此来增加你的胜率。此外，确保你的士兵在游戏中的移动速度与你的敌人相仿。
# -------[67]-----Origin FAQ--------
#
# 问:个人保卫战波数29
# 答:兵种：海军、 士兵数量：780
#
# -------[67]-----New FAQ--------
#
# 问题1: 在个人保卫战中，如何提高海军的作战能力？
# 回答1: 提高海军的作战能力需要从多个方面进行改善，包括加强舰船的建造和升级、增加海军的数量和素质、优化海上的战术和指挥等。建议在游戏中多多练习，积累经验，找出自己在海上的不足之处，并针对性地进行改进。此外，还可以通过研究游戏中的海军战术和战略，了解海军的优势和劣势，从而更好地运用它们来进行作战。
# -------[68]-----Origin FAQ--------
#
# 问:个人保卫战波数30
# 答:兵种：空军、 士兵数量：880
#
# -------[68]-----New FAQ--------
#
# 问题1: 请问在个人保卫战中，选择哪种兵种能够更好地保护我的基地？
# 回答1: 在个人保卫战中，选择空军兵种能够更好地保护你的基地。因为空军可以在空中进行攻击，无法被地面单位抵挡，可以迅速打击敌人，减少敌人的进攻次数，从而保护你的基地。
# 问题2: 那么我需要多少士兵来保护我的基地呢？
# 回答2: 在个人保卫战中，你需要880个士兵来保护你的基地。这是因为，根据游戏规则，每个士兵有2点攻击力，保护你的基地需要880点攻击力，所以需要880个士兵。
# -------[69]-----Origin FAQ--------
#
# 问:个人保卫战一共有多少关？
# 答:黑暗帝国将派遣30波部队。
#
# -------[69]-----New FAQ--------
#
# 问题1: 我在个人保卫战中怎样才能获得更高的分数？
# 回答1: 在个人保卫战中获得更高的分数，可以通过多种方式来实现，例如提升角色等级、获得更多的装备和武器、参与更多任务和挑战等。另外，你还可以尝试在游戏中发掘更多的隐藏要素和技巧，以及与其他玩家合作或竞争来获得更高的分数。
# -------[70]-----Origin FAQ--------
#
# 问:个人保卫战达到30积分奖励
# 答:在个人保卫战中积分达到30分奖励含有：钻石100*1、训练加速1小时*2、重装芯片宝箱*1
#
# -------[70]-----New FAQ--------
#
# 问题1: 我在个人保卫战中如何才能达到30积分？ 回答1: 在个人保卫战中达到30积分需要积极参与战斗，击杀敌方玩家以及摧毁敌方防御塔。同时也可以通过完成保卫任务、摧毁敌方基地等方式获得积分。问题2: 我在游戏中积攒了30积分后，可以获得什么奖励？ 回答2: 通过积攒30积分可以在游戏中获得钻石100、训练加速1小时以及重装芯片宝箱等丰富的奖励，让你的游戏体验更加精彩。
# -------[71]-----Origin FAQ--------
#
# 问:个人保卫战达到75积分奖励
# 答:在个人保卫战中积分达到75分奖励含有：金币砰砰宝箱*50、训练加速1小时*5、重装芯片宝箱*2
#
# -------[71]-----New FAQ--------
#
# 问题1: 什么是个人保卫战？
# 回答1: 个人保卫战是一个游戏模式，在该模式中，玩家将代表自己的阵营与其他玩家进行 Wars 争夺。玩家可以通过击败敌人、摧毁建筑和收集资源来获得积分，并通过击败敌人、摧毁建筑和收集资源来获得积分。积分越高，获得的奖励就越好。
# 问题2: 我要如何在个人保卫战中达到75积分奖励？
# 回答2: 如果你想在个人保卫战中达到75积分奖励，你需要在游戏中击败足够多的敌人、摧毁足够多的建筑，并收集足够的资源。具体来说，你可以尝试以下方法：
#
#   1. 练习攻击技巧，提高击败敌人的效率。
#   2. 谨慎使用资源，确保它们的合理分配和充分利用。
#   3. 寻找盟友，互相支持，共同击败敌人。
#   4. 避免不必要的消耗，尽量减少损失。
#   5. 充分利用游戏中的提示和教程，提高自己的游戏技能和经验。
#
# 如果按照以上步骤，你就可以在游戏中达到75积分奖励了！
# -------[72]-----Origin FAQ--------
#
# 问:个人保卫战达到200积分奖励
# 答:在个人保卫战中积分达到200分奖励含有：体力50点*1、训练加速8小时*1、中级重装芯片宝箱*1
#
# -------[72]-----New FAQ--------
#
# 问题1: 在个人保卫战中，当我达到多少积分时才能获得200积分奖励？
# 回答1: 当你在个人保卫战中积攒达到200积分时，即可获得体力50点、训练加速8小时和中级重装芯片宝箱的奖励。
#
# 问题2: 我如何才能在个人保卫战中获得积分？
# 回答2: 通过完成任务、消灭敌人和击败对手等行为来获得个人保卫战积分，积分可以用来提升角色等级和解锁更多道具和奖励。
# -------[73]-----Origin FAQ--------
#
# 问:个人保卫战达到500积分奖励
# 答:在个人保卫战中积分达到500分奖励含有：绿色图纸随机箱*1、机甲碎片*2、3级强化自选箱*5、训练加速8小时*1
#
# -------[73]-----New FAQ--------
#
# 问题1：如何获得个人保卫战的积分？
# 回答1: 个人保卫战的积分可以通过击败敌人、完成任务和参加活动等方式获得。每击败一个敌人可以获得5分，每完成一项任务可以获得10分，每参加一次活动可以获得20分。
#
# 问题2：在个人保卫战中达到积分奖励需要多少分呢？
# 回答2: 在个人保卫战中达到积分奖励需要达到500分。达到此分数后，将获得绿色图纸随机箱*1、机甲碎片*2、3级强化自选箱*5、训练加速8小时*1等丰厚奖励。
# -------[74]-----Origin FAQ--------
#
# 问:个人保卫战达到700积分奖励
# 答:在个人保卫战中积分达到700分奖励含有：绿色图纸随机箱*1、机甲碎片*4、低级橙色碎片合成箱*5、训练加速8小时*1
#
# -------[74]-----New FAQ--------
#
# 问题1: 个人保卫战中获得700积分需要做什么才能获得奖励？
# 回答1: 在个人保卫战中通过杀死敌方玩家、摧毁敌方防御塔或摧毁敌方基地等方式获得积分，当积分达到700分时，即可获得绿色图纸随机箱*1、机甲碎片*4、低级橙色碎片合成箱*5、训练加速8小时*1的奖励。
#
# 问题2: 个人保卫战中除了获得700积分的奖励之外，还有其他获得积分的方式吗？
# 回答2: 对的，个人保卫战中还有很多其他获得积分的方式，例如摧毁敌方防御塔、击败敌方英雄、摧毁敌方基地等。通过完成这些任务，可以增加自己的积分，达到更高的排名和奖励。
# -------[75]-----Origin FAQ--------
#
# 问:个人保卫战达到1000积分奖励
# 答:在个人保卫战中积分达到1000分奖励含有：蓝色图纸随机箱*1、机甲碎片*4、橙色万能碎片*1、训练加速8小时*1
#
# -------[75]-----New FAQ--------
#
# 问题1: 个人保卫战中获得1000积分会得到什么样的奖励？ 答案1: 个人保卫战中积分达到1000分奖励含有：蓝色图纸随机箱*1、机甲碎片*4、橙色万能碎片*1、训练加速8小时*1。
#
# 问题2: 能否分享一下其他可以获得积分的方法？ 答案2: 除了参加个人保卫战，还可以通过完成任务、击败敌人、参加活动等方式来获得积分。每天登录游戏也会有一定的积分奖励。
# -------[76]-----Origin FAQ--------
#
# 问:个人保卫战达到1500积分奖励
# 答:在个人保卫战中积分达到1500分奖励含有：橙色万能碎片*1、精英抽卡券*1、训练加速1小时*5
#
# -------[76]-----New FAQ--------
#
# 问题1: 在个人保卫战中，达到多少积分可以获得橙色万能碎片呢？ 回答1: 在个人保卫战中，达到1500分可以获得橙色万能碎片。
# -------[77]-----Origin FAQ--------
#
# 问:个人保卫战达到2000积分奖励
# 答:在个人保卫战中积分达到2000分奖励含有：橙色万能碎片*1、精英抽卡券*1、训练加速1小时*10
#
# -------[77]-----New FAQ--------
#
# 问题1: 在个人保卫战中，如果我达到2000积分，除了橙色万能碎片、精英抽卡券和训练加速1小时，还有其他奖励吗？ 答案: 不，这些就是全部的奖励。
# -------[78]-----Origin FAQ--------
#
# 问:个人保卫战达到2700积分奖励
# 答:在个人保卫战中积分达到2700分奖励含有：橙色万能碎片*1、精英抽卡券*1、训练加速8小时*2
#
# -------[78]-----New FAQ--------
#
# 问题1:
# 在个人保卫战中达到2700积分可以获得哪些奖励？
#
# 回答1: 在个人保卫战中积分达到2700分可以得到橙色万能碎片*1、精英抽卡券*1、训练加速8小时*2的奖励。
#
# 问题2:
# 如何才能在个人保卫战中获得2700积分呢？
# -------[79]-----Origin FAQ--------
#
# 问:个人保卫战达到3500积分奖励
# 答:在个人保卫战中积分达到3500分奖励含有：天赋书*1、3级稀有技能宝箱*1、3级专属技能宝箱*1、训练加速8小时*3
#
# -------[79]-----New FAQ--------
#
#
#
# 问题1: 能否告诉我关于训练加速是如何工作的？ 回答1: 训练加速是指在个人保卫战中使用加速道具后，可以提高角色训练速度，让角色在短时间内获得更多的训练经验，以更快的速度提升等级。
# 问题2: 能否告诉我如何获得天赋书？ 回答2: 天赋书是一种重要的游戏道具，可以通过个人保卫战、竞技场等游戏活动获得，也可以在商店中使用虚拟货币购买。
# -------[80]-----Origin FAQ--------
#
# 问:个人保卫战达到5500积分奖励
# 答:在个人保卫战中积分达到5500分奖励含有：橙色万能碎片*2、军阵通用手册*10、蓝色材料随机箱*15、训练加速8小时*3
#
# -------[80]-----New FAQ--------
#
# 问题1: 在个人保卫战中，达到多少积分才能获得橙色万能碎片*2、军阵通用手册*10、蓝色材料随机箱*15、训练加速8小时*3的奖励？ 回答1: 在个人保卫战中，达到5500分才能获得橙色万能碎片*2、军阵通用手册*10、蓝色材料随机箱*15、训练加速8小时*3的奖励。
# -------[81]-----Origin FAQ--------
#
# 问:个人保卫战达到7000积分奖励
# 答:在个人保卫战中积分达到7000分奖励含有：橙色万能碎片*3、高级重装芯片宝箱*1、军阵通用升级手册*30、训练加速8小时*3
#
# -------[81]-----New FAQ--------
#
# 问题1:
# 我如何在个人保卫战中获得7000分？
#
# 回答1: 你需要在个人保卫战中完成多个任务，并获得足够的积分。首先，你可以通过完成各种挑战，如消灭敌人、摧毁敌方防御、摧毁敌方基地等来获得积分。其次，你可以通过完成游戏中的任务和活动来获得积分，例如参加活动、完成每日任务等。最后，你还可以通过购买游戏内的道具或者使用虚拟货币来获得积分。
#
# 问题2:
# 我可以在个人保卫战中获得哪些奖励？
#
# 回答2: 在个人保卫战中达到7000分奖励含有：橙色万能碎片*3、高级重装芯片宝箱*1、军阵通用升级手册*30、训练加速8小时*3。这些奖励可以帮助你在游戏中的发展，提升你的战斗力。
# -------[82]-----Origin FAQ--------
#
# 问:个人保卫战波数1
# 答:兵种：陆军、 士兵数量：9
#
# -------[82]-----New FAQ--------
#
# 问题1: 我需要购买更多的士兵来增加我的兵力，你建议我应该买哪个兵种？
# 回答1: 根据您提供的信息，您已经拥有了陆军兵种。如果想要增加兵力，建议您可以考虑购买其他兵种，如空军、海军或者特殊兵种，具体选择需要根据您的游戏策略和目标来决定。
# -------[83]-----Origin FAQ--------
#
# 问:个人保卫战波数2
# 答:兵种：海军、 士兵数量：15
#
# -------[83]-----New FAQ--------
#
# 问题1: 我如何才能在游戏中获得更高的分数？
# 回答1: 得分的主要因素是玩家在游戏中击败敌人的次数和效率。因此，要想获得更高的分数，可以尝试通过升级自己的装备、增加士兵数量、挖掘更多的资源等方式来提升自己的实力，从而更容易击败敌人并获得更高的分数。此外，还可以通过挑战游戏中的难关、完成任务等方式来获取更多的积分。
# -------[84]-----Origin FAQ--------
#
# 问:个人保卫战波数3
# 答:兵种：空军、 士兵数量：21
#
# -------[84]-----New FAQ--------
#
# 问题1: 你是如何达到波数3的?
# 回答1: 我使用了空军作为我的主要兵种，并且在每波中都尽可能地使用士兵数量21，通过有效的策略和决策，成功地防守了三次攻击。
# -------[85]-----Origin FAQ--------
#
# 问:个人保卫战波数4
# 答:兵种：陆军、士兵数量：27
#
# -------[85]-----New FAQ--------
#
# 问题1: 你觉得如何才能在个人保卫战中取得胜利？
# 回答1: 在个人保卫战中取得胜利的关键因素是合理的兵种组合和灵活的策略。建议选择一些攻击力较强的兵种，如火箭兵或弓箭手，并合理搭配，以充分发挥其优势。此外，在策略方面，可以尝试采取压制性作战或者绕道敌后进行偷袭等方式，以达到取胜的目的。
#
# 问题2: 在你的游戏中，你选择的兵种是陆军，士兵数量为27。你觉得这个组合在个人保卫战中是否具有竞争力？
# 回答2: 我觉得这个组合在个人保卫战中具有一定的竞争力，但具体表现还要看对手的实力和策略。陆军具有较强的近身攻击能力，而27个士兵的数量也足够支撑一段时间的战斗。当然，如果对手实力较强或者采取了更加有效的策略，那么这个组合的竞争力就会受到影响。所以，在实际游戏中，我们需要根据对手的实力和策略来进行相应的调整和变化，以达到最好的战斗效果。
# -------[86]-----Origin FAQ--------
#
# 问:个人保卫战波数5
# 答:兵种：海军、 士兵数量：33
#
# -------[86]-----New FAQ--------
#
# 问题1: 在我的个人保卫战中，我需要将海军的数量增加到多少才能在波数5时取得胜利？回答1: 根据您当前的兵力配置，需要将海军的数量增加到55个才能在波数5时取得胜利。建议您可以考虑增加海军的招募速度或研究新的海军兵种。
# -------[87]-----Origin FAQ--------
#
# 问:个人保卫战波数6
# 答:兵种：空军、 士兵数量：42
#
# -------[87]-----New FAQ--------
#
# 问题1：在个人保卫战中，怎样能够最大化地发挥空军的作用？
# 回答1：在个人保卫战中，空军可以发挥至关重要的作用。建议使用多种类型的空军，包括轰炸机、攻击机和侦察机。其中，轰炸机可以在离敌人基地较远的地方进行地毯式轰炸，攻击机可以在近距离打击敌人，而侦察机则可以提供敌人的情报和位置信息，便于其他兵种的攻击。此外，也可以考虑对敌人的重要目标进行定点打击，以削弱敌人的实力。需要注意的是，使用空军时需要充分考虑敌人的防空能力，调整好攻击时机和角度，以减少损失。
# -------[88]-----Origin FAQ--------
#
# 问:个人保卫战波数7
# 答:兵种：陆军、 士兵数量：51
#
# -------[88]-----New FAQ--------
#
# 问题1: 如果我想提高我的个人保卫战波数7的士兵数量，应该怎么做？
# 回答1: 你需要考虑升级你的兵种，以获得更高的士兵数量。你可以通过使用升级卡、金币或者其他游戏资源来升级你的兵种，从而获得更多的士兵。此外，你还可以考虑提高你的 army stats，例如英雄加成、技能强化等，从而获得更高的士兵数量。
# -------[89]-----Origin FAQ--------
#
# 问:个人保卫战波数8
# 答:兵种：海军、 士兵数量：60
#
# -------[89]-----New FAQ--------
#
# 问题1: 你对个人保卫战波数8的海军兵种有哪些了解？
# 回答1: 在个人保卫战波数8中，海军兵种包括驱逐舰、巡洋舰、潜艇等。驱逐舰可以进行高速追逐，巡洋舰可以防御、攻击和支援，潜艇可以在水下进行侦查和攻击。
# 问题2: 个人保卫战波数8中，海军士兵的数量是多少？
# 回答2: 个人保卫战波数8中，海军士兵的数量为60人，其中包括驱逐舰、巡洋舰、潜艇和其他海军单位。每个海军单位的士兵数量不同，但60人是一个合理的数字。
# -------[90]-----Origin FAQ--------
#
# 问:个人保卫战波数9
# 答:兵种：空军、 士兵数量：69
#
# -------[90]-----New FAQ--------
#
# 问题1: 请问在这个保卫战中，我应该如何搭配我的兵种才能更好地应对敌人的攻击？
# 回答1: 针对敌人的不同兵种，你可以根据你的实际情况进行搭配。例如，如果你的敌人有很多枪兵，你可以增加你的步兵数量以增加防禦力。如果你的敌人有很多弓箭手，你可以增加你的弓箭手数量，以增加攻击力。此外，你也可以考虑增加空军，利用空袭来打击敌人。
# -------[91]-----Origin FAQ--------
#
# 问:个人保卫战波数10
# 答:兵种：陆军、 士兵数量：78
#
# -------[91]-----New FAQ--------
#
# 问题：
#
# 你可以告诉我游戏中如何获得更多的士兵吗？
#
# 回答：
#
# 可以的！在游戏中，可以通过完成任务、战胜敌人、完成游戏挑战等方式来获得士兵。此外，也可以通过购买游戏内道具或使用游戏内的虚拟货币来获得士兵。记得要及时训练你的士兵，使他们变得更强大！
# -------[92]-----Origin FAQ--------
#
# 问:个人保卫战波数11
# 答:兵种：海军、 士兵数量：90
#
# -------[92]-----New FAQ--------
#
# 问题1: 在个人保卫战中，我有哪些兵种可以选择？ 回答1: 你可以选择的兵种有海军、步兵、航空兵等。
# -------[93]-----Origin FAQ--------
#
# 问:个人保卫战波数12
# 答:兵种：空军、 士兵数量：102
#
# -------[93]-----New FAQ--------
#
# 问题1: 我的球队中哪些兵种可以组成一支强大的空军？
# 回答1: 为了构建强大的空军，你可以考虑招募各类战机，包括喷气式战机、轰炸机、侦察机等。同时，还可以配置一定的空对空导弹和空对地导弹来提高战斗能力。
# -------[94]-----Origin FAQ--------
#
# 问:个人保卫战波数13
# 答:兵种：陆军、 士兵数量：114
#
# -------[94]-----New FAQ--------
#
# 问题1: 我在防守第五波时应该怎样调整我的阵容来更好地抵抗对手的攻击？
# 回答1: 在第五波的防守中，您需要确保您有足够的机动性和火力。建议您增加一些机动性强的单位，如坦克和直升机。同时，您也可以考虑增加一些火力强大的武器，如导弹和火箭筒。此外，您还可以考虑增加一些可以治疗伤员的医疗单位，以确保您的部队能够更好地支撑下去。
# -------[95]-----Origin FAQ--------
#
# 问:个人保卫战波数14
# 答:兵种：海军、 士兵数量：126
#
# -------[95]-----New FAQ--------
#
# 问题1: 能否更改兵种等级？
# 回答1: 可以通过对兵种进行升级和训练来提高它们的战斗力。可以通过消耗资源和技能点数来提升等级。建议先选择适合自己需求的兵种，然后再逐步升级和训练。
# -------[96]-----Origin FAQ--------
#
# 问:个人保卫战波数15
# 答:兵种：空军、 士兵数量：138
#
# -------[96]-----New FAQ--------
#
# 问题1：在个人保卫战中，我应该使用什么兵种来最大化我的攻击输出？
# 回答1：在个人保卫战中，使用空军兵种可以最大化你的攻击输出。因为空军兵种可以攻击地面目标，并且可以在空中进行快速支援，攻击范围更广，能够对敌方造成更大的伤害。
# 问题2：在个人保卫战中，我应该投放多少士兵来达到最佳效果？
# 回答2：在个人保卫战中，建议投放138个士兵来达到最佳效果。这是因为这个数量的士兵可以帮助你在攻击和防守方面都有很好的平衡，并且可以提供足够的火力来击败你的敌人。
# -------[97]-----Origin FAQ--------
#
# 问:个人保卫战波数16
# 答:兵种：陆军、 士兵数量：153
#
# -------[97]-----New FAQ--------
#
# 问题1: 在个人保卫战中，如何提高我的胜率？
# 回答1: 在个人保卫战中，提高胜率有很多方法。首先，要选择适合自己的士兵和兵种，例如，如果喜欢近战，可以选择擅长肉搏的士兵。其次，要学会合理的布阵，将士兵放置在有利的位置，增加自己的防守力。此外，也要善于利用自己的优势，如利用建筑物进行掩护，或者在敌军立足未稳时发起突然攻击。最后，要保持耐心，不要在初期急于求成，稳定地赢得每一场战斗，最终才能获得胜利。
# -------[98]-----Origin FAQ--------
#
# 问:个人保卫战波数17
# 答:兵种：海军、 士兵数量：168
#
# -------[98]-----New FAQ--------
#
# 问题1:
# 在游戏中，海军可以提供哪些特别的能力？
# 回答1: 海军通常可以提供空中打击、水下支援和保护港口等能力。它们可以在海上巡逻、拦截船只、攻击敌方基地等任务中发挥重要作用。此外，海军还可以提供宝贵的海军侦察情报，帮助我方决策更明智的军事行动。
# -------[99]-----Origin FAQ--------
#
# 问:个人保卫战波数18
# 答:兵种：空军、 士兵数量：183
#
# -------[99]-----New FAQ--------
#
# 问题1: 你能告诉我你的空军中有哪些兵种吗？
# 回答1: 我的空军中有士兵、轰炸机、导弹等兵种。
# 问题2: 你有多少士兵在个人保卫战中参战？
# 回答2: 我在个人保卫战中共有183名士兵参战。
# -------[100]-----Origin FAQ--------
#
# 问:个人保卫战波数19
# 答:兵种：陆军、 士兵数量：198
#
# -------[100]-----New FAQ--------
#
# 问题1：在这个游戏中，我拥有了198个士兵和一支陆军，应该采取哪一种战略来取得胜利？
# 回答1：在个人保卫战中，一支强大的军队和高效的策略是取胜的关键。建议首先考虑升级您的士兵，提高其属性和攻击力。其次，您应该善于利用地形，寻找合适的战略地点，发挥您军队的优势。此外，您也可以尝试联合其他玩家，以共同对抗对手。最后，保持耐心和冷静，不要轻易放弃，因为胜利只有一步之遥！
# -------[101]-----Origin FAQ--------
#
# 问:个人保卫战波数20
# 答:兵种：海军、 士兵数量：213
#
# -------[101]-----New FAQ--------
#
# 问题1: 在保卫战中，如何有效地运用海军兵种？ 回答1: 在保卫战中，海军兵种可以用于攻击敌方的海岸线，阻止敌方登陆或者运输物资。此外，海军还可以进行搜索和摧毁敌方的船只，对敌方造成重大的战略打击。建议在游戏中，玩家要根据实际情况合理部署海军，在关键时刻进行反击。
# -------[102]-----Origin FAQ--------
#
# 问:个人保卫战波数21
# 答:兵种：空军、 士兵数量：238
#
# -------[102]-----New FAQ--------
#
# 问题1: 在个人保卫战中，如何提高空军的战斗力？
# 回答1: 首先，可以考虑增加空军的兵种数量，以增加攻击力。此外，可以考虑把一些高科技的武器装备到空军中，以提高其攻击力和生存能力。同时，还可以考虑培训高级飞行员，以提高空军的精度和打击能力。
# 问题2: 在个人保卫战中，如何提高士兵的数量？
# 回答2: 首先，可以考虑增加招募士兵的速度，以增加兵力数量。其次，可以考虑培训更多的士兵，以增加他们的战斗力。此外，还可以考虑提高士兵的装备水平，以提高其生存能力。
# -------[103]-----Origin FAQ--------
#
# 问:个人保卫战波数22
# 答:兵种：陆军、 士兵数量：263
#
# -------[103]-----New FAQ--------
#
# 问题1: 我的士兵数量为263，应该选择哪种兵种作为我的主力军队？
# 回答1: 鉴于您有限的士兵数量和您的喜好，我们建议您考虑选择火枪手作为您的主力军队。火枪手具有较高的攻击力和射程，可以在远程攻击时发挥巨大作用。此外，火枪手还具有较低的成本，您可以在游戏中轻松获得。
# -------[104]-----Origin FAQ--------
#
# 问:个人保卫战波数23
# 答:兵种：海军、 士兵数量：290
#
# -------[104]-----New FAQ--------
#
# 问题1: 在个人保卫战中使用海军有哪些优势和劣势？
# 回答1: 优势：海军可以跨越水域，直接攻击敌方的海岸城市或补给站，造成巨大破坏。劣势：由于移动速度较慢，无法快速支援其他兵种，而且在地形不利的情况下作战比较困难。
# -------[105]-----Origin FAQ--------
#
# 问:个人保卫战波数24
# 答:兵种：空军、 士兵数量：320
#
# -------[105]-----New FAQ--------
#
# 问题1: 在个人保卫战中，使用320名士兵、空军，应该选择哪些兵种组合可以给我最大的胜算？
# 回答1: 在个人保卫战中，选择空军与士兵的兵种组合可以为您带来最大的胜算。由于士兵数量众多，可以更好地支持其他兵种进行战斗，并保护您免受敌方的攻击。而空军则可以更好地支援地面部队，进行高空中打击敌人，从而获得更多优势。
# -------[106]-----Origin FAQ--------
#
# 问:个人保卫战波数25
# 答:兵种：陆军、 士兵数量：500
#
# -------[106]-----New FAQ--------
#
# 问题1: 请问如何提高士兵的数量?
# 回答1: 提高士兵数量的方法有多种。首先，您可以尝试在游戏中购买更多士兵，其次您可以通过完成任务和升级来获得士兵经验，还可以通过使用游戏中提供的士兵生成器来增加士兵数量。
# -------[107]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御1波进攻的奖励
# 答:科技宝箱300
#
# -------[107]-----New FAQ--------
#
# 问题1: 你在联盟保卫战中成功抵御了1波进攻，可以获得什么奖励？
# 回答1: 你可以获得科技宝箱300，它可以让你的基地更快发展，提高你的战略部署能力和装备等级。
# -------[108]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御3波进攻的奖励
# 答:体力10点*1，白色图纸随机箱*1
#
# -------[108]-----New FAQ--------
#
# 问题1: 我在联盟保卫战中成功抵御了3波进攻，但我没有得到预期的奖励，为什么呢？
# 回答1: 您可能需要确保您的联盟保卫战设置正确，并积极参与保卫战。此外,您需要确保您的角色有足够的经验和等级才能获得联盟保卫战的奖励。如您仍然没有收到预期的奖励，请联系游戏客服查看您的账户是否存在问题。
#
# 问题2: 联盟保卫战成功抵御3波进攻可以得到什么样的奖励？
# 回答2: 联盟保卫战成功抵御3波进攻的奖励为体力10点*1,白色图纸随机箱*1。这些奖励将自动发放到参与保卫战的玩家的账户中，可以通过游戏中的邮箱查看和领取。
# -------[109]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御5波进攻的奖励
# 答:高级装饰箱*1，白色图纸随机箱*1
#
# -------[109]-----New FAQ--------
#
# 问题1: 我在联盟保卫战中成功抵御了5波进攻，但是为什么我没有得到高级装饰箱和白色图纸随机箱作为奖励呢？
# -------[110]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御10波进攻的奖励
# 答:高级招募券*2，训练加速1小时*3
#
# -------[110]-----New FAQ--------
#
# 问题1: 联盟保卫战成功抵御10波进攻可以获得哪些奖励？
# 回答1: 成功抵御10波进攻将获得高级招募券*2和训练加速1小时*3的奖励。
# 问题2: 高级招募券可以用来做什么？
# 回答2: 高级招募券是一种可在游戏商店中购买高级兵种、加快招募速度的道具，是提升游戏实力的必备品之一。
# -------[111]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御15波进攻的奖励
# 答:金币砰砰宝箱*50，训练加速1小时*8
#
# -------[111]-----New FAQ--------
#
# 问题1:
# 回答1: 你在联盟保卫战中成功抵御了15波进攻，获得了丰厚的奖励。金币砰砰宝箱*50可以让你购买更强大的武器和装备，训练加速1小时*8则可以帮助你快速提升等级和技能。你真是太厉害了！
# 问题2:
# 回答2: 联盟保卫战是一种团队合作的游戏模式，在游戏中，需要与其他玩家配合，共同抵御敌人的进攻。成功抵御15波进攻是一项艰巨的任务，但是你的努力和团队合作最终换来了胜利。这是一次非常成功的经历，也是一次非常棒的游戏体验。
# -------[112]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御20波进攻的奖励
# 答:精英抽卡券*3，训练加速8小时*3
#
# -------[112]-----New FAQ--------
#
# 问题1: 我在联盟保卫战中成功抵御了20波进攻，可以获得哪些奖励？
# 回答1: 你将获得精英抽卡券*3和训练加速8小时*3的奖励。
# -------[113]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御25波进攻的奖励
# 答:额外队列（2天），训练加速8小时*4
#
# -------[113]-----New FAQ--------
#
# 问题1: 我在联盟保卫战中成功抵御了25波进攻，可以获得什么奖励？
# 回答1: 你将获得额外的队列（持续2天）和训练加速8小时*4，这将让你的军队更加壮大和强大，更好地应对未来的挑战。
# 问题2: 队列和训练加速8小时*4对我来说有什么意义？
# 回答2: 队列能够让你在联盟保卫战中更加活跃，而训练加速8小时*4将使你的军队在更短的时间内得到更好的发展，这样你就可以更快地完成任务，更好地保护你的领土。
# -------[114]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御30波进攻的奖励
# 答:海军英雄专属技能宝箱*5，职业天赋加速8小时*5
#
# -------[114]-----New FAQ--------
#
# 问题1: 在联盟保卫战中成功抵御了30波进攻后，我获得了什么奖励？
# 回答1: 你获得了海军英雄专属技能宝箱*5，职业天赋加速8小时*5。你可以使用这些奖励来提升你角色的战斗力，并且更快地升级。
# -------[115]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御35波进攻的奖励
# 答:陆军英雄专属技能宝箱*5，职业天赋加速8小时*5
#
# -------[115]-----New FAQ--------
#
# 问题1: 联盟保卫战成功抵御35波进攻的奖励是什么？
# 回答1: 联盟保卫战成功抵御35波进攻的奖励是陆军英雄专属技能宝箱*5和职业天赋加速8小时*5。
# 问题2: 需要多少波进攻才能获得这个奖励？
# 回答2: 不清楚需要多少波进攻才能获得这个奖励，建议查看游戏规则或者咨询官方客服。
# -------[116]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御40波进攻的奖励
# 答:橙色万能碎片*2，职业天赋加速8小时*5
#
# -------[116]-----New FAQ--------
#
# 问题: 在联盟保卫战中成功抵御40波进攻后可以获得哪些奖励？
# 回答1: 成功抵御40波进攻后，您将获得橙色万能碎片*2和职业天赋加速8小时*5的奖励。
# -------[117]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御45波进攻的奖励
# 答:战争狂人头像框（30天），橙色万能碎片*3，职业天赋加速8小时*10
#
# -------[117]-----New FAQ--------
#
#
#
# 问题1: 我在联盟保卫战中成功抵御了45波进攻。请问我现在可以获得什么奖励？
#
# 回答1: 恭喜你成功抵御了45波进攻！根据你的成绩，你将获得战争狂人头像框（30天）、橙色万能碎片*3以及职业天赋加速8小时*10作为奖励！这些奖励将有助于你更好地提升自己的游戏实力。
#
# 问题2: 我在联盟保卫战中成功抵御了45波进攻。请问这些奖励可以用来做什么？
#
# 回答2: 这些奖励可以帮助您提高角色的战斗力，其中包括可以穿戴的头像框，可以用来加速角色的天赋培养，以及可以获得更多提升角色实力的道具。此外，这些奖励还可以为您提供一定的时间来进一步发挥游戏中的厉害之处。
# -------[118]-----Origin FAQ--------
#
# 问:联盟保卫战成功抵御50波进攻的奖励
# 答:战争狂人铭牌（30天），橙色万能碎片*5，职业天赋加速8小时*20
#
# -------[118]-----New FAQ--------
#
# 问题1: 我在游戏中成功抵御了50波进攻，可以获得什么样的奖励？
# 回答1: 恭喜您成功抵御了50波进攻！您将获得战争狂人铭牌，持续30天。同时，您还将获得橙色万能碎片*5和职业天赋加速8小时*20的奖励。
# 问题2: 我如何才能获得战争狂人铭牌？
# -------[119]-----Origin FAQ--------
#
# 问:发射井活动什么时候开启？
# 答:发射井占领周二21点开启,持续2小时。
#
# -------[119]-----New FAQ--------
#
# 问题1: 这个活动的时间是多久？
# 回答1: 这个活动将会在周二的21点开始，持续2小时。
# -------[120]-----Origin FAQ--------
#
# 问:联盟如何获得占领发射井活动积分？
# 答:联盟通过占领发射井获得累计占领时间，通过4个发射井的累计占领时间决定联盟排行名次。联盟排行,积分相同时按发射井累计时间计算,计算到单位秒,秒数相同时按进入发射井的顺序,优先进入任意一个发射井,则排名在前。
#
# -------[120]-----New FAQ--------
#
# 问题1: 联盟如何获得占领发射井的积分？
# 回答1: 联盟通过占领发射井获得累计占领时间，通过4个发射井的累计占领时间决定联盟排行名次。联盟排行,积分相同时按发射井累计时间计算,计算到单位秒,秒数相同时按进入发射井的顺序,优先进入任意一个发射井,则排名在前。
#
# 问题2: 联盟排行榜是如何计算的？
# 回答2: 联盟排行榜是根据联盟成员在占领发射井活动中的累计占领时间来计算的。也就是说，如果有一个联盟成员占领了某个发射井，那么整个联盟的排名就会相应地提高。
#
# 问题3: 联盟成员在占领发射井活动中是否可以获得个人积分？
# 回答3: 联盟成员在占领发射井活动中可以获得个人积分，但是个人积分的多少与联盟积分无关。个人积分是根据每个成员在占领发射井活动中的表现来计算的，包括占领时间、击杀数、摧毁数等等。
# -------[121]-----Origin FAQ--------
#
# 问:个人如何获得占领发射井活动积分？
# 答:通过以下方式可以获得个人积分
# 占领发射井
# 派兵驻守在发射井,每分钟可以获得对应的积分,不足1分钟不记入积分个人同时多队伍在同一个发射井时,按一支队伍计算积分。多个队伍需要在不同的发射并才会累计积分。
# 杀敌
# 在发射井发生战斗,根据杀敌获得积分,进攻与防守的杀敌都记入在集结战斗中,自己杀敌了才会获得积分,如果只是参与集结但是没有杀敌不会获得积分。
# 获得陷阱
# 发射井占领期间,大世界中的怪物会随机掉落[临时陷阱],每获得一个临时陷阱可以获得积分
# 消耗陷阱
# 发射井占领期间,战斗中使用消耗[临时陷阱]、[陷阱]会获得积分,所有战斗中生效。
#
# -------[121]-----New FAQ--------
#
# 问题1: 个人占领发射井可以获得什么积分？ 答: 通过占领发射井可以获得个人积分。个人每分钟可以获得对应的积分，不足1分钟不记入积分。此外，个人同时多队伍在同一个发射井时，按一支队伍计算积分。多个队伍需要在不同的发射井才会累计积分。
# 问题2: 怎样可以获得杀敌积分？ 答: 在发射井发生战斗时，根据杀敌获得积分。进攻与防守的杀敌都记入在集结战斗中。只有自己杀敌了才会获得积分，如果只是参与集结但是没有杀敌就不会获得积分。
# 问题3: 是否可以获取陷阱积分？ 答: 发射井占领期间，大世界中的怪物会随机掉落[临时陷阱]。每获得一个临时陷阱可以获得积分。
# 问题4: 如果使用消耗[临时陷阱]或[陷阱]会获得什么积分？ 答: 发射井占领期间，战斗中使用消耗[临时陷阱]、[陷阱]会获得积分，所有战斗中积分生效。
# 问题5: 在占领发射井时，如果队伍中有多支队伍，如何分配积分？ 答: 多个队伍需要在不同的发射井才会累计积分，因此，如果队伍中有多个队伍在同一个发射井，按照一支队伍计算积分。
# -------[122]-----Origin FAQ--------
#
# 问:占领发射井活动结束后如何获得奖励？
# 答:联盟排行奖励会在活动结束后通过邮件发送，在奖励发送前请不要退出联盟。个人积分奖励需要在活动页面的[个人奖励]中领
# 取。
#
# -------[122]-----New FAQ--------
#
# 问题1：在占领发射井活动结束后，我怎么才能知道我是否获得了联盟排行奖励？
# 答：联盟排行奖励会在活动结束后通过邮件发送。只要没有出现邮件延迟的情况，您应该会收到邮件通知的。如果您没有收到，请检查您的垃圾邮件箱或联系游戏客服，以确认邮件是否被误判为垃圾邮件。另外，请注意，在奖励发送前请不要退出联盟，以确保您能正确获得奖励。
# 问题2：在占领发射井活动结束后，我如何领取个人积分奖励？
# 答：个人积分奖励需要在活动页面的[个人奖励]中领取。请先登录您的游戏账号，然后点击[活动页面]，找到占领发射井活动的页面，点击页面中的[个人奖励]，即可查看您的个人积分奖励并领取。如果您有任何疑问，请随时联系游戏客服以获得帮助。
# -------[123]-----Origin FAQ--------
#
# 问:占领发射金活动结束后退出联盟会有奖励吗？
# 答:联盟排行奖励会在活动结束后通过邮件发送，在奖励发送前请不要退出联盟。
#
# -------[123]-----New FAQ--------
#
# 问题1: 占领发射金活动结束后退出联盟会有奖励吗？ 答: 不会有，因为联盟排行奖励会在活动结束后通过邮件发送。在奖励发送前请不要退出联盟。
# -------[124]-----Origin FAQ--------
#
# 问:如何在活动期间获得临时陷阱？
# 答:发射井占领期间,大世界中的怪物会随机掉落[临时陷阱]。
#
# -------[124]-----New FAQ--------
#
# 问题3:如何在游戏开启后快速获得第一个成就？ 回答3:游戏开启后,可以在主菜单的“成就”选项卡中找到"初学者大挑战"成就，并完成相应的任务要求，即可快速获得该成就。
# -------[125]-----Origin FAQ--------
#
# 问:占领发射井期间使用临时陷阱是否可以获得积分呢？
# 答:发射井占领期间,战斗中使用消耗[临时陷阱]、[陷阱]会获得积分,所有战斗中生效。
#
# -------[125]-----New FAQ--------
#
# 问题1: 什么情况下会获得积分？
# 回答1: 在发射井占领期间，战斗中使用消耗[临时陷阱]、[陷阱]会获得积分，所有战斗中生效。
#
# 问题2: 临时陷阱和陷阱有什么区别？
# 回答2: 临时陷阱和陷阱是两种不同的陷阱，临时陷阱是一种可以使用一次的陷阱，而陷阱则是一种可以长期放置的陷阱。
# -------[126]-----Origin FAQ--------
#
# 问:参与盟友对发射井集结后我为什么没有获得积分呢？
# 答:在集结战斗中,自己杀敌了才会获得积分,如果只是参与集结但是没有杀敌不会获得积分。
#
# -------[126]-----New FAQ--------
#
# 问题1: 我为什么没有获得战斗中的物资奖励？
# 回答1: 您需要确保在战斗中击败了敌人，只有击败敌人后，您才可获得物资奖励。请检查一下您的击杀记录，确认您是否已经获得了足够的奖励。
# 问题2: 在盟友对发射井集结后，我为什么没有获得参与积分？
# 回答2: 在盟友对发射井集结的战斗中，只有您自己参与战斗并击败敌人，您才能获得积分。如果您只是参与了集结但没有杀敌，您将不会获得积分。请确保您在战斗中积极参与，不断击败敌人，以获得更高的积分。
# -------[127]-----Origin FAQ--------
#
# 问:临时陷阱会一直存在吗？
# 答:活动期间,击败世界中的黑暗军团会掉落[临时陷阱],只能在活动期间使用。活动结束会清除身上的剩余[临时陷阱]
#
# -------[127]-----New FAQ--------
#
# 问题1: 我在哪里可以找到临时陷阱？
# 回答1: 你可以在击败世界中的黑暗军团后掉落的[临时陷阱]。只有在活动期间内，你才能使用这些[临时陷阱]。活动结束后，你身上的剩余[临时陷阱]将被清除。
# -------[128]-----Origin FAQ--------
#
# 问:首府占领活动是什么，如何参与首府占领活动？
# 答:[首府占领战]是以联盟为单位进行的活动。
# 各联盟可以对世界场景中心的[首府]建筑,发起占
# 领。
# 首府占领战首次开战时间将由指挥官投票选择。
# 战区开启前10天20级以上的指挥官可以投票选择期望的开战时间。投票最多的选项为首次开战时间。如果没有指挥官投票选择则首次开战时间为周日10点进入可占领状态首府占领战结束产生首领后的24小时内,由首领来选择下一轮首府占领战的开战时间。超过24小时没有选择则下一轮首府占领战开启时间为周日10点进入可占领状态。
#
# -------[128]-----New FAQ--------
#
# 问题1: 活动绑定了联盟吗？ 答案: 是的，首府占领活动是以联盟为单位进行的活动。问题2: 什么建筑可以被占领？ 答案: 各联盟可以对世界场景中心的[首府]建筑,发起占领军。问题3: 首次开战时间是什么时候决定的？ 答案: 首次开战时间将由指挥官投票选择。战区开启前10天20级以上的指挥官可以投票选择期望的开战时间。投票最多的选项为首次开战时间。如果没有指挥官投票选择则首次开战时间为周日10点进入可占领状态。问题4: 首领是如何产生的？ 答案: 首领是战斗结束后，从所有参与战斗的联盟中选拔出来的。问题5: 营销多久没有选择下一轮首府占领战的开战时间？ 答案: 超过24小时没有选择则下一轮首府占领战开启时间为周日10点进入可占领状态。
# -------[129]-----Origin FAQ--------
#
# 问:如何占领首府？
# 答:首府将根据指挥官投票或首领选择的时间进入可
# 占领状态。
# 阶段1可占领状态开始的1小时内联盟在这个阶段占领首府,持续占领30分钟即可获胜。
# 阶段2可占领状态开始的1小时至1.5小时联盟在这个阶段占领首府,持续占领15分钟即可获胜。
# 阶段3可占领状态开始的1.5小时至2小时联盟在这个阶段占领首府,持续占领5分钟即可获胜。
# 阶段4可占领状态开始的2小时以后联盟在这个阶段占领首府,立即获胜。特别说明:若在占领倒计时过程中进入下一阶段,则倒计时仍会按原时间继续倒数。只有在占领联盟出现变更后才会改用新阶段的占领规则。
#
# -------[129]-----New FAQ--------
#
# 问题1: 首府的占领状态是如何开始的？ 回答1: 首府的占领状态将根据指挥官投票或首领选择的时间进入可占领状态。阶段1可占领状态开始的1小时内联盟在这个阶段占领首府，持续占领30分钟即可获胜。 问题2: 首府的占领状态是如何结束的？ 回答2: 首府的占领状态将持续直到联盟成功占领或者期限结束。 问题3: 阶段2和阶段3中占领时间是如何计算的？ 回答3: 阶段2和阶段3中占领时间的计算方式与阶段1类似，即持续占领30分钟和15分钟即可获胜。 问题4: 阶段4中占领时间是如何计算的？ 回答4: 阶段4中占领时间为进入占领状态后的2小时以后，立即获胜。 问题5: 首府的占领规则会不会因为联盟变更而改变？ 回答5: 首府的占领规则只会因为占领联盟的变更而改变。只有在占领倒计时过程中进入下一阶段，才会改用新阶段的占领规则。
# -------[130]-----Origin FAQ--------
#
# 问:我们占领首府后为何会受到导弹攻击？
# 答:当其他联盟占领世界场景四个角落的导弹发射井后,如果与首府占领者非相同联盟,那么会定时发射导弹,攻击驻守在首府内的部队。受损单位将直接降级。
#
# -------[130]-----New FAQ--------
#
# 问题1: 如果我占领了首府，如何避免导弹攻击？
# 回答1:
# 建议您在占领首府之前占领世界场景中的导弹发射井，以避免受到其他联盟的导弹攻击。如果已经占领了首府，可以考虑建立防空火箭和防空导弹系统以减少导弹攻击对您的部队的损伤。
#
# 问题2: 一旦我受到了导弹攻击，我的部队会受到什么影响？
# 回答2:
# 您的部队会直接降级，这意味着他们的等级和能力将被削弱。同时，导弹攻击也可能造成人员伤亡和建筑损毁。为了减少损失，请在占领首府之前尽可能占领导弹发射井以及建立有效的防空防御系统。
# -------[131]-----Origin FAQ--------
#
# 问:如何成为本区的首领？
# 答:参与占领首府的联盟,盟主成为本战区首领。
#
# -------[131]-----New FAQ--------
#
# 问题1: 如何提高自己的战斗力？
# 回答1: 可以通过培养角色属性、升级技能等级、装备优质武器和防具、参加战斗任务等多种方式来提高自己的战斗力。同时，也可以通过练习和总结经验来提高自己的技巧和策略。
# -------[132]-----Origin FAQ--------
#
# 问:战区首领有什么特权？
# 答:首领可以任命官职、发布本战区强化、赠与礼物、修改本战区名字、发布首领宣言，首领还会多出一个额外队列。
#
# -------[132]-----New FAQ--------
#
# 问题1: 领主有什么特权？
# 回答1: 领主可以任命官职、发布本战区强化、赠与礼物、修改本战区名字、发布首领宣言，领主还会多出一个额外队列。
#
# 问题2: 领主可以任命哪些官职？
# -------[133]-----Origin FAQ--------
#
# 问:占领首府活动期间集结、超级集结参与队员是否可以获得积分？
# 答:集结进攻时,集结发起者和参与者都将获得积分。
#
# -------[133]-----New FAQ--------
#
# 问题1: 在占领首府活动中，队员可以赢得多少积分？ 回答1: 队员在占领首府活动中通过参与集结和超级集结，将会获得相应的积分奖励。每个参与活动的队员都将获得积分，发起和参与集合将获得更多的积分。问题2: 队员可以通过哪些方式赢得积分？ 回答2: 队员可以通过参与占领首府活动期间的集结和超级集结来获得积分，每次集结发起者和参与者都将获得积分。此外，如果队员在战斗中表现出色，还可以获得额外的积分奖励。
# -------[134]-----Origin FAQ--------
#
# 问:参与占领首府活动是否会有奖励？
# 答:每次[首府占领战]期间,发生在首府或发射井的战斗,将根据杀敌积分排行,发送邮件奖励。
#
# -------[134]-----New FAQ--------
#
# 问题1: 参与占领首府活动是否会有道具奖励？
# 回答1: 是的，在占领首府活动期间，参与首府或发射井的战斗，每击杀一位敌人就会获得一定数量的道具奖励。此外，战斗越到最后阶段，击杀积分排名越高，获得的奖励也会越多。
# -------[135]-----Origin FAQ--------
#
# 问:最强指挥官活动击败黑暗军团获得积分是怎么计算的
# 答:积分计算规则是：黑暗军团的等级除以5，有小数点的向上取整数计算。
#
# -------[135]-----New FAQ--------
#
# 问题1: 最强指挥官活动中击败黑暗军团可以获得多少积分？
# 回答1: 活动中，击败黑暗军团可以获得游戏积分，积分计算规则是：黑暗军团的等级除以5，有小数点的向上取整数计算。
#
# 例如，如果黑暗军团等级为87，那么该玩家获得的积分就是17（87/5=17.4,向上取整为17）。每个玩家获得的积分将根据他们的活动表现进行累计，以获得更高的排名和奖励。
#
# 问题2: 最强指挥官活动中的积分有什么用途？
# 回答2: 最强指挥官活动中的积分可以用于解锁游戏道具、游戏皮肤和其他游戏内的奖励。玩家通过参与活动、完成任务和击败黑暗军团等途径积累积分，可以兑换更多的游戏内福利，提高游戏体验。此外，积分排名也会影响玩家在游戏对战中的排名，激发玩家更加努力地参加活动和获取积分。
# -------[136]-----Origin FAQ--------
#
# 问:我的空投资源箱为什么比盟友的少
# 答:每个资源箱运至遗迹后会有10小时的倒计时，倒计时结束后资源箱会消失，请及时上线领取
#
# -------[136]-----New FAQ--------
#
# 问题1: 我的空投资源箱为什么比盟友的少？
# 回答1: 我不知道为什么您的资源箱比盟友的少，可能是您的空投资源箱在遗迹中有被掠夺的情况或者您在遗迹中的时间比盟友长，所以资源都被其他玩家拿完了。我建议您在遗迹中尽可能快地领取资源，这样可以避免资源被他人掠夺。
# 问题2: 如何提高空投资源箱的收益？
# 回答2: 如果您想要提高空投资源箱的收益，可以尝试以下方法：首先，要尽快上线领取资源，这样可以避免资源被他人掠夺；其次，在遗迹中可以通过击败其他玩家来获取更多的资源；最后，可以在遗迹中搜索空投箱，这样可以获得更多的资源。
# -------[137]-----Origin FAQ--------
#
# 问:领取的空投资源箱可以保留到下一次活动吗
# 答:无法保留，兑换刷新倒计时结束后剩余的空投资源箱将被回收。
#
# -------[137]-----New FAQ--------
#
# 问题1:
# 回答1:
#
# 问题2:
# 回答2:
# -------[138]-----Origin FAQ--------
#
# 问:一次空投补给活动中有多少个金色箱子
# 答:一共有10个金色箱子
#
# -------[138]-----New FAQ--------
#
# 问题1：在哪能找到这个空投补给活动？
# 回答1：这个空投补给活动一般会在游戏内的一些限定区域出现，具体位置需要玩家自行探索。有时候会有游戏公告告知玩家空投补给活动的具体位置和时间。
# 问题2：金色箱子有什么区别于其他箱子？奖励金额一样吗？
# 回答2：金色箱子通常比普通箱子的奖励更加丰富，比如更多的游戏道具、货币、经验等。但是具体的奖励金额不会根据箱子的不同而改变，都是一样的。
# -------[139]-----Origin FAQ--------
#
# 问:拉1个蓝色资源箱可以获得多少个空投资源箱
# 答:在没有被阻击的情况下您可以获得50个空投资源箱，盟友可以获得10个
#
# -------[139]-----New FAQ--------
#
# 问题1: 在什么情况下可以获得额外的空投资源箱？
# 回答1: 在成功击落敌方玩家或者摧毁敌方建筑的情况下可以获得额外的空投资源箱，每个击落或摧毁会给您带来1到3个额外的空投资源箱，具体数量取决于您的技巧和敌人的难度。
# 问题2: 拉一个蓝色资源箱能够给我带来多少经验值？
# 回答2: 拉一个蓝色资源箱可以给您带来约 200 到 300 点的经验值，具体取决于您所在的等级。
# -------[140]-----Origin FAQ--------
#
# 问:拉1个金色资源箱可以获得多少个空投资源箱
# 答:在没有被阻击的情况下您可以获得500个空投资源箱，盟友可以获得100个
#
# -------[140]-----New FAQ--------
#
# 问题1: 请问在什么情况下可以获得更多的空投资源箱？
# 回答1: 在没有被阻击的情况下，您可以获得500个空投资源箱，盟友可以获得100个空投资源箱。此外，参加游戏活动或者达到一定的游戏等级也可能获得更多的空投资源箱。
# -------[141]-----Origin FAQ--------
#
# 问:有护盾的情况下拉空投会导致破盾吗
# 答:参与运输不会破盾
#
# -------[141]-----New FAQ--------
#
# 问题1: 如果我在驾驶载具时开了护盾，被其他玩家攻击是否会导致护盾破掉？
# 回答1: 不会。在驾驶载具时，护盾是自动开启的，只要你没有主动关闭它，它就不会因为其他玩家的攻击而破裂。只要你保持移动，护盾就会一直存在，直到你停止移动或因为其他原因关闭它。
# -------[142]-----Origin FAQ--------
#
# 问:空投资源箱在哪里领取
# 答:在联盟频道领取，超过领取时间奖励失效
#
# -------[142]-----New FAQ--------
#
# 问题1: 请问联盟频道在哪里可以找到？
# 回答1: 联盟频道通常位于游戏主界面的右下角，点击进入即可。在联盟频道中，可以领取空投资源箱等道具，领取时间有规定，请务必注意。
# -------[143]-----Origin FAQ--------
#
# 问:空投资源箱在哪里兑换
# 答:在常规活动类目下补给获得页面，点击空投兑换
#
# -------[143]-----New FAQ--------
#
# 问题1: 我在游戏里找不到空投资源箱兑换按钮，怎么办？
# 回答1: 您可以在常规活动类目下补给获得页面，找到空投兑换按钮进行兑换。如果您还是找不到，请检查一下设置中是否启用了相关功能。
# -------[144]-----Origin FAQ--------
#
# 问:拯救难民
# 答:1.指挥官通过悬赏任务的宝箱奖励获得求救信道具。2.指挥官在背包中使用求救信,即可在世界地图上发现隐藏着的难民营。
# 3.只有难民营的发现者可以对该难民营发起集结。集结战斗胜利后,集结队长和队员会分别获得不同的奖励。
# 4.每天最多只能获得10次集结队员奖励。集结队长奖励无每日限制。
# 5发现的难民营仅会存在30分钟。30分钟之后,难民营就会被黑暗军团彻底消灭。
#
# -------[144]-----New FAQ--------
#
# 问题1: 怎么获得求救信道具？回答1: 指挥官可以通过悬赏任务的宝箱奖励获得求救信道具。问题2: 难民营的发现者如何发起集结战斗？回答2: 只有难民营的发现者可以对该难民营发起集结。要发起集结战斗，需要在世界地图上使用求救信道具来发现隐藏的难民营，然后点击难民营图标，点击“集结”，选择要参加集结的队员，最后点击“开始战斗”即可。问题3: 队长和队员在集结战斗中会获得什么奖励？回答3: 集结队长和队员会分别获得不同的奖励。队长会根据战斗结果获得经验、金币和物品等奖励，队员则会获得一定的经验、金币和物品。问题4: 每天最多可以参加多少次集结队员奖励？回答4: 每天最多只能获得10次集结队员奖励。
# -------[145]-----Origin FAQ--------
#
# 问:求救信
# 答:求救信是一个道具，信上用潦草的字迹写着"快来救救我们！“
#
# -------[145]-----New FAQ--------
#
# 问题1:在求救信中，你能看到任何线索吗？
# 回答1:是的，信的右下角有一个小标签，上面写着"来自北方电信局"。
# -------[146]-----Origin FAQ--------
#
# 问:黑暗军团情报盒
# 答:黑暗军团情报盒是一个道具，打开后有几率获得黑暗军团的情报碎片，情报阶段结束只能获得普通道具
#
# -------[146]-----New FAQ--------
#
# 问题1: 我在游戏中找到了一个黑暗军团情报盒，但是不知道该如何打开它。
# 回答1: 您需要找到对应的钥匙才能打开黑暗军团情报盒。可能需要在游戏内完成某些任务或者击败特定的敌人来获得钥匙。请遵循游戏内的提示来解锁情报盒。同时，提示您，黑暗军团情报盒掉落率很低，所以您需要格外珍惜机会。
# -------[147]-----Origin FAQ--------
#
# 问:镶金古箱
# 答:镶金古箱是一个道具，神秘的宝箱内含有各种稀有强化图纹和道具
#
# -------[147]-----New FAQ--------
#
# 问题1:镶金古箱里有什么?
# 回答1: 镶金古箱里包含了各种稀有强化图纹和道具，可以让你更轻松地提升角色的实力。
# -------[148]-----Origin FAQ--------
#
# 问:同样积分为什么个人保卫战排名我的确靠后？
# 答:个人保卫战排名根据参与完成活动时间前后进行排名。
#
# -------[148]-----New FAQ--------
#
# 问题1: 我在个人保卫战中为什么排名靠后？
# 回答1: 个人保卫战的排名是根据您完成活动的时间先后顺序来决定的。可能您完成活动的时间较晚，所以排名靠后。
# 问题2: 我需要采取什么措施来提高个人保卫战的排名呢？
# 回答2: 为了提高个人保卫战的排名，您可以尝试以下措施：
#
# 1. 提高活动完成的速度，及时完成活动任务;
# 2. 把时间安排合理，确保在活动中获得较高的效率;
# 3. 根据活动要求，完成活动任务时尽量做到完美;
# 4. 参加更多的保卫活动，积攒更多的积分和排名。
# -------[149]-----Origin FAQ--------
#
# 问:个人保卫战同样第一名积分是否可以领取第一名奖励？
# 答:个人保卫战同时和其他玩家获得积分一样，是可以领取和该玩家一样的名次奖励。
#
# -------[149]-----New FAQ--------
#
#
#
# 问题 1：
# 答: 作为一名游戏玩家，我在个人保卫战中也获得了第一名的积分。请问在这种情况下，是否可以领取第一名的奖励？
# -------[150]-----Origin FAQ--------
#
# 问:个人保卫战排行榜奖励为什么没有发放？
# 答:个人保卫战活动结束后排行榜奖励通过邮件进行发放。
#
# -------[150]-----New FAQ--------
#
# 问题1：为什么我参加个人保卫战之后没有收到排行榜奖励？
# 回答1：很抱歉，您参加的个人保卫战活动结束后，排行榜奖励通过邮件进行发放。如果您还没有收到奖励，请检查您的邮箱并确保邮件没有被误判为垃圾邮件。如果仍然没有收到奖励，请联系我们的客服人员协助您解决问题。
# -------[151]-----Origin FAQ--------
#
# 问:参与个人保卫战为什么没有获得排名奖励？
# 答:目前只有排名前50名的指挥官可以获得奖励。
#
# -------[151]-----New FAQ--------
#
# 问题1: 为什么我没有获得排名奖励？
# 回答1: 目前只有排名前50名的指挥官可以获得奖励，可能您在这个排名中没有获得足够的分值。
# 问题2: 我要怎样才能获得排名奖励？
# 回答2: 您可以通过提高自己的排行为自己赢得排名奖励，具体可以在排行榜页面查看获得奖励的条件。
# -------[152]-----Origin FAQ--------
#
# 问:个人保卫战伤兵积分是怎么计算的?
# 答:活动每击杀一个敌军积分为1分，战斗中损伤了一个士兵，就会随机扣除1-7分，如果没有士兵损伤，会额外奖励15分。
#
# -------[152]-----New FAQ--------
#
# 问题1：个人保卫战中，如果我的总积分为0，我会失去什么奖励？ 回答1：如果您的总积分为0，您将无法获得任何奖励，包括但不限于荣誉、经验、金币等。
#
# 问题2：在个人保卫战中，我可以增加我的总积分吗？ 回答2：是的，您可以通过击杀敌军和减少己方士兵的伤亡来增加您的总积分。此外，如果您在战斗中表现优异表现，可能会获得额外的奖励，这也会增加您的总积分。
# -------[153]-----Origin FAQ--------
#
# 问:个人保卫战中弱化设施和强化设施是否会有生效呢？
# 答:参与活动中强化设施可以生效，弱化设施无法生效。
#
# -------[153]-----New FAQ--------
#
# 问题1: 在游戏中，强化后的设施和弱化后的设施是否会有不同的效果？
# 回答1: 是的，强化后的设施会具有更高的属性值和更加强大的效果，而弱化后的设施则会降低其属性值并使其更容易受到攻击。建议玩家在游戏过程中谨慎考虑强化和弱化设施的决策，以获得最大的利益。
# -------[154]-----Origin FAQ--------
#
# 问:参与个人保卫战基地是否会受到其他玩家的攻击呢？
# 答:在参与个人保卫战期间，其他联盟玩家无法攻击您的基地。
#
# -------[154]-----New FAQ--------
#
# 问题1: 参与个人保卫战时，其他玩家可以偷我的资源吗？
# 回答1: 参与个人保卫战期间，其他玩家可以偷您的资源，但这种行为被严格禁止，联盟成员之间也会相互监督和共同维护游戏公平。
# -------[155]-----Origin FAQ--------
#
# 问:参与个人保卫战期间是否可以派出队列呢？
# 答:在保卫基地期间，您无法派出行军队列。
#
# -------[155]-----New FAQ--------
#
# 问题1: 请问在游戏中如何获得能量？
# 回答1: 在游戏中，可以通过完成任务、击败敌人、完成活动等方式获得能量。
# 问题2: 游戏中可以与其他玩家组队吗？
# -------[156]-----Origin FAQ--------
#
# 问:沙盘演习
# 答:沙盘演习是一个每天都有的活动，玩家每天有5次挑战次数可自由选择挑战陆军霸主，海军霸主或者空军霸主。
# 1.沙盘演习的士兵由系统提供,指挥官不需要使用自己的士兵。
# 2.指挥官可以选择上阵的英雄,战斗中生效的属性为指挥官自身全部属性。
# 3.每次挑战霸主会根据产生的伤害值获得宝箱,在战斗结束时根据对霸主造成的伤害获得相应奖励。
# 4.当次挑战中的伤害总值超过奖励设定最大值后将不会再获得宝箱。
# 5.每天0点重置挑战次数
# 6.排名榜只展示交流参考,不会有排行榜奖励。
#
# -------[156]-----New FAQ--------
#
# 问题1: 沙盘演习的挑战次数每天几点重置？ 答: 每天0点重置挑战次数。 问题2: 挑战可以获得宝箱吗？如果有，有什么奖励？ 答: 沙盘演习每次挑战都会根据产生的伤害值获得宝箱，在战斗结束时根据对霸主造成的伤害获得相应奖励。问题3: 每次挑战的伤害总值超过奖励设定最大值后会怎么样？ 答: 当次挑战中的伤害总值超过奖励设定最大值后将不会再获得宝箱。问题4: 沙盘演习中可以用自己的士兵吗？若可以，士兵有哪些特点？ 答: 不可以，沙盘演习中的士兵由系统提供，指挥官不需要使用自己的士兵。
# -------[157]-----Origin FAQ--------
#
# 问:沙盘演习配备什么强化部件打出的伤害更高
# 答:推荐使用命中，武器强化，准具强化，伤害加深，会心一击伤害
#
# -------[157]-----New FAQ--------
#
# 问题1: 我需要在沙盘演习中达到更高的伤害，请问应如何强化我的部件？
# 回答1: 推荐使用命中，武器强化，准具强化，伤害加深，会心一击伤害。命中可以提高你的攻击中的命中的概率，武器强化可以增加武器的攻击力，准具强化可以增加你攻击的准确度，伤害加深可以增加你攻击的伤害倍率，而会心一击伤害则可以增加你攻击对敌人造成的伤害。这些部件都可以通过游戏内的商店购买或通过任务奖励获得。建议根据自己的游戏习惯和需求选择合适的强化部件。
# -------[158]-----Origin FAQ--------
#
# 问:沙盘演习英雄配备什么技能打出的伤害更高
# 答:推荐使用稀有出征，普通出征，增伤，会心伤害，命中，会心一击，增加攻击的技能
#
# -------[158]-----New FAQ--------
#
# 问题1: 在沙盘演习中，如何搭配英雄技能才能打出更高的伤害？
# 回答1: 推荐使用稀有出征，普通出征，增伤，会心伤害，命中，会心一击，增加攻击的技能。这些技能可以帮助您在战斗中快速击杀敌方英雄，提高您的游戏胜率。您可以根据自己的喜好和游戏风格来调整技能组合，以获得更好的游戏体验。
#
# 问题2: 我在游戏中经常遇到被敌方英雄击败的情况，如何提高自己的生存能力？
# 回答2: 为了提高自己的生存能力，建议您在游戏中多使用一些保护自己的技能，如加速、隐身、盾墙等。此外，您还可以通过提高自己的移动速度和攻击速度来更快地击败敌人，避免被敌人击败。最后，您可以与其他玩家组队，互相帮助，共同击败敌人，提高游戏胜率。
# -------[159]-----Origin FAQ--------
#
# 问:跨战区演习
# 答:跨战区演习是一个活动：
# 跨战区演习说明：
# 1.在跨战区演习中,指挥官在当前演习分组中与其它战区的指挥官进行挑战
# 2.本轮同战区演习结束,排行榜前20名指挥官且满足跨战区演习等级要求,则可以参与本轮跨战区演习
# 3.指挥官部署防守部队或挑战演习教官可以获得初始排名,按指挥官部署或挑战的先后顺序,越早部署、挑战获得的排名越靠前,挑战演习教官不会消耗挑战次数
# 4.每天在演习中有免费挑战次数,免费挑战次数为0后需要消耗跨区演习通行证
# 5.指挥官挑战其它指挥官将根据战斗结果互换排名,挑战比自己排名高的指挥官获胜,双方排名互换,战斗失败,双方不互换排名。挑战比自己排名低的指挥官,无论胜负都不互换排名。
# 例如:自己排第10名,挑战排行第1名的指挥官胜利,则自己变为第1名,对方变为第10名,如果失败则自己排名仍然是第10名,对方是第1名
# 6.每轮演习持续2天,周六、周日,结束后根据排名发放本轮奖励
# 7.每轮跨战区演习结束后会重置指挥官的积分,并清除所有身上的跨区演习通行证
# 8.每轮开启时,需要挑战一次指挥官或部署防守阵容,才会获得初始积分和排名
# 9.指挥官战力是根据部署防守部队产生的属性战力,没有计算上阵士兵,仅供参考。
#
# 跨战区演习战斗说明：
# 1.指挥官需要分别设定陆、海、空,三支部队
# 2.每支部队使用指挥官自己的当前士兵,包括已出征士兵,但不允许使用受伤、死亡、训练中的士兵。
# 3.演习战斗不会消耗指挥官的士兵,请放心使用
# 4.在保存阵容时会使用指挥官当前所有的属性,如果有属性有更改需要重新设置防守阵容
#
# -------[159]-----New FAQ--------
#
# 问题1: 跨战区演习持续多久？
# 回答1: 跨战区演习持续两天，周六、周日进行。
#
# 问题2: 指挥官在不参与跨区演习时,排名是否会下降？
# 回答2: 不会，指挥官在跨区演习期间排名与不参与跨区演习期间排名一致。
#
# 问题3: 如何获得跨区演习通行证？
# 回答3: 指挥官可以通过购买、参加活动、完成任务等途径获得跨区演习通行证。
#
# 问题4: 在跨战区演习中，挑战失败会怎么办？
# 回答4: 如果挑战失败,双方排名将互换位置.
#
# 问题5: 在跨战区演习中，挑战成功会获得什么奖励？
# 回答5: 指挥官成功挑战他人将根据战斗结果互换排名，挑战比自己排名高的指挥官获胜，双方排名互换,战斗失败,双方不互换排名。挑战比自己排名低的指挥官，无论胜负都不互换排名。指挥官排名前20名可以参与下一轮跨战区演习并获得相应奖励。
#
# 问题6: 指挥官需要设定哪些部队？
# 回答

# %% [markdown]
# ## 把一些不完整的FAQ去除

# %%
import os
def postprocess_faq(file_content,QA_SEP='====='):
    arr = file_content.split(QA_SEP)
    faqtext = ''
    for item in arr:
        try:
            question, answer = item.strip().split("\n", 1)
            question = question.replace("Question:", "").strip()
            answer = answer.replace("Answer:", "").strip()
            if question != '' and answer != '':
                faqtext+=f"Question: {question}\nAnswer: {answer}\n=====\n"
        except:
            pass
    return faqtext[:-6]


cleaned_new_faq = None
with open(newfaq_filename,"r") as f:
    cleaned_new_faq = postprocess_faq(f.read())

# %% [markdown]
# ## 保存最终的FAQ文件，下一步可以导出再由人工审核

# %%
cleaned_filename = 'docs/cleaned_topwar_enrich_faq_0911.faq'
with open(cleaned_filename,"w") as f:
    f.write(cleaned_new_faq)

# %%
print(cleaned_new_faq)
# Out:
# Question: 我如何获得装饰物？
# Answer: 装饰物可以通过摆放在基地，每周会根据活跃度获得一个免费的永久装饰物，也可以通过购买或者参与活动获取更多的装饰物。
# =====
# Question: 我最多能放置多少个装饰物？
# Answer: 你最多可以放置20个装饰物，但是每个装饰物的属性都是有限的，并且只有一个建筑能够放置装饰物，所以在放置装饰物时需要谨慎选择。
# =====
# Question: 我如何查看我的装饰物的属性？
# Answer: 在主城市中，你可以找到"建筑-神奇宝箱"的按钮，点击后会显示你所有已放置的装饰物的属性，还可以通过点击"图鉴"按钮查看所有的装饰物属性。
# =====
# Question: 我如何合成更高等级的装饰物？
# Answer: 在合成高等级装饰物时，需要将三个同等级的装饰物进行合成，合成后会得到一个更高一级的装饰物，但是合成后不会将原有装饰物的属性直接叠加，而是按照合成后的新属性进行叠加。
# =====
# Question: 我的游戏等级显示为什么只有0.2而没有显示0.24？
# Answer: 由于游戏内显示的最多有一位小数，所以当你从0.2提升到0.24时，游戏内会显示0.2，但是实际上你的游戏等级已经得到了提升。
# =====
# Question: 我如何分解高等级装饰物？
# Answer: 你可以通过消耗一定数量的经验值来分解高等级装饰物，分解后会获得对应的经验值和低等级的装饰物。
# =====
# Question: 请问专3技能有哪些可以升级的选项？
# Answer: 专3技能有多种升级选项，包括攻击力、生命值、防御力、移动速度等。你可以根据自己的需要和战斗策略来选择合适的升级选项。
# =====
# Question: 我需要多少经验才能将专3技能升级到下一个等级？
# Answer: 每次升级专3技能需要一定数量的经验。具体情况可以参考游戏内的指导手册或者咨询游戏内的客服。一般情况下，你需要积累一定数量的经验点数才能将专3技能升级到下一个等级。
# =====
# Question: 我在游戏里达到了专5级，这意味着什么？
# Answer: 专5级代表着你在游戏中的专属技能已经到达了最高水平，对应的技能也变得更加强大可靠。这意味着您在游戏中的表现将更加突出，能够应对更高级别的挑战。此外，专5级也可以为您的角色带来更高的经验和能力加成。
# =====
# Question: "专7是什么级别的技能？"
# Answer: "专7是专属技能的第七等级，它可以提供更高的伤害和更优秀的生存能力。"
# =====
# Question: "专7可以给角色带来哪些好处？"
# Answer: "专7可以让角色的攻击更高，同时还可以提高角色的抗性和生命值，使角色在战斗中更加耐打。此外，专7还可以增加角色的移动速度，让角色更方便地躲避敌人的攻击。"
# =====
# Question: 游戏内经验是如何获取的？
# Answer: 游戏内经验可以通过金币消耗来获取，消耗5金币=获取1经验。但是，游戏内显示的经验单位较大，会以四舍五入形式显示。因此，即使获取少量经验，系统也会为玩家增加经验，玩家不必担心。
# =====
# Question: 玩家如何查看升级所需要的经验？
# Answer: 玩家可以点击左上角查看当前升级所需要的经验。
# =====
# Question: 联盟科技-勤俭节约有什么作用？
# Answer: 联盟科技-勤俭节约只能减少消耗的金币，不减少获得的经验。
# =====
# Question: 如果玩家消耗了金币来获取经验，但经验值没增加怎么办？
# Answer: 玩家可以点击左上角查看当前升级所需要的经验，确保消耗金币的数量正确。如果经验数不变，可能是其他原因导致的，建议检查下游戏设置或者联系客服。
# =====
# Question: 请问游戏中如何获得更多的出征队列？
# Answer: 在游戏中可以通过完成游戏内活动或通过领取系统赠送的道具来获得更多的出征队列。
# =====
# Question: 那在创建新角色时，系统赠送的限时出征队列道具是无限时间的吗？
# Answer: 不是的，该限时出征队列道具的有效期结束后会被取消。
# =====
# Question: 可以在哪里查看各种皮肤的获取途径？
# Answer: 可以点击头像查看各种皮肤的获取途径。
# =====
# Question: 皮肤需要怎么装扮？
# Answer: 普通基地占用地块1*1，其他皮肤占用地块2*2。如果购买月卡后不自动装扮外观，需要迁移至空旷区域手动装扮。
# =====
# Question: 皮肤属性有哪两种？
# Answer: 皮肤属性分为2种：拥有属性和使用属性。拥有属性是指只要玩家拥有了这个皮肤，不需要装备就可以获得属性。使用属性是指玩家在使用这个皮肤的时候才会生效。
# =====
# Question: 购买月卡后如何获得月卡皮肤？
# Answer: 购买超级月卡后，可以在月卡持续期间使用月卡皮肤。其他皮肤外观需要活动获得。
# =====
# Question: 我怎么查找我的好友？
# Answer: 点击头像-设置-好友可以查看好友列表。世界聊天中可以点击头像添加好友～在世界地图中点击其他玩家的基地-头像也有添加好友的选项喔～可以在好友页面，点击“邀请好友”发送申请链接，好友点击即可成功添加。如果不在同一个服务器就无法添加好友哦。
# =====
# Question: 能否给士兵进行升级操作？
# Answer: 不可以，目前只支持士兵的合成和删除操作。
# =====
# Question: 能否在车库外放置士兵？
# Answer: 不可以，士兵必须放在车库内才能被收纳。
# =====
# Question: 我如何获得更多的钻石？
# Answer: 除了购买之外，你还可以通过参与游戏内的活动、观看视频等方式来获得钻石。例如，完成每日任务、参加在线比赛、完成活动任务等，都会有机会获得钻石奖励。另外，你也可以尝试在对局中获得胜利、展示技巧，这样也可以提高你获得钻石的几率。
# =====
# Question: 钻石在游戏中的作用有哪些？
# Answer: 钻石在《口袋奇兵》游戏中可以用于部分活动的参与，例如：累计钻石消费、丘比特、翻翻卡等。购买一些特殊的道具可以帮助你在游戏中更好地发挥，而消费钻石也可以让你在对局中获得更多的优势。此外，你还可以用钻石来购买新的角色或者道具，让你的游戏体验更加丰富。
# =====
# Question: 我可以如何设置自动加入集结的兵力？
# Answer: 有哪些类型可以加入集结？
# =====
# Question: 请问职业天赋中的战斗精英和机械大师分别是什么？
# Answer: 战斗精英可以大幅强化玩家的战斗能力，而机械大师则是增强发展的能力。
# =====
# Question: 我购买了成长基金，但是为什么无法领取钻石？
# Answer: 请您先尝试彻底关闭游戏后重新登录领取。如果仍然无法领取，请联系客服寻求帮助。
# =====
# Question: 成长基金可以购买多少钻石？
# Answer: 在礼包商城-成长基金中可以购买14000钻石。
# =====
# Question: 我是否需要达到55级才能购买成长基金2？
# Answer: 是的，在购买过成长基金并达到55级后可以购买成长基金2。
# =====
# Question: 我需要点数才能提升VIP等级吗？
# Answer: 如何查看我还差多少点可以提升VIP等级？
# =====
# Question: 我怎么才能达到5级？
# Answer: 你需要完成一些游戏任务并逐步升级来达到5级。
# =====
# Question: 我可以在哪些等级领取成长基金呢？
# Answer: 成长基金可以按等级要求依次领取，包括达到5级可领取2000钻石，达到10级可领取1000钻石，达到15级可领取1000钻石，达到20级可领取3000钻石，达到25级可领取1000钻石，达到30级可领取1000钻石，达到35级可领取1000钻石，达到40级可领取1000钻石，达到45级可领取1000钻石，达到50级可领取2000钻石，达到55级可领取1000钻石，达到60级可领取1000钻石，达到65级可领取2000钻石，达到70级可领取2500钻石，达到75级可领取2500钻石，达到80级可领取3000钻石。
# =====
# Question: 为什么未成年人玩家在晚上22点到次日 8点之间将无法登录游戏呢？
# Answer: 对于未成年人玩家，单次充值金额和月充值金额有什么限制？
# =====
# Question: 我如何进行实名认证？
# Answer: 如何检查我的实名认证状态？
# =====
# Question: 请问韦德战地维修技能需要达到什么等级才能解锁？
# Answer: 韦德战地维修技能需要达到4级才能解锁。
# =====
# Question: 修理工厂每天可以免费修理多少个单位？
# Answer: 根据您的英雄韦德战地维修技能，如五星可以修理53个单位。
# =====
# Question: 哪里可以找到游戏中的成就列表？
# Answer: 在游戏中，您可以点击主屏幕右上角的“成就”按钮来查看您的成就列表。您也可以通过按下“菜单”按钮，然后选择“设置”>“显示”>“成就”来查看成就列表。
# =====
# Question: 我被禁言了，怎么解除禁言？
# Answer: 您可以联系客服确认您是否被禁言，若确认为禁言，请等待禁言结束。在解除禁言之前，请一定要注意措辞，以避免再次被禁言。
# =====
# Question: 怎样修改游戏头像？
# Answer: 点击头像，可以选择修改性别和头像。如果修改自定义头像，需要修改下微信头像再重新登陆游戏等待一段时间就可以了（也可以通过修改微信性别来修改游戏角色性别）。
# =====
# Question: 什么是英雄？
# Answer: 英雄是口袋骑兵游戏中的核心作战单位，不同英雄具有不同特色的技能、专属装备以及被动技能。
# =====
# Question: 英雄招募分为哪两种？
# Answer: 英雄招募分为低级招募和高级招募，每种招募方式都有自己的消耗和获取的英雄类型。低级招募每日有5次免费机会，可招募到蓝色、紫色英雄以及碎片；高级招募每24小时有一次免费机会，可招募到紫色、橙色英雄以及碎片。
# =====
# Question: 你觉得购买新手礼包和黑金百夫长哪个更划算？
# Answer: 我觉得购买新手礼包和黑金百夫长都是非常不错的，但是具体哪个更划算，还要看个人的需求。
# =====
# Question: 你有什么推荐的月卡、周卡和远征关卡礼包吗？
# Answer: 我推荐购买月卡、周卡和远征关卡礼包，它们可以给您带来巨大的收益和体验。
# =====
# Question: 充值怎么可以带来收益？
# Answer: 充值可以帮您获得更多的游戏资源和福利，比如游戏内的道具、经验、金币等等，这些资源和福利可以帮助您在游戏中更好地发展和成长。
# =====
# Question: 能否查看我的充值历史记录？
# Answer: 您的消费行为属于您的隐私，我们无权进行全面查看，同时考虑到存在泄露风险（比如盗号者冒用您身份套取信息，进而非法获取所有权），所以我们无法向您提供，建议您自主查询支付平台（支付宝、银行卡等）的消费记录。
# =====
# Question: 金砖的价值与本地货币价值是否一致？
# Answer: 是的，金砖的价值与本地货币价值一致。
# =====
# Question: 在游戏内如何购买付费礼包？
# Answer: 可以通过官方网站→官方充值（右上角），输入您游戏内的识别码UID确认后，进行购买。
# =====
# Question: 金砖的使用有什么优势？
# Answer: 金砖的使用方式更加便捷，可以直接购买付费礼包，可以优先消耗金砖，避免繁琐的充值操作。
# =====
# Question: 金砖如何增加军级经验(VIP经验)?
# Answer: 金砖在游戏内消费后增加军级经验(VIP经验)。
# =====
# Question: 游戏中能量值的显示单位是什么？
# Answer: 游戏中能量值的显示单位是“bb”，每点能量值相当于1/1000次全功率输出的结果。
# =====
# Question: 游戏中金币数量的最小显示单位是什么？
# Answer: 游戏中金币数量的最小显示单位是“kk”，即1000个金币。
# =====
# Question: 帝国宝藏中的博士警卫都有哪些不同等级？
# Answer: 帝国宝藏中的博士警卫分为多个等级，每个等级都拥有不同的实力和奖励。低等级的博士警卫可能只拥有少量资源，而高等级的博士警卫则可能拥有丰厚的道具和经验。
# =====
# Question: 如何获得伪造徽章，可以对博士警卫发起攻击？
# Answer: 伪造徽章可以通过击败帝国宝藏中的博士英雄获取，每个博士英雄都有自己的徽章，如果成功击败他们，就可以得到伪造徽章，然后对博士警卫发起攻击。
# =====
# Question: 帝国宝藏中的道具都有哪些，可以带来什么样的效果？
# Answer: 帝国宝藏中的道具多种多样，例如恢复生命值的药物、增加攻击速度的饰品、增强防御力的装备等等，这些道具可以帮助玩家更好的战斗。
# =====
# Question: 帝国宝藏中的黑暗英雄从哪里来？
# Answer: 帝国宝藏中的黑暗英雄可能是来自于某个邪恶势力或者某个神话传说中的生物，因为帝国宝藏中战利品的奖励非常丰厚，所以吸引了众多黑暗英雄前来抢夺。
# =====
# Question: 帝国宝藏可以给玩家带来什么样的收益？
# Answer: 帝国宝藏是一个可以获得丰厚奖励的区域，其中可以击败博士警卫获得道具、击败黑暗英雄获取徽章，还可以获得高额的经验和财富。
# =====
# Question: 帝国宝藏中最高等级的博士警卫有多强大？
# Answer: 帝国宝藏中最高等级的博士警卫拥有无比强大的实力，他们的攻击和防御力都非常高，而且可能拥有特殊的技能和攻击方式。如何击败他们需要玩家运用智慧和实力的完美组合。
# =====
# Question: 我需要什么条件才能开启帝国宝藏？
# Answer: 需要指挥官等级达到23级 在原区服会开启帝国宝藏，如您在曙光之地中需要等到活动活动结束返回原服才能再次攻击帝国宝藏，您如果已经购买了伪造徽章是会正常计入的，请您活动结束后查看。
# =====
# Question: 如何变更游戏中的角色名称？
# Answer: 在游戏中点击头像，选择“个人信息”或“账户设置”，即可进行角色名称的修改。
# =====
# Question: 怎样在游戏中购买更加强大的武器装备？
# Answer: 在游戏中可以通过完成任务、击败敌人等方式获得游戏内的货币或虚拟物品，然后使用这些货币或虚拟物品在商店中购买更加强大的武器装备。
# =====
# Question: 如何关闭”购买者显示“？
# Answer: 点击头像，选择设置，找到”购买者显示“并关闭即可。
# =====
# Question: 神秘盟友购买了礼包后，显示的内容是什么？
# Answer: 若购买带有联盟礼物的礼包，则稀有礼物那一栏会显示：一位神秘盟友购买了此礼包。
# =====
# Question: 转区后可以在同一账号下进行转服吗？
# Answer: 不可以，转区操作会清空账号下的角色和数据，需要重新创建角色。
# =====
# Question: 如果我想转到另一个服务器，需要等多久才可以再次转区？
# Answer: 根据游戏的规定，转区成功后需要等待30天才可以再次转区。
# =====
# Question: 领地战斗力包括哪些方面的内容？
# Answer: 领地战斗力包括领土面积、驻军数量、建筑等级、城市设施等。
# =====
# Question: 重装机兵战斗力是什么？有什么提高方法？
# Answer: 重装机兵战斗力指的是使用重装机兵士兵在战斗中的表现。可以通过升级重装机兵武器、技能、装备等来提高重装机兵的战斗力。
# =====
# Question: 什么是兵种克制？
# Answer: 兵种克制是一个功能，基地等级达到45级时可解锁该功能。
# =====
# Question: 如何运用兵种克制取得胜利？
# Answer: 通过合理搭配和运用不同兵种之间的克制关系，可以取得对对手的胜利。例如，可以先用空军打击对手的海军，再用陆军击败剩余的对手。
# =====
# Question: 我基地等级已经达到了80级，但是为什么我还不能解锁通用天赋呢？
# Answer: 需要是满足一定的条件才能解锁通用天赋，例如邮箱绑定、花一定的金币购买、完成指定的任务等等。你可以查看游戏内的说明或者咨询客服来获取更多详细信息。
# =====
# Question: 我可以通过哪种方式来增加战斗
# Answer: 目前默认战斗回合上限为35，可以通过研究对应的天赋来增加回合数量。如果武术天赋被研究，战斗回合上限可以增加至40。如果武术天赋和政治天赋都被研究，战斗回合上限可以增加至45。
# =====
# Question: 在一局游戏中，当我攻击对手时，他是否也会同时攻击我？
# Answer: 是的，当你攻击对手时，他也会同时攻击你。这就是一回合的计算方式：你攻击对方，对方同时攻击你，这就算作一回合。
# =====
# Question: 什么是轮次？
# Answer: 轮次指的是双方全部单位行动后的一轮。
# =====
# Question: 在最强指挥官活动中，如何获得积分？
# Answer: 消耗金币、疯狂造兵、击杀战锤、肃清怪物、采集资源和提升战力都可以获得积分。
# =====
# Question: 可以在最强指挥官活动中获得什么奖励？
# Answer: 除了可以每天都达到目标获得高额奖励外，周结算时还会以邮件形式送达丰厚的排行奖励，包括金币、钻石、道具和其他游戏内的福利。
# =====
# Question: 活动中心-人气之星在哪里可以找到？
# Answer: 活动中心-人气之星在游戏主界面的右上角，可以通过点击“活动中心”图标进入。您也可以点击左下角的“福利”按钮，再选择“活动中心”进入。
# =====
# Question: 都有什么皮肤可以被评为人气之星？
# Answer: 可以被评为人气之星的皮肤有：人气之星皮肤（收花榜）和粉丝团长皮肤（送花榜）。这些皮肤有独特的外观效果，可以为您的游戏角色添加一些额外的个性化元素。此外，这些皮肤还可以带来一些额外的属性加成，如最高兵种合成等级+1等。
# =====
# Question: 活动期间，排行榜是如何计算的？
# Answer: 影响排行榜的计算因素有很多，包括您在活动中赠送和收到的玫瑰/麦克风数量、质量和时间。每次赠送和收到的玫瑰/麦克风都会为您的收花榜和送花榜增加积分，最终的排行榜排名将根据总积分情况进行计算。
# =====
# Question: 活动结束后，哪些皮肤可以永久保留？
# Answer: 在活动结束后，只有全战区排行榜收花榜、送花榜第一的玩家可以获得永久皮肤。其他排名奖励中的皮肤奖励都将有限时使用期限，使用期限以使用对应皮肤道具后开始计算时间。
# =====
# Question: 活动期间，如何查看自己的排名？
# Answer: 在活动期间，您可以通过活动中心-人气之星的左上角查看自己的排名，具体排名信息包括：收花榜和送花榜的排名、总排行榜收花榜、送花榜和全战区排行榜的收花榜、送花榜。
# =====
# Question: 可以与其他排行榜排名进行比较吗？
# Answer: 是的，您可以与其他排行榜排名进行比较，看看自己在全战区排行榜、收花榜、送花榜的表现如何。
# =====
# Question: 活动期间，皮肤奖励的具体属性是什么？
# Answer: 活动期间，皮肤奖励可以为您的角色带来一定的属性加成，如最高兵种合成等级+1等。除此之外，这些皮肤还可以为您的角色带来一些特殊的外观效果，让您的游戏角色更加与众不同。
# =====
# Question: 普通玩家每天可以送花多少朵?
# Answer: 普通玩家每天可以送花5朵。
# =====
# Question: VIP会员可以送花的数量限制是多少？
# Answer: VIP会员可以送花数量限制是按照VIP等级的不同而有所不同，具体如下：
# =====
# Question: 在活动中赠送玫瑰/麦克风时，如果数量不足如何操作？
# Answer: 如果数量不足，您可以在活动页面点击商店购买界面进行购买，购买成功后即可赠送对应数量的玫瑰/麦克风。
# =====
# Question: 我在战斗中怎么提高我的暴击率呢？
# Answer: 暴击率的提高可以通过一些方法实现，如角色的技能、装备、宝石等。先来了解一下你的角色技能是否有暴击效果，如果有，那么就可以通过升级技能，提高暴击率。另外，装备方面，可以通过购买具有暴击效果的装备，如武器、项链等，来增加暴击率。此外，还可以通过宝石的镶嵌，选择增加暴击率的宝石，来提升暴击率。综上所述，在游戏中提高暴击率需要对角色的技能、装备和宝石都有所了解，并一一进行相应的提升。
# =====
# Question: 我该如何攻击世界boss？
# Answer: 您可以每天定时关注世界boss出现的时间，然后在它出现时及时参与攻击。在攻击时，您最多可以攻击5次，并且需要和其他玩家竞争获得最高名次才会获得奖励。
# =====
# Question: 奖励会在何时发放？
# Answer: 奖励会在每天21:00（UTC+8时区）发放。因此，您需要在攻击世界boss后等待一段时间，才能获得您的奖励。
# =====
# Question: 我可以在不同时间段攻击世界boss吗？
# Answer: 您可以在每个出现的时间段都参与攻击，但是您只有每次参与攻击的5次机会。因此，您需要在每次出现的时间段内都积极参与，以获得最高名次和最佳奖励。
# =====
# Question: 为什么我拉空投的时候，我的全兵种攻击加成会变成负数？
# Answer: 运输空投的队列会有负面效果，会给您的行军速度、全部单位生命加成和全部单位攻击加成都带来降低，具体降低数值为：减去90%的行军速度，减去60%的全部单位生命加成，以及减去60%的全部单位攻击加成。
# =====
# Question: 入盟保卫战需要哪些条件？如何参加防御据点？
# Answer: 联盟保卫战开启条件：玩家至少有一个联盟且联盟有一个联盟堡垒。只有盟主才能报名开启。报名时可以选择XX小时后开启。参加防御据点：玩家可以点击开启联盟保卫战的联盟据点，点击之后点击驻守，在点增员就可以参加保卫据点。
# =====
# Question: 我在个人保卫战中失败了两次，还能继续游戏吗？
# Answer: 当然，你还可以继续游戏，但是你需要在接下来的23波怪物攻城中成功击败它们。建议你查看游戏中的攻略，加强你的技能，并尝试不同的策略来战胜敌人。
# =====
# Question: 在个人保卫战中，怪物的攻击力很强，我应该怎么办？
# Answer: 在个人保卫战中，怪物的攻击力很强，你可以尝试使用一些防御装备和道具来加强你的防御能力。此外，你还可以升级你的角色，提高你的攻击力，以更好地应对怪物的攻击。
# =====
# Question: 报名截止时间是什么时候？
# Answer: 报名截止时间会在活动结束时间前两小时截止，还请下次提早报名。
# =====
# Question: 这个活动是怎样的？
# Answer: 这个活动是一个个人保卫战，玩家需要和其他玩家一起击败怪物，保卫城市。
# =====
# Question: 请问个人保卫战重不重新开始？
# Answer: 不可以，个人保卫战每次活动只能打一次，无法重新开始。
# =====
# Question: 我拥有550名士兵，如何搭配兵种组成一支强大的海军？
# Answer: 在搭配兵种方面，可以考虑将补充型的支援型和防御型兵种相结合，例如水雷、驱逐舰、反潜舰以及巡洋舰等。同时，也可以考虑增加ный корабль（旗舰）以提高舰队的指挥和协调能力。此外，还可以使用各种可以提供额外攻击和防御能力的装备和道具，例如鱼雷发射器、防空导弹和反潜导弹等。
# =====
# Question: "在个人保卫战波数27的战斗中，我应该如何更加有效地利用我的空军？"
# Answer: "在个人保卫战波数27的战斗中，有效地利用空军可以让你的防御更加坚固，可以考虑以下几点：
# =====
# Question: "在个人保卫战波数27中，我应该如何配置士兵数量来展示我的力量？"
# Answer: "在 personal保卫战波数27 中，配置合适的士兵数量对于展示你的力量非常重要。一般来说，可以根据以下几点来配置士兵数量：
# =====
# Question: 如何在个人保卫战波数28中使用陆军？
# Answer: 在波数28中使用陆军的最佳做法是充分了解每个兵种的优势和劣势，以便在战略和战术上做出最佳选择。 你可以考虑将兵力集中在一些关键词可能被搜索到的地方，以此来增加你的胜率。此外，确保你的士兵在游戏中的移动速度与你的敌人相仿。
# =====
# Question: 在个人保卫战中，如何提高海军的作战能力？
# Answer: 提高海军的作战能力需要从多个方面进行改善，包括加强舰船的建造和升级、增加海军的数量和素质、优化海上的战术和指挥等。建议在游戏中多多练习，积累经验，找出自己在海上的不足之处，并针对性地进行改进。此外，还可以通过研究游戏中的海军战术和战略，了解海军的优势和劣势，从而更好地运用它们来进行作战。
# =====
# Question: 请问在个人保卫战中，选择哪种兵种能够更好地保护我的基地？
# Answer: 在个人保卫战中，选择空军兵种能够更好地保护你的基地。因为空军可以在空中进行攻击，无法被地面单位抵挡，可以迅速打击敌人，减少敌人的进攻次数，从而保护你的基地。
# =====
# Question: 那么我需要多少士兵来保护我的基地呢？
# Answer: 在个人保卫战中，你需要880个士兵来保护你的基地。这是因为，根据游戏规则，每个士兵有2点攻击力，保护你的基地需要880点攻击力，所以需要880个士兵。
# =====
# Question: 我在个人保卫战中怎样才能获得更高的分数？
# Answer: 在个人保卫战中获得更高的分数，可以通过多种方式来实现，例如提升角色等级、获得更多的装备和武器、参与更多任务和挑战等。另外，你还可以尝试在游戏中发掘更多的隐藏要素和技巧，以及与其他玩家合作或竞争来获得更高的分数。
# =====
# Question: 我在个人保卫战中如何才能达到30积分？
# Answer: 在个人保卫战中达到30积分需要积极参与战斗，击杀敌方玩家以及摧毁敌方防御塔。同时也可以通过完成保卫任务、摧毁敌方基地等方式获得积分。
# =====
# Question: 我在游戏中积攒了30积分后，可以获得什么奖励？
# Answer: 通过积攒30积分可以在游戏中获得钻石100、训练加速1小时以及重装芯片宝箱等丰富的奖励，让你的游戏体验更加精彩。
# =====
# Question: 什么是个人保卫战？
# Answer: 个人保卫战是一个游戏模式，在该模式中，玩家将代表自己的阵营与其他玩家进行 Wars 争夺。玩家可以通过击败敌人、摧毁建筑和收集资源来获得积分，并通过击败敌人、摧毁建筑和收集资源来获得积分。积分越高，获得的奖励就越好。
# =====
# Question: 我要如何在个人保卫战中达到75积分奖励？
# Answer: 如果你想在个人保卫战中达到75积分奖励，你需要在游戏中击败足够多的敌人、摧毁足够多的建筑，并收集足够的资源。具体来说，你可以尝试以下方法：
# =====
# Question: 在个人保卫战中，当我达到多少积分时才能获得200积分奖励？
# Answer: 当你在个人保卫战中积攒达到200积分时，即可获得体力50点、训练加速8小时和中级重装芯片宝箱的奖励。
# =====
# Question: 我如何才能在个人保卫战中获得积分？
# Answer: 通过完成任务、消灭敌人和击败对手等行为来获得个人保卫战积分，积分可以用来提升角色等级和解锁更多道具和奖励。
# =====
# Question: 个人保卫战的积分可以通过击败敌人、完成任务和参加活动等方式获得。每击败一个敌人可以获得5分，每完成一项任务可以获得10分，每参加一次活动可以获得20分。
# Answer: 在个人保卫战中达到积分奖励需要达到500分。达到此分数后，将获得绿色图纸随机箱*1、机甲碎片*2、3级强化自选箱*5、训练加速8小时*1等丰厚奖励。
# =====
# Question: 个人保卫战中获得700积分需要做什么才能获得奖励？
# Answer: 在个人保卫战中通过杀死敌方玩家、摧毁敌方防御塔或摧毁敌方基地等方式获得积分，当积分达到700分时，即可获得绿色图纸随机箱*1、机甲碎片*4、低级橙色碎片合成箱*5、训练加速8小时*1的奖励。
# =====
# Question: 个人保卫战中除了获得700积分的奖励之外，还有其他获得积分的方式吗？
# Answer: 对的，个人保卫战中还有很多其他获得积分的方式，例如摧毁敌方防御塔、击败敌方英雄、摧毁敌方基地等。通过完成这些任务，可以增加自己的积分，达到更高的排名和奖励。
# =====
# Question: 个人保卫战中获得1000积分会得到什么样的奖励？
# Answer: 能否分享一下其他可以获得积分的方法？
# =====
# Question: 在个人保卫战中，达到多少积分可以获得橙色万能碎片呢？
# Answer: 在个人保卫战中，达到1500分可以获得橙色万能碎片。
# =====
# Question: 能否告诉我关于训练加速是如何工作的？
# Answer: 训练加速是指在个人保卫战中使用加速道具后，可以提高角色训练速度，让角色在短时间内获得更多的训练经验，以更快的速度提升等级。
# =====
# Question: 能否告诉我如何获得天赋书？
# Answer: 天赋书是一种重要的游戏道具，可以通过个人保卫战、竞技场等游戏活动获得，也可以在商店中使用虚拟货币购买。
# =====
# Question: 在个人保卫战中，达到多少积分才能获得橙色万能碎片*2、军阵通用手册*10、蓝色材料随机箱*15、训练加速8小时*3的奖励？
# Answer: 在个人保卫战中，达到5500分才能获得橙色万能碎片*2、军阵通用手册*10、蓝色材料随机箱*15、训练加速8小时*3的奖励。
# =====
# Question: 我需要购买更多的士兵来增加我的兵力，你建议我应该买哪个兵种？
# Answer: 根据您提供的信息，您已经拥有了陆军兵种。如果想要增加兵力，建议您可以考虑购买其他兵种，如空军、海军或者特殊兵种，具体选择需要根据您的游戏策略和目标来决定。
# =====
# Question: 我如何才能在游戏中获得更高的分数？
# Answer: 得分的主要因素是玩家在游戏中击败敌人的次数和效率。因此，要想获得更高的分数，可以尝试通过升级自己的装备、增加士兵数量、挖掘更多的资源等方式来提升自己的实力，从而更容易击败敌人并获得更高的分数。此外，还可以通过挑战游戏中的难关、完成任务等方式来获取更多的积分。
# =====
# Question: 你是如何达到波数3的?
# Answer: 我使用了空军作为我的主要兵种，并且在每波中都尽可能地使用士兵数量21，通过有效的策略和决策，成功地防守了三次攻击。
# =====
# Question: 你觉得如何才能在个人保卫战中取得胜利？
# Answer: 在个人保卫战中取得胜利的关键因素是合理的兵种组合和灵活的策略。建议选择一些攻击力较强的兵种，如火箭兵或弓箭手，并合理搭配，以充分发挥其优势。此外，在策略方面，可以尝试采取压制性作战或者绕道敌后进行偷袭等方式，以达到取胜的目的。
# =====
# Question: 在你的游戏中，你选择的兵种是陆军，士兵数量为27。你觉得这个组合在个人保卫战中是否具有竞争力？
# Answer: 我觉得这个组合在个人保卫战中具有一定的竞争力，但具体表现还要看对手的实力和策略。陆军具有较强的近身攻击能力，而27个士兵的数量也足够支撑一段时间的战斗。当然，如果对手实力较强或者采取了更加有效的策略，那么这个组合的竞争力就会受到影响。所以，在实际游戏中，我们需要根据对手的实力和策略来进行相应的调整和变化，以达到最好的战斗效果。
# =====
# Question: 在我的个人保卫战中，我需要将海军的数量增加到多少才能在波数5时取得胜利？
# Answer: 根据您当前的兵力配置，需要将海军的数量增加到55个才能在波数5时取得胜利。建议您可以考虑增加海军的招募速度或研究新的海军兵种。
# =====
# Question: 如果我想提高我的个人保卫战波数7的士兵数量，应该怎么做？
# Answer: 你需要考虑升级你的兵种，以获得更高的士兵数量。你可以通过使用升级卡、金币或者其他游戏资源来升级你的兵种，从而获得更多的士兵。此外，你还可以考虑提高你的 army stats，例如英雄加成、技能强化等，从而获得更高的士兵数量。
# =====
# Question: 你对个人保卫战波数8的海军兵种有哪些了解？
# Answer: 在个人保卫战波数8中，海军兵种包括驱逐舰、巡洋舰、潜艇等。驱逐舰可以进行高速追逐，巡洋舰可以防御、攻击和支援，潜艇可以在水下进行侦查和攻击。
# =====
# Question: 个人保卫战波数8中，海军士兵的数量是多少？
# Answer: 个人保卫战波数8中，海军士兵的数量为60人，其中包括驱逐舰、巡洋舰、潜艇和其他海军单位。每个海军单位的士兵数量不同，但60人是一个合理的数字。
# =====
# Question: 请问在这个保卫战中，我应该如何搭配我的兵种才能更好地应对敌人的攻击？
# Answer: 针对敌人的不同兵种，你可以根据你的实际情况进行搭配。例如，如果你的敌人有很多枪兵，你可以增加你的步兵数量以增加防禦力。如果你的敌人有很多弓箭手，你可以增加你的弓箭手数量，以增加攻击力。此外，你也可以考虑增加空军，利用空袭来打击敌人。
# =====
# Question: 在个人保卫战中，我有哪些兵种可以选择？
# Answer: 你可以选择的兵种有海军、步兵、航空兵等。
# =====
# Question: 我的球队中哪些兵种可以组成一支强大的空军？
# Answer: 为了构建强大的空军，你可以考虑招募各类战机，包括喷气式战机、轰炸机、侦察机等。同时，还可以配置一定的空对空导弹和空对地导弹来提高战斗能力。
# =====
# Question: 我在防守第五波时应该怎样调整我的阵容来更好地抵抗对手的攻击？
# Answer: 在第五波的防守中，您需要确保您有足够的机动性和火力。建议您增加一些机动性强的单位，如坦克和直升机。同时，您也可以考虑增加一些火力强大的武器，如导弹和火箭筒。此外，您还可以考虑增加一些可以治疗伤员的医疗单位，以确保您的部队能够更好地支撑下去。
# =====
# Question: 能否更改兵种等级？
# Answer: 可以通过对兵种进行升级和训练来提高它们的战斗力。可以通过消耗资源和技能点数来提升等级。建议先选择适合自己需求的兵种，然后再逐步升级和训练。
# =====
# Question: 在个人保卫战中，如何提高我的胜率？
# Answer: 在个人保卫战中，提高胜率有很多方法。首先，要选择适合自己的士兵和兵种，例如，如果喜欢近战，可以选择擅长肉搏的士兵。其次，要学会合理的布阵，将士兵放置在有利的位置，增加自己的防守力。此外，也要善于利用自己的优势，如利用建筑物进行掩护，或者在敌军立足未稳时发起突然攻击。最后，要保持耐心，不要在初期急于求成，稳定地赢得每一场战斗，最终才能获得胜利。
# =====
# Question: 你能告诉我你的空军中有哪些兵种吗？
# Answer: 我的空军中有士兵、轰炸机、导弹等兵种。
# =====
# Question: 你有多少士兵在个人保卫战中参战？
# Answer: 我在个人保卫战中共有183名士兵参战。
# =====
# Question: 在保卫战中，如何有效地运用海军兵种？
# Answer: 在保卫战中，海军兵种可以用于攻击敌方的海岸线，阻止敌方登陆或者运输物资。此外，海军还可以进行搜索和摧毁敌方的船只，对敌方造成重大的战略打击。建议在游戏中，玩家要根据实际情况合理部署海军，在关键时刻进行反击。
# =====
# Question: 在个人保卫战中，如何提高空军的战斗力？
# Answer: 首先，可以考虑增加空军的兵种数量，以增加攻击力。此外，可以考虑把一些高科技的武器装备到空军中，以提高其攻击力和生存能力。同时，还可以考虑培训高级飞行员，以提高空军的精度和打击能力。
# =====
# Question: 在个人保卫战中，如何提高士兵的数量？
# Answer: 首先，可以考虑增加招募士兵的速度，以增加兵力数量。其次，可以考虑培训更多的士兵，以增加他们的战斗力。此外，还可以考虑提高士兵的装备水平，以提高其生存能力。
# =====
# Question: 我的士兵数量为263，应该选择哪种兵种作为我的主力军队？
# Answer: 鉴于您有限的士兵数量和您的喜好，我们建议您考虑选择火枪手作为您的主力军队。火枪手具有较高的攻击力和射程，可以在远程攻击时发挥巨大作用。此外，火枪手还具有较低的成本，您可以在游戏中轻松获得。
# =====
# Question: 在个人保卫战中使用海军有哪些优势和劣势？
# Answer: 优势：海军可以跨越水域，直接攻击敌方的海岸城市或补给站，造成巨大破坏。劣势：由于移动速度较慢，无法快速支援其他兵种，而且在地形不利的情况下作战比较困难。
# =====
# Question: 在个人保卫战中，使用320名士兵、空军，应该选择哪些兵种组合可以给我最大的胜算？
# Answer: 在个人保卫战中，选择空军与士兵的兵种组合可以为您带来最大的胜算。由于士兵数量众多，可以更好地支持其他兵种进行战斗，并保护您免受敌方的攻击。而空军则可以更好地支援地面部队，进行高空中打击敌人，从而获得更多优势。
# =====
# Question: 请问如何提高士兵的数量?
# Answer: 提高士兵数量的方法有多种。首先，您可以尝试在游戏中购买更多士兵，其次您可以通过完成任务和升级来获得士兵经验，还可以通过使用游戏中提供的士兵生成器来增加士兵数量。
# =====
# Question: 你在联盟保卫战中成功抵御了1波进攻，可以获得什么奖励？
# Answer: 你可以获得科技宝箱300，它可以让你的基地更快发展，提高你的战略部署能力和装备等级。
# =====
# Question: 我在联盟保卫战中成功抵御了3波进攻，但我没有得到预期的奖励，为什么呢？
# Answer: 您可能需要确保您的联盟保卫战设置正确，并积极参与保卫战。此外,您需要确保您的角色有足够的经验和等级才能获得联盟保卫战的奖励。如您仍然没有收到预期的奖励，请联系游戏客服查看您的账户是否存在问题。
# =====
# Question: 联盟保卫战成功抵御3波进攻可以得到什么样的奖励？
# Answer: 联盟保卫战成功抵御3波进攻的奖励为体力10点*1,白色图纸随机箱*1。这些奖励将自动发放到参与保卫战的玩家的账户中，可以通过游戏中的邮箱查看和领取。
# =====
# Question: 联盟保卫战成功抵御10波进攻可以获得哪些奖励？
# Answer: 成功抵御10波进攻将获得高级招募券*2和训练加速1小时*3的奖励。
# =====
# Question: 高级招募券可以用来做什么？
# Answer: 高级招募券是一种可在游戏商店中购买高级兵种、加快招募速度的道具，是提升游戏实力的必备品之一。
# =====
# Question: 我在联盟保卫战中成功抵御了20波进攻，可以获得哪些奖励？
# Answer: 你将获得精英抽卡券*3和训练加速8小时*3的奖励。
# =====
# Question: 我在联盟保卫战中成功抵御了25波进攻，可以获得什么奖励？
# Answer: 你将获得额外的队列（持续2天）和训练加速8小时*4，这将让你的军队更加壮大和强大，更好地应对未来的挑战。
# =====
# Question: 队列和训练加速8小时*4对我来说有什么意义？
# Answer: 队列能够让你在联盟保卫战中更加活跃，而训练加速8小时*4将使你的军队在更短的时间内得到更好的发展，这样你就可以更快地完成任务，更好地保护你的领土。
# =====
# Question: 在联盟保卫战中成功抵御了30波进攻后，我获得了什么奖励？
# Answer: 你获得了海军英雄专属技能宝箱*5，职业天赋加速8小时*5。你可以使用这些奖励来提升你角色的战斗力，并且更快地升级。
# =====
# Question: 联盟保卫战成功抵御35波进攻的奖励是什么？
# Answer: 联盟保卫战成功抵御35波进攻的奖励是陆军英雄专属技能宝箱*5和职业天赋加速8小时*5。
# =====
# Question: 需要多少波进攻才能获得这个奖励？
# Answer: 不清楚需要多少波进攻才能获得这个奖励，建议查看游戏规则或者咨询官方客服。
# =====
# Question: 在联盟保卫战中成功抵御40波进攻后可以获得哪些奖励？
# Answer: 成功抵御40波进攻后，您将获得橙色万能碎片*2和职业天赋加速8小时*5的奖励。
# =====
# Question: 我在联盟保卫战中成功抵御了45波进攻。请问我现在可以获得什么奖励？
# Answer: 恭喜你成功抵御了45波进攻！根据你的成绩，你将获得战争狂人头像框（30天）、橙色万能碎片*3以及职业天赋加速8小时*10作为奖励！这些奖励将有助于你更好地提升自己的游戏实力。
# =====
# Question: 我在联盟保卫战中成功抵御了45波进攻。请问这些奖励可以用来做什么？
# Answer: 这些奖励可以帮助您提高角色的战斗力，其中包括可以穿戴的头像框，可以用来加速角色的天赋培养，以及可以获得更多提升角色实力的道具。此外，这些奖励还可以为您提供一定的时间来进一步发挥游戏中的厉害之处。
# =====
# Question: 我在游戏中成功抵御了50波进攻，可以获得什么样的奖励？
# Answer: 恭喜您成功抵御了50波进攻！您将获得战争狂人铭牌，持续30天。同时，您还将获得橙色万能碎片*5和职业天赋加速8小时*20的奖励。
# =====
# Question: 这个活动的时间是多久？
# Answer: 这个活动将会在周二的21点开始，持续2小时。
# =====
# Question: 联盟如何获得占领发射井的积分？
# Answer: 联盟通过占领发射井获得累计占领时间，通过4个发射井的累计占领时间决定联盟排行名次。联盟排行,积分相同时按发射井累计时间计算,计算到单位秒,秒数相同时按进入发射井的顺序,优先进入任意一个发射井,则排名在前。
# =====
# Question: 联盟排行榜是如何计算的？
# Answer: 联盟排行榜是根据联盟成员在占领发射井活动中的累计占领时间来计算的。也就是说，如果有一个联盟成员占领了某个发射井，那么整个联盟的排名就会相应地提高。
# =====
# Question: 联盟成员在占领发射井活动中是否可以获得个人积分？
# Answer: 联盟成员在占领发射井活动中可以获得个人积分，但是个人积分的多少与联盟积分无关。个人积分是根据每个成员在占领发射井活动中的表现来计算的，包括占领时间、击杀数、摧毁数等等。
# =====
# Question: 个人占领发射井可以获得什么积分？
# Answer: 怎样可以获得杀敌积分？
# =====
# Question: 是否可以获取陷阱积分？
# Answer: 如果使用消耗[临时陷阱]或[陷阱]会获得什么积分？
# =====
# Question: 如何在游戏开启后快速获得第一个成就？
# Answer: 游戏开启后,可以在主菜单的“成就”选项卡中找到"初学者大挑战"成就，并完成相应的任务要求，即可快速获得该成就。
# =====
# Question: 什么情况下会获得积分？
# Answer: 在发射井占领期间，战斗中使用消耗[临时陷阱]、[陷阱]会获得积分，所有战斗中生效。
# =====
# Question: 临时陷阱和陷阱有什么区别？
# Answer: 临时陷阱和陷阱是两种不同的陷阱，临时陷阱是一种可以使用一次的陷阱，而陷阱则是一种可以长期放置的陷阱。
# =====
# Question: 我为什么没有获得战斗中的物资奖励？
# Answer: 您需要确保在战斗中击败了敌人，只有击败敌人后，您才可获得物资奖励。请检查一下您的击杀记录，确认您是否已经获得了足够的奖励。
# =====
# Question: 在盟友对发射井集结后，我为什么没有获得参与积分？
# Answer: 在盟友对发射井集结的战斗中，只有您自己参与战斗并击败敌人，您才能获得积分。如果您只是参与了集结但没有杀敌，您将不会获得积分。请确保您在战斗中积极参与，不断击败敌人，以获得更高的积分。
# =====
# Question: 我在哪里可以找到临时陷阱？
# Answer: 你可以在击败世界中的黑暗军团后掉落的[临时陷阱]。只有在活动期间内，你才能使用这些[临时陷阱]。活动结束后，你身上的剩余[临时陷阱]将被清除。
# =====
# Question: 首府的占领状态是如何开始的？
# Answer: 首府的占领状态将根据指挥官投票或首领选择的时间进入可占领状态。阶段1可占领状态开始的1小时内联盟在这个阶段占领首府，持续占领30分钟即可获胜。
# =====
# Question: 首府的占领状态是如何结束的？
# Answer: 首府的占领状态将持续直到联盟成功占领或者期限结束。
# =====
# Question: 阶段2和阶段3中占领时间是如何计算的？
# Answer: 阶段2和阶段3中占领时间的计算方式与阶段1类似，即持续占领30分钟和15分钟即可获胜。
# =====
# Question: 阶段4中占领时间是如何计算的？
# Answer: 阶段4中占领时间为进入占领状态后的2小时以后，立即获胜。
# =====
# Question: 首府的占领规则会不会因为联盟变更而改变？
# Answer: 首府的占领规则只会因为占领联盟的变更而改变。只有在占领倒计时过程中进入下一阶段，才会改用新阶段的占领规则。
# =====
# Question: 如果我占领了首府，如何避免导弹攻击？
# Answer: 一旦我受到了导弹攻击，我的部队会受到什么影响？
# =====
# Question: 如何提高自己的战斗力？
# Answer: 可以通过培养角色属性、升级技能等级、装备优质武器和防具、参加战斗任务等多种方式来提高自己的战斗力。同时，也可以通过练习和总结经验来提高自己的技巧和策略。
# =====
# Question: 领主有什么特权？
# Answer: 领主可以任命官职、发布本战区强化、赠与礼物、修改本战区名字、发布首领宣言，领主还会多出一个额外队列。
# =====
# Question: 在占领首府活动中，队员可以赢得多少积分？
# Answer: 队员在占领首府活动中通过参与集结和超级集结，将会获得相应的积分奖励。每个参与活动的队员都将获得积分，发起和参与集合将获得更多的积分。
# =====
# Question: 队员可以通过哪些方式赢得积分？
# Answer: 队员可以通过参与占领首府活动期间的集结和超级集结来获得积分，每次集结发起者和参与者都将获得积分。此外，如果队员在战斗中表现出色，还可以获得额外的积分奖励。
# =====
# Question: 参与占领首府活动是否会有道具奖励？
# Answer: 是的，在占领首府活动期间，参与首府或发射井的战斗，每击杀一位敌人就会获得一定数量的道具奖励。此外，战斗越到最后阶段，击杀积分排名越高，获得的奖励也会越多。
# =====
# Question: 最强指挥官活动中击败黑暗军团可以获得多少积分？
# Answer: 活动中，击败黑暗军团可以获得游戏积分，积分计算规则是：黑暗军团的等级除以5，有小数点的向上取整数计算。
# =====
# Question: 最强指挥官活动中的积分有什么用途？
# Answer: 最强指挥官活动中的积分可以用于解锁游戏道具、游戏皮肤和其他游戏内的奖励。玩家通过参与活动、完成任务和击败黑暗军团等途径积累积分，可以兑换更多的游戏内福利，提高游戏体验。此外，积分排名也会影响玩家在游戏对战中的排名，激发玩家更加努力地参加活动和获取积分。
# =====
# Question: 我的空投资源箱为什么比盟友的少？
# Answer: 我不知道为什么您的资源箱比盟友的少，可能是您的空投资源箱在遗迹中有被掠夺的情况或者您在遗迹中的时间比盟友长，所以资源都被其他玩家拿完了。我建议您在遗迹中尽可能快地领取资源，这样可以避免资源被他人掠夺。
# =====
# Question: 如何提高空投资源箱的收益？
# Answer: 如果您想要提高空投资源箱的收益，可以尝试以下方法：首先，要尽快上线领取资源，这样可以避免资源被他人掠夺；其次，在遗迹中可以通过击败其他玩家来获取更多的资源；最后，可以在遗迹中搜索空投箱，这样可以获得更多的资源。
# =====
# Question: 在什么情况下可以获得额外的空投资源箱？
# Answer: 在成功击落敌方玩家或者摧毁敌方建筑的情况下可以获得额外的空投资源箱，每个击落或摧毁会给您带来1到3个额外的空投资源箱，具体数量取决于您的技巧和敌人的难度。
# =====
# Question: 拉一个蓝色资源箱能够给我带来多少经验值？
# Answer: 拉一个蓝色资源箱可以给您带来约 200 到 300 点的经验值，具体取决于您所在的等级。
# =====
# Question: 请问在什么情况下可以获得更多的空投资源箱？
# Answer: 在没有被阻击的情况下，您可以获得500个空投资源箱，盟友可以获得100个空投资源箱。此外，参加游戏活动或者达到一定的游戏等级也可能获得更多的空投资源箱。
# =====
# Question: 如果我在驾驶载具时开了护盾，被其他玩家攻击是否会导致护盾破掉？
# Answer: 不会。在驾驶载具时，护盾是自动开启的，只要你没有主动关闭它，它就不会因为其他玩家的攻击而破裂。只要你保持移动，护盾就会一直存在，直到你停止移动或因为其他原因关闭它。
# =====
# Question: 请问联盟频道在哪里可以找到？
# Answer: 联盟频道通常位于游戏主界面的右下角，点击进入即可。在联盟频道中，可以领取空投资源箱等道具，领取时间有规定，请务必注意。
# =====
# Question: 我在游戏里找不到空投资源箱兑换按钮，怎么办？
# Answer: 您可以在常规活动类目下补给获得页面，找到空投兑换按钮进行兑换。如果您还是找不到，请检查一下设置中是否启用了相关功能。
# =====
# Question: 怎么获得求救信道具？
# Answer: 指挥官可以通过悬赏任务的宝箱奖励获得求救信道具。
# =====
# Question: 难民营的发现者如何发起集结战斗？
# Answer: 只有难民营的发现者可以对该难民营发起集结。要发起集结战斗，需要在世界地图上使用求救信道具来发现隐藏的难民营，然后点击难民营图标，点击“集结”，选择要参加集结的队员，最后点击“开始战斗”即可。
# =====
# Question: 队长和队员在集结战斗中会获得什么奖励？
# Answer: 集结队长和队员会分别获得不同的奖励。队长会根据战斗结果获得经验、金币和物品等奖励，队员则会获得一定的经验、金币和物品。
# =====
# Question: 每天最多可以参加多少次集结队员奖励？
# Answer: 每天最多只能获得10次集结队员奖励。
# =====
# Question: 在求救信中，你能看到任何线索吗？
# Answer: 是的，信的右下角有一个小标签，上面写着"来自北方电信局"。
# =====
# Question: 我在游戏中找到了一个黑暗军团情报盒，但是不知道该如何打开它。
# Answer: 您需要找到对应的钥匙才能打开黑暗军团情报盒。可能需要在游戏内完成某些任务或者击败特定的敌人来获得钥匙。请遵循游戏内的提示来解锁情报盒。同时，提示您，黑暗军团情报盒掉落率很低，所以您需要格外珍惜机会。
# =====
# Question: 镶金古箱里有什么?
# Answer: 镶金古箱里包含了各种稀有强化图纹和道具，可以让你更轻松地提升角色的实力。
# =====
# Question: 我在个人保卫战中为什么排名靠后？
# Answer: 个人保卫战的排名是根据您完成活动的时间先后顺序来决定的。可能您完成活动的时间较晚，所以排名靠后。
# =====
# Question: 我需要采取什么措施来提高个人保卫战的排名呢？
# Answer: 为了提高个人保卫战的排名，您可以尝试以下措施：
# =====
# Question: 为什么我没有获得排名奖励？
# Answer: 目前只有排名前50名的指挥官可以获得奖励，可能您在这个排名中没有获得足够的分值。
# =====
# Question: 我要怎样才能获得排名奖励？
# Answer: 您可以通过提高自己的排行为自己赢得排名奖励，具体可以在排行榜页面查看获得奖励的条件。
# =====
# Question: 在游戏中，强化后的设施和弱化后的设施是否会有不同的效果？
# Answer: 是的，强化后的设施会具有更高的属性值和更加强大的效果，而弱化后的设施则会降低其属性值并使其更容易受到攻击。建议玩家在游戏过程中谨慎考虑强化和弱化设施的决策，以获得最大的利益。
# =====
# Question: 参与个人保卫战时，其他玩家可以偷我的资源吗？
# Answer: 参与个人保卫战期间，其他玩家可以偷您的资源，但这种行为被严格禁止，联盟成员之间也会相互监督和共同维护游戏公平。
# =====
# Question: 请问在游戏中如何获得能量？
# Answer: 在游戏中，可以通过完成任务、击败敌人、完成活动等方式获得能量。
# =====
# Question: 我需要在沙盘演习中达到更高的伤害，请问应如何强化我的部件？
# Answer: 推荐使用命中，武器强化，准具强化，伤害加深，会心一击伤害。命中可以提高你的攻击中的命中的概率，武器强化可以增加武器的攻击力，准具强化可以增加你攻击的准确度，伤害加深可以增加你攻击的伤害倍率，而会心一击伤害则可以增加你攻击对敌人造成的伤害。这些部件都可以通过游戏内的商店购买或通过任务奖励获得。建议根据自己的游戏习惯和需求选择合适的强化部件。
# =====
# Question: 在沙盘演习中，如何搭配英雄技能才能打出更高的伤害？
# Answer: 推荐使用稀有出征，普通出征，增伤，会心伤害，命中，会心一击，增加攻击的技能。这些技能可以帮助您在战斗中快速击杀敌方英雄，提高您的游戏胜率。您可以根据自己的喜好和游戏风格来调整技能组合，以获得更好的游戏体验。
# =====
# Question: 我在游戏中经常遇到被敌方英雄击败的情况，如何提高自己的生存能力？
# Answer: 为了提高自己的生存能力，建议您在游戏中多使用一些保护自己的技能，如加速、隐身、盾墙等。此外，您还可以通过提高自己的移动速度和攻击速度来更快地击败敌人，避免被敌人击败。最后，您可以与其他玩家组队，互相帮助，共同击败敌人，提高游戏胜率。
# =====
# Question: 跨战区演习持续多久？
# Answer: 跨战区演习持续两天，周六、周日进行。
# =====
# Question: 指挥官在不参与跨区演习时,排名是否会下降？
# Answer: 不会，指挥官在跨区演习期间排名与不参与跨区演习期间排名一致。
# =====
# Question: 如何获得跨区演习通行证？
# Answer: 指挥官可以通过购买、参加活动、完成任务等途径获得跨区演习通行证。
# =====
# Question: 在跨战区演习中，挑战失败会怎么办？
# Answer: 如果挑战失败,双方排名将互换位置.
# =====
# Question: 在跨战区演习中，挑战成功会获得什么奖励？
# Answer: 指挥官成功挑战他人将根据战斗结果互换排名，挑战比自己排名高的指挥官获胜，双方排名互换,战斗失败,双方不互换排名。挑战比自己排名低的指挥官，无论胜负都不互换排名。指挥官排名前20名可以参与下一轮跨战区演习并获得相应奖励。
# =====
# Question: 指挥官需要设定哪些部队？
# Answer: 指挥官需要分别设定陆、海、空三部队。
# =====
# Question: 指挥官在防御阵容保存时需要注意什么？
# Answer: 在保存阵容时会使用指挥官当前所有的属性,如果有属性有更改需要重新设置防守阵容。
# =====
# Question: 跨区演习排行榜是如何计算的？
# Answer: 指挥官的排名根据他们在跨战区演习中的表现和成绩进行计算。
# =====
# Question: 跨战区演习会重置指挥官的积分吗？
# Answer: 是的，每轮跨战区演习结束后都会重置指挥官的积分。
# =====
# Question: 指挥官在跨战区演习中需要消费什么？
# Answer: 在保存阵容时需要消费跨区演习通行证。
# =====
# Question: 指挥官在同战区演习中可以通过什么来获得演习积分？
# Answer: 在同战区演习中,指挥官可以通过挑战其他指挥官获得演习积分,赢取奖励。
# =====
# Question: 指挥官在同战区演习中可以免费挑战几次？
# Answer: 每天在同战区演习中有免费挑战次数,免费挑战次数为0后需要消耗演习通行证。
# =====
# Question: 指挥官在战斗中获胜会获得多少积分?
# Answer: 指挥官在战斗中获胜,积分将提升,战斗失败,积分将降低。主动挑战按战斗结果提升或降低积分。被挑战防守胜利积分不增加,防守失败积分将降低。
# =====
# Question: 同战区演习每轮持续多久？
# Answer: 同战区演习每轮持续7天,倒计时结束后结算,并根据排名发放本轮奖励。结算5小时后将开启下一轮同战区演习。
# =====
# Question: 每轮同战区演习结束后会重新开始吗？
# Answer: 每轮同战区演习结束后会重置指挥官的积分,并清除所有身上的演习通行证。
# =====
# Question: 每轮同战区演习开启时需要做什么？
# Answer: 每轮同战区演习开启时,需要挑战一次指挥官或部署防守阵容,才会获得初始积分和排名。
# =====
# Question: 这轮同战区演习结束之后那些指挥官可以参与跨战区演习？
# Answer: 这轮同战区演习结束,排行榜前20名指挥官且满足跨战区演习等级要求,本轮跨战区演习开启时可参与。
# =====
# Question: 在同战区演习中，可以使用自己定义的士兵和英雄吗？
# Answer: 指挥官在同战区演习中可以使用系统提供的士兵或自己的英雄,使用自己的重装机兵,使用指挥官自己属性。
# =====
# Question: 同战区演习的主题是什么？
# Answer: 同战区演习的主
# =====
# Question: 我进行了属性数值的提升，为什么在同战区演习中没有生效呢？
# Answer: 请您重新登录同战区演习活动，然后点击防守阵容重新设置一下就可以恢复正常效果了。
# =====
# Question: 能否告诉我重新设置防守阵容的具体步骤呢？
# Answer: 当您重新登录游戏后，点击同战区演习活动的页面，然后选择防守阵容，最后进行重新设置即可。
# =====
# Question: 我在游戏中怎么才能找到同战区演习排名奖励呢？
# Answer: 同战区演习结束后，奖励将会通过邮件发放。您可以在邮件或活动邮件类目下查看您的奖励。如果您没有收到邮件，请尝试清空垃圾邮件箱或联系我们的客服部门。
# =====
# Question: 那如何在同战区演习中提高进攻效率呢？
# Answer: 在进攻时可以先利用技能优势秒杀敌方前排，随后尽快打击敌方后排输出较高的角色，同时要注意利用地形和走位躲避敌方技能和陷阱。
# =====
# Question: 那如何在游戏中避免被队友坑呢？
# Answer: 在游戏中可以和队友保持良好的沟通，及时告知彼此状况，同时也要避免在游戏中上演“坑队友”的剧情，多为团队着想，这样才能达到游戏的真正乐趣。
# =====
# Question: 邮件发放时间是多久？
# Answer: 邮件发放需等待活动结束后，由系统自动发放，请耐心等待。
# =====
# Question: 我需要注意什么才能在巅峰试炼中获得更高的分数？
# Answer: 在巅峰试炼中获得高分需要多种因素的关注。首先，要保持队伍的综合实力，确保每个队员都能够在战斗中发挥出最大的能力；其次，要注意阵容的搭配和技能的释放，充分利用角色的特点和能力；最后，要善于调整策略，根据战局的变化及时作出调整以取得最佳效果。
# =====
# Question: How can I get more resources in the game?
# Answer: Can you give me some tips on how to make the most out of the game's missions?
# =====
# Question: 我想知道巅峰试炼中，敌方阵容刷新的次数是每日刷新10次还是活动期间只有10次？
# Answer: 我看到敌方阵容刷新次数每日重置的信息，也就是说活动期间只有10次刷新次数。
# =====
# Question: 如果巅峰试炼中的玩家退出联盟，会如何影响他的排名？
# Answer: 如果有玩家退出联盟，该玩家会自动退出联盟，并将从其所在的联盟中扣除一定的联盟积分。具体扣除多少积分取决于该玩家在联盟中的贡献和地位。同时，退出联盟的玩家将不能继续参与联盟的活动和竞赛，也不能重新加入联盟。
# =====
# Question: 如果巅峰试炼中的玩家重新加入联盟，会如何影响他的排名？
# Answer: 如果有玩家重新加入联盟，其在联盟中的排名就会重新计算。具体的排名规则与巅峰试炼中联盟积分的计算方法有关，但一般情况下，玩家的排名会基于其个人的关卡积分和联盟贡献综合考虑。
# =====
# Question: 我现在在一个联盟中，但我希望加入到另一个联盟中。联盟积分会受到影响吗？
# Answer: 不会。在活动期间参与活动，如果更换联盟，您的关卡积分将被加入到您新加入的联盟中。
# =====
# Question: 我为什么在巅峰试炼中总是比其他玩家排名靠后？
# Answer: 由于你的通关数、失败关卡所造成的实际伤害和游戏时间与其他玩家存在差距，所以你的排名可能较靠后。建议提高自己的游戏水平，增加自己的通关数，并尽量减少失败关卡造成的真实伤害，同时优化自己的游戏时间，以提高排名。
# =====
# Question: 您能告诉我为什么游戏决定将深海寻宝的时间从6小时调整为8小时吗？
# Answer: 我们是按照玩家的建议做出了这一决定，希望能够在保持玩家休息的同时，不耽误寻宝的操作，让玩家获得更好的收益体验。
# =====
# Question: 深海寻宝青铜海藏箱除了包含科技箱、训练加速和低级招募，还有哪些奖励？
# Answer: 青铜海藏箱除了包含科技箱、训练加速和低级招募之外，还包含金币箱、高级招募和1级强化。
# =====
# Question: 银蓝海藏箱奖励有哪些？
# Answer: 银蓝海藏箱奖励有金币箱、高级招募和1级强化，还有一些其他奖励，如1级科技招募加速、30%的经验加成等。
# =====
# Question: 紫金海藏箱和红晶海藏箱有什么区别？
# Answer: 紫金海藏箱和红晶海藏箱之间的最大区别在于奖励的不同，紫金海藏箱奖励包括橙色万能碎片、职业天赋加速8小时和专属技能宝箱，而红晶海藏箱则包含橙色万能碎片、职业天赋加速8小时以及橙色招募加速剂10个。
# =====
# Question: 我已经拥有了青铜海藏箱和银蓝海藏箱，还能获得其他宝箱吗？
# Answer: 可以，但是你需要在升级新生海域寻宝之后才能开启新的宝箱，而且原来的宝箱也不能进行兑换。
# =====
# Question: 深海寻宝的新宝箱会按照什么比例兑换旧版宝箱？
# Answer: 目前我们还没有确定兑换比例，请关注深海寻宝后续开启的兑换活动，以便您可以将旧版宝箱进行兑换。
# =====
# Question: 活动期间消耗钻石可以获得钻石积分，您可以在积分商城中兑换超值道具。具体兑换物品可以根据活动的轮换道具进行调整。
# Answer: 活动结束后积分会清零，请及时兑换您所需的物品。
# =====
# Question: 我所在的服务器还没有开启曙光之地活动，为什么不能参加装饰物许愿活动呢？
# Answer: 需要所在服开过一次曙光之地活动或者开服时间满84天后才具备开启该活动的条件（个别新服除外），如果不满足相关条件的话暂时无法参与该活动哦。
# =====
# Question: 我开服时间还不到84天，为什么不能参加装饰物许愿活动呢？
# Answer: 对不起，您所在的服务器目前不符合装饰物许愿活动的开启条件。装饰物许愿活动需要所在服开过一次曙光之地活动或者开服时间满84天后才能够开启。建议您等待一段时间或者留意服务器的活动公告。
# =====
# Question: 请问装饰物许愿活动是否会定期举办？
# Answer: 我还有一些剩余的许愿瓶，是否可以留待后续使用？
# =====
# Question: 超值活动在哪里可以找到惊喜折扣商城？
# Answer: 您可以在超值活动中找到惊喜折扣商城。我们每天都会更新超值活动，确保您能够在活动中找到您想要的商品。
# =====
# Question: 我为什么看不到其他玩家发出的砍价信息？
# Answer: 因为你关闭了屏蔽请求砍价信息。需要回到惊喜折扣商城界面关闭屏蔽请求砍价信息后聊天界面才能显示。
# =====
# Question: 我怎么才能关闭屏蔽请求砍价信息？
# Answer: 在惊喜折扣商城界面中点击右上角的设置按钮，然后选择“屏蔽请求砍价信息”，最后点击确定即可关闭屏蔽请求砍价信息。
# =====
# Question: 请问在惊喜折扣商城活动中兑换的数字金币可以在以后的活动中再次使用吗？
# Answer: 不可以，数字金币会在活动结束后1
# =====
# Question: 为什么折扣商城的道具比其他礼包内的都贵呢？
# Answer: 折扣商城道具的初始定价和已含优惠的商城或礼包相比为什么价格会略微高呢？
# =====
# Question: 在游戏中如何获取更多的金币？
# Answer: 您可以通过完成任务、参加活动、通关副本等方式获得金币，同时您也可以通过交易出售道具来获取金币。
# =====
# Question: 钛蓝金币可以兑换哪些道具?
# Answer: 钛蓝金币可兑换商城内的不同道具，具体道具及兑换数量以商城内标注为准。
# =====
# Question: 累计购买钛蓝金币达到多少数额可以获得额外的进度宝箱奖励?
# Answer: 累计购买钛蓝金币达到一定的数额后，可额外获得进度宝箱奖励，请指挥官及时领取。
# =====
# Question: 钛蓝金币在什么时间重置?
# Answer: 钛蓝金币在每期活动结束时重置。活动结束后，未使用完的钛蓝金币会自动转换成等额钻石，通过邮件发送，请指挥官注意查收。
# =====
# Question: 钛蓝金币的兑换途径在哪里?
# Answer: 钛蓝金币的兑换途径在商城内，具体操作请参照游戏内的指示。
# =====
# Question: 我在游戏中获得了一个钛蓝金币，能兑换多少钻石？
# Answer: 按照1：1的比例，您可以兑换1个钻石。
# =====
# Question: 活动期间可以免费获得多少道具？
# Answer: 活动期间指挥官免费挖矿随机可以获得道具或者矿车,道具直接进入背包,矿车需要点击收取,等待一定时间后方可领取奖励。
# =====
# Question: 为什么要等待一段时间才能领取矿车奖励？
# Answer: 因为收取矿车奖励需要等待一段时间,指挥官也可使用矿车收取加速道具立即获得,加速道具通过礼包购买获得。
# =====
# Question: 如何知道矿车位是否已满？
# Answer: 指挥官可以通过查看任务界面中的矿车位数量来判断矿车位是否已满。
# =====
# Question: 活动期间每天可以挖矿几次？
# Answer: 每日挖矿次数有限,次日刷新。
# =====
# Question: 如果领奖阶段错过了领取矿车的机会怎么办？
# Answer: 如果在领奖时间结束时您仍有未收取的矿车,则矿车会随活动一起消失,请您合理安排时间,避免损失。
# =====
# Question: 在矿产大亨活动时，我的矿车加速道具是否会消失？
# Answer: 不会消失，它会保留在您的背包中，您可以随时在下一次活动中使用它。
# =====
# Question: 活动期间每个钻石可以获得多少积分？
# Answer: 活动期间每消耗1钻石可获得1积分。
# =====
# Question: 怎么获得免费奖励？
# Answer: 只要累计积分达到指定条件，就可以解锁超级礼包购买资格，并有机会获得免费奖励。
# =====
# Question: 积分商城内的哪些商品需要每日兑换次数限制？
# Answer: 积分商城内的部分商品兑换需要每日次数限制，例如每天只有一次机会兑换它们。
# =====
# Question: 消耗积分兑换商品会影响累计积分吗？
# Answer: 不会影响。消耗积分兑换商品不影响本期累计积分获得。
# =====
# Question: 活动结束后，钻石积分会怎样？
# Answer: 活动结束后，钻石积分将会清零，所以请玩家及时兑换使用。
# =====
# Question: 好礼连连看的活动结束时间是什么时候？
# Answer: 活动结束后，所有任务及奖励状态清空，请确保及时领取奖励。
# =====
# Question: 完成整行或整列的任务后会获得什么奖励？
# Answer: 完成整行或整列的任务后，可领取对应行或列的奖励。
# =====
# Question: 如何查看任务详情？
# Answer: 可点击不同图标代表的不同任务，查看任务详情。
# =====
# Question: 这个联盟运输队由哪些成员组成？
# Answer: 对不起，我无法提供有关联盟运输队成员构成的信息，因为我只是一个语言模型，无法访问互联网或实时更新数据。
# =====
# Question: 可以在什么时候参与四叶草的祝福活动？
# Answer: 四叶草的祝福活动将在活动期间限时开放，具体时间未公布，请关注官方公告。
# =====
# Question: 可以通过什么方式获得四叶草花瓣和抽奖券？
# Answer: 可以通过充值获得四叶草花瓣，每日登录也可以获得一定数量的四叶草花瓣。积攒一定数量的花瓣后，可以在四叶草的祝福活动中领取完整的四叶草抽奖券。
# =====
# Question: 花瓣和四叶草在活动结束后会如何处理？
# Answer: 活动结束后，花瓣和四叶草会清空，建议玩家及时使用。
# =====
# Question: 使用什么水晶购买礼包可以获得四叶草花瓣？
# Answer: 使用水晶购买礼包不会获得四叶草花瓣。
# =====
# Question: 活动期间使用四叶草进行祝福会有什么概率获得奖励？
# Answer: 活动期间使用四叶草进行祝福，可以获得不同等级的军阶物品奖励，概率在5%-25%之间。其中，获得所有四叶草则可以获得奖池内所有奖励哦！
# =====
# Question: 请问游戏中 Players 的经验积分可以累积到下一个游戏活动使用吗？
# Answer: 当然可以，玩家的经验积分不会因游戏活动结束而清空，可以累积到下一个游戏活动继续使用。
# =====
# Question: 游戏中物品的购买需要消耗游戏币吗？如果需要，物品的购买是否有优惠？
# Answer: 是的，游戏中的一些物品需要消耗游戏币来购买，但有些物品会有限时优惠活动，可以在购买时享受优惠价格。
# =====
# Question: 可以在劲爆囤货节活动中购买什么来获得额外奖励？
# Answer: 在劲爆囤货节活动中购买礼包可以获得额外奖励，具体来说，您可以在购买特定的礼包时，随机额外获得指定的其他奖励。
# =====
# Question: 需要在劲爆囤货节活动中收集什么来兑换丰厚的奖品？
# Answer: 在劲爆囤货节活动中，您可以通过积累礼券来兑换丰厚的奖品。您可以在礼券兑换中选择您希望收到的兑奖提示，以避免多余干扰。积攒的礼券会在每日重置后失效，并按10倍数量返还钻石。
# =====
# Question: 在劲爆囤货节活动中，礼包进度会如何重置？
# Answer: 在劲爆囤货节活动中，您购买的每个礼包都将自每日0时开始重新计时。这意味着您可以在每个新的一天开始时，重新开始购买新礼券和积攒礼券以获得更多奖励。
# =====
# Question: 钻石奖励是如何计算的？
# Answer: 在劲爆囤货节活动中，您每购买一个礼包，都将获得一定数量的礼券。如果您在活动期间积攒了大量的礼券，可以在礼券兑换中选择您希望收到的兑奖提示。当您兑换一个奖品时，您将获得相应数量的钻石奖励。
# =====
# Question: 请问在装扮狂欢活动中购买的道具是否可以退款？
# Answer: 本次活动的道具一旦售出,恕不支持退款！建议在购买前仔细阅读活动规则！
# =====
# Question: 我在装扮狂欢活动中兑换错了道具，应该怎么办？
# Answer: 如果您在装扮狂欢活动中兑换错了道具，可以尝试申请误操作撤回，具体可以联系游戏内客服进行咨询。他们会帮助您进行撤回操作并为您解决问题。请注意，撤回操作可能需要一定的时间。建议您尽快联系客服以确保您的权益得到保障。
# =====
# Question: 为什么我在劲爆囤货节中只能看到一个礼包选项，而别人可以查看四个？
# Answer: 可能是因为您没有按照活动的要求进行左右滑动。在活动期间，指挥官需要左右滑动屏幕来查看不同的礼包选项，并在出现心仪的那个选项时点击立即购买，才能看到完整的列表和数量限制。建议您多尝试几次，或者查看一下活动规则，可能存在未实现的漏洞。
# =====
# Question: 请问劲爆囤货节结束后的鲜花礼券兑换期限是多久？
# Answer: 礼券过期时间为7天，超过7天未兑换将会清空，并按10倍数量返还钻石，建议及时兑换。
# =====
# Question: 如果我在劲爆囤货节结束后未能兑换完所有的鲜花礼券，我会收到什么处理？
# Answer: 如果在劲爆囤货节结束后未能兑换完所有的鲜花礼券，将会按10倍数量返还钻石。但是，礼券过期后将会被清空，请及时兑换。
# =====
# Question: 我在劲爆囤货节活动中错过了某些优惠券？我是否还能再次获得它们？
# Answer: 您可以关注该活动的官方社交媒体账号或者访问官方网站，以获取有关再次获得优惠券的信息。一般来说，活动会提供一些重新获取优惠券的机会，但需要注意活动的时间和条件限制。
# =====
# Question: 我在劲爆囤货节活动中购买的商品是否可以退货或退款？
# Answer: 请查看您所购买商品的退货和退款政策。在大多数情况下，您可以在一定时间内退货或退款，但需要满足一些条件，例如保持商品原貌和未使用。如果不确定，请立即联系客服以获得帮助。
# =====
# Question: 我在劲爆囤货节购买的“新春豪华大礼包”中获得的道具与显示不符，为什么?
# Answer: 对不起，给您带来了不便。根据我们的活动规则，礼包显示的道具是随机获赠的，具体获得的道具会在您购买成功后发送到您的游戏账户中。请您耐心等待道具的到账。
# =====
# Question: 那我购买的“新春豪华大礼包”一定会有鲜花礼券吗?
# Answer: 是的，购买“新春豪华大礼包”就一定会获得鲜花礼券。相信这个礼券会给您的游戏体验带来不少乐趣。
# =====
# Question: 可以的，如果您符合申请条件并且在活动期间内联系我们确认，我们将尽力为您提供误操作补偿。
# Answer: 请问误操作补偿的申请条件是什么？
# =====
# Question: 聚能掘宝的活动结束时间是什么时候？
# Answer: 活动期间聚能掘宝能量结晶保留活动结束，每日将不会重置进度。
# =====
# Question: 每日重置进度是否会影响我的奖励？
# Answer: 每日重置进度不会影响您的奖励，但会影响您的聚能掘宝进度。
# =====
# Question: 该服务器现在的等级是什么级别？
# Answer: 我是一个AI助手，无法得知该服务器当前的等级，请您自行查询。
# =====
# Question: 我怎么样可以获得烘焙材料？
# Answer: 指挥官活动期间攻击黑暗军团或战锤4000随机获得烘焙材料。
# =====
# Question: 我可以通过什么方式将烘焙材料转换成烘焙值？
# Answer: 获得的烘焙材料自动捐献给战区蛋糕后按照1
# =====
# Question: 在烘焙排行榜上获得的奖励需要手动领取吗？
# Answer: 不需要手动领取，奖励在活动结束后将通过邮件自动发放。
# =====
# Question: 领奖时间结束后烘焙值会怎样处理?
# Answer: 领奖时间结束后，烘焙值将被清空。建议玩家在领奖时间结束后及时使用烘焙值，以免浪费。
# =====
# Question: 活动结束后是否会增加额外的奖励?
# Answer: 活动结束后，将额外设置24小时领奖时间，玩家可以在领奖时间内领取和兑换奖励。此外，攻击黑暗军团或战锤将不再获得烘焙值。
# =====
# Question: 活动期间需要完成哪些试炼任务才能参与先锋试炼活动？
# Answer: 怎样才能知道自己是否已经解锁了“试炼奖励”中的对应奖励领取资格？
# =====
# Question: 我有64%的概率抽取到高级招募券吗？
# Answer: 是的，您有64%的概率抽取到高级招募券。
# =====
# Question: 我能从这个活动中抽取到稀有技能宝箱吗？
# Answer: 是的，您有20%的概率抽取到稀有技能宝箱。
# =====
# Question: 训练加速1小时能为我带来什么？
# Answer: 训练加速1小时可以为您带来1小时的训练加速。
# =====
# Question: 我能从这个活动中抽取到绿色个级强化宝箱吗？
# Answer: 是的，您有30%的概率抽取到1级强化宝箱。
# =====
# Question: 我如何获得游戏中的神秘力量？
# Answer: 在游戏的神秘商店中，你可以通过购买相应的道具来获得神秘力量。此外，你也可以通过完成各种任务和挑战来获取神秘力量的提升。
# =====
# Question: 在游戏中，星银纹章有什么特殊效果？
# Answer: 星银纹章在游戏中可以带来游戏内的优惠和特殊道具，例如折扣优惠、限时特供、额外经验等。此外，还可以在星银秘藏活动期间进行兑换，以获取秘藏内容。
# =====
# Question: 秘藏内容是什么？
# Answer: 秘藏内容包括限定道具、游戏内货币、稀有的道具等。每次参加星银秘藏活动，都可以通过消耗星银纹章来兑换相应的秘藏内容。
# =====
# Question: 星银秘藏为什么会有刷新限制呢？
# Answer: 星银秘藏的刷新限制是为了控制游戏的节奏和平衡性，避免玩家短时间内兑换大量奖励，导致游戏的不公平。
# =====
# Question: 星银秘藏的刷新时间是多少呢？
# Answer: 星银秘藏的刷新时间是每个小时刷新一次，但指挥官VIP等级越高，每次刷新后可以获取更多的奖励。
# =====
# Question: 在星银秘藏活动中兑换的星银纹章如何处理？
# Answer: 活动结束后剩余未兑换的星银纹章将按照1
# =====
# Question: 我的星银纹章目前还有2000点，可以再充值吗？
# Answer: 不可以，因为你的星银纹章已经达到最大储蓄量5000点，超过了存储上限。
# =====
# Question: 请问兑换错了的星银纹章礼包可以退款吗？
# Answer: 不可以哦，我们非常抱歉，但兑换错了的星银纹章礼包是不支持退款的。请您谨慎操作。
# =====
# Question: 可以兑换其他类型的星银纹章礼包吗？
# Answer: 当然可以，您可以在游戏内的商城中选择其他类型的星银纹章礼包进行兑换。
# =====
# Question: 星银秘藏活动最近一次开启是什么时候？
# Answer: 我不太清楚具体时间，不过通常会以游戏内推送为准，您可以关注官方公告或游戏内通知来获取最新信息。
# =====
# Question: 深海寻宝初始有什么类型的探测器？
# Answer: 每个指挥官初始拥有1个深海探测器。
# =====
# Question: 活动期间如何增加深海探测器的数量？
# Answer: 可以花钻石开启额外深海探测器，增加的探测器本期活动期间可以一直使用，活动重开时重置。
# =====
# Question: 第三个探测器开启需要多少钻石？
# Answer: 3000钻石。
# =====
# Question: 活动结束后多开启一天是否可以?
# Answer: 可以,但领奖时间只可以开启和合成宝箱,不可再进行宝箱探测。
# =====
# Question: 领奖时间有多长时间?
# Answer: 领奖时间只有1天,在这1天内可以开启和合成宝箱,但不可再进行宝箱探测。
# =====
# Question: 深海寻宝活动探测器能否在探测到紫色宝箱后直接获得金色宝箱？
# Answer: 不可以，探测器只能获得青铜海藏箱、银蓝海藏箱，而紫色、金色宝箱需要使用三个银蓝海藏箱合成获得。
# =====
# Question: 如果我已经获得了三个银蓝海藏箱，能否直接合成获得紫铂海藏箱？
# Answer: 不可以，还需要获得另外两个珍贵的海藏箱，即金晶海藏箱，才能合成获得紫铂海藏箱。
# =====
# Question: 在探测器倒计时结束后，探索青铜海藏箱获得品质宝箱的概率是多少？
# Answer: 探测青铜海藏箱获得品质宝箱的概率是80.00%。
# =====
# Question: 在探测器倒计时结束后，探索银蓝海藏箱获得品质宝箱的概率是多少？
# Answer: 探测银蓝海藏箱获得品质宝箱的概率是20.00%。
# =====
# Question: 深海寻宝活动的紫铂海藏箱和金晶海藏箱的合成概率分别是多少？
# Answer: 深海寻宝活动的紫铂海藏箱合成概率为67.00%，金晶海藏箱的合成概率为33.00%。
# =====
# Question: 在深海寻宝活动中，我想要获得高级宝箱，应该选择合成紫铂海藏箱还是金晶海藏箱？
# Answer: 如果你想尽可能地获得高级宝箱，那么建议你合成紫铂海藏箱。因为合成紫铂海藏箱的概率更高，即70%的概率可以得到紫铂海藏箱，而只有30%的概率可以得到金晶海藏箱。
# =====
# Question: 我在深海寻宝活动中购买的深海宝箱探测加速是否可以在其他活动中使用？
# Answer: 对不起，深海宝箱探测加速道具是专门为本次深海寻宝活动而设计的，不能在其他活动中使用。但是您可以在下次深海寻宝活动中再次购买加速道具，以更快地发现宝箱和宝藏。
# =====
# Question: 我在深海寻宝活动中购买的深海宝箱探测加速道具是否可以叠加使用？
# Answer: 不可以，深海宝箱探测加速道具是独立于其他道具的，无法叠加使用。但是您可以在下次深海寻宝活动中再次购买加速道具，以更好地进行探索和发现。
# =====
# Question: 幸运寻宝的活动规则中，每5次抽奖会必中一次橙色万能碎片吗？
# Answer: 没有说明每5次抽奖会必中一次橙色万能碎片，每5次抽奖后有一定的概率能获得橙色万能碎片。
# =====
# Question: 幸运寻宝活动每天的免费机会有几次？
# Answer: 每天有5次免费机会,每次CD时间10分钟。
# =====
# Question: 在幸运寻宝中抽奖，我能有机会获得紫色万能碎片吗？
# Answer: 能，根据你提供的信息，概率为8.40%。
# =====
# Question: 抽奖时每次必得什么宝箱？
# Answer: 每次必得科技宝箱。
# =====
# Question: 抽奖时，我能获得多少次高级抽卡券？
# Answer: 不能获得固定数量的高级抽卡券，每一次抽奖都有机会获得。
# =====
# Question: 抽奖时我能获得多少次1级强化部件宝箱？
# Answer: 不能获得固定数量的1级强化部件宝箱，每一次抽奖都有机会获得。
# =====
# Question: 能否提供更多关于掘宝2000活动的详细信息？
# Answer: 当然可以！掘宝2000活动时间为x月x日至x月x日。在此期间,您可以参加各种活动以获得能量结晶、金币和道具等好礼。此外,您还可以使用掘宝钻头挖掘神秘宝藏,获取更多丰富奖励。
# =====
# Question: 掘宝2000活动的领奖是否会消耗能量结晶？
# Answer: 领奖不会消耗能量结晶，但是能量结晶进度每日重置，请指挥官及时领奖。
# =====
# Question: 请问在参加掘宝2000活动时，能量结晶进度如何重置？
# Answer: 能量结晶进度在每日00
# =====
# Question: 我的游戏账号被锁定了怎么办？
# Answer: 可以尝试重置密码或联系游戏客服来解决账号被锁定的问题。
# =====
# Question: 为什么集结惧星游戏里没有限时兑换券？
# Answer: 限时兑换券是一种游戏内限时活动提供的奖励物品，通常是为了促进玩家积极参与游戏活动而设计的。然而，作为一款成熟的多人在线游戏，《集结惧星》已经拥有了丰富的游戏内容和活动，而限时兑换券可能会导致游戏中的平衡性和游戏体验受到影响。因此，游戏开发团队决定将限时兑换券作为一种非必要的游戏元素，以确保游戏的可持续性和玩家满意度。
# =====
# Question: 在《集结惧星》中，完成哪些任务可以奖励额外的奖励？
# Answer: 在《集结惧星》中，完成黑暗军团、战锤4k和雷达任务都可以获得额外的奖励。黑暗军团任务是游戏中的一个主线任务，玩家需要击败黑暗军团领袖并完成相关任务以获得奖励。战锤4k任务则是一种限时活动任务，玩家需要在规定时间内完成指定任务以获得奖励。雷达任务则是游戏中的一种收集任务，玩家需要找到隐藏在游戏地图中的雷达印记并完成任务以获得奖励。完成这些任务都可以获得额外的奖励，为玩家的游戏历程增色添彩。
# =====
# Question: 限时兑换券活动结束后是否有额外领奖时间？
# Answer: 在领奖时间内是否还能获得限时兑换券？
# =====
# Question: 如果我购买了但未使用的限时兑换券会怎样？
# Answer: 请放心，您可以后期留意回收商店对道具进行回收，或者在活动结束7日内向客服申请误操作进行兑换。具体请咨询游戏内客服。
# =====
# Question: 该如何参加幸运宝库活动？
# Answer: 参加幸运宝库活动非常简单，只需要在每个月的超值活动中寻找相关入口即可。通常，活动会伴随着新英雄的开启而开启，所以请关注官方公告，及时参与活动。
# =====
# Question: 参与幸运宝库活动需要花费钻石吗？
# Answer: 是的，参与幸运宝库活动需要使用钻石进行抽奖。每次抽奖可以获得一个道具奖励，同时获得一组幸运图标和10点宝库积分。
# =====
# Question: 参与幸运宝库活动能获得多少钻石？
# Answer: 具体能获得多少钻石与您所获得的幸运图标数量和宝库积分有关。获得对应的幸运图标可获得不同比例的钻石（详情见奖励预览），宝库中的钻石不足2000时，系统会补足2000。
# =====
# Question: 抽奖后能立即获得英雄碎片吗？
# Answer: 是的，每次抽奖后将会获得宝库积分积累到一定值，会立即获得英雄碎片*1。
# =====
# Question: 本次活动分为哪两个战区？
# Answer: 本次活动分为2组
# =====
# Question: 参加幸运宝库活动有什么限制？
# Answer: 本次活动只对当前游戏中所有指挥官开放，每个账号在同一时间只能参与一次活动，每日抽奖次数限制为5次。
# =====
# Question: 超频芯片能为橙色芯片带来哪些额外效果？
# Answer: 超频芯片可以将消耗的4个普通橙色芯片升级为1个新的紫宝石芯片，并且该紫宝石芯片必须满足所有的神圣宝石词条。高级芯片超频则需要消耗4个紫宝石芯片，升级为1个新的橙色宝石芯片，并且玩家可以选择自己想要升级的橙色宝石芯片的套装、部位和所有属性军种类型。顶级芯片超频需要消耗4个橙色宝石芯片，升级为1个新的红宝石芯片，并且玩家可以选择自己想要升级的红宝石芯片的套装、部位、所有属性军种类型和2条确定属性（这2条属性可以从该芯片的所有属性中选择，不受属性类型限制）。
# =====
# Question: 超频获得的芯片能否进行重复合成？
# Answer: 能，而且合成的芯片位置是随机的，但是获得核心芯片的概率稍微高一点。
# =====
# Question: 合成条件是否有限制，例如只能在特定的关卡或阶段进行合成？
# Answer: 不受限制，只要拥有足够的橙色芯片就可以随时进行合成。
# =====
# Question: 用词不够准确，请问获得较好的属性，指的是在平均属性的基础上获得更高的属性值吗？
# Answer: 不是的，获得较好的属性是指在随机属性中获得比其他橙色芯片更好的属性，这些属性可能包括攻击、减免伤害、防御等。
# =====
# Question: 能否举出一个具体的例子来说明获得较好属性的概率是如何计算的？
# Answer: 当你进行超频时，会有更高的概率获得较好的随机属性。例如，核心芯片可能会获得+10%的攻击伤害，而其他的位置可能只能获得+5%的攻击伤害。
# =====
# Question: 我在游戏中的角色属性为什么老是比其他玩家低呢？
# Answer: 你的角色可能还没有达到等级要求，或者还没有收集足够的经验。可以通过多完成任务和副本来提高角色等级和属性。
# =====
# Question: 我在游戏中怎么获得更多的货币呢？
# Answer: 你可以通过完成任务、击败敌人、参与活动和出售不需要的装备来获得更多的货币。同时要注意节约使用货币，避免浪费。
# =====
# Question: 如果我已经使用了一个升级过的橙色机甲芯片进行了超频，是否还会返还全部升级获得的经验？
# Answer: 不会，已经消耗掉的机甲芯片不返还任何经验。
# =====
# Question: 如果我消耗了一个橙色机甲芯片进行了超频，会返还多少升级获得的经验？
# Answer: 消耗一个橙色机甲芯片进行超频会返还对应的65%升级获得的经验，向下取整。
# =====
# Question: 用一个橙色机甲芯片升级到1级可以获得多少经验？
# Answer: 橙色机甲芯片升级到1级可以获得2500经验。
# =====
# Question: 超频活动的下次开放时间是什么时候？
# Answer: 根据目前的计划，后续会再开放的哦，但不确定具体开放间隔，建议您及时参与~
# =====
# Question: 请问曙光金币有什么用途？
# Answer: 曙光金币可以在神秘商店中兑换道具，包括但不限于装备、技能书、天赋书等。
# =====
# Question: 怎样才能获得更多的曙光金币？
# Answer: 经过高完成远征任务、远征计划中的限时计划、远征排行中达到相应名次、以及在军功商店中每次重置兑换等方式可以获得更多曙光金币。
# =====
# Question: 我需要完成哪些远征成就才能获得曙光宝石？
# Answer: 你可以通过完成永恒科技的研究和远征活动中的混乱之源的排行奖励来获得曙光宝石。
# =====
# Question: 需要在哪个远征活动中获得曙光宝石？
# Answer: 你可以通过参与方舟战斗来获得排名奖励，或者在全面军备当前竞赛中的积分奖励中获取曙光宝石。
# =====
# Question: 我可以通过做什么来提高我在全面军备当前竞赛中的积分？
# Answer: 你可以通过完成挑战任务、参与随机任务和击败地图boss等方式来提高你在全面军备当前竞赛中的积分。
# =====
# Question: 如何获得曙光之地的军功？
# Answer: 可以通过击杀敌方士兵和损失己方士兵获得。需要注意的是40级以下的士兵没有军功，高于对方指挥官20级之后击杀敌方士兵不得军功，指挥官受伤的士兵等级低于指挥官自身5级后不会获得军功，并且军功兑换商店会周期重置，重置时超过30000的军功会被清除。建议及时兑换以避免军功浪费。
# =====
# Question: 曙光之地的军功有什么用？
# Answer: 曙光之地的军功可以用于神秘商店中进行军功兑换，可以兑换各种游戏道具。
# =====
# Question: 曙光之地的军功兑换商店什么时候会重置？
# Answer: 重置时间不确定，但会周期性重置。建议及时兑换以避免军功浪费。
# =====
# Question: 在曙光之地活动中，超过30000的军功是否会被清除？
# Answer: 是的，超过30000的军功会在重置时被清除，建议及时兑换以避免军功浪费。
# =====
# Question: 我的曙光之地战斗中，如何提高陆军的伤害？
# Answer: 可以通过升级角色，每升1级可以使陆军伤害提升4%，一共可以提升20%。
# =====
# Question: 我的海军伤害为什么没有提升？
# Answer: 首先，请确保您已经升级了曙光之地海军伤害技能。其次，请确认您每次升级技能时都获得了所需的的点数。最后，请检查您的游戏设置，确保游戏中的伤害计算方式正确。
# =====
# Question: 我在曙光之地游戏中如何获得空军伤害提升效果？
# Answer: 您可以在游戏中达到5级，并且每升1级提升空军伤害，一共可以提升20%的空军伤害。
# =====
# Question: 如果我已经到达了5级，那么我空军伤害的提升效果是多少？
# Answer: 您的空军伤害已经提升了20%，每升1级都可以提升4%的伤害，因此总共提升了20%的伤害效果。
# =====
# Question: 在曙光之地任务中，我该如何对抗黑暗军团呢？
# Answer: 你可以先升级曙光之地，积累攻击力加成。随着等级的提升，曙光之地会对黑暗军团造成越来越多的伤害。此外，你还可以购买一些抗黑暗的装备，增强自己的实力。最后，多和队友配合，共同战胜黑暗军团。
# =====
# Question: 我在游戏中发现随着曙光科技等级的提升，消耗的资源越来越多，有什么办法可以减少资源的消耗呢？
# Answer: 可以通过研究曙光科技消耗资源减少，每升1级消耗资源减少2%，共5级累计减少10%的方式来减少资源的消耗。具体来说，当你将曙光科技等级升到1级时消耗1单位资源，升到2级时消耗1.02单位资源，以此类推，升到5级时消耗1.1元单位资源。这样，累计下来你就可以节省10%的资源消耗。
# =====
# Question: 我在游戏中被攻击了，但受到黑暗军团的减伤提升了，这对我有帮助吗？
# Answer: 当然是有帮助的！您在游戏中受到黑暗军团的减伤提升了，每升1级受到黑暗军团减伤提升10%，所以共5级累计提升50%。这意味着您的角色将会在受到攻击时受到更大的保护，从而更轻松地应对攻击。
# =====
# Question: 我在游戏中怎么能获得更多的个人荣誉值？
# Answer: 可以去曙光之地进行采集，每次采集都会增加个人荣誉值。每升1级，采集增加的个人荣誉值也越来越多：一级4%，二级8%，三级12%，四级16%，五级20%。
# =====
# Question: 我需要达到多少级才能获得所有增加的个人荣誉值？
# Answer: 你需要达到五级才能获得所有增加的个人荣誉值，每升一级就可获相应增加的荣誉值，累计共增加20%。
# =====
# Question: 有什么建筑可以提升战斗攻击？
# Answer: 领地的联盟堡垒和电力站可以提升战斗攻击。
# =====
# Question: 建筑的战斗攻击提升有什么机制？
# Answer: 随着等级的提高，每个联盟建筑战斗攻击提升20%，共可累积提升100%。
# =====
# Question: 我在游戏中需要增加更多的军队列，有什么方法可以实现？
# Answer: 您可以在曙光之地地区增加一行军队列，这种方法可以让您在游戏中更加出色。
# =====
# Question: 增加一行为军队列是否会增加游戏难度？
# Answer: 增加一行军队列并不会增加游戏难度，因为它只会为您提供更多的资源和能力，使您在游戏中更加从容。
# =====
# Question: 如何提高曙光之地的全军防御能力？
# Answer: 在游戏中，可通过将曙光之地升级到较高的等级来提高全军防御能力。每升1级，全军防御能力将提升5%，共可升级5级，累计提升25%的全军防御能力。
# =====
# Question: 是否只有一种方式可以提高曙光之地的全军防御能力？
# Answer: 不是的，除了升级之外，还可以通过配置正确的英雄和装备来提高全军防御能力。同时，还可以通过合理地调整部队的站位和阵型来增加全军的防御效果。
# =====
# Question: 温泉任务
# Answer: 温泉任务是游戏中的一个任务，玩家需要去指定的温泉区域找到指定的温泉，并完成相应的任务才能获得奖励。
# =====
# Question: 龙族坐骑获得方法
# Answer: 龙族坐骑可以通过在游戏中完成相关任务或活动获得。常见的获得方式包括击败特定的龙族BOSS、完成龙族Event等等。
# =====
# Question: 联盟成员的具体是什么？
# Answer: 联盟成员是指在游戏中加入同一联盟的玩家，他们可以一起参加联盟活动、共同挑战副本和进攻其他玩家等。
# =====
# Question: 提升森林图腾的等级需要满足什么条件？
# Answer: 想要提升森林图腾的等级需要联盟成员在游戏中完成一定的任务，例如攻击其他联盟玩家、参加联盟活动等。每完成一定的任务，就会累积一定的点数，当点数达到一定数量时，即可提升森林图腾的等级。升一级会给所有联盟成员带来生命值加成，加成比例为1%，最多可提升5级。
# =====
# Question: 集群冲锋的发动时间要怎么计算？
# Answer: 集群冲锋的发动时间是在联盟成员行军的时候进行的，而且是每次使用都会进行发动。每次的发动时间是从同一点出发计算的，直至使用次数达到上限或冷却完毕为止。
# =====
# Question: 提高联盟成员的攻击力需要达到多少级曙光之地才能完成？
# Answer: 需要达到5级曙光之地，每升1级全部单位攻击加成提升1%。
# =====
# Question: 我现在在游戏中，可以用临时提升盟友修理工厂的容量上限吗？
# Answer: 可以的，不过只有在曙光之地期间可以使用这个功能。另外，每升1级修理工厂，容量上限会增加10个，共5级累计增加50个。建议让你的盟友尽快升级他们的修理工厂，以获取更多的空间。
# =====
# Question: 除了容量上限的提升，还有哪些方法可以提升盟友修理工厂的性能？
# Answer: 除了容量上限的提升，还可以通过升级建筑等级、添加新的设施和雇佣更多的修理工来提升修理工厂的性能。此外，还可以考虑升级联盟科技，增加联盟成员的科技水平，从而提高他们的修理工厂效率。
# =====
# Question: 在什么情况下可以激活烈豹图腾的效果？
# Answer: 烈豹图腾需要在曙光之地内使用。联盟成员在向考古卡车行军时，可以使用烈豹图腾来提高移动速度。每升1级烈豹图腾，移动速度会提升40%，最多可提升5级，累计提升200%的移动速度。
# =====
# Question: 烈豹图腾的效果可以持续多长时间？
# Answer: 烈豹图腾的效果是短暂的，具体持续时间取决于联盟成员的等级。每提升1级烈豹图腾，持续时间会增加30秒。另外，当移动速度达到最大值后，烈豹图腾的效果将自动消失。
# =====
# Question: 在什么情况下可以使用激怒敌军技能？
# Answer: 只有在敌方指挥官的基地护盾被取消的情况下才能使用激怒敌军技能。此外，玩家需要先进入战争狂热状态，然后才能使用该技能。激怒敌军技能的冷却时间为2小时，可发动次数为10次，每次消耗科技点10点。
# =====
# Question: 激怒敌军技能能够带来什么效果？
# Answer: 激怒敌军技能可以取消敌方指挥官的基地护盾，并使其进入战争狂热状态，持续30分钟。在战争狂热状态中，敌人会更加强力，更难以被打垮。激怒敌军技能可以提高玩家在战斗中的胜率，但需要玩家谨慎使用，以免vp减少。
# =====
# Question: 这个雨林图腾在升级的过程中是否会增加联盟成员的攻击力？
# Answer: 不会，在这个雨林图腾中，只有生命值的增加。
# =====
# Question: 那么这个雨林图腾需要多少级才能累计提升5%的生命值？
# Answer: 需要升级5级。
# =====
# Question: 在曙光之地中，快速修理可以修复哪些类型的损坏？
# Answer: 快速修理可以在战斗中立即修复士兵30%，包括士兵受到的物理、魔法和中毒伤害。
# =====
# Question: 快速修理的冷却时间是什么意思？如何计算？
# Answer: 快速修理的冷却时间是指从上一次使用快速修理效果后到再次使用之间的时间间隔。在冷却时间结束后，玩家可以再次使用快速修理效果。计算冷却时间可以通过观察游戏内的倒计时来确定。
# =====
# Question: 部落基地有什么样的建筑占领可以获得加成?
# Answer: 部落基地内的建筑攻占可享受加成，其中包括战区荣誉值+30/分钟，联盟荣誉值+30/分钟的加成效果。
# =====
# Question: 部落基地的建筑加成效果在什么时间内生效?
# Answer: 部落基地的建筑加成效果每分钟可以加成30点战区荣誉值和30点联盟荣誉值，持续时间为每分钟。
# =====
# Question: 请问这个建筑可以给哪些兵种进行训练？
# Answer: 地智慧祭坛可以给全体兵种进行训练。
# =====
# Question: 胜利之殿能够提供哪些加成效果？
# Answer: 胜利之殿可以为部队提供伤害减免加成，数值为2%，同时还可以为战区和联盟提供荣誉值加成，数值为30/分钟和30/分钟。
# =====
# Question: 欢舞神庙的加成可以作用于哪些单位？
# Answer: 欢舞神庙的加成可以作用于全部单位攻击。
# =====
# Question: 愤怒神庙的加成效果是什么？
# Answer: 愤怒神庙的加成效果是全部单位攻击加成+4%,战区荣誉值+20/分钟,联盟荣誉值+20/分钟。
# =====
# Question: 愤怒神庙何时可以被占领？
# Answer: 愤怒神庙需要被建造之后才能被占领，可以在建筑建筑界面找到并占领。
# =====
# Question: 我可以在曙光之地的太阳之城享受哪些加成效果？
# Answer: 在太阳之城内占领建筑可以享受全部单位攻击加成+5%,全部单位生命加成+5%,战区荣誉值+150/分钟,联盟荣誉值+150/分钟的加成效果。
# =====
# Question: 我在什么样的情况下可以使用联盟荣誉值?
# Answer: 在曙光之地中，联盟荣誉值可以在战区中使用，以增加分数和荣誉等级，但是每分钟只有50点联盟荣誉值可以使用。
# =====
# Question: 我在游戏中遇到了问题，如何联系客服解决？
# Answer: 您可以通过游戏内的客服系统或我们的官方渠道（电子邮件、社交媒体等）联系客服，我们会在24小时内尽快回复您。同时，您也可以参考游戏内的官方帮助文档，以便更好地自行解决问题。
# =====
# Question: 混乱之源的最高级别是多少？
# Answer: 混乱之源的最高级别是50级。
# =====
# Question: 寻宝行会的每日任务具体是什么？
# Answer: 在寻宝行会活动中，每日可以完成的任务包括：击败游戏内的怪物、完成行会争霸赛、参与宝藏探秘等。每完成一项任务，可以获得一定的行会贡献。
# =====
# Question: 寻宝行会里召唤出来的宝藏守卫能存活多久？
# Answer: 唤出来的宝藏守卫存活时间为1小时。活动中，玩家可以召唤出多只宝藏守卫来保护宝藏，每只宝藏守卫的存活时间相同，都是1小时。如果在1小时内宝藏没有被其他玩家 or 守卫守护好，宝藏就会被其他玩家抢走或被破坏，宝藏守卫就会消失。
# =====
# Question: 我在宝藏守卫的战斗中，已经击败了他但并没有得到对应的奖励，这是为什么？
# Answer: 您需要确保在规定时间内击败宝藏守卫才能获得相应的奖励。如果您超过了规定的时间，那么您将无法获得任何奖励，包括召唤奖励和攻击奖励。
# =====
# Question: 我该如何提高我的宝藏守卫击杀速度？
# Answer: 为了提高宝藏守卫的击杀速度，您可以尝试以下一些方法：
# =====
# Question: 宝藏守卫每日击败limit有吗？
# Answer: 每日击败20次达到上限，达到上限后再次攻击将不会获得攻击奖励。
# =====
# Question: 在游戏中，我达到宝藏守卫攻打次数上限后，还可以继续获得召唤奖励吗？
# Answer: 可以，即使宝藏守卫被打死了，你还可以继续获得召唤奖励。
# =====
# Question: 如果我在游戏中不小心把宝藏守卫打死了，那么我还会得到召唤奖励吗？
# Answer: 不会，一旦宝藏守卫被打死，那么你就无法再获得召唤奖励了。
# =====
# Question: 我在探索宝藏的时候不小心把宝藏守卫打死了，我现在怎么查看我获得的奖励呢？
# Answer: 您可以在活动邮件中查看您的宝藏守卫奖励，通常在您击败宝藏守卫后几分钟内就会收到邮件。如果您还没有收到邮件，请耐心等待，有时可能会出现网络延迟的情况。
# =====
# Question: 在哪个服务器可以搜索帝国宝藏？
# Answer: 在曙光之地内是无法搜索帝国宝藏的哦，需要等待曙光之地结束后回到原生服务器才能进行搜索。
# =====
# Question: 我们应该在哪个时间段去搜索帝国宝藏？
# Answer: 在游戏客户端设置中找到“搜索宝藏”按钮，选择正确的服务器和时间段即可。建议在游戏人口稠密的时间段进行搜索，这样可以更容易地找到宝藏。
# =====
# Question: 在游戏中，我可以拥有超过5个仓库吗？
# Answer: 仓库数量有限，超过 five 个需要付费解锁。
# =====
# Question: 反作弊措施如何防止我在游戏里使用伪造徽章获得奖励？
# Answer: 游戏内会使用多种反作弊措施，包括实时监测异常行为、帐号绑定硬件设备、定期进行安全检查等。此外，如果发现有玩家使用伪造徽章，将会根据游戏规则进行严厉处罚，包括暂时或永久封号。
# =====
# Question: 普通周卡在首日可以获得多少钻石？
# Answer: 开卡后首日可以领取到540钻石。
# =====
# Question: 普通周卡在剩余6天内每天可以领取多少钻石？
# Answer: 剩余6天每天可以领取50钻石。
# =====
# Question: 我在游戏中的角色属性和游戏中描述的不太一样，该怎么办？
# Answer: 请检查您游戏内的角色属性设置是否正确，或者联系游戏客服寻求帮助。
# =====
# Question: 能否在沙盘演习中使用道具？
# Answer: 沙盘演习中是明令禁止使用道具的，因为这会影响到游戏的平衡性和真实性。
# =====
# Question: 我在进行沙盘演习时，为什么战报不显示在我的邮箱里？
# Answer: 沙盘演习战报需要在活动界面记录中进行查看，您可以在活动中找到相关记录进行查看。
# =====
# Question: 雷达等级需要如何提升？
# Answer: 指挥官可以通过完成雷达任务来增加能量，当能量充满时会显示升级按钮，点击按钮进行雷达升级操作。升级雷达可增加一次截取信号获得的任务数，升级雷达可减少任务补给等待时间，升级雷达可解锁雷达其他功能。
# =====
# Question: 雷达信号的强度如何影响任务选择？
# Answer: 雷达信号的功率为1~5，完成雷达任务时，有概率增强信号功率。当雷达信号功率为5时，接下来截取的任务必为5星，同时信号功率衰减为1格。指挥官可以消耗钻石增强1格功率，每日首次免费。
# =====
# Question: 雷达任务中出现黑暗军团干扰攻击时，该怎么办？
# Answer: 雷达等级3开启该功能，当雷达任务全部完成，且下一次补给时间大于10分钟，雷达将面对来自黑暗军团的干扰攻击，指挥官需要完成特定的防守任务。当防守任务完成时，雷达信号功率将达到满格状态，黑暗军团的干扰攻击每日不会超过1次；若规定时间内未完成该任务，雷达会自行清理防守任务，等待下次触发。
# =====
# Question: 雷达任务可以重置吗？
# Answer: 指挥官可以消耗钻石对当前选中任务进行重置处理。
# =====
# Question: 雷达车有哪些特殊功能？
# Answer: 雷达车建筑可以摆放在基地中，它可以截取基地外的信号并转换成不同种类的任务。完成雷达任务可积攒能量，能量充满时会显示升级按钮，点击按钮进行雷达升级操作；升级雷达可增加一次截取信号获得的任务数；升级雷达可减少任务补给等待时间；升级雷达可解锁雷达其他功能。
# =====
# Question: 雷达信号的更新规则是什么？
# Answer: 当雷达信号功率为5时，接下来截取的任务必为5星，同时信号功率衰减为1格。点击按钮"增强信号"可消耗钻石增强1格功率，每日首次免费。
# =====
# Question: 雷达车有哪些经验可以获得？
# Answer: 雷达任务是建筑，每天可通过完成雷达任务获得奖励，完成雷达任务可以获得基础经验。
# =====
# Question: 在游戏中，城垛的效果是什么？
# Answer: 在游戏中，城垛的效果是保护金币不被他人获得。
# =====
# Question: 我能够在哪些地方发现灯笼？
# Answer: 灯笼可以被发现于多个游戏区域，包括但不限于主城、地宫、副本、活动区域等。
# =====
# Question: 灯笼可以为我带来什么收益？
# Answer: 灯笼可以带来金币产出的略微增加，但具体增加量取决于游戏内设定的相关参数。
# =====
# Question: 使用紫色地板会有什么效果？
# Answer: 紫色地板的效果为训练速度略微增加。
# =====
# Question: 高速公路有什么效果？
# Answer: 高速公路可以让黑暗军团行军速度略微加快。
# =====
# Question: 高速公路的生效数量最大是多少？
# Answer: 高速公路的生效数量最大是100。
# =====
# Question: 我有几个幸运泉可以激活金币产出效果？
# Answer: 您最多可以激活100个幸运泉。每个幸运泉将增加0.2%的金币产出效果，每升1级增加0.2%。
# =====
# Question: 长椅有什么效果？
# Answer: 长椅会让行军速度加快。
# =====
# Question: 我的新礼物箱是什么？
# Answer: 礼物箱是一种装饰物，用于增加训练速度。
# =====
# Question: 这个礼物箱能生效多少次？
# Answer: 礼物箱效应最多只能生效5次。
# =====
# Question: 指挥官雕像有什么特殊效果吗？
# Answer: 指挥官雕像可能有几率在训练坦克时立即完成训练。
# =====
# Question: 双子摇摇马有什么特殊效果？
# Answer: 双子摇摇马可以让破损坦克修理时不降级。
# =====
# Question: 黄金坦克可以增强坦克的血量吗？
# Answer: 是的，黄金坦克可以附体，让坦克的血量大增。
# =====
# Question: 黄金坦克可以同时生效于多个坦克吗？
# Answer: 不可以，黄金坦克的生效数量最多为1。
# =====
# Question: 请问龙舟的海军损坏完美修复几率是多少？
# Answer: 龙舟的海军损坏完美修复几率是1级效果10%，每升1级增加1%。
# =====
# Question: 景观鲜花的1级效果是增率多少？
# Answer: 景观鲜花的1级效果是2%，即每升1级增加2%的速度。
# =====
# Question: 沙袋堡垒有什么效果?
# Answer: 沙袋堡垒可以让部队在防守时受到的伤害减少最多。
# =====
# Question: 沙袋堡垒的生效数量限制是多少?
# Answer: 沙袋堡垒的生效数量最多为1个。
# =====
# Question: 感恩节火鸡有什么效果？
# Answer: 感恩节火鸡的效果是全体单位生命提升，1级效果5%，每升1级增加1%。这意味着使用后，所有单位的健康值都将得到提高，随着时间的推移，健康值的提升速度会越来越快。
# =====
# Question: 比较常见的装饰物有什么？
# Answer: 比较常见的装饰物有圣诞节树、彩灯、暖气、五彩缤纷的挂件等等。
# =====
# Question: 圣诞树的效果是什么？
# Answer: 圣诞树的效果是全体单位攻击增加，1级效果为2%，每升高1级，增加0.5%。
# =====
# Question: 什么是黄金飞机？
# Answer: 黄金飞机是一种装饰物，可以增加飞机的血量。
# =====
# Question: 黄金飞机可以增加多少血量？
# Answer: 黄金飞机可以最多增加1点血量。
# =====
# Question: 你最近玩过的游戏中有什么装饰物能够增加空军训练速度吗？ 相关的信息有哪些？
# Answer: 爱神天使是一个常见的装饰物，它可以提升空军训练的速度。其他游戏中可能也有一些类似的装饰物，比如爱神之弓、黄金守护者等等。这些装饰物的效果和生效数量也各不相同，需要根据具体的游戏进行查询和选择。
# =====
# Question: 这个玩具的名字是什么？
# Answer: 这个玩具的名字是玩具。
# =====
# Question: 玩具有什么效果？
# Answer: 玩具的效果是陆军生命增加，并且有1级效果2%，每升1级增加0.5%。
# =====
# Question: 请问粮食可以增加海军的血量吗？
# Answer: 是的，粮食可以增加海军的血量。每个粮食都可以增加一点海军的血量，说明书上写着最多可以增加1点。
# =====
# Question: 那么粮食可以被用作装饰品吗？
# Answer: 不可以，粮食并不是装饰品，它是一种海军血量增加的道具。如果船上没有粮食，海军的血量就会慢慢减少。
# =====
# Question: 躺椅能为玩家带来什么效果？
# Answer: 躺椅可以增加玩家的空军血量。
# =====
# Question: 躺椅有几个生效数量？
# Answer: 躺椅最多只能生效1次。
# =====
# Question: 沙滩伞的海军攻击增加是多少?
# Answer: 沙滩伞能增加海军攻击，但没有具体说明增加的数值。
# =====
# Question: 沙滩伞是否只能在海滩上使用？
# Answer: 没有明确说明沙滩伞只能在海滩上使用，但根据名称推测应该是海滩上常用的一种装饰物。
# =====
# Question: F-1是什么类型的装饰物？
# Answer: F-1是一种装饰物，常用于改善游戏中的角色属性。
# =====
# Question: F-1有什么效果？可以为角色提供什么帮助？
# Answer: F-1可以减少海军伤害，每级效果增加2%，最高可增加10%。此外, F-1还能够增加角色的耐力。
# =====
# Question: 你能给我一些有关炮弹装饰物的其他信息吗？
# Answer: 当你装备了炮弹装饰物之后，你的空军角色的伤害减免效果将会增加。此外，你也可以通过装备其他的装饰物来提高你的游戏体验。
# =====
# Question: 我如何获得定时器的1级效果？
# Answer: 只要佩戴“定时器”装饰物，即可立即获得1级效果，空军攻击将增加2%，每升1级还可以增加0.5%的效果。
# =====
# Question: 我可以同时佩戴多个定时器吗？
# Answer: 不可以，您只能佩戴一个“定时器”装饰物。每一个装饰物只能佩戴一次，多余的装饰物将被浪费掉。
# =====
# Question: 请问假日垂钓可以增加采集速度吗？如果可以，请问是按照什么比例增加的？
# Answer: 可以的，假日垂钓是一个装饰物，可以增加采集速度，1级效果2%，每升1级增加2%。
# =====
# Question: 请问最多可以佩戴几个假日垂钓？
# Answer: 最多可以佩戴一个假日垂钓。
# =====
# Question: 我应该在哪里找到假日小舟装饰物？
# Answer: 使用假日小舟装饰物会对我的游戏有什么影响？
# =====
# Question: 滑梯会对体力有什么影响？
# Answer: 滑梯是一种常见的装饰物，可以对体力上限产生影响。一级效果为增加6点体力，每升一级可以增加4点体力。上限为1，即最多只能有一个滑梯生效。
# =====
# ...
# =====
# Question: 我在玩黑金百夫长的时候，下午为什么只有3个队伍了？
# Answer: 领队的权利会随着时间的流逝而消失，或者你可能因为月卡到期、额外队列时间到期、首领队列权限消失等情况导致当前仅剩3个队伍。建议你可以检查一下自己的游戏设置，或者重启游戏以确认当前的情况。
# =====
# Question: 我发现中午的战争之源血量经常跟不上服务器玩家实力发展的速度，是否会有调整呢？
# Answer: 目前新区的战争之源可能存在
# =====
# Question: 周日中午的世界BOSS延迟5分钟出现，这个情况是否会影响到我的游戏体验？
# Answer: 这是一个临时的措施，我们希望为玩家提供更好的游戏体验，因此在周日中午的世界BOSS出现时会延迟5分钟，这不会对你的游戏体验造成太大的影响。
# =====
# Question: 我已经有一整套装饰物了，为什么还要在背包中使用？
# Answer: 此时，您需要将整套装饰物放置到基地内，才能使装饰物生效并获得套装属性加成。
# =====
# Question: 我在哪里可以找到对应的套装装饰物？
# Answer: 您可以在神奇宝箱的装饰物组合中找到对应的套装装饰物，并领取套装收集奖励！
# =====
# Question: 我怎样可以领取套装装饰物并提升它们到二级？
# Answer: 你可以在神奇宝箱的装饰物组合中找到对应的套装装饰物，然后领取套装并完成进阶收集任务来提升它们到二级。
# =====
# Question: 我需要将所有装饰物都升级到二级才能使套装生效吗？
# Answer: 不一定，只需将其中一级或二级的装饰物升到二级即可使套装生效。
# =====
# Question: 我的套装装饰物不在神奇宝箱中，我该怎么办？
# Answer: 如果你的套装装饰物不在神奇宝箱中，那么你可能需要去探索其他游戏模式或任务来获取它们。你也可以尝试在商店或其他交易平台上购买它们。
# =====
# Question: 我的队伍如何才能在游戏中获得更多的资源?
# Answer: 首先，可以通过完成任务和成就来获得经验和金币，从而在商店中购买更多的资源。此外，还可以参加游戏中的活动和比赛，获得更多的奖励。最简单的方法就是多参加游戏，并与他人合作一起完成任务和挑战。
# =====
# Question: 如何在游戏中建立一个强大的联盟?
# Answer: 建立一个强大的联盟需要一些规划和合作。首先，成员需要有明确的目标和分工，并定期讨论游戏策略和行动计划。其次，每个成员都需要积极参与游戏，提供有价值的贡献。最后，联盟成员之间应该建立良好的沟通和信任，以便更好地合作完成任务。
# =====
# Question: 请问到达70级之后，有没有快速出兵的权益？
# Answer: 那这个权益有什么限制吗？
# =====
# Question: 非新兵能否将自己的士兵放入背包中？
# Answer: 可以。玩家可以通过将士兵合成新等级士兵系统赠送的士兵、自选兵种宝箱开出的兵以及首领每日发放的战区礼物放入士兵背包中。
# =====
# Question: 除了自选兵种宝箱、成新等级士兵系统赠送的士兵和首领每日发放的战区礼物外，还有其他哪些兵种可以放入士兵背包中？
# Answer: 不是所有兵种都能够放入士兵背包中。比如，某些兵种可能由于体力或者其他原因而无法放入士兵背包中。因此，玩家在将士兵放入背包中之前需要确认该士兵是否符合条件。
# =====
# Question: 为什么无法退级我的科技？
# Answer: 已经升级的科技无法退级，但请注意高等级士兵会比低等级士兵更加强大。
# =====
# Question: 我如何让我的士兵降级？
# Answer: 只有完全损毁状态下的士兵才会被重新降级。
# =====
# Question: 我可以用那个雪松装饰我的游戏基地吗？
# Answer: 可以的! 目前，雪松可以用来装饰你的基地，让基地看起来更加壮观，也可以在每年圣诞节的篝火活动中用于捐赠燃烧获得道具用于兑换其他游戏道具。所以，使用那个雪松来装饰基地是非常有帮助的。
# =====
# Question: 我找不到通关线索，有什么可以帮助我吗？
# Answer: 当你探索地图时，可能会发现一些密码锁。这些密码锁可以通过不同的方法解谜，例如解字谜、拼图等。你也可以在游戏的论坛或社区上查看其他玩家的通关经验，希望能对你有所帮助。
# =====
# Question: 我的游戏出现了卡顿和崩溃，怎么办？
# Answer: 如果遇到游戏卡顿和崩溃的问题，首先要确认你的设备是否满足游戏的最低配置要求。另外，尝试清理缓存和数据，关闭其他正在运行的应用。如果问题仍然存在，可以尝试重新安装游戏或联系游戏官方技术支持获取帮助。
# =====
# Question: 我需要多少个十级高速开火才能合成出一个高11的高速开火？
# Answer: 按照游戏中的合成规则，你需要19683个1级高速开火才能合成出一个高11的高速开火。
# =====
# Question: 高11的高速开火在游戏中是否有？
# Answer: 不是的，游戏中目前最高的高速开火等级是十级，而没有高11的高速开火。
# =====
# Question: 为什么兰凯斯特英雄无法免费修理所有兵种的雷神兵？
# Answer: 因为兰凯斯特英雄的5专属技能只能免费修理空军雷神兵，对其他兵种不生效。
# =====
# Question: 我购买了兰凯斯特英雄的全部技能，为什么仍然不能免费修理其他兵种的雷神兵？
# Answer: 请检查您是否购买了相应的配件或道具，以确保技能的正常生效。如果仍然无法解决问题，可以根据游戏内的帮助文档或联系客服寻求进一步的协助。
# =====
# Question: 我在兰凯斯特英雄游戏里购买了一台超雷神空军，但是它损坏了很多次。是否可以免费修理它？
# Answer: 可以修理新雷神空军，但免费修理次数与普通雷神同享。
# =====
# Question: 我的游戏账户不见了，该怎么办？
# Answer: 您可以首先尝试重新登录，或者联系客服查询您的账户状态。如果您还是无法找到账户，请提供您的识别码给我们，我们会帮助您找回账户。
# =====
# Question: 如果我把游戏账号密码借给朋友玩，会发生什么？
# Answer: 如果你把游戏账号密码借给朋友玩，那么你的朋友可能会利用这个账号登录游戏并进行交易或者修改你的关键设置。建议不要将密码借给他人。
# =====
# Question: 打攻战锤的普通集结和超级集结有什么不同?
# Answer: 普通集结消耗10体力能集结5个盟友，而超级集结消耗20体力能集结10个盟友。
# =====
# Question: 在游戏中，哪个集结更加有利？
# Answer: 这取决于您的游戏策略和需求。如果您更注重控制盟友的数量和消耗的体力，那么普通集结可能更适合您；如果您需要更大的盟友数量和更多的控制力，那么超级集结可能更适合您。最终的选择应该根据您的具体情况和游戏计划来决定。
# =====
# Question: 采集6级田和采集机械大师设施田有什么优缺点？做完后有什么成就感？
# Answer: 采集设施可以为玩家带来采集速度的提升，并且随机掉落职业道具箱子，这使得玩家能够更快地收集粮食，提高游戏进程。但是，采集设施的时间有限，对于时间不充裕的玩家来说可能不太方便，并且无法获取强化石头。但是在成功采集完设施之后，会给玩家带来强烈的成就感和满足感，让人体验到游戏中种植的收获和趣味。
# =====
# Question: 怎样查看我的原账号？
# Answer: 需要您点击头像——设置——角色管理，查看原（旧）账号。
# =====
# Question: 我需要
# Answer: 您需要点击回复进度，即可查看您在本次游戏中的进展。
# =====
# Question: 我的游戏账号被系统封锁了，怎么解决？
# Answer: 如果您的账号被系统封锁，可能是由于您进行了不当的操作，或者是没有遵守游戏规定。建议您仔细阅读游戏规则，并尽量避免不当操作，如果账号还是被封锁，请联系游戏官方客服，他们会帮助您解决
# =====
# Question: 我朋友想登录我的游戏账号，可以吗？
# Answer: 我们禁止账号共享，因为这可能会导致账号安全
# =====
# Question: 我在游戏里不知道怎么升级我的角色？
# Answer: 升级角色需要完成任务、击败敌人和获得经验等多种方式，可以在游戏中查看指导手册和任务提示来了解具体操作。
# =====
# Question: 我在游戏中找不到我想要的游戏模式？
# Answer: 你可以通过游戏设置中的筛选功能来查找不同类型的游戏模式，也可以查看游戏内的推荐和热门模式列表来获取建议。
# =====
# Question: 我的游戏角色为什么无法击败当前副本 Boss？
# Answer: 你需要收集更多的装备和升级你的技能来提高你的战斗力。此外，熟悉副本 Boss 的攻击模式并制定合理的战术策略也是击败它的关键。
# =====
# Question: 我可以在哪一级开启第二个车库、船坞、机场？
# Answer: 我需要完成什么任务才能解锁通用天赋？
# =====
# Question: 随着研究通用天赋，战斗轮
# Answer: 在什么情况下，战斗轮
# =====
# Question: 如何使用增加战斗轮
# Answer: 增加战斗轮
# =====
# Question: 为什么升级没有恢复满体力？
# Answer: 升级20级以前恢复30体力，20-30级恢复50体力，30级以后恢复75体力。每升级10级恢复量增加25体力。Upgrade获得的体力可以超过体力上限。
# =====
# Question: 我怎么能够在游戏中获得更多的金矿奖励？
# Answer: 你可以通过完成游戏任务，击败敌人，击败领主等方式来获得额外的金矿奖励。你也可以通过购买游戏内的物品或使用游戏中提供的奖励来获取金矿。
# =====
# Question: 我需要升级到金矿的哪个等级可以获得更多的金币奖励？
# Answer: 金矿的等级越高，您获得的金币奖励也就越多。具体的奖励金额和升级条件可以在游戏内的帮助文档中找到。
# =====
# Question: 我需要达到金矿的什么条件才能解锁下一个等级？
# Answer: 通常情况下，您需要完成一定的游戏任务、积累一定的金币数量或者购买相关的道具才能解锁下一个等级。详情可以在游戏内的帮助文档中找到。
# =====
# Question: 升级金矿能给我带来什么样的收益？
# Answer: 升级金矿可以让你更快地收取到更多的金币。
# =====
# Question: 基地的城防值如何增加？
# Answer: 如何避免连续三次防守失败导致基地被打飞？
# =====
# Question: 我在游戏中总是遇到困难，无法继续游戏，该怎么办？
# Answer: 遇到游戏中的困难是非常正常的，但可以通过以下方法来解决：
# =====
# Question: 我在游戏中买到一个装饰物，但等级只有1级，那么它对我造成的加成效果和等级更高的装饰物是一样的吗？
# Answer: 不是的，装饰物生效数量最多1则是指同类型不同等级的装饰物加成属性只取最高等级的生效，所以即使您的装饰物等级只有1级，其加成效果也将取等级为3级的装饰物的属性值。
# =====
# Question: 装饰物在背包中的特殊类目下如何找到并使用？
# Answer: 在背包中找到特殊类目，然后点击使用按钮，就可以找到并使用装饰物了。
# =====
# Question: 如何在装饰主题公园里放置装饰物？
# Answer: 首先，在装饰主题公园内找到放置装饰物的按钮，然后将装饰物拖放到相应的区域即可。
# =====
# Question: 如何集齐一整套套装装饰物？
# Answer: 集齐一整套套装装饰物的情况下，在背包特殊类目下依次找到套装装饰物并点击使用，整套装饰物进入到建筑类目下后无需摆放即可生效。
# =====
# Question: 套装装饰物有哪些特殊效果？
# Answer: 套装装饰物进入建筑类目下后无需摆放即可生效，可以为建筑增加特殊效果，例如改变建筑颜色、增加建筑特效等。
# =====
# Question: 我如何才能获得官职？
# Answer: 官职可以通过战区首领颁发，您可以尝试与战区首领进行交流，以获得更多的帮助和建议。一旦获得官职，您将可以享受到相关属性的加成，让您的游戏体验更加顺畅和愉快。
# =====
# Question: 官职有什么用？
# Answer: 官职可以帮助您提高游戏体验和战能力，例如增加士兵数量、提高士兵属性等。如果您在游戏中想要取得更大的成就，那么获得官职将是一个非常好的选择。
# =====
# Question: 如何获得跨战区天梯赛的战绩卡?
# Answer: 参加跨战区天梯赛就能获得战绩卡。
# =====
# Question: 跨战区天梯赛需要准备什么才能参加?
# Answer: 需要准备一个游戏账号，并确保账号下拥有足够的游戏资源，如游戏时间、角色等级和其他必要的道具等。另外需要确保您的账号在过去一段时间内没有被封禁或禁言。
# =====
# Question: 雷达等级为什么不能升级？
# Answer: 目前的雷达等级上限为5级，无法继续升级。
# =====
# Question: 雷达等级有没有可能在未来得到提升？
# Answer: 目前没有相关计划或公告。
# =====
# Question: 我可以在哪里找到更多的皮肤碎片？
# Answer: 你可以通过参加游戏活动、完成任务、击败对手等多种方式来获得皮肤碎片。你也可以在商店中购买皮肤碎片包，不过这需要您花费一定的钻石才能购买。此外，你还可以与朋友交换皮肤碎片，以获得更多的皮肤碎片。
# =====
# Question: 联盟保卫战中，哪些行为会破盾？
# Answer: 在联盟保卫战中，如果机械大师建造强化塔、削弱塔的行为会破盾。
# =====
# Question: 我想知道如何快速提升联盟等级。
# Answer: 提升联盟等级需要积极参与联盟的活动，如任务、副本等，同时也可以完成联盟商店的购买和兑换，以及与其他玩家交流和分享经验等方式来提高联盟等级。
# =====
# Question: 我在游戏中可以获得联盟帮助吗？
# Answer: 当然可以。联盟帮助有助于您更快地完成游戏任务和挑战，也可以帮助您在游戏过程中更好地互相支持和协作。通过与盟友合作，您可以共同完成更具挑战性和奖励的任务。
# =====
# Question: 我可以通过联盟帮助来获取物品吗？
# Answer: 当然可以！通过联盟帮助，您可以获取到自己需要的物品，而无需消耗自己的物品。此外，您还可以通过帮助盟友来获取一些特殊的奖励和物品。
# =====
# Question: 游戏中体力为什么没有恢复满？
# Answer: 体力恢复是根据玩家的不同等级而定的，20级以前恢复30体力，20-30级恢复50体力，30级以后恢复75体力。建议玩家在升级过程中多进行体力恢复的操作或在游戏过程中多注意体力的使用。
# =====
# Question: 我在游戏中一共获得了多少个遗迹等级？
# Answer: 我需要怎么样的条件才能获得更高等级的遗迹？
# =====
# Question: 我在用粘液技能时，对方竟然还能路过去迁城，这是怎么
# Answer: 可能是因为您释放粘液技能时，需要几秒钟的时间来运送到对方位置并生效。在这期间，对方可能已经完成了迁城的操作。建议您提前计算好时间，或者提高自己的移动速度，以便能快速到达对方位置并阻止他们迁城。
# =====
# Question: 王者威仪在什么情况下可以使用？
# Answer: 王者威仪可以在目标无法迁城的情况下使用。
# =====
# Question: 王者威仪的冷却时间是多少？
# Answer: 王者威仪的冷却时间是30分钟。
# =====
# Question: 我在游戏中连续获胜为什么我的奖励没有增加？
# Answer: 连续获胜会获得一定的奖励，但并不是每次获胜都会增加奖励。可能需要更多的连续获胜才能获得更多的奖励。
# =====
# Question: 我在游戏中道具使用次数达到上限为什么我的道具没有自动恢复？
# Answer: 当你道具使用次数达到上限时，系统并不会自动恢复。你需要等待一段时间或者使用道具恢复功能来恢复道具。
# =====
# Question: 您好，我想知道游戏中有哪些累充活动可以获取奖励？
# Answer: 游戏内有很多累充活动，例如一次性充值相应金额可以获得游戏内的道具、经验、金币等丰富奖励。除此之外，游戏还会不定时推出各种优惠政策，如充值折扣、 könnte优惠劵等，玩家可以根据自身的需要选择不同的活动进行充值。
# =====
# Question: 我的士兵状态为什么没有出现在部队详情中？
# Answer: 点击头像，城市下详情，部队详情即可查看到士兵状态，请仔细检查兵工厂，飞机场，船坞，修理厂，地块的士兵。
# =====
# Question: 我为什么无法进入无双峡谷？
# Answer: 请检查您的士兵状态是否全部正常，如士兵数量不足或者有受伤的士兵，请前往兵工厂或相关设施进行补充或治疗，以便能够参加战斗。
# =====
# Question: 我的角色已经满了，为什么还提示需要更多角色呢？
# Answer: 请检查您的角色是否全部出战并装备好了；或者尝试添加新的角色到队伍中。
# =====
# Question: 如何获得积分？
# Answer: 游戏内充值可以获得积分，每充值6元可获得6积分。
# =====
# Question: 如何使用积分提升军级？
# Answer: 使用积分可以提升军级，具体方法是通过累积积分来兑换军阶提升所需的道具，例如：升级贡献、科举令、军纪令等。
# =====
# Question: 我在游戏中的金币为什么被盗了？
# Answer: 请您检查您的游戏账号安全设置，以防止未经授权的访问。另外，请注意不要泄露您的账号信息和密码。如果您仍然怀疑存在被盗号的情况，请联系游戏客服以获得更多帮助。
# =====
# Question: 什么是限时兑换？
# Answer: 限时兑换是一个活动，该活动一个月开展一次，活动期间击败黑暗军团、战锤4k和完成雷达任务获得限时兑换券，使用兑换券在限时兑换活动中兑换超值奖励。
# =====
# Question: 活动结束后是否还有兑换奖励的机会？
# Answer: 活动结束后额外设一天领奖时间，领奖时间可以继续兑换奖励，但不再获得限时兑换券，未使用的限时兑换券将无法使用，请您及时兑换心仪物品。
# =====
# Question: 可以使用哪些物品来兑换奖励？
# Answer: 在限时兑换活动中可以兑换各种超值物品，例如皮肤、武器、道具等等。具体兑换物品以活动期间的公告为准。
# =====
# Question: 是否考虑在未来添加英雄分解和重置功能？
# Answer: 当前游戏内没有英雄分解和重置功能，这是出于游戏平衡和用户体验的考虑。我们会持续关注玩家的意见和建议，并在适当的时候考虑添加新的功能。
# =====
# Question: 那么在口袋奇兵中，礼品码有什么用呢？
# Answer: 礼品码是口袋奇兵里的一种礼包码，一组字母和数字组成的CD-KEY，游戏内点击头像——设置——礼品码，输入礼品码后可以兑换到奖励。
# =====
# Question: 我的礼品码为什么不能使用了？
# Answer: 您的礼品码每个角色只能使用1次，若提示“礼品码已使用”说明对应角色已经领取过这个礼品码的奖励。
# =====
# Question: 我需要怎么领取新的礼品码？
# Answer: 您可以通过参加官方活动、邀请好友等方式获得新的礼品码，具体的领取方式可以参考我们的官方指南。
# =====
# Question: 我的礼品码为什么失效了？
# Answer: 很抱歉，可能是因为您的礼品码超过了领取时限或者礼品码已被用完，建议您重新关注活动以获取最新的礼品码或者联系客服咨询详情。
# =====
# Question: 我的礼品码还有多久过期？
# Answer: 抱歉，我无法提供具体的过期时间，但一般情况下，礼品码会在活动期间有效，请及时使用以避免失效。
# =====
# Question: 游戏中的道具怎么获得？
# Answer: 游戏中的道具可以通过购买、完成任务、充值等方式获得。每个道具的获得方式可能会有所不同，需要根据具体游戏的规则来获得。建议多多留意官方网站和游戏内的公告，以便更好地了解道具的获得方式。
# =====
# Question: 实战中如何选择合适的强化部件？
# Answer: 在实战中，选择合适的强化部件需要根据自身的游戏风格和战斗需求来决定。如果更注重火力输出，可以选择高速开火和武器强化；如果看重生存能力，可以选择装甲强化和伤害减免。当然，可以根据自己的喜好和实际情况，选择适合自己的强化部件组合。问题2: 实战中为什么推荐使用高速开火、武器强化、装甲强化、伤害加深和伤害减免这几个强化部件？
# =====
# Question: 在《某一游戏》中，如何提高角色的生存能力？
# Answer: 针对角色的玩法和敌人的攻击方式，可以加强抗性的属性，例如体质、魔法防御等，同时也可以装备一些具有np技能的装备或防具来增加生存能力。此外，合理利用药品和陷阱也是提高生存能力的方法之一。
# =====
# Question: 在《某一游戏》中，如何获得更多的金币？
# Answer: 通过完成游戏中的任务、击败敌人、参加活动等方法可以获得金币。同时，也可以通过挖掘宝箱、打败精英敌人等方式获得丰富的金币。在进行游戏时，可以注意节约资源，尽量减少消耗，这样也可以帮助积累更多的金币。
# =====
# Question: 有没有什么方法可以在个人保卫战期间前往曙光之地、永恒之地？
# Answer: 我不建议在个人保卫战期间前往曙光之地和永恒之地，因为这可能会导致你无法成功完成个人保卫战的任务。建议等到个人保卫战结束后再考虑前往这些地方。
# =====
# Question: 如果我必须在个人保卫战期间前往曙光之地或永恒之地，会有哪些风险？
# Answer: 如果你在个人保卫战期间前往曙光之地或永恒之地，你可能会面临以下风险：
# =====
# Question: 联盟保卫战有什么推荐的强化部件吗？
# Answer: 我建议您尽量使用：高速开火、武器强化、装甲强化、伤害加深和伤害减免这五种强化部件。
# =====
# Question: 使用这五种强化部件的效果怎么样？
# Answer: 这五种强化部件可以大大提高您的战局胜率，使您的攻击速度更快，对敌人造成的伤害更高，同时您的防御能力也会相应提高。
# =====
# Question: 我刚玩这个游戏，还不太了解强化部件的作用，可以给我介绍一下吗？
# Answer: 当然可以！强化部件可以提高角色的属性，不同的部件有不同的效果。比如，高速开火可以让角色更快地开火，武器强化可以提高武器的攻击力，装甲强化可以提高角色的防御力，伤害加深可以让角色造成的伤害更高，伤害减免可以减少角色受到的伤害。你可以根据自己的需求选择适合自己的强化部件来提高自己的战斗力。
# =====
# Question: 我的游戏账号被别人绑定了，我该怎么办？
# Answer: 很抱歉，游戏账号无法更换绑定。请您一定要保护好自己的账号安全，不要轻易将自己的账号分享给他人。如果您的账号被恶意绑定，请及时联系游戏官方客服寻求帮助。
# =====
# Question: 我在游戏中的账号被冻结了，怎么才能重新激活账号？
# Answer: 需要联系游戏客服解决，提供相应的证明材料以确认身份并解决问题。
# =====
# Question: 游戏中的装备被盗了，怎么办？
# Answer: 可以联系游戏客服进行报案，同时注意加强账号安全，避免再次被盗。
# =====
# Question: 我最近在游戏中获得了一个道具，请问这个道具能否在我的账户中通用？
# Answer: 您可以检查一下该道具的适用范围，通常会在道具说明中明确是否适用于您的账户和游戏。如果您不确定，请联系游戏官方客服，他们可以帮助您解决这个问题。
# =====
# Question: 我忘记了我的游戏账号，请问是否可以重设密码？
# Answer: 没问题，您可以登录游戏的找回密码页面，根据提示填写您的相关信息进行密码重设。
# =====
# Question: 我登录游戏的时候忘记密码了怎么办？
# Answer: 可以通过找回密码功能进行密码重置，或者联系游戏客服进行密码重置。
# =====
# Question: 战争之源在每周日的12点延时5分钟刷新，那么延时结束后的12点15分再进入游戏时，战争之源是否可以刷新了呢？
# Answer: 是的，在每周日的12点延时结束后的12点15分再进入游戏时，战争之源可以刷新了。
# =====
# Question: 跨战区战战斗阶段会不会影响到战争之源的刷新呢？
# Answer: 跨战区战战斗阶段不会影响到战争之源的刷新，战争之源的刷新时间是每周日的12点，具体时间也不会因为跨战区战战斗阶段而发生变化。
# =====
# Question: 如果周围有强化塔，战争之源的伤害会增加吗？
# Answer: 的确，强化塔的加成对战争之源有效果，周围的强化塔数量越多，战争之源的伤害就越高。
# =====
# Question: 弱化塔可以减少战争之源的伤害吗？
# Answer: 不可以，弱化塔是没有效果的。它只会清除战争之源的增益效果，但无法直接减少伤害。
# =====
# Question: 我为什么无法在游戏商店购买游戏中的道具？
# Answer: 您可能尚未达到游戏中的购买等级或者已经消耗完了您的游戏余额。
# =====
# Question: 我在游戏中遇到了卡顿和掉帧的情况，怎么解决？
# Answer: 您可以尝试清理缓存、关闭不必要的后台程序、降低画质等方法来改善游戏性能。如果问题仍未解决，您可以联系游戏官方客服寻求帮助。
# =====
# Question: 雷神元素可以在哪些建筑里制造出雷神兵？
# Answer: 雷神元素可以在超级武器实验室建筑里制造出各个军种的雷神兵。
# =====
# Question: 独一无二的雷神兵可以为士兵带来什么好处？
# Answer: 独一无二的雷神兵可以提升士兵的实力，包括攻击力、移动速度和生命值等。
# =====
# Question: 我在游戏中购买了一个皮肤，但是无法使用，该怎么办?
# Answer: 需要检查一下游戏设置中是否正确装备了这个皮肤。通常可以在设置中找到皮肤相关的选项，检查是否已经装备并确认适合自己使用的角色。如果仍然无法使用，可以向游戏官方客服反馈问题，寻求帮助。
# =====
# Question: 雷神兵被攻击后降级的具体计算公式是什么？
# Answer: 雷神兵被攻击后降级的计算公式取决于您制造该雷神兵时使用的士兵等级，以及您当前拥有的士兵等级。具体来说，您制造该雷神兵时使用的是多少等级的士兵，降级后就恢复到制造时使用的那个等级士兵。
# =====
# Question: 雷神兵被攻击后降级会影响其他属性吗？
# Answer: 雷神兵被攻击后降级只会影响其等级属性，并不会对其他属性产生影响。因此，即使您的雷神兵被攻击降级了，它的攻击、防御、生命值等其他属性将保持不变。
# =====
# Question: 我最近参加了一次幸运宝库抽奖，但是为什么使用的钻石数量和累计积分不对？请问我应该如何解决这个问题？
# Answer: 非常抱歉，可能是由于网络延迟或者系统错误导致的，请您稍等片刻后重新登录游戏并尝试抽奖。如果问题仍然存在，请您联系我们的客服团队，我们会尽快给予您相应的帮助。
# =====
# Question: 我的幸运宝库为什么没有显示在其他服务器的排行榜上？
# Answer: 幸运宝库的排行榜活动分为两个组，一个是1~1000战区，另一个是1001及以上战区。请确认你所在的战区是否在本次活动范围内。
# =====
# Question: 我如何才能进入活动范围内的1001及以上战区？
# Answer: 你可以通过在游戏中进行领土扩张、参与活动等方式来提升自己的战区排名，达到1001及以上战区的门槛。同时，也可以通过和其他玩家进行交流，获取更多的信息和技巧。
# =====
# Question: 幸运宝库奖池初始钻石有多少?
# Answer: 活动开始时钻石宝库内拥有2000钻石。
# =====
# Question: 如何增加计算的?
# Answer: 本战区所有指挥官抽奖一次性,奖池内将会增加3钻石,钻石奖池内的钻石为本战区共有,其他指挥官抽奖,您的奖池中同样增加3钻石。
# =====
# Question: 我在幸运宝库抽奖中获得了错误的奖品，可以帮我退
# Answer: 不好意思，随机性的行为不能申请误操作，建议您联系游戏内的客服进行确认和解决。如果您不确定如何联系客服，可以在游戏中使用菜单或帮助中心查找相关信息。
# =====
# Question: 发放时间是多久以后？
# Answer: 活动结束后，排行榜奖励会通过系统邮件自动发放。具体的时间可能会因网络状况而有所不同，但通常会在活动结束后的几天内发放完毕。
# =====
# Question: 请问夏日精选活动的购买次数是在每天固定的时间重置吗？或者是一直保持不变？
# Answer: 活动期间购买次数每日重置，也就是说，每天都会进行新的累计。
# =====
# Question: 如果我在某天错过了夏日精选的重置时间，那么我的购买次数是否会重置？
# Answer: 如果您错过了夏日精选活动当日的购买次数重置时间，那么购买次数不会自动重置，您需要等待下一天的重置时间。
# =====
# Question: 在荒野行动中，我可以在多少小时内达到挂机奖励上限？
# Answer: 活动累计奖励时间为12个小时，超过该时间后将不再获得奖励。
# =====
# Question: 我想知道在荒野行动中，如果首次领取了累计奖励，最多可以获几张门禁卡呢？
# Answer: 每日首次领取荒野行动累计奖励可以随机获得两张门禁卡。
# =====
# Question: 如何才能提升荒野行动的射击精准度？
# Answer: 提升荒野行动射击精准度的方法有很多，但主要可以分为以下几类：1. 练习目标射击，可以在训练模式中找到对应的靶子进行练习；2. 熟练掌握游戏中的瞄准技巧，例如三点一线、预瞄准等等；3. 保持稳定的手部动作，以减少射击时的抖动；4. 选择适合自己的武器，不同类型的武器具有不同的射击精度，需要根据自己的游戏习惯进行选择。
# =====
# Question: 荒野行动中有哪些可以提高生存能力的技巧？
# Answer: 荒野行动中提高生存能力的技巧有很多，例如：1. 保持警惕，多观察周围环境，及时发现危险；2. 打算好战斗策略，根据自己的实力和敌人的情况制定战斗计划；3. 合理分配体力和耐力，保证自己可以长时间坚持战斗；4. 分别利用环境中的掩体和地形进行躲避和攻击；5. 不要轻易放弃，即使战败也不要放弃游戏，可以通过多次尝试来提高自己的生存能力。
# =====
# Question: 问
# Answer: 问
# =====
# Question: 购买铂金指挥官月卡后为什么我的金币购买次数没有增加？
# Answer: 即使您购买了铂金指挥官月卡，每天在商城中购买金币的次数也只是增加10次，而不是增加金币收割机免费收割的次数。如果您仍然无法增加金币购买次数，请检查一下游戏设置中的相关选项是否正确配置。
# =====
# Question: 为什么购买月卡后我每天在商城中购买金币的次数只增加了10次呢？
# Answer: 购买月卡后增加每日商城购买金币次数+10，尽管游戏设置中表明购买月卡可以增加每天在商城中购买金币的次数，但请注意这个数字实际上是“+10”，而不是“100%”。此外，请确保您的游戏客户端已更新到最新版本，并且没有其他配置问题导致您无法享受月卡的优惠。
# =====
# Question: 我在某个游戏中忘记领取了月卡奖励，怎么办？
# Answer: 可以申请误操作进行补发道具，但是无法补发体力。具体请联系游戏内客服进行咨询。
# =====
# Question: 我在某个游戏中忘记领取了月卡奖励，可以补发体力吗？
# Answer: 不可以，因为忘记领取已经超过了补发的时间窗口。需要等待下个月的月卡奖励发放。
# =====
# Question: 我购买了黑金百夫长卡为什么在游戏中我没有收到任何奖励或者道具？
# Answer: 请检查您的游戏内邮箱，可能奖励已经发放到您的邮箱中。如果没有，请联系官方客服进行解决。
# =====
# Question: 我在游戏中购买了黑金百夫长卡为什么我的头像框没有在我的头像设置中显示？
# Answer: 需要在背包-特殊内点击使用该头像框，再点击头像-头像-头像框进行更换。可能是因为您的游戏版本过低或者连接不稳定导致的。建议您检查一下游戏版本和网络连接，或者重启游戏重新尝试。如果问题仍然存在，可以联系官方客服进行解决。
# =====
# Question: 我需要怎么让我的英雄获得更多的经验和金币？
# Answer: 你可以参加游戏中的比赛，通过赢得比赛可以获得经验和金币，也可以通过完成游戏中的任务和挑战来获得经验和金币。
# =====
# Question: 我在游戏中遇到了一些困难，能有人帮我吗？
# Answer: 当然可以！可以加入游戏中的公会或者好友名单，与其他玩家一起组队游戏，或者在游戏论坛上寻求帮助。
# =====
# Question: 为什么我购买的周卡无法领取钻石？
# Answer: 请您检查一下您是否已经开卡，如果已经开卡，那恭喜您！您已经获得了首次奖励，奖励将会自动发放到您的游戏中，请您耐心等待一下。如果还没有开卡，那可能是系统暂时故障，请您稍后再试。
# =====
# Question: 我的激活码在哪里可以查看？
# Answer: 激活码一般可以在购买游戏时提供的兑换码或者是在游戏官方网站的激活码查询页面中查看。
# =====
# Question: 我购买的游戏道具什么时候可以到账？
# Answer: 通常情况下，道具会在24小时内到账，请您耐心等待。如果超过24小时还未到账，可以联系客服进行查询和处理。
# =====
# Question: 我在购买的周卡中选择了一款道具，现在我想更换其他道具，请问可以吗?
# Answer: 当然可以！你在购买的周卡中，可以随时选择你想要领取的道具，不需要重新购买新的周卡。只要登录你的账号，进入游戏后点击周卡领取按钮，选择你想要领取的道具即可。
# =====
# Question: 特惠礼包中的奖励有哪些？
# Answer: 特惠礼包中可能包含游戏中的各种稀有道具和资源，具体奖励取决于您购买的特惠礼包种类和进度值的多少。
# =====
# Question: 特惠礼包会有不同的等级吗？
# Answer: 是的，特惠礼包有不同的等级，等级越高的特惠礼包包含的奖励越丰富。您可以花费一定的金币或元宝来升级特惠礼包的等级，以获得更多的奖励。
# =====
# Question: 请问你们的游戏会定期更新新的特惠礼包吗？
# Answer: 是的，我们的游戏会周期性更新新的特惠礼包，以提供给我们的玩家更多的游戏体验和奖励选择。
# =====
# Question: 那么这些特惠礼包的奖励内容是固定的吗？
# Answer: 不是，特惠礼包的奖励内容会周期性更新，以保持游戏的可玩性和吸引力。我们会根据游戏的进度和最新进展来更新不同的特惠礼包，让玩家可以持续获得新的游戏体验和奖励。
# =====
# Question: 购买一份特效药剂会增加多少生命力值？
# Answer: 购买特效药剂将增加10点生命力值。
# =====
# Question: 在游戏中，玩家可以通过什么方式获得经验？
# Answer: 玩家可以通过击败敌人、完成任务、参加活动、登录游戏等获得经验。
# =====
# Question: 请问捆绑包中的任务进度值是如何计算的？
# Answer: 捆绑包任务进度值是根据您完成任务的进度和数量计算得出的，每完成一个任务会增加相应的进度值。请您注意及时完成任务，以获得更高的奖励。
# =====
# Question: 特惠礼包的活动规则是什么？
# Answer: 特惠礼包的奖励内容会周期性更新吗？
# =====
# Question: 每日的免费奖励会赠送多少进度值？
# Answer: 特惠礼包的进度值有什么限制？
# =====
# Question: 游戏里有没有每日登录奖励？
# Answer: 是的，游戏中设有每日登录奖励，奖励内容根据游戏不同而不同，可以是道具、金币或者经验药品等。
# =====
# Question: 游戏中有什么样的活动？
# Answer: 游戏定期会举办各种活动，例如限时活动、节日活动、公会活动等，玩家可以通过参与活动获得各种奖励。
# =====
# Question: 我可以使用哪些装饰材料购买装饰物？
# Answer: 我可以在装饰物商店中购买什么等级的装饰物？
# =====
# Question: 可以在装饰物商店内购买各种不同的装饰物，如：家具、壁挂、灯具、地毯、花卉等。
# Answer: 装饰物商店在哪里可以找到？
# =====
# Question: 请问装饰物半价券的使用期限是多久？
# Answer: 装饰物半价券的有效期限是30天，超过期限将无法使用。
# =====
# Question: 能否与他人共享装饰物半价券？
# Answer: 不可以，装饰物半价券是一个个人道具，只能由持有者使用。
# =====
# Question: 什么是专属技能万能碎片？
# Answer: 专属技能万能碎片是一种可以在专属技能商店中兑换心仪专属技能的道具。它可以让你节省购买技能的费用，并且可以让你更轻松地获取到你想要的技能。
# =====
# Question: 我在游戏中的账号安全如何保障？
# Answer: 游戏账号的安全非常重要，建议您定期修改密码、不要在公共网络上登录游戏、不要轻易分享账号信息，并安装防病毒软件。
# =====
# Question: 职业天赋重置券能重置哪些职业的天赋进度？
# Answer: 职业天赋重置券能重置所有已完成职业天赋的研究进度，包括游戏内各种职业的天赋。
# =====
# Question: 职业天赋重置券需要多少钱可以购买？
# Answer: 职业天赋重置券在游戏中需要花费5000钻石才能购买。
# =====
# Question: 职业转换券是如何获得的呢?
# Answer: 职业转换券可以在道具商店中购买，售价为10000钻石。此外，有些游戏内活动也可能会提供职业转换券的奖励。
# =====
# Question: 职业转换券可以用来替换成任意职业吗?
# Answer: 不完全正确。职业转换券只能用来替换到与当前职业不同的职业。因此，如果你想要转换成与当前职业相同的另一个职业，可能需要花费其他方式来实现，比如重新创建一个新角色获得所需职业的初始技能和属性。
